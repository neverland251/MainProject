# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
    
import keras
from keras import models
from keras.models import Sequential
from keras.models import Model
from keras.models import load_model
from keras import backend as K
from keras import layers
from keras.layers import Layer
from keras.layers import Input,Dense,Flatten,Embedding,Permute,Dot,Reshape
from keras.layers.convolutional import Conv1D,MaxPooling1D,MaxPooling2D
from keras.layers import Dropout
from keras.layers import LSTM,GRU
from keras.callbacks import Callback
from keras.preprocessing import sequence
from keras.utils import np_utils
 
import tensorflow as tf
from tensorflow.python.framework import function
import math
 
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score,accuracy_score

import lightgbm as lgb
 
import scipy

import statsmodels.api
import statsmodels as sm
 
import copy
import random
import time
from time import sleep

import re
import os
# Out:
# Using TensorFlow backend.

# %%
os.listdir("data")
# Out:
# ['dangjin_fcst_data.csv',
#  'dangjin_obs_data.csv',
#  'energy.csv',
#  'sample_submission.csv',
#  'site_info.csv',
#  'ulsan_fcst_data.csv',
#  'ulsan_obs_data.csv']

# %% [markdown]
# # 1. Data Load

# %%
dangjin_fcst = pd.read_csv("data/dangjin_fcst_data.csv")
dangjin_obs = pd.read_csv("data/dangjin_obs_data.csv")
energy = pd.read_csv("data/energy.csv")
site_info = pd.read_csv("data/site_info.csv")
ulsan_fcst = pd.read_csv("data/ulsan_fcst_data.csv")
ulsan_obs = pd.read_csv("data/ulsan_obs_data.csv")

# %% [markdown]
# ## 1) 데이터 준비

# %% [markdown]
# ### (1) Forecast Time 변환

# %%
dangjin_fcst["forecast"] = pd.to_datetime(dangjin_fcst["Forecast time"]) + dangjin_fcst["forecast"].apply(
    lambda x : pd.Timedelta(x, unit = "H"))

# %%
ulsan_fcst["forecast"] = pd.to_datetime(ulsan_fcst["Forecast time"]) + ulsan_fcst["forecast"].apply(
    lambda x : pd.Timedelta(x, unit = "H"))

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ## 1) 기초 통계 및 결측, 이상치 확인

# %% [markdown]
# ### (1) 결측치

# %%
print(dangjin_fcst.isna().apply(lambda x : x.value_counts()))
print(dangjin_obs.isna().apply(lambda x : x.value_counts()))
print(energy.isna().apply(lambda x : x.value_counts()))
print(site_info.isna().apply(lambda x : x.value_counts()))
print(ulsan_fcst.isna().apply(lambda x : x.value_counts()))
print(ulsan_obs.isna().apply(lambda x : x.value_counts()))
# Out:
#        Forecast time  forecast  Temperature  Humidity  WindSpeed  \
# False         162208    162208       162208    162208     162208
#
#        WindDirection   Cloud
# False         162208  162208
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# False  25626.0  25626.0  25626.0   25589    25590     25590  25591      21656
# True       NaN      NaN      NaN      37       36        36     35       3970
#           time  dangjin_floating  dangjin_warehouse  dangjin    ulsan
# False  25632.0             25608              25584  25632.0  25632.0
# True       NaN                24                 48      NaN      NaN
#        Id  Capacity  Address  InstallationAngle  IncidentAngle  Latitude  \
# False   4         4        4                  4              4         4
#
#        Longitude
# False          4
#        Forecast time  forecast  Temperature  Humidity  WindSpeed  \
# False         162208    162208       162208    162208     162208
#
#        WindDirection   Cloud
# False         162208  162208
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위
# 430  2018-03-18 23:00:00               0.0                NaN        0      0
# 431  2018-03-18 24:00:00               0.0                NaN        0      0

# %%
energy.loc[energy["dangjin_floating"].isna()]
# Out:
#                       time  dangjin_floating  dangjin_warehouse  dangjin  \
# 20352   2020-06-26 1:00:00               NaN                0.0        0
# 20353   2020-06-26 2:00:00               NaN                0.0        0
# 20354   2020-06-26 3:00:00               NaN                0.0        0
# 20355   2020-06-26 4:00:00               NaN                0.0        0
# 20356   2020-06-26 5:00:00               NaN                0.0        0
# 20357   2020-06-26 6:00:00               NaN                0.0        0
# 20358   2020-06-26 7:00:00               NaN                7.0        2
# 20359   2020-06-26 8:00:00               NaN               20.0       18
# 20360   2020-06-26 9:00:00               NaN              148.0      175
# 20361  2020-06-26 10:00:00               NaN              242.0      330
# 20362  2020-06-26 11:00:00               NaN              371.0      534
# 20363  2020-06-26 12:00:00               NaN              415.0      590
# 20364  2020-06-26 13:00:00               NaN              484.0      691
# 20365  2020-06-26 14:00:00               NaN              459.0      669
# 20366  2020-06-26 15:00:00               NaN              449.0      647
# 20367  2020-06-26 16:00:00               NaN              380.0      552
# 20368  2020-06-26 17:00:00               NaN              311.0      447
# 20369  2020-06-26 18:00:00               NaN              165.0      253
# 20370  2020-06-26 19:00:00               NaN               37.0       57
# 20371  2020-06-26 20:00:00               NaN                2.0        0
# 20372  2020-06-26 21:00:00               NaN                0.0        0
# 20373  2020-06-26 22:00:00               NaN                0.0        0
# 20374  2020-06-26 23:00:00               NaN                0.0        0
# 20375  2020-06-26 24:00:00               NaN                0.0        0
#
#        ulsan
# 20352      0
# 20353      0
# 20354      0
# 20355      0
# 20356      0
# 20357      0
# 20358      7
# 20359     50
# 20360    161
# 20361    170
# 20362    283
# 20363    318
# 20364    334
# 20365    331
# 20366    303
# 20367    248
# 20368    190
# 20369    101
# 20370     29
# 20371      1
# 20372      0
# 20373      0
# 20374      0
# 20375      0

# %% [markdown]
# Enegry 내부에선 상관성이 있는 변수가 없어보인다.
#
# 정확히 하루 단위로 데이터가 NA이므로, 삭제해도 무방할 것으로 판단됨

# %%
energy = energy.dropna().reset_index(drop = True)

# %% [markdown]
# #### - obs 결측 탐색

# %%
dangjin_obs.isna().apply(lambda x : x.value_counts())
# Out:
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# False  25626.0  25626.0  25626.0   25589    25590     25590  25591      21656
# True       NaN      NaN      NaN      37       36        36     35       3970

# %%
dangjin_fcst[dangjin_fcst["Forecast time"] == '2019-01-31 11:00:00']
# Out:
#              Forecast time            forecast  Temperature  Humidity  \
# 49728  2019-01-31 11:00:00 2019-01-31 15:00:00         -1.0      40.0
# 49729  2019-01-31 11:00:00 2019-01-31 18:00:00         -3.0      45.0
# 49730  2019-01-31 11:00:00 2019-01-31 21:00:00         -3.0      50.0
# 49731  2019-01-31 11:00:00 2019-02-01 00:00:00         -4.0      50.0
# 49732  2019-01-31 11:00:00 2019-02-01 03:00:00         -2.0      60.0
# 49733  2019-01-31 11:00:00 2019-02-01 06:00:00         -2.0      70.0
# 8072  129  서산  2019-01-31 14:00    -0.6      5.3     340.0   42.0       10.0
# 8073  129  서산  2019-01-31 15:00    -0.4      4.7     360.0   40.0        4.0
# 8074  129  서산  2019-01-31 16:00    -1.0      5.1     340.0   39.0        4.0
# 8075  129  서산  2019-01-31 17:00    -1.3      2.6     360.0   42.0        1.0
# 8076  129  서산  2019-01-31 18:00    -2.6      1.5     340.0   43.0        7.0
# 8077  129  서산  2019-01-31 19:00    -3.4      1.5     340.0   46.0        0.0
# 8078  129  서산  2019-01-31 20:00    -3.2      2.2     340.0   49.0        0.0
# 8079  129  서산  2019-01-31 21:00    -3.3      2.5     340.0   49.0        0.0
# 8080  129  서산  2019-01-31 22:00    -3.3      3.8     360.0   45.0        0.0
# 8081  129  서산  2019-01-31 23:00    -3.5      2.3     360.0   45.0        6.0

# %% [markdown]
# 기온, 풍속, 풍향, 습도 결측치는 서로 밀접한 연관이 있는 것으로 보인다.
#
# 활용이 불가능하므로 제외한다.

# %%
dangjin_obs = dangjin_obs.dropna(axis = 0, subset = ["기온(°C)","풍속(m/s)", "풍향(16방위)", "습도(%)"]).reset_index(drop = True)

# %% [markdown]
# ### - 전운량 결측 탐색

# %%
dangjin_obs["전운량(10분위)"].isna().value_counts()
# Out:
# False    21618
# True      3970
# Name: 전운량(10분위), dtype: int64

# %%
dangjin_obs["date"] = dangjin_obs["forecast"].dt.date
dangjin_obs["hour"] = dangjin_obs["date"].astype("str") + " " + dangjin_obs["forecast"].dt.hour.astype("str")

# %%
# 하루 중 전운량이 NA인 비율

k = dangjin_obs[dangjin_obs["전운량(10분위)"].isna()].groupby("date").apply(lambda x : x["전운량(10분위)"].isna() / len(x))

k.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 최초 예상으로는 전운량이 Na인 경우 하루 전체가 다 그럴것이라는 가설을 세웠지만
#
# 그 가설은 사실이 아닌것으로 판명되었다.

# %%
# 시간 중 전운량이 NA인 비율

k = dangjin_obs[dangjin_obs["전운량(10분위)"].isna()].groupby("hour").apply(lambda x : x["전운량(10분위)"].isna() / len(x))

k.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2) 파생 변수 생성 전략 탐색

# %% [markdown]
# ### (1) obs의 전운량과 fcst의 cloud간 비교

# %% [markdown]
# #### - 데이터 Merge

# %%
dangjin_obs = dangjin_obs.rename(columns = {"일시" : "forecast"})

dangjin_obs["forecast"] = pd.to_datetime(dangjin_obs["forecast"])

# %%
result = pd.merge(dangjin_obs, dangjin_fcst, on = "forecast", how = "left")

# %% [markdown]
# #### - 상관계수

# %%
result[["Cloud","전운량(10분위)"]].corr()
# Out:
#               Cloud  전운량(10분위)
# Cloud      1.000000   0.493646
# 전운량(10분위)  0.493646   1.000000

# %% [markdown]
# 상관도가 생각보다 낮다. 예측과 실제값 사이에 괴리감이 큰 것으로 보인다.

# %% [markdown]
# #### - 오차값(잔차) 확인

# %% [markdown]
# 잔차를 확인하면 이를 이용하여 예측값에서 실제 정답값을 유사하게라도 보정할 수 있지 않을까?
#
# 히스토그램을 그려 잔차가 정규분포를 따르는지 확인하고, 실제 정규성 검정을 수행해본다.

# %%
plt.hist(result["Cloud"] - result["전운량(10분위)"])
# Out:
# (array([ 6963., 12617., 26617., 33842., 10633.,  8692., 16352., 26363.,
#          7278.,  8144.]),
#  array([-9. , -7.7, -6.4, -5.1, -3.8, -2.5, -1.2,  0.1,  1.4,  2.7,  4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 쌍봉 분포를 보인다.
#
# 차이가 전혀 없는 경우(평균이 0인 정규분포)와 차이가 5~6정도 나는 경우(평균이 5인 정규분포)로 나뉘는 것으로 보인다.

# %%
scipy.stats.kstest((result["Cloud"] - result["전운량(10분위)"]).dropna(), "norm")
# Out:
# KstestResult(statistic=0.6081284021563662, pvalue=0.0)

# %% [markdown]
# 아쉽게도, 잔차는 정규분포를 따르지 않는다.

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]
# Out:
#          지점 지점명            forecast  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 78      129  서산 2018-03-02 18:00:00     1.6      1.4     360.0   53.0
# 79      129  서산 2018-03-02 18:00:00     1.6      1.4     360.0   53.0
# 80      129  서산 2018-03-02 18:00:00     1.6      1.4     360.0   53.0
# 81      129  서산 2018-03-02 18:00:00     1.6      1.4     360.0   53.0
# 82      129  서산 2018-03-02 18:00:00     1.6      1.4     360.0   53.0
# ...     ...  ..                 ...     ...      ...       ...    ...
# 174529  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174538  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174539  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174540  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174541  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
#
#         전운량(10분위)        date           hour        Forecast time  \
# 78            6.0  2018-03-02  2018-03-02 18  2018-03-01 11:00:00
# 79            6.0  2018-03-02  2018-03-02 18  2018-03-01 14:00:00
# 80            6.0  2018-03-02  2018-03-02 18  2018-03-01 17:00:00
# 81            6.0  2018-03-02  2018-03-02 18  2018-03-01 20:00:00
# 82            6.0  2018-03-02  2018-03-02 18  2018-03-01 23:00:00
# ...           ...         ...            ...                  ...
# 174529        8.0  2021-01-31  2021-01-31 18  2021-01-30 02:00:00
# 174538        8.0  2021-01-31  2021-01-31 18  2021-01-31 05:00:00
# 174539        8.0  2021-01-31  2021-01-31 18  2021-01-31 08:00:00
# 174540        8.0  2021-01-31  2021-01-31 18  2021-01-31 11:00:00
# 174541        8.0  2021-01-31  2021-01-31 18  2021-01-31 14:00:00
#
#         Temperature  Humidity  WindSpeed  WindDirection  Cloud
# 78              1.0      55.0        1.9          264.0    1.0
# 79              1.0      55.0        1.9          264.0    1.0
# 80              1.0      60.0        1.4          278.0    1.0
# 81              1.0      60.0        1.4          278.0    1.0
# 82              1.0      60.0        1.4          278.0    1.0
# ...             ...       ...        ...            ...    ...
# 174529          6.0      75.0        2.9          180.0    3.0
# 174538          6.0      75.0        3.3          168.0    3.0
# 174539          6.0      75.0        3.3          168.0    3.0
# 174540          6.0      75.0        3.3          168.0    3.0
# 174541          6.0      75.0        3.3          168.0    3.0
#
# [18722 rows x 16 columns]

# %%
result["Cloud"].hist()
# Out:
# <AxesSubplot:>

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]["Cloud"].hist()
# Out:
# <AxesSubplot:>

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]["전운량(10분위)"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 전운량의 예측은 1 ~ 4밖에 없다.
#
# 예측 오차가 크게 나는 경우는 실제 전운량이 6 이상으로 나타나는 경우였다.

# %%
dangjin_fcst.describe()
# Out:
#             forecast    Temperature       Humidity      WindSpeed  \
# count  162208.000000  162208.000000  162208.000000  162208.000000
# mean       30.675676      12.624634      76.996147       3.639262
# std        16.714755       9.816256      17.435418       2.627592
# min         4.000000     -14.000000       5.000000       0.000000
# 25%        16.000000       4.000000      65.000000       1.900000
# 50%        31.000000      13.000000      80.000000       2.800000
# 75%        43.000000      21.000000      90.000000       4.600000
# max        67.000000      36.000000     100.000000      32.299999
#
#        WindDirection          Cloud
# count  162208.000000  162208.000000
# mean      214.147761       2.439411
# std       108.020035       1.214753
# min         0.000000       1.000000
# 25%       115.000000       1.000000
# 50%       237.000000       3.000000
# 75%       313.000000       4.000000
# max       360.000000       4.000000

# %% [markdown]
# ## 2) 변수 선별

# %% [markdown]
# ### (1) 변수 선별용 데이터 전처리

# %% [markdown]
# #### - X, y 데이터 생성

# %%
temp = DataFrame(list(DataFrame(list(energy["time"].str.split(" ")))[1].str.split(":")))

# %%
energy["time"] = pd.to_datetime(
    DataFrame(list(energy["time"].str.split(" ")))[0] + 
    " " 
    + (temp[0].astype("int") - 1).astype("str") + ":" + temp[1] + ":" + temp[2])

# %%
energy_obs = pd.merge(energy, dangjin_obs, left_on = "time", right_on = "forecast", how = "left")

# %%
energy_obs = energy_obs.dropna().reset_index(drop = True)

energy_obs = energy_obs.drop(["date","hour", "지점", "지점명", "forecast"], axis = 1)

# %% [markdown]
# #### - 일출 일몰 정보 생성

# %%
def day_night(x):
    if x < 6 or x > 18:
        return 0
    else:
        return 1

# %%
energy_obs["day_night"] = energy_obs["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %% [markdown]
# ### (2) Boruta 알고리즘 활용

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor(n_jobs=-1, max_depth=5, random_state = 42)
forest.fit(energy_obs[["기온(°C)", "풍속(m/s)", "풍향(16방위)", "습도(%)", "전운량(10분위)", "day_night"]], 
           energy_obs["dangjin_warehouse"].to_numpy())
# Out:
# RandomForestRegressor(max_depth=5, n_jobs=-1, random_state=42)

# %%
from boruta import BorutaPy

feat_selector = BorutaPy(forest, 
                         n_estimators='auto',
                         verbose=2, 
                         random_state=42)

# find all relevant features
feat_selector.fit(energy_obs[["기온(°C)", "풍속(m/s)", "풍향(16방위)", "습도(%)", "전운량(10분위)", "day_night"]].to_numpy(), 
                  energy_obs["dangjin_warehouse"].to_numpy())

# check selected features
feat_selector.support_

# check ranking of features
feat_selector.ranking_

# call transform() on X to filter it down to selected features
X_filtered = feat_selector.transform(energy_obs[["기온(°C)", "풍속(m/s)", "풍향(16방위)", "습도(%)", "전운량(10분위)", "day_night"]].to_numpy())
# Out:
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	6
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	0
# Iteration: 	14 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	0
# Iteration: 	15 / 100
# Confirmed: 	5
# Tentative: 	1
# Rejected: 	0
# Iteration: 	16 / 100
# Confirmed: 	6
# Tentative: 	0
# Rejected: 	0
#
#
# BorutaPy finished running.
#
# Iteration: 	17 / 100
# Confirmed: 	6
# Tentative: 	0
# Rejected: 	0

# %% [markdown]
# 선별된 변수는 없다. 모든 변수를 다 활용할 것이다.

# %% [markdown]
# # 3. 데이터 전처리

# %% [markdown]
# ## 1) 결측값 대체

# %% [markdown]
# ### (1) fcst 보간

# %% [markdown]
# #### - spline 보간

# %%
temp = DataFrame(list(DataFrame(list(energy["time"].str.split(" ")))[1].str.split(":")))

energy["time"] = pd.to_datetime(
    DataFrame(list(energy["time"].str.split(" ")))[0] + 
    " " 
    + (temp[0].astype("int") - 1).astype("str") + ":" + temp[1] + ":" + temp[2])

energy = energy.dropna().reset_index(drop = True)

# %%
def time_interpolate(x, data):
    
    temp = data[data["time"].dt.date == x].drop_duplicates("time", keep = "last")
    
    min_time = np.min(temp["time"])
    
    max_time = min_time + pd.Timedelta(hours = 23)
    
    time_index = pd.date_range(min_time, max_time, freq = "H")
    
    temp = pd.merge(pd.Series(pd.date_range(min_time, max_time, freq = "H"),name = "time"),
         temp,
         how = "left")
    
    return temp

# %%
dangjin_fcst = dangjin_fcst.dropna(axis = 0, subset = ["Temperature","Humidity", "WindSpeed", "WindDirection"]).reset_index(drop = True)

dangjin_fcst["Forecast time"] = pd.to_datetime(dangjin_fcst["Forecast time"])

dangjin_fcst = dangjin_fcst.rename(columns = {"forecast":"time"})

result = pd.Series(dangjin_fcst["time"].dt.date.unique()).apply(lambda x : time_interpolate(x, dangjin_fcst))

dangjin_fcst = pd.concat(list(result))

del dangjin_fcst["Forecast time"]

dangjin_fcst = dangjin_fcst.drop_duplicates("time").reset_index(drop = True)

# %%
dangjin_fcst.iloc[:,1:] = dangjin_fcst.iloc[:,1:].apply(lambda x : x.interpolate(method = "spline", order = 2))

# %%
ulsan_fcst = ulsan_fcst.dropna(axis = 0, subset = ["Temperature","Humidity", "WindSpeed", "WindDirection"]).reset_index(drop = True)

ulsan_fcst["Forecast time"] = pd.to_datetime(ulsan_fcst["Forecast time"])

ulsan_fcst = ulsan_fcst.rename(columns = {"forecast":"time"})

result = pd.Series(ulsan_fcst["time"].dt.date.unique()).apply(lambda x : time_interpolate(x, ulsan_fcst))

ulsan_fcst = pd.concat(list(result))

del ulsan_fcst["Forecast time"]

ulsan_fcst = ulsan_fcst.drop_duplicates("time").reset_index(drop = True)

# %%
ulsan_fcst.iloc[:,1:] = ulsan_fcst.iloc[:,1:].apply(lambda x : x.interpolate(method = "spline", order = 2))

# %% [markdown]
# ## 2) 파생 변수 생성

# %% [markdown]
# ### (1) day_night 변수 추가

# %%
def day_night(x):
    if x < 5 or x > 19:
        return 0
    else:
        return 1

# %%
dangjin_fcst["day_night"] = dangjin_fcst["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %%
ulsan_fcst["day_night"] = ulsan_fcst["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %% [markdown]
# ### (2) 월 변수 추가

# %% [markdown]
# #### - dangjin

# %%
temp = pd.DataFrame(dangjin_fcst["time"]).copy()

# %%
temp["month"] = dangjin_fcst["time"].dt.month
temp["year"] = dangjin_fcst["time"].dt.year
temp["day"] = dangjin_fcst["time"].dt.day

temp["hour"] = dangjin_fcst["time"].dt.hour

# %%
dangjin_fcst = pd.merge(dangjin_fcst, temp, how = "left")

# %%
energy_fcst_dangjin = pd.merge(energy, dangjin_fcst).dropna()

# %% [markdown]
# #### - ulsan

# %%
temp = pd.DataFrame(ulsan_fcst["time"]).copy()

# %%
temp["month"] = ulsan_fcst["time"].dt.month
temp["year"] = ulsan_fcst["time"].dt.year
temp["day"] = ulsan_fcst["time"].dt.day

temp["hour"] = ulsan_fcst["time"].dt.hour

# %%
ulsan_fcst = pd.merge(ulsan_fcst, temp)

# %%
energy_fcst_ulsan = pd.merge(energy, ulsan_fcst, how = "left").dropna()

# %% [markdown]
# # 4. 모델링

# %% [markdown]
# ## 1) train_test 분할

# %% [markdown]
# ### (1) 당진 분할

# %%
temp = DataFrame(energy_fcst_dangjin["time"].dt.date)

# %%
def gen():
    n = 0
    while True:
        n += 1
        yield n
        
num = gen()

# %%
temp = temp.groupby("time").apply(lambda x : next(num))

temp = temp.reset_index(name = "num")
temp.columns = ["date","num"]

energy_fcst_dangjin["date"] = energy_fcst_dangjin["time"].dt.date

energy_fcst_dangjin = pd.merge(energy_fcst_dangjin, temp)

k = energy_fcst_dangjin.groupby("num").apply(lambda x : len(x) / 24)

k = k.reset_index(name = "ratio")

k_full = DataFrame(list(set(k["num"]).difference(set(k.loc[k["ratio"] < 1, "num"]))),
         columns = ["num"])

energy_fcst_dangjin = pd.merge(k_full, 
         energy_fcst_dangjin,
         how = "left")

#train_num = np.random.choice(energy_fcst_dangjin["num"].unique(),
#              size = int(len(energy_fcst_dangjin["num"].unique()) * 0.75),
#                replace = False)

train_num = [i for i in range(0, len(energy_fcst_dangjin["num"].unique()) - 30)]

test_num = [i for i in range(len(energy_fcst_dangjin["num"].unique()) - 30, 
                            len(energy_fcst_dangjin["num"].unique()))]

train = pd.merge(DataFrame(train_num, columns = ["num"]), energy_fcst_dangjin)

test = pd.merge(DataFrame(test_num, columns = ["num"]), energy_fcst_dangjin)

X_train_dangjin = train[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "WindDirection", 
                         "Cloud",
                         "day_night",
                         "month",
                         "year",
                         "day",
                         "hour",
                         "num"]]

X_train_dangjin = X_train_dangjin.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "WindDirection", 
                         "Cloud",
                         "day_night",
                         "month",
                         "year",
                         "day",
                         "hour",]].to_numpy())

X_test_dangjin = test[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "WindDirection", 
                         "Cloud",
                         "day_night",
                         "month",
                         "year",
                         "day",
                         "hour",
                       "num"]]

X_test_dangjin = X_test_dangjin.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "WindDirection", 
                         "Cloud",
                         "day_night",
                         "month",
                         "year",
                         "day",
                         "hour",]].to_numpy())

X_train_dangjin = np.stack(X_train_dangjin)
X_test_dangjin = np.stack(X_test_dangjin)

# %%
y_train_dangjin = train[["num","dangjin"]]
y_test_dangjin = test[["num","dangjin"]]

y_train_dangjin = np.stack(y_train_dangjin.groupby("num").apply(lambda x : np.array(x["dangjin"])))
y_test_dangjin = np.stack(y_test_dangjin.groupby("num").apply(lambda x : np.array(x["dangjin"])))

# %%
y_train_dangjin_ware = train[["num","dangjin_warehouse"]]
y_test_dangjin_ware = test[["num","dangjin_warehouse"]]

y_train_dangjin_ware = np.stack(y_train_dangjin_ware.groupby("num").apply(lambda x : np.array(x["dangjin_warehouse"])))
y_test_dangjin_ware = np.stack(y_test_dangjin_ware.groupby("num").apply(lambda x : np.array(x["dangjin_warehouse"])))

# %%
y_train_dangjin_float = train[["num","dangjin_floating"]]
y_test_dangjin_float = test[["num","dangjin_floating"]]

y_train_dangjin_float = np.stack(y_train_dangjin_float.groupby("num").apply(lambda x : np.array(x["dangjin_floating"])))
y_test_dangjin_float = np.stack(y_test_dangjin_float.groupby("num").apply(lambda x : np.array(x["dangjin_floating"])))

# %% [markdown]
# ### (2) 울산 분할

# %%
temp = DataFrame(energy_fcst_ulsan["time"].dt.date)

# %%
temp = temp.groupby("time").apply(lambda x : next(num))

temp = temp.reset_index(name = "num")
temp.columns = ["date","num"]

energy_fcst_ulsan["date"] = energy_fcst_ulsan["time"].dt.date

energy_fcst_ulsan = pd.merge(energy_fcst_ulsan, temp)

k = energy_fcst_ulsan.groupby("num").apply(lambda x : len(x) / 24)

# %%
k = k.reset_index(name = "ratio")

k_full = DataFrame(list(set(k["num"]).difference(set(k.loc[k["ratio"] < 1, "num"]))),
         columns = ["num"])

energy_fcst_ulsan = pd.merge(k_full, 
         energy_fcst_ulsan,
         how = "left")

#train_num = np.random.choice(energy_fcst_dangjin["num"].unique(),
#              size = int(len(energy_fcst_dangjin["num"].unique()) * 0.75),
#                replace = False)

train_num = [i for i in range(np.min(energy_fcst_ulsan["num"].unique()), 
                              np.max(energy_fcst_ulsan["num"].unique()) - 30)]

test_num = [i for i in range(np.max(energy_fcst_ulsan["num"].unique()) - 30, 
                            np.max(energy_fcst_ulsan["num"].unique()) + 1)]

train = pd.merge(DataFrame(train_num, columns = ["num"]), energy_fcst_ulsan)

test = pd.merge(DataFrame(test_num, columns = ["num"]), energy_fcst_ulsan)

X_train_ulsan = train[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "WindDirection", 
                         "Cloud",
                         "day_night",
                         "year",
                         "month",
                         "day",
                         "hour",
                         "num"]]

X_train_ulsan = X_train_ulsan.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "WindDirection", 
                         "Cloud",
                         "day_night",
                         "year",
                         "month",
                         "day",
                         "hour",]].to_numpy())

X_test_ulsan = test[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "WindDirection", 
                         "Cloud",
                         "day_night",
                         "year",
                         "month",
                         "day",
                         "hour",
                       "num"]]

X_test_ulsan = X_test_ulsan.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "WindDirection", 
                         "Cloud",
                         "day_night",
                         "year",
                         "month",
                         "day",
                         "hour",]].to_numpy())

X_train_ulsan = np.stack(X_train_ulsan)
X_test_ulsan = np.stack(X_test_ulsan)

# %%
y_train_ulsan = train[["num","ulsan"]]
y_test_ulsan = test[["num","ulsan"]]

y_train_ulsan = np.stack(y_train_ulsan.groupby("num").apply(lambda x : np.array(x["ulsan"])))
y_test_ulsan = np.stack(y_test_ulsan.groupby("num").apply(lambda x : np.array(x["ulsan"])))

# %% [markdown]
# ## 1) LightGBM

# %% [markdown]
# ### (1) Parameter Tune

# %% [markdown]
# #### - dangjin

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, y_train_dangjin, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin, [-1])

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_valid_dangjin_lgb, y_valid_dangjin_lgb)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
from sklearn.metrics import r2_score, mean_squared_error

def LGB_cv(learning_rate, 
           feature_fraction, 
           bagging_fraction,
           lambda_l2,
           silent=True, 
           nthread=-1):

    params = {"learning_rate": learning_rate,
                "feature_fraction" : feature_fraction,
                "bagging_fraction" : bagging_fraction, 
               "lambda_l2" : lambda_l2,
               "objective" :  "regression",
              "nthread" : nthread
                }
    
    model = lgb.train(params,
                      train_dataset,
                      feval = nmae_10
                     )

    y_pred = model.predict(X_valid_dangjin_lgb)

    mae = np.mean(nmae_10(y_valid_dangjin_lgb, y_pred))

    return 1/mae

# %%
import scipy.optimize as optimize
from bayes_opt import BayesianOptimization

params = {"learning_rate": (0.0001, 0.2),
            "feature_fraction" : (0.0001, 1),
            "bagging_fraction" : (0.0001, 1), 
           "lambda_l2" : (0 , 1),
            }

capacity = 1000
train_max = 1
train_min = 0

bo=BayesianOptimization(f=LGB_cv, 
                        pbounds=params, 
                        verbose=2, 
                        random_state=1 )

bo.maximize(init_points=2, n_iter=100, acq='ei', xi=0.01)

print(bo.max)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l2 | learni... |
# -------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000397 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  1        |  0.1014   |  0.4171   |  0.7204   |  0.000114 |  0.06054  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000059 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  2        |  0.04732  |  0.1468   |  0.09243  |  0.1863   |  0.06918  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000100 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  3        |  0.1018   |  0.4182   |  0.7762   |  0.009261 |  0.093    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000407 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  4        |  0.1016   |  0.4132   |  0.7921   |  0.03435  |  0.1082   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000159 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  5        |  0.03594  |  0.9935   |  0.8823   |  0.09567  |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000109 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  6        |  0.1033   |  0.0213   |  0.8079   |  0.9649   |  0.1404   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  7        |  0.03594  |  0.06077  |  0.9397   |  0.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000478 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  8        |  0.1013   |  0.2848   |  0.8436   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000087 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  9        |  0.1001   |  0.1567   |  0.5437   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000077 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  10       |  0.1036   |  0.3249   |  0.6358   |  0.4005   |  0.1503   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  11       |  0.1014   |  0.2501   |  0.7432   |  0.6948   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000086 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  12       |  0.03589  |  0.5161   |  0.5715   |  0.8      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000321 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  13       |  0.1022   |  0.4242   |  0.7674   |  0.04903  |  0.1099   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  14       |  0.1016   |  0.0001   |  0.6505   |  0.6495   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000070 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  15       |  0.09695  |  0.2341   |  0.4471   |  0.5501   |  0.1898   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  16       |  0.1022   |  0.1101   |  1.0      |  0.7777   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000060 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  17       |  0.05341  |  0.0001   |  0.1019   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000052 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  18       |  0.05336  |  1.0      |  0.0001   |  0.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000116 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  19       |  0.101    |  0.1619   |  0.6818   |  0.433    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000093 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  20       |  0.1017   |  0.3397   |  0.5699   |  0.156    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000128 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  21       |  0.1023   |  0.0001   |  1.0      |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000063 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  22       |  0.06091  |  0.8181   |  0.1636   |  0.01503  |  0.03228  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  23       |  0.1026   |  0.4063   |  1.0      |  0.464    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  24       |  0.1023   |  1.0      |  1.0      |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000383 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  25       |  0.1023   |  0.6462   |  1.0      |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000062 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  26       |  0.05341  |  1.0      |  0.0001   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  27       |  0.03595  |  0.1859   |  1.0      |  1.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  28       |  0.1027   |  0.006037 |  0.6565   |  0.8784   |  0.1856   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  29       |  0.09691  |  0.5393   |  0.3921   |  0.9372   |  0.08439  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000059 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |
seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  75       |  0.1024   |  0.5273   |  0.8081   |  0.79     |  0.1287   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000124 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  76       |  0.1016   |  0.584    |  0.9016   |  0.8136   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  77       |  0.1013   |  0.4943   |  0.7947   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  78       |  0.1022   |  0.3936   |  0.8223   |  0.8181   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  79       |  0.1009   |  0.5564   |  0.8326   |  0.6086   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000406 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  80       |  0.1023   |  0.6042   |  0.6901   |  0.6522   |  0.08308  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000097 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  81       |  0.1012   |  0.6693   |  0.6258   |  0.538    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000087 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  82       |  0.07421  |  0.2757   |  0.393    |  0.5682   |  0.02402  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000415 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  83       |  0.1027   |  0.6953   |  0.851    |  0.6348   |  0.08628  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  84       |  0.07984  |  0.4463   |  1.0      |  0.5703   |  0.01642  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000139 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  85       |  0.1018   |  0.419    |  0.783    |  0.007542 |  0.1001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000368 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  86       |  0.1026   |  0.6744   |  0.7264   |  0.7503   |  0.1949   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  87       |  0.1037   |  0.0001   |  0.875    |  0.5705   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  88       |  0.1025   |  0.8068   |  0.6778   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000100 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  89       |  0.09444  |  0.5423   |  0.627    |  0.498    |  0.03662  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000089 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  90       |  0.1011   |  0.0001   |  0.5203   |  0.3417   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  91       |  0.1011   |  0.2153   |  0.5314   |  0.3337   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000093 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  92       |  0.1004   |  0.4884   |  0.6479   |  0.4768   |  0.1836   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000414 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  93       |  0.1016   |  0.2736   |  0.6532   |  0.8961   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000087 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  94       |  0.1001   |  1.0      |  0.4649   |  0.5031   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  95       |  0.1014   |  0.8406   |  0.7154   |  0.5633   |  0.06507  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  96       |  0.1011   |  0.8109   |  0.5263   |  0.3561   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000495 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  97       |  0.1027   |  0.02707  |  0.807    |  0.9745   |  0.1405   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000081 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  98       |  0.06329  |  0.2389   |  0.3062   |  0.4796   |  0.02583  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000081 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  99       |  0.09683  |  0.7268   |  0.4061   |  0.5325   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  100      |  0.03587  |  1.0      |  0.4626   |  0.4936   |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000106 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  101      |  0.1      |  0.8571   |  0.6325   |  0.4473   |  0.1997   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000398 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# |  102      |  0.1014   |  0.8432   |  0.8563   |  0.5471   |  0.1806   |
# =========================================================================
# {'target': 0.10373723043991727, 'params': {'bagging_fraction': 0.0001, 'feature_fraction': 0.8750467371420657, 'lambda_l2': 0.5704893130410732, 'learning_rate': 0.2}}

# %%
def nmae_10_lgb(y_pred, dataset):
    y_true = dataset.get_label()
    
    absolute_error = abs(y_true - y_pred)
    absolute_error /= capacity
    
    target_idx = np.where(y_true>=capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx].mean()
    
    return 'score', nmae, False

# %%
params = {"learning_rate": 0.2,
            "feature_fraction" : 0.8750467371420657,
            "bagging_fraction" : 0.0001, 
           "lambda_l2" :  0.5704893130410732,
          "objective" : 'regression'
            }

# %%
capacity = 1000
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 8086.6	valid_0's score: 11.8887
# [1000]	valid_0's l2: 8412.03	valid_0's score: 12.0835
# Early stopping, best iteration is:
# [25]	valid_0's l2: 7638.34	valid_0's score: 10.8145

# %%
params = {
    'learning_rate': 0.01,
    'objective': 'regression',
    'metric':'mae',
    'seed':42
}

# %%
capacity = 1000
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000498 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l1: 45.4301	valid_0's score: 10.9869
# [1000]	valid_0's l1: 45.9319	valid_0's score: 11.1868
# Early stopping, best iteration is:
# [370]	valid_0's l1: 47.8138	valid_0's score: 10.8581

# %% [markdown]
# #### - dangjin_ware

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, 
                                                                                                      y_train_dangjin_ware, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin_ware, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
from sklearn.metrics import r2_score, mean_squared_error


# 탐색 대상 함수 (XGBRegressor)
def LGB_cv(learning_rate, 
           feature_fraction, 
           bagging_fraction,
           lambda_l2,
           silent=True, 
           nthread=-1):

    params = {"learning_rate": learning_rate,
                "feature_fraction" : feature_fraction,
                "bagging_fraction" : bagging_fraction, 
               "lambda_l2" : lambda_l2,
               "objective" :  "regression",
              "nthread" : nthread
                }
    
  # 모델 정의
    model = lgb.train(params,
                      train_dataset,
                      feval = nmae_10
                     )

  # 예측값 출력
    y_pred = model.predict(X_valid_dangjin_lgb)

  # 각종 metric 계산
    mae = np.mean(nmae_10(y_valid_dangjin_lgb, y_pred))

  # 오차 최적화로 사용할 metric 반환
    return 1/mae

# %%
import scipy.optimize as optimize
from bayes_opt import BayesianOptimization

params = {"learning_rate": (0.0001, 0.2),
            "feature_fraction" : (0.0001, 1),
            "bagging_fraction" : (0.0001, 1), 
           "lambda_l2" : (0 , 1),
            }

capacity = 700
train_max = 1
train_min = 0

bo=BayesianOptimization(f=LGB_cv, 
                        pbounds=params, 
                        verbose=2, 
                        random_state=42 )

bo.maximize(init_points=2, n_iter=100, acq='ei', xi=0.01)

print(bo.max)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l2 | learni... |
# -------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.
seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  83       |  0.1059   |  0.8403   |  0.6401   |  0.3885   |  0.06085  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  84       |  0.09     |  0.6492   |  0.9227   |  0.4176   |  0.02113  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000342 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  85       |  0.09294  |  0.4647   |  0.6815   |  0.04797  |  0.02603  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000388 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  86       |  0.1064   |  0.7305   |  0.6749   |  0.4834   |  0.1086   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000093 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  87       |  0.1058   |  0.7779   |  0.5471   |  0.2647   |  0.09152  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000431 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  88       |  0.1012   |  0.4839   |  0.9858   |  0.612    |  0.03351  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000093 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  89       |  0.1046   |  0.0001   |  0.4892   |  0.7707   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  90       |  0.1067   |  0.3962   |  0.9021   |  0.4754   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000079 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  91       |  0.102    |  0.8151   |  0.4371   |  0.7856   |  0.1385   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  92       |  0.105    |  0.8856   |  0.568    |  0.7778   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  93       |  0.05198  |  0.5776   |  0.7323   |  0.8554   |  0.005388 |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000451 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  94       |  0.1074   |  0.5966   |  0.8944   |  0.7576   |  0.07841  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  95       |  0.1098   |  0.3735   |  0.7716   |  0.881    |  0.174    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000133 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  96       |  0.109    |  0.3832   |  0.9584   |  0.9609   |  0.1061   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  97       |  0.1094   |  0.07344  |  0.9753   |  0.6798   |  0.1204   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000155 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  98       |  0.1094   |  0.4012   |  0.8923   |  0.8905   |  0.1337   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000172 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  99       |  0.1091   |  0.2088   |  0.9632   |  0.9773   |  0.1987   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  100      |  0.1082   |  0.4336   |  0.7531   |  0.8632   |  0.06871  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  101      |  0.1081   |  0.6934   |  0.7786   |  0.7776   |  0.1342   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# |  102      |  0.1075   |  0.3808   |  0.9277   |  0.9922   |  0.1935   |
# =========================================================================
# {'target': 0.10982281479681895, 'params': {'bagging_fraction': 0.37348978650671216, 'feature_fraction': 0.7715776391263182, 'lambda_l2': 0.8809952775628214, 'learning_rate': 0.1739590488029273}}

# %%
params = {"learning_rate": 0.1739590488029273,
            "feature_fraction" : 0.7715776391263182,
            "bagging_fraction" : 0.37348978650671216, 
           "lambda_l2" :  0.8809952775628214,
          "objective" : 'regression'
            }

# %%
capacity = 700
dangjin_model = lgb.train(params, train_dataset, 10000, val_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000434 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 4273.1	valid_0's score: 12.2037
# [1000]	valid_0's l2: 4319.68	valid_0's score: 12.3233
# Early stopping, best iteration is:
# [16]	valid_0's l2: 3702.01	valid_0's score: 10.9721

# %%
params = {
    'learning_rate': 0.01,
    'objective': 'regression',
    'metric':'mae',
    'seed':42
}

# %%
capacity = 700
dangjin_model = lgb.train(params, train_dataset, 10000, val_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000139 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l1: 31.8622	valid_0's score: 11.1551
# [1000]	valid_0's l1: 33.2165	valid_0's score: 11.3279
# Early stopping, best iteration is:
# [274]	valid_0's l1: 36.3935	valid_0's score: 10.9644

# %% [markdown]
# #### - dangjin_float

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, 
                                                                                                      y_train_dangjin_float, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin_float, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
from sklearn.metrics import r2_score, mean_squared_error


# 탐색 대상 함수 (XGBRegressor)
def LGB_cv(learning_rate, 
           feature_fraction, 
           bagging_fraction,
           lambda_l2,
           silent=True, 
           nthread=-1):

    params = {"learning_rate": learning_rate,
                "feature_fraction" : feature_fraction,
                "bagging_fraction" : bagging_fraction, 
               "lambda_l2" : lambda_l2,
               "objective" :  "regression",
              "nthread" : nthread
                }
    
  # 모델 정의
    model = lgb.train(params,
                      train_dataset,
                      feval = nmae_10
                     )

  # 예측값 출력
    y_pred = model.predict(X_valid_dangjin_lgb)

  # 각종 metric 계산
    mae = np.mean(nmae_10(y_valid_dangjin_lgb, y_pred))

  # 오차 최적화로 사용할 metric 반환
    return 1/mae

# %%
import scipy.optimize as optimize
from bayes_opt import BayesianOptimization

params = {"learning_rate": (0.0001, 0.2),
            "feature_fraction" : (0.0001, 1),
            "bagging_fraction" : (0.0001, 1), 
           "lambda_l2" : (0 , 1),
            }

capacity = 1000
train_max = 1
train_min = 0

bo=BayesianOptimization(f=LGB_cv, 
                        pbounds=params, 
                        verbose=2, 
                        random_state=42 )

bo.maximize(init_points=2, n_iter=100, acq='ei', xi=0.01)

print(bo.max)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l2 | learni... |
# -------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  1        |  0.1244   |  0.3746   |  0.9507   |  0.732    |  0.1198   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000063 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  2        |  0.09864  |  0.1561   |  0.1561   |  0.05808  |  0.1732   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  3        |  0.123    |  0.3543   |  0.9372   |  0.6763   |  0.1314   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000361 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  4        |  0.0407   |  1.0      |  1.0      |  1.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000051 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  5        |  0.05367  |  0.004578 |  0.04046  |  0.4665   |  0.07049  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  6        |  0.1257   |  0.1397   |  1.0      |  0.8383   |  0.1536   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000448 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  7        |  0.1203   |  0.2308   |  0.7385   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000092 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  8        |  0.12     |  0.9383   |  0.7064   |  0.4501   |  0.1997   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.
|  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000113 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  89       |  0.04057  |  0.0001   |  0.417    |  0.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000465 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  90       |  0.1207   |  0.0001   |  0.7673   |  0.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000082 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  91       |  0.1136   |  0.8151   |  0.4371   |  0.7856   |  0.1385   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000093 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  92       |  0.1184   |  0.9228   |  0.6053   |  0.743    |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000414 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  93       |  0.05655  |  0.5776   |  0.7323   |  0.8554   |  0.005388 |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  94       |  0.1224   |  0.831    |  0.731    |  0.2705   |  0.09636  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000462 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  95       |  0.1212   |  0.6602   |  0.7827   |  0.8627   |  0.1806   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  96       |  0.1239   |  0.3832   |  0.9584   |  0.9609   |  0.1061   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000170 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  97       |  0.1231   |  0.07344  |  0.9753   |  0.6798   |  0.1204   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  98       |  0.1243   |  0.4602   |  0.8581   |  0.917    |  0.141    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000152 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  99       |  0.1238   |  0.5294   |  0.9944   |  0.8568   |  0.0844   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000157 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  100      |  0.1229   |  0.7248   |  0.8547   |  0.1712   |  0.1847   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000447 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  101      |  0.1215   |  0.8044   |  0.8199   |  0.5345   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# |  102      |  0.1245   |  0.6346   |  0.874    |  0.8391   |  0.11     |
# =========================================================================
# {'target': 0.1256521115582958, 'params': {'bagging_fraction': 0.13970012625235748, 'feature_fraction': 1.0, 'lambda_l2': 0.8382979270089052, 'learning_rate': 0.15360009139262032}}

# %%
params = {"learning_rate": 0.15360009139262032,
            "feature_fraction" : 1,
            "bagging_fraction" : 0.13970012625235748, 
           "lambda_l2" :  0.8382979270089052,
          "objective" : 'regression'
            }

# %%
capacity = 1000
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000195 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 5053.66	valid_0's score: 8.89678
# [1000]	valid_0's l2: 5162.07	valid_0's score: 9.0123
# Early stopping, best iteration is:
# [22]	valid_0's l2: 4963.2	valid_0's score: 8.04688

# %%
params = {
    'learning_rate': 0.01,
    'objective': 'regression',
    'metric':'mae',
    'seed':42
}

# %%
capacity = 1000
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000167 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l1: 36.6045	valid_0's score: 8.1538
# [1000]	valid_0's l1: 35.6984	valid_0's score: 8.40834
# Early stopping, best iteration is:
# [475]	valid_0's l1: 36.7875	valid_0's score: 8.13864

# %% [markdown]
# #### -ulsan

# %%
X_train_ulsan_lgb, X_valid_ulsan_lgb, y_train_ulsan_lgb, y_valid_ulsan_lgb = train_test_split(X_train_ulsan, 
                                                                                                      y_train_ulsan, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_ulsan_lgb = np.reshape(X_train_ulsan_lgb, [-1,np.shape(X_train_ulsan_lgb)[-1]])
X_valid_ulsan_lgb = np.reshape(X_valid_ulsan_lgb, [-1,np.shape(X_valid_ulsan_lgb)[-1]])

# %%
y_train_ulsan_lgb = np.reshape(y_train_ulsan_lgb, [-1])
y_valid_ulsan_lgb = np.reshape(y_valid_ulsan_lgb, [-1])

# %%
X_test_ulsan_lgb = np.reshape(X_test_ulsan, [-1,np.shape(X_test_ulsan)[-1]])
y_test_ulsan_lgb = np.reshape(y_test_ulsan, [-1])

# %%
train_dataset = lgb.Dataset(X_train_ulsan_lgb, y_train_ulsan_lgb)
test_dataset = lgb.Dataset(X_test_ulsan_lgb, y_test_ulsan_lgb)
val_dataset = lgb.Dataset(X_valid_ulsan_lgb, y_valid_ulsan_lgb)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
from sklearn.metrics import r2_score, mean_squared_error


# 탐색 대상 함수 (XGBRegressor)
def LGB_cv(learning_rate, 
           feature_fraction, 
           bagging_fraction,
           lambda_l2,
           silent=True, 
           nthread=-1):

    params = {"learning_rate": learning_rate,
                "feature_fraction" : feature_fraction,
                "bagging_fraction" : bagging_fraction, 
               "lambda_l2" : lambda_l2,
               "objective" :  "regression",
              "nthread" : nthread
                }
    
  # 모델 정의
    model = lgb.train(params,
                      train_dataset,
                      feval = nmae_10
                     )

  # 예측값 출력
    y_pred = model.predict(X_valid_ulsan_lgb)

  # 각종 metric 계산
    mae = np.mean(nmae_10(y_valid_ulsan_lgb, y_pred))

  # 오차 최적화로 사용할 metric 반환
    return 1/mae

# %%
import scipy.optimize as optimize
from bayes_opt import BayesianOptimization

params = {"learning_rate": (0.0001, 0.2),
            "feature_fraction" : (0.0001, 1),
            "bagging_fraction" : (0.0001, 1), 
           "lambda_l2" : (0 , 1),
            }

capacity = 500
train_max = 1
train_min = 0

bo=BayesianOptimization(f=LGB_cv, 
                        pbounds=params, 
                        verbose=2, 
                        random_state=1 )

bo.maximize(init_points=2, n_iter=100, acq='ei', xi=0.01)

print(bo.max)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l2 | learni... |
# -------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  1        |  0.1229   |  0.4171   |  0.7204   |  0.000114 |  0.06054  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000070 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  2        |  0.05081  |  0.1468   |  0.09243  |  0.1863   |  0.06918  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  3        |  0.125    |  0.4182   |  0.7762   |  0.009261 |  0.093    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  4        |  0.04088  |  0.8277   |  0.9776   |  0.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000464 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  5        |  0.126    |  0.214    |  0.7889   |  0.0      |  0.1321   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000404 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  6        |  0.1221   |  0.0213   |  0.8079   |  0.9649   |  0.1404   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000451 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  7        |  0.1233   |  0.226    |  0.8712   |  0.3588   |  0.1614   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000378 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  8        |  0.12     |  0.323    |  1.0      |  0.8238   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  9        |  0.04088  |  0.0001   |  1.0      |  0.6411   |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000103 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  10       |  0.1225   |  0.3249   |  0.6358   |  0.4005   |  0.1503   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000108 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  11       |  0.1228   |  0.01938  |  0.8166   |  0.9656   |  0.1391   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  12       |  0.1207   |  0.3286   |  0.7665   |  0.1939   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  13       |  0.1216   |  0.1934   |  0.9329   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000424 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  14       |  0.1228   |  0.4979   |  0.7956   |  0.6122   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.
seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  97       |  0.1248   |  0.02707  |  0.807    |  0.9745   |  0.1405   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000084 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  98       |  0.07134  |  0.2389   |  0.3062   |  0.4796   |  0.02583  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000440 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  99       |  0.1213   |  0.4979   |  1.0      |  0.8526   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000418 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  100      |  0.04084  |  0.3605   |  0.819    |  0.03108  |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000124 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  101      |  0.124    |  0.4628   |  0.7123   |  0.04914  |  0.1289   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000432 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# |  102      |  0.1231   |  0.1412   |  0.9963   |  0.1062   |  0.1242   |
# =========================================================================
# {'target': 0.12598306776741144, 'params': {'bagging_fraction': 0.2140235305744609, 'feature_fraction': 0.7888937434650488, 'lambda_l2': 0.0, 'learning_rate': 0.1321160020150741}}

# %%
params = {"learning_rate": 0.1321160020150741,
            "feature_fraction" : 0.7888937434650488,
            "bagging_fraction" : 0.2140235305744609, 
           "lambda_l2" :  0,
          "objective" : 'regression'
            }

# %%
capacity = 500
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000457 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 795.43	valid_0's score: 6.85606
# [1000]	valid_0's l2: 818.503	valid_0's score: 6.99186
# Early stopping, best iteration is:
# [143]	valid_0's l2: 680.044	valid_0's score: 6.26881

# %%
params = {
    'learning_rate': 0.01,
    'objective': 'regression',
    'metric':'mae',
    'seed':42
}

# %%
capacity = 500
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000444 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l1: 13.4735	valid_0's score: 6.76242
# [1000]	valid_0's l1: 12.7782	valid_0's score: 6.59146
# [1500]	valid_0's l1: 12.889	valid_0's score: 6.70918
# Early stopping, best iteration is:
# [842]	valid_0's l1: 12.8923	valid_0's score: 6.51321

# %% [markdown]
# ### (2) 모델 학습

# %%
def nmae_10_lgb(y_pred, dataset):
    y_true = dataset.get_label()
    
    absolute_error = abs(y_true - y_pred)
    absolute_error /= capacity
    
    target_idx = np.where(y_true>=capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx].mean()
    
    return 'score', nmae, False

# %% [markdown]
# #### -dangjin

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, y_train_dangjin, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin, [-1])

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_valid_dangjin_lgb, y_valid_dangjin_lgb)

# %%
params = {"learning_rate": 0.2,
            "feature_fraction" : 0.8750467371420657,
            "bagging_fraction" : 0.0001, 
           "lambda_l2" :  0.5704893130410732,
          "objective" : 'regression'
            }

# %%
capacity = 1000
Models_dangjin = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000144 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 139.977576
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 8086.6	valid_0's score: 11.8887
# [1000]	valid_0's l2: 8412.03	valid_0's score: 12.0835
# Early stopping, best iteration is:
# [25]	valid_0's l2: 7638.34	valid_0's score: 10.8145

# %% [markdown]
# #### -dangjin_ware

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, 
                                                                                                      y_train_dangjin_ware, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin_ware, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_valid_dangjin_lgb, y_valid_dangjin_lgb)

# %%
params = {"learning_rate": 0.1739590488029273,
            "feature_fraction" : 0.7715776391263182,
            "bagging_fraction" : 0.37348978650671216, 
           "lambda_l2" :  0.8809952775628214,
          "objective" : 'regression'
            }

# %%
capacity = 700
Models_dangjin_warehouse = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000371 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 92.546364
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 4273.1	valid_0's score: 12.2037
# [1000]	valid_0's l2: 4319.68	valid_0's score: 12.3233
# Early stopping, best iteration is:
# [16]	valid_0's l2: 3702.01	valid_0's score: 10.9721

# %% [markdown]
# #### - dangjin_float

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, 
                                                                                                      y_train_dangjin_float, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin_float, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_valid_dangjin_lgb, y_valid_dangjin_lgb)

# %%
params = {"learning_rate": 0.15360009139262032,
            "feature_fraction" : 1,
            "bagging_fraction" : 0.13970012625235748, 
           "lambda_l2" :  0.8382979270089052,
          "objective" : 'regression'
            }

# %%
capacity = 1000
Models_dangjin_floating = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000350 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1350
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 10
# [LightGBM] [Info] Start training from score 122.399495
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 5053.66	valid_0's score: 8.89678
# [1000]	valid_0's l2: 5162.07	valid_0's score: 9.0123
# Early stopping, best iteration is:
# [22]	valid_0's l2: 4963.2	valid_0's score: 8.04688

# %% [markdown]
# #### - ulsan

# %%
X_train_ulsan_lgb, X_valid_ulsan_lgb, y_train_ulsan_lgb, y_valid_ulsan_lgb = train_test_split(X_train_ulsan, 
                                                                                                      y_train_ulsan, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_ulsan_lgb = np.reshape(X_train_ulsan_lgb, [-1,np.shape(X_train_ulsan_lgb)[-1]])
X_valid_ulsan_lgb = np.reshape(X_valid_ulsan_lgb, [-1,np.shape(X_valid_ulsan_lgb)[-1]])

# %%
y_train_ulsan_lgb = np.reshape(y_train_ulsan_lgb, [-1])
y_valid_ulsan_lgb = np.reshape(y_valid_ulsan_lgb, [-1])

# %%
X_test_ulsan_lgb = np.reshape(X_test_ulsan, [-1,np.shape(X_test_ulsan)[-1]])
y_test_ulsan_lgb = np.reshape(y_test_ulsan, [-1])

# %%
train_dataset = lgb.Dataset(X_train_ulsan_lgb, y_train_ulsan_lgb)
test_dataset = lgb.Dataset(X_test_ulsan_lgb, y_test_ulsan_lgb)
val_dataset = lgb.Dataset(X_valid_ulsan_lgb, y_valid_ulsan_lgb)

# %%
params = {"learning_rate": 0.1321160020150741,
            "feature_fraction" : 0.7888937434650488,
            "bagging_fraction" : 0.2140235305744609, 
           "lambda_l2" :  0,
          "objective" : 'regression'
            }

# %%
capacity = 500
Models_ulsan = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000395 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1355
# [LightGBM] [Info] Number of data points in the train set: 19848, number of used features: 10
# [LightGBM] [Info] Start training from score 64.479696
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 795.43	valid_0's score: 6.85606
# [1000]	valid_0's l2: 818.503	valid_0's score: 6.99186
# Early stopping, best iteration is:
# [143]	valid_0's l2: 680.044	valid_0's score: 6.26881

# %% [markdown]
# ### 2) LSTM_AUTOENCODER

# %% [markdown]
# ### (1) min_max_scale

# %%
train_min_dangjin = np.min(X_train_dangjin)
train_max_dangjin = np.max(X_train_dangjin)

X_train_dangjin_scaled = (X_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

X_test_dangjin_scaled = (X_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

X_train_dangjin_scaled[:,:,5] = X_train_dangjin[:,:,5]

X_test_dangjin_scaled[:,:,5] = X_test_dangjin[:,:,5]

# %%
y_train_dangjin_scaled = (y_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_scaled = (y_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_ware_scaled = (y_train_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_ware_scaled = (y_test_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_float_scaled = (y_train_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_float_scaled = (y_test_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %% [markdown]
# #### - 울산

# %%
train_min_ulsan = np.min(X_train_ulsan)
train_max_ulsan = np.max(X_train_ulsan)

X_train_ulsan_scaled = (X_train_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

X_test_ulsan_scaled = (X_test_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

X_train_ulsan_scaled[:,:,5] = X_train_ulsan[:,:,5]

X_test_ulsan_scaled[:,:,5] = X_test_ulsan[:,:,5]

# %%
y_train_ulsan_scaled = (y_train_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

y_test_ulsan_scaled = (y_test_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

# %%
class TrainModel(tf.keras.Model):
    def __init__(self,
                 kernel_size, 
                 lstm_dim):
        
        super(TrainModel, self).__init__()
        
        self.kernel_size = kernel_size
        self.lstm_dim = lstm_dim
     
    def build(self, input_shape):
    
        
        self.lstm = tf.keras.layers.LSTM(self.lstm_dim,
                                        return_sequences = True)
        
        self.lstm_2 = tf.keras.layers.LSTM(int(self.lstm_dim / 2),
                                          return_sequences = True)
        
        self.lstm_3 = tf.keras.layers.LSTM(int(self.lstm_dim / 3))
        
        self.lstm_4 = tf.keras.layers.LSTM(int(self.lstm_dim / 2),
                                          return_sequences = True)
        
        self.lstm_5 = tf.keras.layers.LSTM(self.lstm_dim,
                                          return_sequences = True)
        
        self.repeat_vec = tf.keras.layers.RepeatVector(input_shape[1])
        
        self.dropout = tf.keras.layers.Dropout(0.2)
        
        output_layer = tf.keras.layers.Dense(1, activation = "relu")
        
        self.outputs = tf.keras.layers.TimeDistributed(output_layer)
    
    def call(self, input_tensor):
        
        lstm_enc = self.lstm(input_tensor)
        lstm_enc = self.lstm_2(lstm_enc)
        lstm_enc = self.lstm_3(lstm_enc)
        lstm_enc = self.dropout(lstm_enc)
        
        lstm_dec = self.repeat_vec(lstm_enc)
        
        lstm_dec = self.lstm_4(lstm_dec)
        lstm_dec = self.lstm_5(lstm_dec)
        lstm_dec = self.dropout(lstm_dec)
        
        output = self.outputs(lstm_dec)
        
        return output

# %%
Models_dangjin = TrainModel(
                     kernel_size = 200, 
                      lstm_dim = 256)

Models_dangjin_warehouse = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

Models_ulsan = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

Models_dangjin_floating = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
@tf.function()
def train_step_dangjin(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_dangjin(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_dangjin.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_dangjin_ware(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_dangjin_warehouse(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_dangjin_warehouse.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin_warehouse.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_dangjin_float(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_dangjin_floating(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_dangjin_floating.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin_floating.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_dangjin_float(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_ulsan(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_ulsan.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_ulsan.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
def val_accuracy(inp, tar, Models):
    output = Models(inp)
    
    test_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
EPOCHS = 200
batch_size = 50

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_scaled, Models_dangjin)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.0216 Accuracy 45.8588
# Epoch 1 Batch 10 Loss 0.0217 Accuracy 47.5793
# Epoch 1 Batch 15 Loss 0.0198 Accuracy 46.0120
# Epoch 1 Batch 20 Loss 0.0201 Accuracy 46.1413
# Time taken for 1 epoch: 5.89 secs
#
# WARNING:tensorflow:Layer train_model_20 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 44.0452
# Epoch 2 Batch 5 Loss 0.0203 Accuracy 46.0885
# Epoch 2 Batch 10 Loss 0.0205 Accuracy 46.5944
# Epoch 2 Batch 15 Loss 0.0199 Accuracy 46.0869
# Epoch 2 Batch 20 Loss 0.0200 Accuracy 46.1402
# Time taken for 1 epoch: 1.34 secs
#
# TestLoss 0.0000 TestAccuracy 44.0452
# Epoch 3 Batch 5 Loss 0.0201 Accuracy 46.1113
# Epoch 3 Batch 10 Loss 0.0203 Accuracy 46.4095
# Epoch 3 Batch 15 Loss 0.0199 Accuracy 46.1063
# Epoch 3 Batch 20 Loss 0.0200 Accuracy 46.1398
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 44.0452
# Epoch 4 Batch 5 Loss 0.0201 Accuracy 46.1199
# Epoch 4 Batch 10 Loss 0.0202 Accuracy 46.3314
# Epoch 4 Batch 15 Loss 0.0199 Accuracy 46.1151
# Epoch 4 Batch 20 Loss 0.0200 Accuracy 46.1396
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 44.0452
# Epoch 5 Batch 5 Loss 0.0201 Accuracy 46.1245
# Epoch 5 Batch 10 Loss 0.0202 Accuracy 46.2883
# Epoch 5 Batch 15 Loss 0.0200 Accuracy 46.1202
# Epoch 5 Batch 20 Loss 0.0200 Accuracy 46.1395
# Time taken for 1 epoch: 1.31 secs
#
# TestLoss 0.0000 TestAccuracy 44.0452
# Epoch 6 Batch 5 Loss 0.0200 Accuracy 46.1273
# Epoch 6 Batch 10 Loss 0.0201 Accuracy 46.2610
# Epoch 6 Batch 15 Loss 0.0200 Accuracy 46.1235
# Epoch 6 Batch 20 Loss 0.0200 Accuracy 46.1394
# Time taken for 1 epoch: 1.33 secs
#
# TestLoss 0.0000 TestAccuracy 44.0452
# Epoch 7 Batch 5 Loss 0.0200 Accuracy 46.1292
# Epoch 7 Batch 10 Loss 0.0201 Accuracy 46.2421
# Epoch 7 Batch 15 Loss 0.0200 Accuracy 46.1259
# Epoch 7 Batch 20 Loss 0.0200 Accuracy 46.1394
# Time taken for 1 epoch: 1.32 secs
#
# TestLoss 0.0000 TestAccuracy 44.0452
# Epoch 8 Batch 5 Loss 0.0200 Accuracy 46.1305
# Epoch 8 Batch 10 Loss 0.0201 Accuracy 46.2283
# Epoch 8 Batch 15 Loss 0.0200 Accuracy 46.1276
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-8cafef98a126> in <module>
#      20     while True:
#      21
# ---> 22         inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
#      23         tar = tf.Variable(y_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
#      24
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     259       return cls._variable_v1_call(*args, **kwargs)
#     260     elif cls is Variable:
# --> 261       return cls._variable_v2_call(*args, **kwargs)
#     262     else:
#     263       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in _variable_v2_call(cls, initial_value, trainable, validate_shape, caching_device, name, variable_def, dtype, import_scope, constraint, synchronization, aggregation, shape)
#     241     if aggregation is None:
#     242       aggregation = VariableAggregation.NONE
# --> 243     return previous_getter(
#     244         initial_value=initial_value,
#     245         trainable=trainable,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in <lambda>(**kws)
#     234                         shape=None):
#     235     """Call on Variable class. Useful to force the signature."""
# --> 236     previous_getter = lambda **kws: default_variable_creator_v2(None, **kws)
#     237     for _, getter in ops.get_default_graph()._variable_creator_stack:  # pylint: disable=protected-access
#     238       previous_getter = _make_getter(getter, previous_getter)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variable_scope.py in default_variable_creator_v2(next_creator, **kwargs)
#    2632   shape = kwargs.get("shape", None)
#    2633
# -> 2634   return resource_variable_ops.ResourceVariable(
#    2635       initial_value=initial_value,
#    2636       trainable=trainable,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\variables.py in __call__(cls, *args, **kwargs)
#     261       return cls._variable_v2_call(*args, **kwargs)
#     262     else:
# --> 263       return super(VariableMetaclass, cls).__call__(*args, **kwargs)
#     264
#     265
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in __init__(self, initial_value, trainable, collections, validate_shape, caching_device, name, dtype, variable_def, import_scope, constraint, distribute_strategy, synchronization, aggregation, shape)
#    1421       self._init_from_proto(variable_def, import_scope=import_scope)
#    1422     else:
# -> 1423       self._init_from_args(
#    1424           initial_value=initial_value,
#    1425           trainable=trainable,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in _init_from_args(self, initial_value, trainable, collections, caching_device, name, dtype, constraint, synchronization, aggregation, distribute_strategy, shape)
#    1564         with ops.get_default_graph()._attr_scope({"_class": attr}):
#    1565           with ops.name_scope("Initializer"), device_context_manager(None):
# -> 1566             initial_value = ops.convert_to_tensor(
#    1567                 initial_value() if init_from_fn else initial_value,
#    1568                 name="initial_value", dtype=dtype)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1339
#    1340     if ret is None:
# -> 1341       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1342
#    1343     if ret is NotImplemented:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in constant(value, dtype, shape, name)
#     259     ValueError: if called on a symbolic tensor.
#     260   """
# --> 261   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     262                         allow_broadcast=True)
#     263
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     268   ctx = context.context()
#     269   if ctx.executing_eagerly():
# --> 270     t = convert_to_eager_tensor(value, ctx, dtype)
#     271     if shape is None:
#     272       return t
#
# ~\anaconda3\lib\site-packages\tensorflow\python\framework\constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#      94       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#      95   ctx.ensure_initialized()
# ---> 96   return ops.EagerTensor(value, ctx.device_name, dtype)
#      97
#      98
#
# KeyboardInterrupt:

# %%
capacity = 700
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_ware_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin_ware(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_ware_scaled, Models_dangjin_warehouse)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.0169 Accuracy 38.9175
# Epoch 1 Batch 10 Loss 0.0103 Accuracy 31.8790
# Epoch 1 Batch 15 Loss 0.0080 Accuracy 28.6350
# Epoch 1 Batch 20 Loss 0.0074 Accuracy 27.2192
# Time taken for 1 epoch: 5.61 secs
#
# WARNING:tensorflow:Layer train_model_21 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 24.5941
# Epoch 2 Batch 5 Loss 0.0068 Accuracy 27.2192
# Epoch 2 Batch 10 Loss 0.0064 Accuracy 25.9711
# Epoch 2 Batch 15 Loss 0.0060 Accuracy 25.6469
# Epoch 2 Batch 20 Loss 0.0058 Accuracy 25.1716
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 20.0956
# Epoch 3 Batch 5 Loss 0.0055 Accuracy 24.5957
# Epoch 3 Batch 10 Loss 0.0053 Accuracy 24.0130
# Epoch 3 Batch 15 Loss 0.0051 Accuracy 23.4176
# Epoch 3 Batch 20 Loss 0.0050 Accuracy 23.2473
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 18.1200
# Epoch 4 Batch 5 Loss 0.0048 Accuracy 22.7292
# Epoch 4 Batch 10 Loss 0.0046 Accuracy 22.2192
# Epoch 4 Batch 15 Loss 0.0045 Accuracy 21.6355
# Epoch 4 Batch 20 Loss 0.0044 Accuracy 21.6567
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 17.2314
# Epoch 5 Batch 5 Loss 0.0043 Accuracy 21.3051
# Epoch 5 Batch 10 Loss 0.0042 Accuracy 20.9351
# Epoch 5 Batch 15 Loss 0.0041 Accuracy 20.5121
# Epoch 5 Batch 20 Loss 0.0040 Accuracy 20.5238
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 16.6566
# Epoch 6 Batch 5 Loss 0.0039 Accuracy 20.0594
# Epoch 6 Batch 10 Loss 0.0038 Accuracy 19.8516
# Epoch 6 Batch 15 Loss 0.0038 Accuracy 19.6422
# Epoch 6 Batch 20 Loss 0.0037 Accuracy 19.4713
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 16.0263
# Epoch 7 Batch 5 Loss 0.0036 Accuracy 19.1987
# Epoch 7 Batch 10 Loss 0.0036 Accuracy 19.0014
# Epoch 7 Batch 15 Loss 0.0035 Accuracy 18.8052
# Epoch 7 Batch 20 Loss 0.0034 Accuracy 18.7071
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 15.6143
# Epoch 8 Batch 5 Loss 0.0034 Accuracy 18.4798
# Epoch 8 Batch 10 Loss 0.0033 Accuracy 18.3365
# Epoch 8 Batch 15 Loss 0.0033 Accuracy 18.1905
# Epoch 8 Batch 20 Loss 0.0033 Accuracy 18.1191
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 15.2931
# Epoch 9 Batch 5 Loss 0.0032 Accuracy 17.9397
# Epoch 9 Batch 10 Loss 0.0032 Accuracy 17.8262
# Epoch 9 Batch 15 Loss 0.0031 Accuracy 17.7074
# Epoch 9 Batch 20 Loss 0.0031 Accuracy 17.6589
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 15.0434
# Epoch 10 Batch 5 Loss 0.0031 Accuracy 17.5097
# Epoch 10 Batch 10 Loss 0.0030 Accuracy 17.4185
# Epoch 10 Batch 15 Loss 0.0030 Accuracy 17.3211
# Epoch 10 Batch 20 Loss 0.0030 Accuracy 17.2856
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 14.8410
# Epoch 11 Batch 5 Loss 0.0030 Accuracy 17.1610
# Epoch 11 Batch 10 Loss 0.0029 Accuracy 17.0854
# Epoch 11 Batch 15 Loss 0.0029 Accuracy 17.0027
# Epoch 11 Batch 20 Loss 0.0029 Accuracy 16.9785
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 14.6734
# Epoch 12 Batch 5 Loss 0.0029 Accuracy 16.8716
# Epoch 12 Batch 10 Loss 0.0029 Accuracy 16.8079
# Epoch 12 Batch 15 Loss 0.0028 Accuracy 16.7374
# Epoch 12 Batch 20 Loss 0.0028 Accuracy 16.7204
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 14.5310
# Epoch 13 Batch 5 Loss 0.0028 Accuracy 16.6278
# Epoch 13 Batch 10 Loss 0.0028 Accuracy 16.5731
# Epoch 13 Batch 15 Loss 0.0028 Accuracy 16.5117
# Epoch 13 Batch 20 Loss 0.0027 Accuracy 16.5010
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 14.4067
# Epoch 14 Batch 5 Loss 0.0027 Accuracy 16.4195
# Epoch 14 Batch 10 Loss 0.0027 Accuracy 16.3719
# Epoch 14 Batch 15 Loss 0.0027 Accuracy 16.3181
# Epoch 14 Batch 20 Loss 0.0027 Accuracy 16.3115
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 14.2953
# Epoch 15 Batch 5 Loss 0.0027 Accuracy 16.2396
# Epoch 15 Batch 10 Loss 0.0027 Accuracy 16.1973
# Epoch 15 Batch 15 Loss 0.0026 Accuracy 16.1500
# Epoch 15 Batch 20 Loss 0.0026 Accuracy 16.1454
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 14.1949
# Epoch 16 Batch 5 Loss 0.0026 Accuracy 16.0805
# Epoch 16 Batch 10 Loss 0.0026 Accuracy 16.0426
# Epoch 16 Batch 15 Loss 0.0026 Accuracy 16.0005
# Epoch 16 Batch 20 Loss 0.0026 Accuracy 15.9974
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 14.1056
# Epoch 17 Batch 5 Loss 0.0026 Accuracy 15.9379
# Epoch 17 Batch 10 Loss 0.0026 Accuracy 15.9028
# Epoch 17 Batch 15 Loss 0.0025 Accuracy 15.8630
# Epoch 17 Batch 20 Loss 0.0025 Accuracy 15.8618
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 14.0173
# Epoch 18 Batch 5 Loss 0.0025 Accuracy 15.8090
# Epoch 18 Batch 10 Loss 0.0025 Accuracy 15.7751
# Epoch 18 Batch 15 Loss 0.0025 Accuracy 15.7378
# Epoch 18 Batch 20 Loss 0.0025 Accuracy 15.7405
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 13.9419
# Epoch 19 Batch 5 Loss 0.0025 Accuracy 15.6889
# Epoch 19 Batch 10 Loss 0.0025 Accuracy 15.6601
# Epoch 19 Batch 15 Loss 0.0025 Accuracy 15.6297
# Epoch 19 Batch 20 Loss 0.0025 Accuracy 15.6335
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 13.8675
# Epoch 20 Batch 5 Loss 0.0024 Accuracy 15.5912
# Epoch 20 Batch 10 Loss 0.0024 Accuracy 15.5663
# Epoch 20 Batch 15 Loss 0.0024 Accuracy 15.5384
# Epoch 20 Batch 20 Loss 0.0024 Accuracy 15.5413
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 13.7950
# Epoch 21 Batch 5 Loss 0.0024 Accuracy 15.5049
# Epoch 21 Batch 10 Loss 0.0024 Accuracy 15.4829
# Epoch 21 Batch 15 Loss 0.0024 Accuracy 15.4598
# Epoch 21 Batch 20 Loss 0.0024 Accuracy 15.4628
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 13.7359
# Epoch 22 Batch 5 Loss 0.0024 Accuracy 15.4290
# Epoch 22 Batch 10 Loss 0.0024 Accuracy 15.4078
# Epoch 22 Batch 15 Loss 0.0023 Accuracy 15.3850
# Epoch 22 Batch 20 Loss 0.0023 Accuracy 15.3909
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 13.6780
# Epoch 23 Batch 5 Loss 0.0023 Accuracy 15.3568
# Epoch 23 Batch 10 Loss 0.0023 Accuracy 15.3381
# Epoch 23 Batch 15 Loss 0.0023 Accuracy 15.3174
# Epoch 23 Batch 20 Loss 0.0023 Accuracy 15.3209
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 13.6243
# Epoch 24 Batch 5 Loss 0.0023 Accuracy 15.2898
# Epoch 24 Batch 10 Loss 0.0023 Accuracy 15.2725
# Epoch 24 Batch 15 Loss 0.0023 Accuracy 15.2523
# Epoch 24 Batch 20 Loss 0.0023 Accuracy 15.2575
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 13.5748
# Epoch 25 Batch 5 Loss 0.0023 Accuracy 15.2281
# Epoch 25 Batch 10 Loss 0.0023 Accuracy 15.2118
# Epoch 25 Batch 15 Loss 0.0023 Accuracy 15.1933
# Epoch 25 Batch 20 Loss 0.0023 Accuracy 15.1982
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 13.5307
# Epoch 26 Batch 5 Loss 0.0022 Accuracy 15.1705
# Epoch 26 Batch 10 Loss 0.0022 Accuracy 15.1555
# Epoch 26 Batch 15 Loss 0.0022 Accuracy 15.1381
# Epoch 26 Batch 20 Loss 0.0022 Accuracy 15.1435
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 13.4886
# Epoch 27 Batch 5 Loss 0.0022 Accuracy 15.1173
# Epoch 27 Batch 10 Loss 0.0022 Accuracy 15.1033
# Epoch 27 Batch 15 Loss 0.0022 Accuracy 15.0871
# Epoch 27 Batch 20 Loss 0.0022 Accuracy 15.0922
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 13.4506
# Epoch 28 Batch 5 Loss 0.0022 Accuracy 15.0675
# Epoch 28 Batch 10 Loss 0.0022 Accuracy 15.0545
# Epoch 28 Batch 15 Loss 0.0022 Accuracy 15.0392
# Epoch 28 Batch 20 Loss 0.0022 Accuracy 15.0447
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 13.4143
# Epoch 29 Batch 5 Loss 0.0022 Accuracy 15.0213
# Epoch 29 Batch 10 Loss 0.0022 Accuracy 15.0090
# Epoch 29 Batch 15 Loss 0.0022 Accuracy 14.9946
# Epoch 29 Batch 20 Loss 0.0022 Accuracy 15.0000
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 13.3816
# Epoch 30 Batch 5 Loss 0.0022 Accuracy 14.9776
# Epoch 30 Batch 10 Loss 0.0022 Accuracy 14.9663
# Epoch 30 Batch 15 Loss 0.0021 Accuracy 14.9527
# Epoch 30 Batch 20 Loss 0.0021 Accuracy 14.9583
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 13.3499
# Epoch 31 Batch 5 Loss 0.0021 Accuracy 14.9371
# Epoch 31 Batch 10 Loss 0.0021 Accuracy 14.9264
# Epoch 31 Batch 15 Loss 0.0021 Accuracy 14.9136
# Epoch 31 Batch 20 Loss 0.0021 Accuracy 14.9189
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 13.3215
# Epoch 32 Batch 5 Loss 0.0021 Accuracy 14.8986
# Epoch 32 Batch 10 Loss 0.0021 Accuracy 14.8887
# Epoch 32 Batch 15 Loss 0.0021 Accuracy 14.8766
# Epoch 32 Batch 20 Loss 0.0021 Accuracy 14.8820
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 13.2939
# Epoch 33 Batch 5 Loss 0.0021 Accuracy 14.8628
# Epoch 33 Batch 10 Loss 0.0021 Accuracy 14.8534
# Epoch 33 Batch 15 Loss 0.0021 Accuracy 14.8419
# Epoch 33 Batch 20 Loss 0.0021 Accuracy 14.8471
# Time taken for 1 epoch: 1.28 secs
#
# TestLoss 0.0000 TestAccuracy 13.2691
# Epoch 34 Batch 5 Loss 0.0021 Accuracy 14.8286
# Epoch 34 Batch 10 Loss 0.0021 Accuracy 14.8199
# Epoch 34 Batch 15 Loss 0.0021 Accuracy 14.8090
# Epoch 34 Batch 20 Loss 0.0021 Accuracy 14.8143
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 13.2450
# Epoch 35 Batch 5 Loss 0.0021 Accuracy 14.7967
# Epoch 35 Batch 10 Loss 0.0021 Accuracy 14.7883
# Epoch 35 Batch 15 Loss 0.0021 Accuracy 14.7780
# Epoch 35 Batch 20 Loss 0.0021 Accuracy 14.7830
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 13.2233
# Epoch 36 Batch 5 Loss 0.0021 Accuracy 14.7660
# Epoch 36 Batch 10 Loss 0.0021 Accuracy 14.7582
# Epoch 36 Batch 15 Loss 0.0021 Accuracy 14.7484
# Epoch 36 Batch 20 Loss 0.0020 Accuracy 14.7535
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 13.2023
# Epoch 37 Batch 5 Loss 0.0020 Accuracy 14.7372
# Epoch 37 Batch 10 Loss 0.0020 Accuracy 14.7297
# Epoch 37 Batch 15 Loss 0.0020 Accuracy 14.7202
# Epoch 37 Batch 20 Loss 0.0020 Accuracy 14.7252
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 13.1830
# Epoch 38 Batch 5 Loss 0.0020 Accuracy 14.7094
# Epoch 38 Batch 10 Loss 0.0020 Accuracy 14.7023
# Epoch 38 Batch 15 Loss 0.0020 Accuracy 14.6934
# Epoch 38 Batch 20 Loss 0.0020 Accuracy 14.6983
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 13.1642
# Epoch 39 Batch 5 Loss 0.0020 Accuracy 14.6832
# Epoch 39 Batch 10 Loss 0.0020 Accuracy 14.6764
# Epoch 39 Batch 15 Loss 0.0020 Accuracy 14.6677
# Epoch 39 Batch 20 Loss 0.0020 Accuracy 14.6725
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 13.1469
# Epoch 40 Batch 5 Loss 0.0020 Accuracy 14.6576
# Epoch 40 Batch 10 Loss 0.0020 Accuracy 14.6513
# Epoch 40 Batch 15 Loss 0.0020 Accuracy 14.6430
# Epoch 40 Batch 20 Loss 0.0020 Accuracy 14.6477
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 13.1299
# Epoch 41 Batch 5 Loss 0.0020 Accuracy 14.6337
# Epoch 41 Batch 10 Loss 0.0020 Accuracy 14.6274
# Epoch 41 Batch 15 Loss 0.0020 Accuracy 14.6196
# Epoch 41 Batch 20 Loss 0.0020 Accuracy 14.6241
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 13.1141
# Epoch 42 Batch 5 Loss 0.0020 Accuracy 14.6104
# Epoch 42 Batch 10 Loss 0.0020 Accuracy 14.6044
# Epoch 42 Batch 15 Loss 0.0020 Accuracy 14.5963
# Epoch 42 Batch 20 Loss 0.0020 Accuracy 14.6011
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 13.0986
# Epoch 43 Batch 5 Loss 0.0020 Accuracy 14.5875
# Epoch 43 Batch 10 Loss 0.0020 Accuracy 14.5824
# Epoch 43 Batch 15 Loss 0.0020 Accuracy 14.5755
# Epoch 43 Batch 20 Loss 0.0020 Accuracy 14.5798
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 13.0827
# Epoch 44 Batch 5 Loss 0.0020 Accuracy 14.5682
# Epoch 44 Batch 10 Loss 0.0020 Accuracy 14.5618
# Epoch 44 Batch 15 Loss 0.0020 Accuracy 14.5541
# Epoch 44 Batch 20 Loss 0.0020 Accuracy 14.5584
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 13.0722
# Epoch 45 Batch 5 Loss 0.0020 Accuracy 14.5452
# Epoch 45 Batch 10 Loss 0.0020 Accuracy 14.5414
# Epoch 45 Batch 15 Loss 0.0020 Accuracy 14.5350
# Epoch 45 Batch 20 Loss 0.0020 Accuracy 14.5391
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 13.0553
# Epoch 46 Batch 5 Loss 0.0020 Accuracy 14.5290
# Epoch 46 Batch 10 Loss 0.0019 Accuracy 14.5225
# Epoch 46 Batch 15 Loss 0.0019 Accuracy 14.5153
# Epoch 46 Batch 20 Loss 0.0019 Accuracy 14.5198
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 13.0470
# Epoch 47 Batch 5 Loss 0.0019 Accuracy 14.5069
# Epoch 47 Batch 10 Loss 0.0019 Accuracy 14.5015
# Epoch 47 Batch 15 Loss 0.0019 Accuracy 14.4939
# Epoch 47 Batch 20 Loss 0.0019 Accuracy 14.4995
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 13.0387
# Epoch 48 Batch 5 Loss 0.0019 Accuracy 14.4868
# Epoch 48 Batch 10 Loss 0.0019 Accuracy 14.4828
# Epoch 48 Batch 15 Loss 0.0019 Accuracy 14.4776
# Epoch 48 Batch 20 Loss 0.0019 Accuracy 14.4813
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 13.0220
# Epoch 49 Batch 5 Loss 0.0019 Accuracy 14.4719
# Epoch 49 Batch 10 Loss 0.0019 Accuracy 14.4658
# Epoch 49 Batch 15 Loss 0.0019 Accuracy 14.4585
# Epoch 49 Batch 20 Loss 0.0019 Accuracy 14.4643
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 13.0196
# Epoch 50 Batch 5 Loss 0.0019 Accuracy 14.4517
# Epoch 50 Batch 10 Loss 0.0019 Accuracy 14.4467
# Epoch 50 Batch 15 Loss 0.0019 Accuracy 14.4414
# Epoch 50 Batch 20 Loss 0.0019 Accuracy 14.4441
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 13.0074
# Epoch 51 Batch 5 Loss 0.0019 Accuracy 14.4335
# Epoch 51 Batch 10 Loss 0.0019 Accuracy 14.4327
# Epoch 51 Batch 15 Loss 0.0019 Accuracy 14.4253
# Epoch 51 Batch 20 Loss 0.0019 Accuracy 14.4321
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.9891
# Epoch 52 Batch 5 Loss 0.0019 Accuracy 14.4236
# Epoch 52 Batch 10 Loss 0.0019 Accuracy 14.4178
# Epoch 52 Batch 15 Loss 0.0019 Accuracy 14.4125
# Epoch 52 Batch 20 Loss 0.0019 Accuracy 14.4150
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.9862
# Epoch 53 Batch 5 Loss 0.0019 Accuracy 14.4044
# Epoch 53 Batch 10 Loss 0.0019 Accuracy 14.3999
# Epoch 53 Batch 15 Loss 0.0019 Accuracy 14.3939
# Epoch 53 Batch 20 Loss 0.0019 Accuracy 14.3987
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.9736
# Epoch 54 Batch 5 Loss 0.0019 Accuracy 14.3879
# Epoch 54 Batch 10 Loss 0.0019 Accuracy 14.3834
# Epoch 54 Batch 15 Loss 0.0019 Accuracy 14.3769
# Epoch 54 Batch 20 Loss 0.0019 Accuracy 14.3831
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.9706
# Epoch 55 Batch 5 Loss 0.0019 Accuracy 14.3724
# Epoch 55 Batch 10 Loss 0.0019 Accuracy 14.3686
# Epoch 55 Batch 15 Loss 0.0019 Accuracy 14.3653
# Epoch 55 Batch 20 Loss 0.0019 Accuracy 14.3667
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.9544
# Epoch 56 Batch 5 Loss 0.0019 Accuracy 14.3585
# Epoch 56 Batch 10 Loss 0.0019 Accuracy 14.3571
# Epoch 56 Batch 15 Loss 0.0019 Accuracy 14.3505
# Epoch 56 Batch 20 Loss 0.0019 Accuracy 14.3592
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.9330
# Epoch 57 Batch 5 Loss 0.0019 Accuracy 14.3521
# Epoch 57 Batch 10 Loss 0.0019 Accuracy 14.3458
# Epoch 57 Batch 15 Loss 0.0019 Accuracy 14.3403
# Epoch 57 Batch 20 Loss 0.0019 Accuracy 14.3431
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.9347
# Epoch 58 Batch 5 Loss 0.0019 Accuracy 14.3328
# Epoch 58 Batch 10 Loss 0.0019 Accuracy 14.3297
# Epoch 58 Batch 15 Loss 0.0019 Accuracy 14.3243
# Epoch 58 Batch 20 Loss 0.0019 Accuracy 14.3290
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.9221
# Epoch 59 Batch 5 Loss 0.0019 Accuracy 14.3187
# Epoch 59 Batch 10 Loss 0.0019 Accuracy 14.3139
# Epoch 59 Batch 15 Loss 0.0019 Accuracy 14.3086
# Epoch 59 Batch 20 Loss 0.0019 Accuracy 14.3132
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.9246
# Epoch 60 Batch 5 Loss 0.0019 Accuracy 14.3032
# Epoch 60 Batch 10 Loss 0.0019 Accuracy 14.2989
# Epoch 60 Batch 15 Loss 0.0018 Accuracy 14.2954
# Epoch 60 Batch 20 Loss 0.0018 Accuracy 14.2969
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.9056
# Epoch 61 Batch 5 Loss 0.0018 Accuracy 14.2880
# Epoch 61 Batch 10 Loss 0.0018 Accuracy 14.2888
# Epoch 61 Batch 15 Loss 0.0018 Accuracy 14.2786
# Epoch 61 Batch 20 Loss 0.0018 Accuracy 14.2880
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.9001
# Epoch 62 Batch 5 Loss 0.0018 Accuracy 14.2761
# Epoch 62 Batch 10 Loss 0.0018 Accuracy 14.2716
# Epoch 62 Batch 15 Loss 0.0018 Accuracy 14.2691
# Epoch 62 Batch 20 Loss 0.0018 Accuracy 14.2701
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.9024
# Epoch 63 Batch 5 Loss 0.0018 Accuracy 14.2615
# Epoch 63 Batch 10 Loss 0.0018 Accuracy 14.2576
# Epoch 63 Batch 15 Loss 0.0018 Accuracy 14.2530
# Epoch 63 Batch 20 Loss 0.0018 Accuracy 14.2562
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 12.8867
# Epoch 64 Batch 5 Loss 0.0018 Accuracy 14.2474
# Epoch 64 Batch 10 Loss 0.0018 Accuracy 14.2434
# Epoch 64 Batch 15 Loss 0.0018 Accuracy 14.2387
# Epoch 64 Batch 20 Loss 0.0018 Accuracy 14.2471
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.9007
# Epoch 65 Batch 5 Loss 0.0018 Accuracy 14.2348
# Epoch 65 Batch 10 Loss 0.0018 Accuracy 14.2304
# Epoch 65 Batch 15 Loss 0.0018 Accuracy 14.2266
# Epoch 65 Batch 20 Loss 0.0018 Accuracy 14.2243
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.8890
# Epoch 66 Batch 5 Loss 0.0018 Accuracy 14.2145
# Epoch 66 Batch 10 Loss 0.0018 Accuracy 14.2155
# Epoch 66 Batch 15 Loss 0.0018 Accuracy 14.2073
# Epoch 66 Batch 20 Loss 0.0018 Accuracy 14.2145
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.8773

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_float_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin_float(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_float_scaled, Models_dangjin_floating)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break

# %%
capacity = 500
train_max = train_max_ulsan.copy()
train_min = train_min_ulsan.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_ulsan_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_ulsan_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_ulsan(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_ulsan_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_ulsan_scaled, y_test_ulsan_scaled, Models_ulsan)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break

# %% [markdown]
# ## 3) CNN-LSTM

# %% [markdown]
# ### (1) min_max scale

# %% [markdown]
# #### - 당진

# %%
train_min_dangjin = np.min(X_train_dangjin)
train_max_dangjin = np.max(X_train_dangjin)

X_train_dangjin_scaled = (X_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

X_test_dangjin_scaled = (X_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

X_train_dangjin_scaled[:,:,5] = X_train_dangjin[:,:,5]

X_test_dangjin_scaled[:,:,5] = X_test_dangjin[:,:,5]

# %%
y_train_dangjin_scaled = (y_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_scaled = (y_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_ware_scaled = (y_train_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_ware_scaled = (y_test_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_float_scaled = (y_train_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_float_scaled = (y_test_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %% [markdown]
# #### - 울산

# %%
train_min_ulsan = np.min(X_train_ulsan)
train_max_ulsan = np.max(X_train_ulsan)

X_train_ulsan_scaled = (X_train_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

X_test_ulsan_scaled = (X_test_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

X_train_ulsan_scaled[:,:,5] = X_train_ulsan[:,:,5]

X_test_ulsan_scaled[:,:,5] = X_test_ulsan[:,:,5]

# %%
y_train_ulsan_scaled = (y_train_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

y_test_ulsan_scaled = (y_test_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

# %% [markdown]
# ### (2) 모델 구성

# %%
class TrainModel(tf.keras.Model):
    def __init__(self, 
                 kernel_size, 
                 lstm_dim):
        
        super(TrainModel, self).__init__()

        self.kernel_size = kernel_size
        self.lstm_dim = lstm_dim
     
    def build(self, input_shape):
    
        self.conv = tf.keras.layers.Dense(self.kernel_size, 
                                      activation = "relu")
        
        self.conv_2 = tf.keras.layers.Dense(self.kernel_size, 
                                      activation = "relu")
        
        self.lstm = tf.keras.layers.LSTM(self.lstm_dim,
                                        return_sequences = True)
        
        self.concat = tf.keras.layers.Add()
        
        self.dropout = tf.keras.layers.Dropout(0.2)
        
        output_layer = tf.keras.layers.Dense(1, activation = "relu")
        
        self.outputs = tf.keras.layers.TimeDistributed(output_layer)
    
    def call(self, input_tensor):
        
        
        conv_output = self.conv(input_tensor)
        conv_output = self.dropout(conv_output)
        conv_output = self.conv_2(conv_output)
        conv_output = self.dropout(conv_output)
        
        lstm_output_1 = self.lstm(conv_output)
        
        output = self.outputs(lstm_output_1)
        
        return output

# %% [markdown]
# ### (3) 모델 컴파일

# %% [markdown]
# #### - 학습 스케쥴러 정의

# %%
Models_dangjin = TrainModel(
                     kernel_size = 200, 
                      lstm_dim = 256)

Models_dangjin_warehouse = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

Models_ulsan = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

Models_dangjin_floating = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
@tf.function()
def train_step_dangjin(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_dangjin(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_dangjin.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_dangjin_floating(inp , tar):
    with tf.GradientTape() as tape:
        output = Models_dangjin_floating(inp)

        loss =  loss_function(tar, output)
 
    gradients = tape.gradient(loss, Models_dangjin_floating.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin_floating.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_dangjin_warehouse(inp , tar):
    with tf.GradientTape() as tape:
        output = Models_dangjin_warehouse(inp)

        loss =  loss_function(tar, output)
 
    gradients = tape.gradient(loss, Models_dangjin_warehouse.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin_warehouse.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_ulsan(inp , tar):
    with tf.GradientTape() as tape:
        output = Models_ulsan(inp)

        loss =  loss_function(tar, output)
 
    gradients = tape.gradient(loss, Models_ulsan.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_ulsan.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
def val_accuracy(inp, tar, Models):
    output = Models(inp)
    
    test_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
EPOCHS = 300
batch_size = 50

# %% [markdown]
# #### - dangjin

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_scaled, Models_dangjin)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.0225 Accuracy 29.1710
# Epoch 1 Batch 10 Loss 0.0175 Accuracy 32.9480
# Epoch 1 Batch 15 Loss 0.0145 Accuracy 27.1681
# Epoch 1 Batch 20 Loss 0.0127 Accuracy 25.8063
# Time taken for 1 epoch: 1.69 secs
#
# WARNING:tensorflow:Layer train_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 21.1337
# Epoch 2 Batch 5 Loss 0.0116 Accuracy 24.9597
# Epoch 2 Batch 10 Loss 0.0109 Accuracy 23.9365
# Epoch 2 Batch 15 Loss 0.0100 Accuracy 22.5892
# Epoch 2 Batch 20 Loss 0.0096 Accuracy 22.5278
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 18.3319
# Epoch 3 Batch 5 Loss 0.0091 Accuracy 21.6150
# Epoch 3 Batch 10 Loss 0.0086 Accuracy 21.1613
# Epoch 3 Batch 15 Loss 0.0082 Accuracy 20.3750
# Epoch 3 Batch 20 Loss 0.0082 Accuracy 20.7229
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 17.4027
# Epoch 4 Batch 5 Loss 0.0078 Accuracy 19.9771
# Epoch 4 Batch 10 Loss 0.0076 Accuracy 19.6993
# Epoch 4 Batch 15 Loss 0.0074 Accuracy 19.3139
# Epoch 4 Batch 20 Loss 0.0072 Accuracy 19.0959
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 16.3373
# Epoch 5 Batch 5 Loss 0.0069 Accuracy 18.7567
# Epoch 5 Batch 10 Loss 0.0068 Accuracy 18.5004
# Epoch 5 Batch 15 Loss 0.0066 Accuracy 18.1700
# Epoch 5 Batch 20 Loss 0.0065 Accuracy 18.2169
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 15.6800
# Epoch 6 Batch 5 Loss 0.0064 Accuracy 17.9611
# Epoch 6 Batch 10 Loss 0.0063 Accuracy 17.7812
# Epoch 6 Batch 15 Loss 0.0062 Accuracy 17.5601
# Epoch 6 Batch 20 Loss 0.0061 Accuracy 17.5609
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 15.2467
# Epoch 7 Batch 5 Loss 0.0060 Accuracy 17.3674
# Epoch 7 Batch 10 Loss 0.0059 Accuracy 17.2366
# Epoch 7 Batch 15 Loss 0.0058 Accuracy 17.0583
# Epoch 7 Batch 20 Loss 0.0058 Accuracy 17.0897
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 14.9204
# Epoch 8 Batch 5 Loss 0.0057 Accuracy 16.9476
# Epoch 8 Batch 10 Loss 0.0056 Accuracy 16.8493
# Epoch 8 Batch 15 Loss 0.0056 Accuracy 16.7100
# Epoch 8 Batch 20 Loss 0.0055 Accuracy 16.7448
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 14.6827
# Epoch 9 Batch 5 Loss 0.0055 Accuracy 16.6266
# Epoch 9 Batch 10 Loss 0.0054 Accuracy 16.5441
# Epoch 9 Batch 15 Loss 0.0054 Accuracy 16.4269
# Epoch 9 Batch 20 Loss 0.0053 Accuracy 16.4655
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 14.4848
# Epoch 10 Batch 5 Loss 0.0053 Accuracy 16.3740
# Epoch 10 Batch 10 Loss 0.0053 Accuracy 16.3032
# Epoch 10 Batch 15 Loss 0.0052 Accuracy 16.2023
# Epoch 10 Batch 20 Loss 0.0052 Accuracy 16.2421
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 14.3261
# Epoch 11 Batch 5 Loss 0.0051 Accuracy 16.1672
# Epoch 11 Batch 10 Loss 0.0051 Accuracy 16.1056
# Epoch 11 Batch 15 Loss 0.0051 Accuracy 16.0170
# Epoch 11 Batch 20 Loss 0.0051 Accuracy 16.0616
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 14.1957
# Epoch 12 Batch 5 Loss 0.0050 Accuracy 15.9993
# Epoch 12 Batch 10 Loss 0.0050 Accuracy 15.9451
# Epoch 12 Batch 15 Loss 0.0050 Accuracy 15.8666
# Epoch 12 Batch 20 Loss 0.0050 Accuracy 15.9090
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 14.0843
# Epoch 13 Batch 5 Loss 0.0049 Accuracy 15.8572
# Epoch 13 Batch 10 Loss 0.0049 Accuracy 15.8085
# Epoch 13 Batch 15 Loss 0.0049 Accuracy 15.7373
# Epoch 13 Batch 20 Loss 0.0049 Accuracy 15.7795
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.9896
# Epoch 14 Batch 5 Loss 0.0048 Accuracy 15.7367
# Epoch 14 Batch 10 Loss 0.0048 Accuracy 15.6925
# Epoch 14 Batch 15 Loss 0.0048 Accuracy 15.6274
# Epoch 14 Batch 20 Loss 0.0048 Accuracy 15.6692
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.9077
# Epoch 15 Batch 5 Loss 0.0048 Accuracy 15.6340
# Epoch 15 Batch 10 Loss 0.0047 Accuracy 15.5936
# Epoch 15 Batch 15 Loss 0.0047 Accuracy 15.5333
# Epoch 15 Batch 20 Loss 0.0047 Accuracy 15.5740
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 13.8376
# Epoch 16 Batch 5 Loss 0.0047 Accuracy 15.5452
# Epoch 16 Batch 10 Loss 0.0047 Accuracy 15.5075
# Epoch 16 Batch 15 Loss 0.0047 Accuracy 15.4512
# Epoch 16 Batch 20 Loss 0.0047 Accuracy 15.4901
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 13.7745
# Epoch 17 Batch 5 Loss 0.0046 Accuracy 15.4669
# Epoch 17 Batch 10 Loss 0.0046 Accuracy 15.4322
# Epoch 17 Batch 15 Loss 0.0046 Accuracy 15.3792
# Epoch 17 Batch 20 Loss 0.0046 Accuracy 15.4166
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 13.7213
# Epoch 18 Batch 5 Loss 0.0046 Accuracy 15.3985
# Epoch 18 Batch 10 Loss 0.0046 Accuracy 15.3659
# Epoch 18 Batch 15 Loss 0.0046 Accuracy 15.3158
# Epoch 18 Batch 20 Loss 0.0046 Accuracy 15.3516
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.6737
# Epoch 19 Batch 5 Loss 0.0045 Accuracy 15.3377
# Epoch 19 Batch 10 Loss 0.0045 Accuracy 15.3073
# Epoch 19 Batch 15 Loss 0.0045 Accuracy 15.2598
# Epoch 19 Batch 20 Loss 0.0045 Accuracy 15.2934
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 13.6323
# Epoch 20 Batch 5 Loss 0.0045 Accuracy 15.2833
# Epoch 20 Batch 10 Loss 0.0045 Accuracy 15.2546
# Epoch 20 Batch 15 Loss 0.0045 Accuracy 15.2098
# Epoch 20 Batch 20 Loss 0.0045 Accuracy 15.2417
# Time taken for 1 epoch: 0.60 secs
#
# TestLoss 0.0000 TestAccuracy 13.5977
# Epoch 21 Batch 5 Loss 0.0045 Accuracy 15.2341
# Epoch 21 Batch 10 Loss 0.0045 Accuracy 15.2072
# Epoch 21 Batch 15 Loss 0.0044 Accuracy 15.1647
# Epoch 21 Batch 20 Loss 0.0044 Accuracy 15.1949
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 13.5688
# Epoch 22 Batch 5 Loss 0.0044 Accuracy 15.1895
# Epoch 22 Batch 10 Loss 0.0044 Accuracy 15.1638
# Epoch 22 Batch 15 Loss 0.0044 Accuracy 15.1232
# Epoch 22 Batch 20 Loss 0.0044 Accuracy 15.1522
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5449
# Epoch 23 Batch 5 Loss 0.0044 Accuracy 15.1489
# Epoch 23 Batch 10 Loss 0.0044 Accuracy 15.1244
# Epoch 23 Batch 15 Loss 0.0044 Accuracy 15.0857
# Epoch 23 Batch 20 Loss 0.0044 Accuracy 15.1133
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5261
# Epoch 24 Batch 5 Loss 0.0044 Accuracy 15.1117
# Epoch 24 Batch 10 Loss 0.0044 Accuracy 15.0884
# Epoch 24 Batch 15 Loss 0.0044 Accuracy 15.0514
# Epoch 24 Batch 20 Loss 0.0044 Accuracy 15.0778
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5127
# Epoch 25 Batch 5 Loss 0.0044 Accuracy 15.0783
# Epoch 25 Batch 10 Loss 0.0043 Accuracy 15.0558
# Epoch 25 Batch 15 Loss 0.0043 Accuracy 15.0202
# Epoch 25 Batch 20 Loss 0.0043 Accuracy 15.0456
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5034
# Epoch 26 Batch 5 Loss 0.0043 Accuracy 15.0477
# Epoch 26 Batch 10 Loss 0.0043 Accuracy 15.0261
# Epoch 26 Batch 15 Loss 0.0043 Accuracy 14.9919
# Epoch 26 Batch 20 Loss 0.0043 Accuracy 15.0159
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.4978
# Epoch 27 Batch 5 Loss 0.0043 Accuracy 15.0198
# Epoch 27 Batch 10 Loss 0.0043 Accuracy 14.9993
# Epoch 27 Batch 15 Loss 0.0043 Accuracy 14.9666
# Epoch 27 Batch 20 Loss 0.0043 Accuracy 14.9890
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.4975
# Epoch 28 Batch 5 Loss 0.0043 Accuracy 14.9946
# Epoch 28 Batch 10 Loss 0.0043 Accuracy 14.9753
# Epoch 28 Batch 15 Loss 0.0043 Accuracy 14.9441
# Epoch 28 Batch 20 Loss 0.0043 Accuracy 14.9651
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5007
# Epoch 29 Batch 5 Loss 0.0043 Accuracy 14.9721
# Epoch 29 Batch 10 Loss 0.0043 Accuracy 14.9534
# Epoch 29 Batch 15 Loss 0.0043 Accuracy 14.9238
# Epoch 29 Batch 20 Loss 0.0043 Accuracy 14.9435
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5087
# Epoch 30 Batch 5 Loss 0.0043 Accuracy 14.9517
# Epoch 30 Batch 10 Loss 0.0043 Accuracy 14.9345
# Epoch 30 Batch 15 Loss 0.0043 Accuracy 14.9067
# Epoch 30 Batch 20 Loss 0.0043 Accuracy 14.9247
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5189
# Epoch 31 Batch 5 Loss 0.0042 Accuracy 14.9344
# Epoch 31 Batch 10 Loss 0.0042 Accuracy 14.9184
# Epoch 31 Batch 15 Loss 0.0042 Accuracy 14.8925
# Epoch 31 Batch 20 Loss 0.0042 Accuracy 14.9085
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5325
# Epoch 32 Batch 5 Loss 0.0042 Accuracy 14.9189
# Epoch 32 Batch 10 Loss 0.0042 Accuracy 14.9048
# Epoch 32 Batch 15 Loss 0.0042 Accuracy 14.8811
# Epoch 32 Batch 20 Loss 0.0042 Accuracy 14.8952
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5461
# Epoch 33 Batch 5 Loss 0.0042 Accuracy 14.9062
# Epoch 33 Batch 10 Loss 0.0042 Accuracy 14.8935
# Epoch 33 Batch 15 Loss 0.0042 Accuracy 14.8720
# Epoch 33 Batch 20 Loss 0.0042 Accuracy 14.8826
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5566
# Epoch 34 Batch 5 Loss 0.0042 Accuracy 14.8939
# Epoch 34 Batch 10 Loss 0.0042 Accuracy 14.8830
# Epoch 34 Batch 15 Loss 0.0042 Accuracy 14.8635
# Epoch 34 Batch 20 Loss 0.0042 Accuracy 14.8716
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5659
# Epoch 35 Batch 5 Loss 0.0042 Accuracy 14.8824
# Epoch 35 Batch 10 Loss 0.0042 Accuracy 14.8728
# Epoch 35 Batch 15 Loss 0.0042 Accuracy 14.8547
# Epoch 35 Batch 20 Loss 0.0042 Accuracy 14.8609
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5739
# Epoch 36 Batch 5 Loss 0.0042 Accuracy 14.8703
# Epoch 36 Batch 10 Loss 0.0042 Accuracy 14.8620
# Epoch 36 Batch 15 Loss 0.0042 Accuracy 14.8449
# Epoch 36 Batch 20 Loss 0.0042 Accuracy 14.8503
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5796
# Epoch 37 Batch 5 Loss 0.0042 Accuracy 14.8585
# Epoch 37 Batch 10 Loss 0.0042 Accuracy 14.8501
# Epoch 37 Batch 15 Loss 0.0042 Accuracy 14.8332
# Epoch 37 Batch 20 Loss 0.0042 Accuracy 14.8382
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5859
# Epoch 38 Batch 5 Loss 0.0042 Accuracy 14.8450
# Epoch 38 Batch 10 Loss 0.0042 Accuracy 14.8375
# Epoch 38 Batch 15 Loss 0.0042 Accuracy 14.8208
# Epoch 38 Batch 20 Loss 0.0042 Accuracy 14.8263
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5920
# Epoch 39 Batch 5 Loss 0.0042 Accuracy 14.8327
# Epoch 39 Batch 10 Loss 0.0042 Accuracy 14.8252
# Epoch 39 Batch 15 Loss 0.0041 Accuracy 14.8090
# Epoch 39 Batch 20 Loss 0.0041 Accuracy 14.8130
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5950
# Epoch 40 Batch 5 Loss 0.0041 Accuracy 14.8183
# Epoch 40 Batch 10 Loss 0.0041 Accuracy 14.8117
# Epoch 40 Batch 15 Loss 0.0041 Accuracy 14.7961
# Epoch 40 Batch 20 Loss 0.0041 Accuracy 14.8000
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5956
# Epoch 41 Batch 5 Loss 0.0041 Accuracy 14.8048
# Epoch 41 Batch 10 Loss 0.0041 Accuracy 14.7979
# Epoch 41 Batch 15 Loss 0.0041 Accuracy 14.7824
# Epoch 41 Batch 20 Loss 0.0041 Accuracy 14.7858
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5958
# Epoch 42 Batch 5 Loss 0.0041 Accuracy 14.7894
# Epoch 42 Batch 10 Loss 0.0041 Accuracy 14.7825
# Epoch 42 Batch 15 Loss 0.0041 Accuracy 14.7672
# Epoch 42 Batch 20 Loss 0.0041 Accuracy 14.7713
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5978
# Epoch 43 Batch 5 Loss 0.0041 Accuracy 14.7747
# Epoch 43 Batch 10 Loss 0.0041 Accuracy 14.7676
# Epoch 43 Batch 15 Loss 0.0041 Accuracy 14.7524
# Epoch 43 Batch 20 Loss 0.0041 Accuracy 14.7567
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.6013
# Epoch 44 Batch 5 Loss 0.0041 Accuracy 14.7594
# Epoch 44 Batch 10 Loss 0.0041 Accuracy 14.7524
# Epoch 44 Batch 15 Loss 0.0041 Accuracy 14.7375
# Epoch 44 Batch 20 Loss 0.0041 Accuracy 14.7423
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.6064
# Epoch 45 Batch 5 Loss 0.0041 Accuracy 14.7447
# Epoch 45 Batch 10 Loss 0.0041 Accuracy 14.7375
# Epoch 45 Batch 15 Loss 0.0041 Accuracy 14.7228
# Epoch 45 Batch 20 Loss 0.0041 Accuracy 14.7285
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.6126
# Epoch 46 Batch 5 Loss 0.0041 Accuracy 14.7302
# Epoch 46 Batch 10 Loss 0.0041 Accuracy 14.7232
# Epoch 46 Batch 15 Loss 0.0041 Accuracy 14.7090
# Epoch 46 Batch 20 Loss 0.0041 Accuracy 14.7150
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.6166
# Epoch 47 Batch 5 Loss 0.0041 Accuracy 14.7158
# Epoch 47 Batch 10 Loss 0.0041 Accuracy 14.7090
# Epoch 47 Batch 15 Loss 0.0041 Accuracy 14.6952
# Epoch 47 Batch 20 Loss 0.0040 Accuracy 14.7011
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.6157
# Epoch 48 Batch 5 Loss 0.0040 Accuracy 14.7016
# Epoch 48 Batch 10 Loss 0.0040 Accuracy 14.6960
# Epoch 48 Batch 15 Loss 0.0040 Accuracy 14.6829
# Epoch 48 Batch 20 Loss 0.0040 Accuracy 14.6909
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 13.6060
# Epoch 49 Batch 5 Loss 0.0040 Accuracy 14.6899
# Epoch 49 Batch 10 Loss 0.0040 Accuracy 14.6828
# Epoch 49 Batch 15 Loss 0.0040 Accuracy 14.6704
# Epoch 49 Batch 20 Loss 0.0040 Accuracy 14.6781
# Time taken for 1 epoch: 0.58 secs
#
# TestLoss 0.0000 TestAccuracy 13.5944
# Epoch 50 Batch 5 Loss 0.0040 Accuracy 14.6780
# Epoch 50 Batch 10 Loss 0.0040 Accuracy 14.6699
# Epoch 50 Batch 15 Loss 0.0040 Accuracy 14.6567
# Epoch 50 Batch 20 Loss 0.0040 Accuracy 14.6644
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5862
# Epoch 51 Batch 5 Loss 0.0040 Accuracy 14.6643
# Epoch 51 Batch 10 Loss 0.0040 Accuracy 14.6567
# Epoch 51 Batch 15 Loss 0.0040 Accuracy 14.6438
# Epoch 51 Batch 20 Loss 0.0040 Accuracy 14.6515
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5806
# Epoch 52 Batch 5 Loss 0.0040 Accuracy 14.6502
# Epoch 52 Batch 10 Loss 0.0040 Accuracy 14.6433
# Epoch 52 Batch 15 Loss 0.0040 Accuracy 14.6312
# Epoch 52 Batch 20 Loss 0.0040 Accuracy 14.6377
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5712
# Epoch 53 Batch 5 Loss 0.0040 Accuracy 14.6356
# Epoch 53 Batch 10 Loss 0.0040 Accuracy 14.6275
# Epoch 53 Batch 15 Loss 0.0040 Accuracy 14.6152
# Epoch 53 Batch 20 Loss 0.0040 Accuracy 14.6223
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5648
# Epoch 54 Batch 5 Loss 0.0040 Accuracy 14.6197
# Epoch 54 Batch 10 Loss 0.0040 Accuracy 14.6119
# Epoch 54 Batch 15 Loss 0.0040 Accuracy 14.6000
# Epoch 54 Batch 20 Loss 0.0040 Accuracy 14.6072
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5589
# Epoch 55 Batch 5 Loss 0.0040 Accuracy 14.6043
# Epoch 55 Batch 10 Loss 0.0039 Accuracy 14.5966
# Epoch 55 Batch 15 Loss 0.0039 Accuracy 14.5854
# Epoch 55 Batch 20 Loss 0.0039 Accuracy 14.5916
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5487
# Epoch 56 Batch 5 Loss 0.0039 Accuracy 14.5885
# Epoch 56 Batch 10 Loss 0.0039 Accuracy 14.5805
# Epoch 56 Batch 15 Loss 0.0039 Accuracy 14.5699
# Epoch 56 Batch 20 Loss 0.0039 Accuracy 14.5752
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5387
# Epoch 57 Batch 5 Loss 0.0039 Accuracy 14.5719
# Epoch 57 Batch 10 Loss 0.0039 Accuracy 14.5639
# Epoch 57 Batch 15 Loss 0.0039 Accuracy 14.5536
# Epoch 57 Batch 20 Loss 0.0039 Accuracy 14.5586
# Time taken for 1 epoch: 0.56 secs
#
# TestLoss 0.0000 TestAccuracy 13.5301
# Epoch 58 Batch 5 Loss 0.0039 Accuracy 14.5549
# Epoch 58 Batch 10 Loss 0.0039 Accuracy 14.5471
# Epoch 58 Batch 15 Loss 0.0039 Accuracy 14.5371
# Epoch 58 Batch 20 Loss 0.0039 Accuracy 14.5422
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5223
# Epoch 59 Batch 5 Loss 0.0039 Accuracy 14.5378
# Epoch 59 Batch 10 Loss 0.0039 Accuracy 14.5302
# Epoch 59 Batch 15 Loss 0.0039 Accuracy 14.5204
# Epoch 59 Batch 20 Loss 0.0039 Accuracy 14.5255
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5135
# Epoch 60 Batch 5 Loss 0.0039 Accuracy 14.5205
# Epoch 60 Batch 10 Loss 0.0039 Accuracy 14.5130
# Epoch 60 Batch 15 Loss 0.0039 Accuracy 14.5035
# Epoch 60 Batch 20 Loss 0.0039 Accuracy 14.5081
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5039
# Epoch 61 Batch 5 Loss 0.0039 Accuracy 14.5029
# Epoch 61 Batch 10 Loss 0.0039 Accuracy 14.4955
# Epoch 61 Batch 15 Loss 0.0039 Accuracy 14.4863
# Epoch 61 Batch 20 Loss 0.0039 Accuracy 14.4906
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.4945
# Epoch 62 Batch 5 Loss 0.0039 Accuracy 14.4850
# Epoch 62 Batch 10 Loss 0.0039 Accuracy 14.4777
# Epoch 62 Batch 15 Loss 0.0039 Accuracy 14.4688
# Epoch 62 Batch 20 Loss 0.0039 Accuracy 14.4729
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.4847
# Epoch 63 Batch 5 Loss 0.0038 Accuracy 14.4668
# Epoch 63 Batch 10 Loss 0.0038 Accuracy 14.4596
# Epoch 63 Batch 15 Loss 0.0038 Accuracy 14.4509
# Epoch 63 Batch 20 Loss 0.0038 Accuracy 14.4548
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.4748
# Epoch 64 Batch 5 Loss 0.0038 Accuracy 14.4483
# Epoch 64 Batch 10 Loss 0.0038 Accuracy 14.4412
# Epoch 64 Batch 15 Loss 0.0038 Accuracy 14.4327
# Epoch 64 Batch 20 Loss 0.0038 Accuracy 14.4362
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.4643
# Epoch 65 Batch 5 Loss 0.0038 Accuracy 14.4295
# Epoch 65 Batch 10 Loss 0.0038 Accuracy 14.4225
# Epoch 65 Batch 15 Loss 0.0038 Accuracy 14.4142
# Epoch 65 Batch 20 Loss 0.0038 Accuracy 14.4167
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.4525
# Epoch 66 Batch 5 Loss 0.0038 Accuracy 14.4096
# Epoch 66 Batch 10 Loss 0.0038 Accuracy 14.4030
# Epoch 66 Batch 15 Loss 0.0038 Accuracy 14.3942
# Epoch 66 Batch 20 Loss 0.0038 Accuracy 14.3970
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.4361
# Epoch 67 Batch 5 Loss 0.0038 Accuracy 14.3895
# Epoch 67 Batch 10 Loss 0.0038 Accuracy 14.3825
# Epoch 67 Batch 15 Loss 0.0038 Accuracy 14.3738
# Epoch 67 Batch 20 Loss 0.0038 Accuracy 14.3771
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.4258
# Epoch 68 Batch 5 Loss 0.0038 Accuracy 14.3696
# Epoch 68 Batch 10 Loss 0.0038 Accuracy 14.3629
# Epoch 68 Batch 15 Loss 0.0038 Accuracy 14.3538
# Epoch 68 Batch 20 Loss 0.0038 Accuracy 14.3576
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.4155
# Epoch 69 Batch 5 Loss 0.0038 Accuracy 14.3502
# Epoch 69 Batch 10 Loss 0.0038 Accuracy 14.3436
# Epoch 69 Batch 15 Loss 0.0038 Accuracy 14.3352
# Epoch 69 Batch 20 Loss 0.0038 Accuracy 14.3384
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.4023
# Epoch 70 Batch 5 Loss 0.0038 Accuracy 14.3311
# Epoch 70 Batch 10 Loss 0.0038 Accuracy 14.3244
# Epoch 70 Batch 15 Loss 0.0038 Accuracy 14.3167
# Epoch 70 Batch 20 Loss 0.0038 Accuracy 14.3189
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.3892
# Epoch 71 Batch 5 Loss 0.0037 Accuracy 14.3116
# Epoch 71 Batch 10 Loss 0.0037 Accuracy 14.3049
# Epoch 71 Batch 15 Loss 0.0037 Accuracy 14.2974
# Epoch 71 Batch 20 Loss 0.0037 Accuracy 14.2991
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.3774
# Epoch 72 Batch 5 Loss 0.0037 Accuracy 14.2919
# Epoch 72 Batch 10 Loss 0.0037 Accuracy 14.2853
# Epoch 72 Batch 15 Loss 0.0037 Accuracy 14.2779
# Epoch 72 Batch 20 Loss 0.0037 Accuracy 14.2797
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.3663
# Epoch 73 Batch 5 Loss 0.0037 Accuracy 14.2723
# Epoch 73 Batch 10 Loss 0.0037 Accuracy 14.2659
# Epoch 73 Batch 15 Loss 0.0037 Accuracy 14.2586
# Epoch 73 Batch 20 Loss 0.0037 Accuracy 14.2601
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.3545
# Epoch 74 Batch 5 Loss 0.0037 Accuracy 14.2527
# Epoch 74 Batch 10 Loss 0.0037 Accuracy 14.2465
# Epoch 74 Batch 15 Loss 0.0037 Accuracy 14.2395
# Epoch 74 Batch 20 Loss 0.0037 Accuracy 14.2408
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.3425
# Epoch 75 Batch 5 Loss 0.0037 Accuracy 14.2332
# Epoch 75 Batch 10 Loss 0.0037 Accuracy 14.2270
# Epoch 75 Batch 15 Loss 0.0037 Accuracy 14.2202
# Epoch 75 Batch 20 Loss 0.0037 Accuracy 14.2212
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.3299
# Epoch 76 Batch 5 Loss 0.0037 Accuracy 14.2136
# Epoch 76 Batch 10 Loss 0.0037 Accuracy 14.2074
# Epoch 76 Batch 15 Loss 0.0037 Accuracy 14.2009
# Epoch 76 Batch 20 Loss 0.0037 Accuracy 14.2015
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.3175
# Epoch 77 Batch 5 Loss 0.0037 Accuracy 14.1938
# Epoch 77 Batch 10 Loss 0.0037 Accuracy 14.1878
# Epoch 77 Batch 15 Loss 0.0037 Accuracy 14.1814
# Epoch 77 Batch 20 Loss 0.0037 Accuracy 14.1819
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.3045
# Epoch 78 Batch 5 Loss 0.0037 Accuracy 14.1740
# Epoch 78 Batch 10 Loss 0.0037 Accuracy 14.1681
# Epoch 78 Batch 15 Loss 0.0037 Accuracy 14.1620
# Epoch 78 Batch 20 Loss 0.0037 Accuracy 14.1621
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.2914
# Epoch 79 Batch 5 Loss 0.0037 Accuracy 14.1543
# Epoch 79 Batch 10 Loss 0.0036 Accuracy 14.1484
# Epoch 79 Batch 15 Loss 0.0036 Accuracy 14.1423
# Epoch 79 Batch 20 Loss 0.0036 Accuracy 14.1423
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2775
# Epoch 80 Batch 5 Loss 0.0036 Accuracy 14.1344
# Epoch 80 Batch 10 Loss 0.0036 Accuracy 14.1287
# Epoch 80 Batch 15 Loss 0.0036 Accuracy 14.1228
# Epoch 80 Batch 20 Loss 0.0036 Accuracy 14.1225
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2637
# Epoch 81 Batch 5 Loss 0.0036 Accuracy 14.1146
# Epoch 81 Batch 10 Loss 0.0036 Accuracy 14.1089
# Epoch 81 Batch 15 Loss 0.0036 Accuracy 14.1032
# Epoch 81 Batch 20 Loss 0.0036 Accuracy 14.1028
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2490
# Epoch 82 Batch 5 Loss 0.0036 Accuracy 14.0949
# Epoch 82 Batch 10 Loss 0.0036 Accuracy 14.0893
# Epoch 82 Batch 15 Loss 0.0036 Accuracy 14.0836
# Epoch 82 Batch 20 Loss 0.0036 Accuracy 14.0830
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.2348
# Epoch 83 Batch 5 Loss 0.0036 Accuracy 14.0750
# Epoch 83 Batch 10 Loss 0.0036 Accuracy 14.0695
# Epoch 83 Batch 15 Loss 0.0036 Accuracy 14.0640
# Epoch 83 Batch 20 Loss 0.0036 Accuracy 14.0633
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2198
# Epoch 84 Batch 5 Loss 0.0036 Accuracy 14.0554
# Epoch 84 Batch 10 Loss 0.0036 Accuracy 14.0499
# Epoch 84 Batch 15 Loss 0.0036 Accuracy 14.0445
# Epoch 84 Batch 20 Loss 0.0036 Accuracy 14.0435
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2046
# Epoch 85 Batch 5 Loss 0.0036 Accuracy 14.0357
# Epoch 85 Batch 10 Loss 0.0036 Accuracy 14.0303
# Epoch 85 Batch 15 Loss 0.0036 Accuracy 14.0251
# Epoch 85 Batch 20 Loss 0.0036 Accuracy 14.0240
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.1884
# Epoch 86 Batch 5 Loss 0.0036 Accuracy 14.0161
# Epoch 86 Batch 10 Loss 0.0036 Accuracy 14.0108
# Epoch 86 Batch 15 Loss 0.0036 Accuracy 14.0055
# Epoch 86 Batch 20 Loss 0.0036 Accuracy 14.0041
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.5282
# Epoch 120 Batch 5 Loss 0.0032 Accuracy 13.4109
# Epoch 120 Batch 10 Loss 0.0032 Accuracy 13.4063
# Epoch 120 Batch 15 Loss 0.0032 Accuracy 13.4023
# Epoch 120 Batch 20 Loss 0.0032 Accuracy 13.3992
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.5112
# Epoch 121 Batch 5 Loss 0.0032 Accuracy 13.3946
# Epoch 121 Batch 10 Loss 0.0032 Accuracy 13.3900
# Epoch 121 Batch 15 Loss 0.0032 Accuracy 13.3858
# Epoch 121 Batch 20 Loss 0.0032 Accuracy 13.3826
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.4947
# Epoch 122 Batch 5 Loss 0.0032 Accuracy 13.3780
# Epoch 122 Batch 10 Loss 0.0032 Accuracy 13.3735
# Epoch 122 Batch 15 Loss 0.0032 Accuracy 13.3692
# Epoch 122 Batch 20 Loss 0.0032 Accuracy 13.3661
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.4785
# Epoch 123 Batch 5 Loss 0.0032 Accuracy 13.3615
# Epoch 123 Batch 10 Loss 0.0032 Accuracy 13.3571
# Epoch 123 Batch 15 Loss 0.0032 Accuracy 13.3528
# Epoch 123 Batch 20 Loss 0.0032 Accuracy 13.3496
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 12.4627
# Epoch 124 Batch 5 Loss 0.0032 Accuracy 13.3451
# Epoch 124 Batch 10 Loss 0.0032 Accuracy 13.3407
# Epoch 124 Batch 15 Loss 0.0032 Accuracy 13.3364
# Epoch 124 Batch 20 Loss 0.0032 Accuracy 13.3332
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.4475
# Epoch 125 Batch 5 Loss 0.0032 Accuracy 13.3288
# Epoch 125 Batch 10 Loss 0.0032 Accuracy 13.3244
# Epoch 125 Batch 15 Loss 0.0032 Accuracy 13.3199
# Epoch 125 Batch 20 Loss 0.0032 Accuracy 13.3168
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.4327
# Epoch 126 Batch 5 Loss 0.0032 Accuracy 13.3123
# Epoch 126 Batch 10 Loss 0.0032 Accuracy 13.3081
# Epoch 126 Batch 15 Loss 0.0032 Accuracy 13.3036
# Epoch 126 Batch 20 Loss 0.0032 Accuracy 13.3005
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.4181
# Epoch 127 Batch 5 Loss 0.0032 Accuracy 13.2961
# Epoch 127 Batch 10 Loss 0.0032 Accuracy 13.2919
# Epoch 127 Batch 15 Loss 0.0032 Accuracy 13.2874
# Epoch 127 Batch 20 Loss 0.0032 Accuracy 13.2842
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.4037
# Epoch 128 Batch 5 Loss 0.0032 Accuracy 13.2799
# Epoch 128 Batch 10 Loss 0.0032 Accuracy 13.2758
# Epoch 128 Batch 15 Loss 0.0032 Accuracy 13.2713
# Epoch 128 Batch 20 Loss 0.0032 Accuracy 13.2681
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.3895
# Epoch 129 Batch 5 Loss 0.0032 Accuracy 13.2639
# Epoch 129 Batch 10 Loss 0.0032 Accuracy 13.2598
# Epoch 129 Batch 15 Loss 0.0032 Accuracy 13.2552
# Epoch 129 Batch 20 Loss 0.0032 Accuracy 13.2521
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.3756
# Epoch 130 Batch 5 Loss 0.0032 Accuracy 13.2479
# Epoch 130 Batch 10 Loss 0.0032 Accuracy 13.2438
# Epoch 130 Batch 15 Loss 0.0032 Accuracy 13.2393
# Epoch 130 Batch 20 Loss 0.0032 Accuracy 13.2362
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.0105
# Epoch 163 Batch 5 Loss 0.0029 Accuracy 12.7932
# Epoch 163 Batch 10 Loss 0.0029 Accuracy 12.7906
# Epoch 163 Batch 15 Loss 0.0029 Accuracy 12.7868
# Epoch 163 Batch 20 Loss 0.0029 Accuracy 12.7845
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.0028
# Epoch 164 Batch 5 Loss 0.0029 Accuracy 12.7816
# Epoch 164 Batch 10 Loss 0.0029 Accuracy 12.7790
# Epoch 164 Batch 15 Loss 0.0029 Accuracy 12.7752
# Epoch 164 Batch 20 Loss 0.0029 Accuracy 12.7729
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.9950
# Epoch 165 Batch 5 Loss 0.0029 Accuracy 12.7701
# Epoch 165 Batch 10 Loss 0.0029 Accuracy 12.7674
# Epoch 165 Batch 15 Loss 0.0029 Accuracy 12.7637
# Epoch 165 Batch 20 Loss 0.0029 Accuracy 12.7614
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.9871
# Epoch 166 Batch 5 Loss 0.0029 Accuracy 12.7585
# Epoch 166 Batch 10 Loss 0.0029 Accuracy 12.7559
# Epoch 166 Batch 15 Loss 0.0029 Accuracy 12.7522
# Epoch 166 Batch 20 Loss 0.0029 Accuracy 12.7499
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.9789
# Epoch 167 Batch 5 Loss 0.0029 Accuracy 12.7471
# Epoch 167 Batch 10 Loss 0.0029 Accuracy 12.7444
# Epoch 167 Batch 15 Loss 0.0029 Accuracy 12.7408
# Epoch 167 Batch 20 Loss 0.0029 Accuracy 12.7384
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.9707
# Epoch 168 Batch 5 Loss 0.0029 Accuracy 12.7357
# Epoch 168 Batch 10 Loss 0.0029 Accuracy 12.7330
# Epoch 168 Batch 15 Loss 0.0029 Accuracy 12.7294
# Epoch 168 Batch 20 Loss 0.0029 Accuracy 12.7271
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9625
# Epoch 169 Batch 5 Loss 0.0029 Accuracy 12.7244
# Epoch 169 Batch 10 Loss 0.0029 Accuracy 12.7217
# Epoch 169 Batch 15 Loss 0.0029 Accuracy 12.7181
# Epoch 169 Batch 20 Loss 0.0029 Accuracy 12.7159
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9544
# Epoch 170 Batch 5 Loss 0.0029 Accuracy 12.7132
# Epoch 170 Batch 10 Loss 0.0029 Accuracy 12.7106
# Epoch 170 Batch 15 Loss 0.0029 Accuracy 12.7070
# Epoch 170 Batch 20 Loss 0.0029 Accuracy 12.7048
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.9463
# Epoch 171 Batch 5 Loss 0.0029 Accuracy 12.7021
# Epoch 171 Batch 10 Loss 0.0029 Accuracy 12.6995
# Epoch 171 Batch 15 Loss 0.0029 Accuracy 12.6960
# Epoch 171 Batch 20 Loss 0.0029 Accuracy 12.6938
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.9384
# Epoch 172 Batch 5 Loss 0.0029 Accuracy 12.6912
# Epoch 172 Batch 10 Loss 0.0029 Accuracy 12.6885
# Epoch 172 Batch 15 Loss 0.0029 Accuracy 12.6850
# Epoch 172 Batch 20 Loss 0.0029 Accuracy 12.6828
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9304
# Epoch 173 Batch 5 Loss 0.0029 Accuracy 12.6803
# Epoch 173 Batch 10 Loss 0.0029 Accuracy 12.6776
# Epoch 173 Batch 15 Loss 0.0029 Accuracy 12.6741
# Epoch 173 Batch 20 Loss 0.0029 Accuracy 12.6720
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9224
# Epoch 174 Batch 5 Loss 0.0029 Accuracy 12.6695
# Epoch 174 Batch 10 Loss 0.0029 Accuracy 12.6669
# Epoch 174 Batch 15 Loss 0.0029 Accuracy 12.6634
# Epoch 174 Batch 20 Loss 0.0029 Accuracy 12.6613
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9144
# Epoch 175 Batch 5 Loss 0.0029 Accuracy 12.6588
# Epoch 175 Batch 10 Loss 0.0029 Accuracy 12.6562
# Epoch 175 Batch 15 Loss 0.0029 Accuracy 12.6528
# Epoch 175 Batch 20 Loss 0.0029 Accuracy 12.6507
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9064
# Epoch 176 Batch 5 Loss 0.0029 Accuracy 12.6483
# Epoch 176 Batch 10 Loss 0.0029 Accuracy 12.6457
# Epoch 176 Batch 15 Loss 0.0029 Accuracy 12.6422
# Epoch 176 Batch 20 Loss 0.0029 Accuracy 12.6403
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8985
# Epoch 177 Batch 5 Loss 0.0029 Accuracy 12.6378
# Epoch 177 Batch 10 Loss 0.0029 Accuracy 12.6353
# Epoch 177 Batch 15 Loss 0.0029 Accuracy 12.6318
# Epoch 177 Batch 20 Loss 0.0029 Accuracy 12.6298
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.8906
# Epoch 178 Batch 5 Loss 0.0029 Accuracy 12.6274
# Epoch 178 Batch 10 Loss 0.0029 Accuracy 12.6249
# Epoch 178 Batch 15 Loss 0.0029 Accuracy 12.6215
# Epoch 178 Batch 20 Loss 0.0029 Accuracy 12.6194
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8825
# Epoch 179 Batch 5 Loss 0.0029 Accuracy 12.6174
# Epoch 179 Batch 10 Loss 0.0029 Accuracy 12.6151
# Epoch 179 Batch 15 Loss 0.0028 Accuracy 12.6115
# Epoch 179 Batch 20 Loss 0.0028 Accuracy 12.6099
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8760
# Epoch 180 Batch 5 Loss 0.0028 Accuracy 12.6077
# Epoch 180 Batch 10 Loss 0.0028 Accuracy 12.6055
# Epoch 180 Batch 15 Loss 0.0028 Accuracy 12.6021
# Epoch 180 Batch 20 Loss 0.0028 Accuracy 12.6005
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8695
# Epoch 181 Batch 5 Loss 0.0028 Accuracy 12.5980
# Epoch 181 Batch 10 Loss 0.0028 Accuracy 12.5957
# Epoch 181 Batch 15 Loss 0.0028 Accuracy 12.5924
# Epoch 181 Batch 20 Loss 0.0028 Accuracy 12.5907
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8628
# Epoch 182 Batch 5 Loss 0.0028 Accuracy 12.5882
# Epoch 182 Batch 10 Loss 0.0028 Accuracy 12.5859
# ...
# Epoch 240 Batch 10 Loss 0.0026 Accuracy 12.1416
# Epoch 240 Batch 15 Loss 0.0026 Accuracy 12.1397
# Epoch 240 Batch 20 Loss 0.0026 Accuracy 12.1389
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5346
# Epoch 241 Batch 5 Loss 0.0026 Accuracy 12.1384
# Epoch 241 Batch 10 Loss 0.0026 Accuracy 12.1373
# Epoch 241 Batch 15 Loss 0.0026 Accuracy 12.1355
# Epoch 241 Batch 20 Loss 0.0026 Accuracy 12.1342
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5360
# Epoch 242 Batch 5 Loss 0.0026 Accuracy 12.1336
# Epoch 242 Batch 10 Loss 0.0026 Accuracy 12.1321
# Epoch 242 Batch 15 Loss 0.0026 Accuracy 12.1299
# Epoch 242 Batch 20 Loss 0.0026 Accuracy 12.1300
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4937
# Epoch 254 Batch 5 Loss 0.0026 Accuracy 12.0624
# Epoch 254 Batch 10 Loss 0.0026 Accuracy 12.0608
# Epoch 254 Batch 15 Loss 0.0026 Accuracy 12.0585
# Epoch 254 Batch 20 Loss 0.0026 Accuracy 12.0575
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4907
# Epoch 255 Batch 5 Loss 0.0026 Accuracy 12.0561
# Epoch 255 Batch 10 Loss 0.0026 Accuracy 12.0546
# Epoch 255 Batch 15 Loss 0.0026 Accuracy 12.0522
# Epoch 255 Batch 20 Loss 0.0026 Accuracy 12.0517
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4877
# Epoch 256 Batch 5 Loss 0.0026 Accuracy 12.0502
# Epoch 256 Batch 10 Loss 0.0026 Accuracy 12.0487
# Epoch 256 Batch 15 Loss 0.0026 Accuracy 12.0464
# Epoch 256 Batch 20 Loss 0.0026 Accuracy 12.0460
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4843
# Epoch 257 Batch 5 Loss 0.0026 Accuracy 12.0444
# Epoch 257 Batch 10 Loss 0.0026 Accuracy 12.0429
# Epoch 257 Batch 15 Loss 0.0026 Accuracy 12.0406
# Epoch 257 Batch 20 Loss 0.0026 Accuracy 12.0398
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4810
# Epoch 258 Batch 5 Loss 0.0026 Accuracy 12.0383
# Epoch 258 Batch 10 Loss 0.0026 Accuracy 12.0368
# Epoch 258 Batch 15 Loss 0.0026 Accuracy 12.0344
# Epoch 258 Batch 20 Loss 0.0026 Accuracy 12.0337
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4781
# Epoch 259 Batch 5 Loss 0.0026 Accuracy 12.0322
# Epoch 259 Batch 10 Loss 0.0026 Accuracy 12.0307
# Epoch 259 Batch 15 Loss 0.0026 Accuracy 12.0284
# Epoch 259 Batch 20 Loss 0.0026 Accuracy 12.0277
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4753
# Epoch 260 Batch 5 Loss 0.0026 Accuracy 12.0263
# Epoch 260 Batch 10 Loss 0.0026 Accuracy 12.0248
# Epoch 260 Batch 15 Loss 0.0026 Accuracy 12.0226
# Epoch 260 Batch 20 Loss 0.0026 Accuracy 12.0221
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4724
# Epoch 261 Batch 5 Loss 0.0026 Accuracy 12.0206
# Epoch 261 Batch 10 Loss 0.0026 Accuracy 12.0192
# Epoch 261 Batch 15 Loss 0.0026 Accuracy 12.0168
# Epoch 261 Batch 20 Loss 0.0026 Accuracy 12.0164
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4696
# Epoch 262 Batch 5 Loss 0.0026 Accuracy 12.0150
# Epoch 262 Batch 10 Loss 0.0026 Accuracy 12.0136
# Epoch 262 Batch 15 Loss 0.0026 Accuracy 12.0114
# Epoch 262 Batch 20 Loss 0.0026 Accuracy 12.0108
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4666
# Epoch 263 Batch 5 Loss 0.0026 Accuracy 12.0095
# Epoch 263 Batch 10 Loss 0.0026 Accuracy 12.0082
# Epoch 263 Batch 15 Loss 0.0026 Accuracy 12.0059
# Epoch 263 Batch 20 Loss 0.0026 Accuracy 12.0055
# Time taken for 1 epoch: 0.56 secs
#
# TestLoss 0.0000 TestAccuracy 11.4633
# Epoch 264 Batch 5 Loss 0.0026 Accuracy 12.0044
# Epoch 264 Batch 10 Loss 0.0026 Accuracy 12.0031
# Epoch 264 Batch 15 Loss 0.0025 Accuracy 12.0009
# Epoch 264 Batch 20 Loss 0.0025 Accuracy 12.0009
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4607
# Epoch 265 Batch 5 Loss 0.0025 Accuracy 11.9994
# Epoch 265 Batch 10 Loss 0.0025 Accuracy 11.9983
# Epoch 265 Batch 15 Loss 0.0025 Accuracy 11.9961
# Epoch 265 Batch 20 Loss 0.0025 Accuracy 11.9959
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4569
# Epoch 266 Batch 5 Loss 0.0025 Accuracy 11.9952
# Epoch 266 Batch 10 Loss 0.0025 Accuracy 11.9939
# Epoch 266 Batch 15 Loss 0.0025 Accuracy 11.9917
# Epoch 266 Batch 20 Loss 0.0025 Accuracy 11.9924
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4567
# Epoch 267 Batch 5 Loss 0.0025 Accuracy 11.9910
# Epoch 267 Batch 10 Loss 0.0025 Accuracy 11.9900
# Epoch 267 Batch 15 Loss 0.0025 Accuracy 11.9880
# Epoch 267 Batch 20 Loss 0.0025 Accuracy 11.9883
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4527
# Epoch 268 Batch 5 Loss 0.0025 Accuracy 11.9872
# Epoch 268 Batch 10 Loss 0.0025 Accuracy 11.9857
# Epoch 268 Batch 15 Loss 0.0025 Accuracy 11.9835
# Epoch 268 Batch 20 Loss 0.0025 Accuracy 11.9836
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4517
# Epoch 269 Batch 5 Loss 0.0025 Accuracy 11.9827
# Epoch 269 Batch 10 Loss 0.0025 Accuracy 11.9815
# Epoch 269 Batch 15 Loss 0.0025 Accuracy 11.9792
# Epoch 269 Batch 20 Loss 0.0025 Accuracy 11.9803
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4523
# Epoch 270 Batch 5 Loss 0.0025 Accuracy 11.9791
# Epoch 270 Batch 10 Loss 0.0025 Accuracy 11.9782
# Epoch 270 Batch 15 Loss 0.0025 Accuracy 11.9759
# Epoch 270 Batch 20 Loss 0.0025 Accuracy 11.9774
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4535
# Epoch 271 Batch 5 Loss 0.0025 Accuracy 11.9765
# Epoch 271 Batch 10 Loss 0.0025 Accuracy 11.9754
# Epoch 271 Batch 15 Loss 0.0025 Accuracy 11.9732
# Epoch 271 Batch 20 Loss 0.0025 Accuracy 11.9739
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4501
# Epoch 272 Batch 5 Loss 0.0025 Accuracy 11.9730
# Epoch 272 Batch 10 Loss 0.0025 Accuracy 11.9718
# Epoch 272 Batch 15 Loss 0.0025 Accuracy 11.9697
# Epoch 272 Batch 20 Loss 0.0025 Accuracy 11.9701
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4479
# Epoch 273 Batch 5 Loss 0.0025 Accuracy 11.9686
# Epoch 273 Batch 10 Loss 0.0025 Accuracy 11.9675
# Epoch 273 Batch 15 Loss 0.0025 Accuracy 11.9653
# Epoch 273 Batch 20 Loss 0.0025 Accuracy 11.9666
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4494
# Epoch 274 Batch 5 Loss 0.0025 Accuracy 11.9655
# Epoch 274 Batch 10 Loss 0.0025 Accuracy 11.9645
# Epoch 274 Batch 15 Loss 0.0025 Accuracy 11.9623
# Epoch 274 Batch 20 Loss 0.0025 Accuracy 11.9633
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4517
# Epoch 275 Batch 5 Loss 0.0025 Accuracy 11.9625
# Epoch 275 Batch 10 Loss 0.0025 Accuracy 11.9617
# Epoch 275 Batch 15 Loss 0.0025 Accuracy 11.9594
# Epoch 275 Batch 20 Loss 0.0025 Accuracy 11.9609
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4607
# Epoch 276 Batch 5 Loss 0.0025 Accuracy 11.9606
# Epoch 276 Batch 10 Loss 0.0025 Accuracy 11.9598
# Epoch 276 Batch 15 Loss 0.0025 Accuracy 11.9579
# Epoch 276 Batch 20 Loss 0.0025 Accuracy 11.9608
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4704
# Epoch 277 Batch 5 Loss 0.0025 Accuracy 11.9610
# Epoch 277 Batch 10 Loss 0.0025 Accuracy 11.9602
# Epoch 277 Batch 15 Loss 0.0025 Accuracy 11.9582
# Epoch 277 Batch 20 Loss 0.0025 Accuracy 11.9587
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4691
# Epoch 278 Batch 5 Loss 0.0025 Accuracy 11.9594
# Epoch 278 Batch 10 Loss 0.0025 Accuracy 11.9587
# Epoch 278 Batch 15 Loss 0.0025 Accuracy 11.9572
# Epoch 278 Batch 20 Loss 0.0025 Accuracy 11.9566
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4659
# Epoch 279 Batch 5 Loss 0.0025 Accuracy 11.9559
# Epoch 279 Batch 10 Loss 0.0025 Accuracy 11.9546
# Epoch 279 Batch 15 Loss 0.0025 Accuracy 11.9526
# Epoch 279 Batch 20 Loss 0.0025 Accuracy 11.9525
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4635
# Epoch 280 Batch 5 Loss 0.0025 Accuracy 11.9514
# Epoch 280 Batch 10 Loss 0.0025 Accuracy 11.9502
# Epoch 280 Batch 15 Loss 0.0025 Accuracy 11.9482
# Epoch 280 Batch 20 Loss 0.0025 Accuracy 11.9478
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4615
# Epoch 281 Batch 5 Loss 0.0025 Accuracy 11.9469
# Epoch 281 Batch 10 Loss 0.0025 Accuracy 11.9457
# Epoch 281 Batch 15 Loss 0.0025 Accuracy 11.9435
# Epoch 281 Batch 20 Loss 0.0025 Accuracy 11.9436
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 11.4619
# Epoch 282 Batch 5 Loss 0.0025 Accuracy 11.9427
# Epoch 282 Batch 10 Loss 0.0025 Accuracy 11.9418
# Epoch 282 Batch 15 Loss 0.0025 Accuracy 11.9395
# Epoch 282 Batch 20 Loss 0.0025 Accuracy 11.9406
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4701
# Epoch 283 Batch 5 Loss 0.0025 Accuracy 11.9405
# Epoch 283 Batch 10 Loss 0.0025 Accuracy 11.9397
# Epoch 283 Batch 15 Loss 0.0025 Accuracy 11.9378
# Epoch 283 Batch 20 Loss 0.0025 Accuracy 11.9411
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4811
# Epoch 284 Batch 5 Loss 0.0025 Accuracy 11.9422
# Epoch 284 Batch 10 Loss 0.0025 Accuracy 11.9422
# Epoch 284 Batch 15 Loss 0.0025 Accuracy 11.9410
# Epoch 284 Batch 20 Loss 0.0025 Accuracy 11.9401
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4846
# Epoch 285 Batch 5 Loss 0.0025 Accuracy 11.9411
# Epoch 285 Batch 10 Loss 0.0025 Accuracy 11.9406
# Epoch 285 Batch 15 Loss 0.0025 Accuracy 11.9401
# Epoch 285 Batch 20 Loss 0.0025 Accuracy 11.9393
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4847
# Epoch 286 Batch 5 Loss 0.0025 Accuracy 11.9394
# Epoch 286 Batch 10 Loss 0.0025 Accuracy 11.9382
# Epoch 286 Batch 15 Loss 0.0025 Accuracy 11.9365
# Epoch 286 Batch 20 Loss 0.0025 Accuracy 11.9362
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4813
# Epoch 287 Batch 5 Loss 0.0025 Accuracy 11.9354
# Epoch 287 Batch 10 Loss 0.0025 Accuracy 11.9341
# Epoch 287 Batch 15 Loss 0.0025 Accuracy 11.9320
# Epoch 287 Batch 20 Loss 0.0025 Accuracy 11.9320
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4797
# Epoch 288 Batch 5 Loss 0.0025 Accuracy 11.9308
# Epoch 288 Batch 10 Loss 0.0025 Accuracy 11.9298
# Epoch 288 Batch 15 Loss 0.0025 Accuracy 11.9276
# Epoch 288 Batch 20 Loss 0.0025 Accuracy 11.9280
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4803
# Epoch 289 Batch 5 Loss 0.0025 Accuracy 11.9270
# Epoch 289 Batch 10 Loss 0.0025 Accuracy 11.9261
# Epoch 289 Batch 15 Loss 0.0025 Accuracy 11.9239
# Epoch 289 Batch 20 Loss 0.0025 Accuracy 11.9247
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4869
# Epoch 290 Batch 5 Loss 0.0025 Accuracy 11.9244
# Epoch 290 Batch 10 Loss 0.0025 Accuracy 11.9236
# Epoch 290 Batch 15 Loss 0.0025 Accuracy 11.9216
# Epoch 290 Batch 20 Loss 0.0025 Accuracy 11.9229
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4995
# Epoch 291 Batch 5 Loss 0.0025 Accuracy 11.9240
# Epoch 291 Batch 10 Loss 0.0025 Accuracy 11.9232
# Epoch 291 Batch 15 Loss 0.0025 Accuracy 11.9219
# Epoch 291 Batch 20 Loss 0.0025 Accuracy 11.9229
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5122
# Epoch 292 Batch 5 Loss 0.0025 Accuracy 11.9245
# Epoch 292 Batch 10 Loss 0.0025 Accuracy 11.9245
# Epoch 292 Batch 15 Loss 0.0025 Accuracy 11.9226
# Epoch 292 Batch 20 Loss 0.0025 Accuracy 11.9226
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5090
# Epoch 293 Batch 5 Loss 0.0025 Accuracy 11.9219
# Epoch 293 Batch 10 Loss 0.0025 Accuracy 11.9208
# Epoch 293 Batch 15 Loss 0.0025 Accuracy 11.9191
# Epoch 293 Batch 20 Loss 0.0025 Accuracy 11.9188
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5056
# Epoch 294 Batch 5 Loss 0.0025 Accuracy 11.9179
# Epoch 294 Batch 10 Loss 0.0025 Accuracy 11.9167
# Epoch 294 Batch 15 Loss 0.0025 Accuracy 11.9146
# Epoch 294 Batch 20 Loss 0.0025 Accuracy 11.9146
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5038
# Epoch 295 Batch 5 Loss 0.0025 Accuracy 11.9135
# Epoch 295 Batch 10 Loss 0.0025 Accuracy 11.9125
# Epoch 295 Batch 15 Loss 0.0025 Accuracy 11.9106
# Epoch 295 Batch 20 Loss 0.0025 Accuracy 11.9105
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5044
# Epoch 296 Batch 5 Loss 0.0025 Accuracy 11.9096
# Epoch 296 Batch 10 Loss 0.0025 Accuracy 11.9087
# Epoch 296 Batch 15 Loss 0.0025 Accuracy 11.9066
# Epoch 296 Batch 20 Loss 0.0025 Accuracy 11.9071
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5139
# Epoch 297 Batch 5 Loss 0.0025 Accuracy 11.9075
# Epoch 297 Batch 10 Loss 0.0025 Accuracy 11.9067
# Epoch 297 Batch 15 Loss 0.0025 Accuracy 11.9053
# Epoch 297 Batch 20 Loss 0.0025 Accuracy 11.9067
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5235
# Epoch 298 Batch 5 Loss 0.0025 Accuracy 11.9077
# Epoch 298 Batch 10 Loss 0.0025 Accuracy 11.9075
# Epoch 298 Batch 15 Loss 0.0025 Accuracy 11.9054
# Epoch 298 Batch 20 Loss 0.0025 Accuracy 11.9057
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5204
# Epoch 299 Batch 5 Loss 0.0025 Accuracy 11.9049
# Epoch 299 Batch 10 Loss 0.0025 Accuracy 11.9042
# Epoch 299 Batch 15 Loss 0.0025 Accuracy 11.9026
# Epoch 299 Batch 20 Loss 0.0025 Accuracy 11.9023
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5175
# Epoch 300 Batch 5 Loss 0.0025 Accuracy 11.9013
# Epoch 300 Batch 10 Loss 0.0025 Accuracy 11.9002
# Epoch 300 Batch 15 Loss 0.0025 Accuracy 11.8983
# Epoch 300 Batch 20 Loss 0.0025 Accuracy 11.8979
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5156

# %% [markdown]
# #### - dangjin_ware

# %%
capacity = 700
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_ware_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin_warehouse(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_ware_scaled, Models_dangjin_warehouse)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.0177 Accuracy 44.3165
# Epoch 1 Batch 10 Loss 0.0129 Accuracy 44.9041
# Epoch 1 Batch 15 Loss 0.0116 Accuracy 44.9911
# Epoch 1 Batch 20 Loss 0.0115 Accuracy 45.8457
# Time taken for 1 epoch: 1.67 secs
#
# WARNING:tensorflow:Layer train_model_13 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 41.5551
# Epoch 2 Batch 5 Loss 0.0111 Accuracy 45.8923
# Epoch 2 Batch 10 Loss 0.0108 Accuracy 45.8131
# Epoch 2 Batch 15 Loss 0.0106 Accuracy 45.7180
# Epoch 2 Batch 20 Loss 0.0106 Accuracy 46.0371
# Time taken for 1 epoch: 0.57 secs
#
# TestLoss 0.0000 TestAccuracy 41.5551
# Epoch 3 Batch 5 Loss 0.0106 Accuracy 46.0406
# Epoch 3 Batch 10 Loss 0.0104 Accuracy 45.9792
# Epoch 3 Batch 15 Loss 0.0103 Accuracy 45.9045
# Epoch 3 Batch 20 Loss 0.0104 Accuracy 46.0989
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 41.5551
# Epoch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-6e058a70f208> in <module>
#      25         i += 1
#      26
# ---> 27         train_step_dangjin_warehouse(inp, tar)
#      28
#      29         if i % 5 == 0:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### - dangjin_float

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_float_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin_floating(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_float_scaled, Models_dangjin_floating)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.3223 Accuracy 84.6864
# Epoch 1 Batch 10 Loss 0.1519 Accuracy 63.0835
# Epoch 1 Batch 15 Loss 0.1020 Accuracy 54.7482
# Epoch 1 Batch 20 Loss 0.0794 Accuracy 51.4029
# Time taken for 1 epoch: 1.65 secs
#
# WARNING:tensorflow:Layer train_model_17 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 2 Batch 5 Loss 0.0669 Accuracy 49.7515
# Epoch 2 Batch 10 Loss 0.0581 Accuracy 48.5406
# Epoch 2 Batch 15 Loss 0.0513 Accuracy 47.0836
# Epoch 2 Batch 20 Loss 0.0468 Accuracy 46.4378
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 3 Batch 5 Loss 0.0437 Accuracy 46.1400
# Epoch 3 Batch 10 Loss 0.0408 Accuracy 45.7701
# Epoch 3 Batch 15 Loss 0.0382 Accuracy 45.0903
# Epoch 3 Batch 20 Loss 0.0363 Accuracy 44.8331
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 4 Batch 5 Loss 0.0350 Accuracy 44.7644
# Epoch 4 Batch 10 Loss 0.0336 Accuracy 44.5962
# Epoch 4 Batch 15 Loss 0.0321 Accuracy 44.1736
# Epoch 4 Batch 20 Loss 0.0311 Accuracy 44.0399
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 5 Batch 5 Loss 0.0304 Accuracy 44.0390
# Epoch 5 Batch 10 Loss 0.0296 Accuracy 43.9475
# Epoch 5 Batch 15 Loss 0.0287 Accuracy 43.6467
# Epoch 5 Batch 20 Loss 0.0280 Accuracy 43.5668
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 6 Batch 5 Loss 0.0276 Accuracy 43.5911
# Epoch 6 Batch 10 Loss 0.0271 Accuracy 43.5359
# Epoch 6 Batch 15 Loss 0.0264 Accuracy 43.3046
# Epoch 6 Batch 20 Loss 0.0260 Accuracy 43.2527
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 7 Batch 5 Loss 0.0257 Accuracy 43.2869
# Epoch 7 Batch 10 Loss 0.0253 Accuracy 43.2515
# Epoch 7 Batch 15 Loss 0.0248 Accuracy 43.0646
# Epoch 7 Batch 20 Loss 0.0245 Accuracy 43.0288
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 8 Batch 5 Loss 0.0243 Accuracy 43.0668
# Epoch 8 Batch 10 Loss 0.0240 Accuracy 43.0433
# Epoch 8 Batch 15 Loss 0.0237 Accuracy 42.8869
# Epoch 8 Batch 20 Loss 0.0234 Accuracy 42.8613
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 9 Batch 5 Loss 0.0233 Accuracy 42.9003
# Epoch 9 Batch 10 Loss 0.0231 Accuracy 42.8842
# Epoch 9 Batch 15 Loss 0.0228 Accuracy 42.7501
# Epoch 9 Batch 20 Loss 0.0226 Accuracy 42.7311
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 10 Batch 5 Loss 0.0225 Accuracy 42.7698
# Epoch 10 Batch 10 Loss 0.0223 Accuracy 42.7587
# Epoch 10 Batch 15 Loss 0.0220 Accuracy 42.6414
# Epoch 10 Batch 20 Loss 0.0219 Accuracy 42.6271
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 11 Batch 5 Loss 0.0218 Accuracy 42.6648
# Epoch 11 Batch 10 Loss 0.0217 Accuracy 42.6572
# Epoch 11 Batch 15 Loss 0.0215 Accuracy 42.5531
# Epoch 11 Batch 20 Loss 0.0213 Accuracy 42.5421
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 12 Batch 5 Loss 0.0213 Accuracy 42.5785
# Epoch 12 Batch 10 Loss 0.0212 Accuracy 42.5734
# Epoch 12 Batch 15 Loss 0.0210 Accuracy 42.4798
# Epoch 12 Batch 20 Loss 0.0209 Accuracy 42.4713
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 13 Batch 5 Loss 0.0208 Accuracy 42.5063
# Epoch 13 Batch 10 Loss 0.0207 Accuracy 42.5030
# Epoch 13 Batch 15 Loss 0.0206 Accuracy 42.4181
# Epoch 13 Batch 20 Loss 0.0205 Accuracy 42.4114
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 14 Batch 5 Loss 0.0205 Accuracy 42.4451
# Epoch 14 Batch 10 Loss 0.0204 Accuracy 42.4431
# Epoch 14 Batch 15 Loss 0.0202 Accuracy 42.3654
# Epoch 14 Batch 20 Loss 0.0202 Accuracy 42.3602
# Time taken for 1 epoch: 0.56 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 15 Batch 5 Loss 0.0201 Accuracy 42.3924
# Epoch 15 Batch 10 Loss 0.0201 Accuracy 42.3914
# Epoch 15 Batch 15 Loss 0.0199 Accuracy 42.3198
# Epoch 15 Batch 20 Loss 0.0199 Accuracy 42.3157
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 16 Batch 5 Loss 0.0199 Accuracy 42.3467
# Epoch 16 Batch 10 Loss 0.0198 Accuracy 42.3465
# Epoch 16 Batch 15 Loss 0.0197 Accuracy 42.2801
# Epoch 16 Batch 20 Loss 0.0196 Accuracy 42.2769
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 17 Batch 5 Loss 0.0196 Accuracy 42.3066
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-7464026fc746> in <module>
#      23         i += 1
#      24
# ---> 25         train_step_dangjin_floating(inp, tar)
#      26
#      27         if i % 5 == 0:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### - ulsan

# %%
capacity = 500
train_max = train_max_ulsan.copy()
train_min = train_min_ulsan.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_ulsan_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_ulsan_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_ulsan(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_ulsan_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_ulsan_scaled, y_test_ulsan_scaled, Models_ulsan)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.0059 Accuracy 48.1035
# Epoch 1 Batch 10 Loss 0.0056 Accuracy 48.4553
# Epoch 1 Batch 15 Loss 0.0053 Accuracy 47.6245
# Epoch 1 Batch 20 Loss 0.0055 Accuracy 47.9485
# Time taken for 1 epoch: 1.01 secs
#
# WARNING:tensorflow:Layer train_model_16 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 2 Batch 5 Loss 0.0055 Accuracy 47.9824
# Epoch 2 Batch 10 Loss 0.0055 Accuracy 48.1132
# Epoch 2 Batch 15 Loss 0.0054 Accuracy 47.8201
# Epoch 2 Batch 20 Loss 0.0055 Accuracy 47.9524
# Time taken for 1 epoch: 0.50 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 3 Batch 5 Loss 0.0055 Accuracy 47.9706
# Epoch 3 Batch 10 Loss 0.0055 Accuracy 48.0493
# Epoch 3 Batch 15 Loss 0.0054 Accuracy 47.8706
# Epoch 3 Batch 20 Loss 0.0055 Accuracy 47.9537
# Time taken for 1 epoch: 0.49 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 4 Batch 5 Loss 0.0055 Accuracy 47.9661
# Epoch 4 Batch 10 Loss 0.0055 Accuracy 48.0224
# Epoch 4 Batch 15 Loss 0.0054 Accuracy 47.8937
# Epoch 4 Batch 20 Loss 0.0054 Accuracy 47.9543
# Time taken for 1 epoch: 0.49 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 5 Batch 5 Loss 0.0055 Accuracy 47.9637
# Epoch 5 Batch 10 Loss 0.0055 Accuracy 48.0075
# Epoch 5 Batch 15 Loss 0.0054 Accuracy 47.9070
# Epoch 5 Batch 20 Loss 0.0054 Accuracy 47.9547
# Time taken for 1 epoch: 0.48 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 6 Batch 5 Loss 0.0055 Accuracy 47.9623
# Epoch 6 Batch 10 Loss 0.0055 Accuracy 47.9981
# Epoch 6 Batch 15 Loss 0.0054 Accuracy 47.9156
# Epoch 6 Batch 20 Loss 0.0054 Accuracy 47.9549
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 7 Batch 5 Loss 0.0055 Accuracy 47.9613
# Epoch 7 Batch 10 Loss 0.0055 Accuracy 47.9916
# Epoch 7 Batch 15 Loss 0.0054 Accuracy 47.9217
# Epoch 7 Batch 20 Loss 0.0054 Accuracy 47.9551
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 8 Batch 5 Loss 0.0055 Accuracy 47.9606
# Epoch 8 Batch 10 Loss 0.0055 Accuracy 47.9869
# Epoch 8 Batch 15 Loss 0.0054 Accuracy 47.9262
# Epoch 8 Batch 20 Loss 0.0054 Accuracy 47.9552
# Time taken for 1 epoch: 0.47 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch
Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 191 Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.49 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 192 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 192 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 192 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 192 Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 193 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 193 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 193 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 193 Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 194 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 194 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 194 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 194 Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 195 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 195 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 195 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 195 Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 196 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 196 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 196 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 196 Batch 20 Loss 0.0054 Accuracy 47.9562
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 197 Batch 5 Loss 0.0054 Accuracy 47.9564
# Epoch 197 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 197 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 197 Batch 20 Loss 0.0054 Accuracy 47.9562
# Time taken for 1 epoch: 0.50 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 198 Batch 5 Loss 0.0054 Accuracy 47.9564
# Epoch 198 Batch 10 Loss 0.0054 Accuracy 47.9574
# Epoch 198 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 198 Batch 20 Loss 0.0054 Accuracy 47.9562
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 199 Batch 5 Loss 0.0054 Accuracy 47.9564
# Epoch 199 Batch 10 Loss 0.0054 Accuracy 47.9574
# Epoch 199 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 199 Batch 20 Loss 0.0054 Accuracy 47.9562
# Time taken for 1 epoch: 0.51 secs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-92bca7e2782d> in <module>
#      31         if i > int(len(X_train_ulsan_scaled) / batch_size) :
#      32             print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# ---> 33             val_accuracy(X_test_ulsan_scaled, y_test_ulsan_scaled, Models_ulsan)
#      34             print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
#      35             break
#
# <ipython-input-111-5fa1a869a583> in val_accuracy(inp, tar, Models)
#       1 def val_accuracy(inp, tar, Models):
# ----> 2     output = Models(inp)
#       3
#       4     test_accuracy(tf.numpy_function(nmae_10,
#       5                                      [tar, tf.squeeze(output, -1)],
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# <ipython-input-74-d29ceb546d0b> in call(self, input_tensor)
#      42         conv_output = self.dropout(conv_output)
#      43
# ---> 44         lstm_output_1 = self.lstm(conv_output)
#      45
#      46         output = self.outputs(lstm_output_1)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     652
#     653     if initial_state is None and constants is None:
# --> 654       return super(RNN, self).__call__(inputs, **kwargs)
#     655
#     656     # If any of `initial_state` or `constants` are specified and are Keras
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1181               **gpu_lstm_kwargs)
#    1182         else:
# -> 1183           last_output, outputs, new_h, new_c, runtime = standard_lstm(
#    1184               **normal_lstm_kwargs)
#    1185       else:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py in standard_lstm(inputs, init_h, init_c, kernel, recurrent_kernel, bias, activation, recurrent_activation, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask)
#    1308     return h, [h, c]
#    1309
# -> 1310   last_output, outputs, new_states = K.rnn(
#    1311       step,
#    1312       inputs, [init_h, init_c],
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask)
#    4234         return (time + 1, output_ta_t) + tuple(new_states)
#    4235
# -> 4236       final_outputs = control_flow_ops.while_loop(
#    4237           body=_step,
#    4238           loop_vars=(time, output_ta) + states,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2725                                               list(loop_vars))
#    2726       while cond(*loop_vars):
# -> 2727         loop_vars = body(*loop_vars)
#    2728         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2729           packed = True
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in _step(time, output_ta_t, *states)
#    4220         current_input = tuple(ta.read(time) for ta in input_ta)
#    4221         current_input = nest.pack_sequence_as(inputs, current_input)
# -> 4222         output, new_states = step_function(current_input,
#    4223                                            tuple(states) + tuple(constants))
#    4224         flat_state = nest.flatten(states)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py in step(cell_inputs, cell_states)
#    1302     i = recurrent_activation(z0)
#    1303     f = recurrent_activation(z1)
# -> 1304     c = f * c_tm1 + i * activation(z2)
#    1305     o = recurrent_activation(z3)
#    1306
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py in binary_op_wrapper(x, y)
#     982     with ops.name_scope(None, op_name, [x, y]) as name:
#     983       if isinstance(x, ops.Tensor) and isinstance(y, ops.Tensor):
# --> 984         return func(x, y, name=name)
#     985       elif not isinstance(y, sparse_tensor.SparseTensor):
#     986         try:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py in _mul_dispatch(x, y, name)
#    1281   is_tensor_y = isinstance(y, ops.Tensor)
#    1282   if is_tensor_y:
# -> 1283     return gen_math_ops.mul(x, y, name=name)
#    1284   else:
#    1285     assert isinstance(y, sparse_tensor.SparseTensor)  # Case: Dense * Sparse.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in mul(x, y, name)
#    6076   if tld.is_eager:
#    6077     try:
# -> 6078       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6079         _ctx._context_handle, tld.device_name, "Mul", name, tld.op_callbacks,
#    6080         x, y)
#
# KeyboardInterrupt:

# %%
dangjin_fcst["Forecast time"] = pd.to_datetime(dangjin_fcst["Forecast time"])

# %%
dangjin_fcst[(dangjin_fcst["Forecast time"] == pd.Timestamp(2021,1,31,23,0,0)) & (
    dangjin_fcst["forecast"].dt.date == pd.datetime(2021,2,1).date())]
# Out:
# <ipython-input-430-d9d50c632d67>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dangjin_fcst["forecast"].dt.date == pd.datetime(2021,2,1).date())]
#              Forecast time            forecast  Temperature  Humidity  \
# 157990 2021-01-31 23:00:00 2021-02-01 03:00:00          7.0      90.0
# 157991 2021-01-31 23:00:00 2021-02-01 06:00:00          6.0      90.0
# 157992 2021-01-31 23:00:00 2021-02-01 09:00:00          6.0      95.0
# 157993 2021-01-31 23:00:00 2021-02-01 12:00:00          9.0      75.0
# 157994 2021-01-31 23:00:00 2021-02-01 15:00:00          8.0      70.0
# 157995 2021-01-31 23:00:00 2021-02-01 18:00:00          4.0      75.0
# 157996 2021-01-31 23:00:00 2021-02-01 21:00:00          1.0      65.0
#
#         WindSpeed  WindDirection  Cloud
# 157990        3.4          207.0    4.0
# 157991        2.5          222.0    4.0
# 157992        3.3          232.0    4.0
# 157993        2.9          262.0    4.0
# 157994        5.2          312.0    3.0
# 157995        3.6          309.0    3.0
# 157996        6.6          325.0    3.0

# %%
dangjin_fcst_fore = pd.merge(pd.DataFrame(pd.date_range(start = pd.Timestamp(2021,2,1,0,0,0), 
              end = pd.Timestamp(2021,2,1,23,0,0),
             freq = "H"),
            columns = ["forecast"]),
         dangjin_fcst[(dangjin_fcst["Forecast time"] == pd.Timestamp(2021,1,31,23,0,0)) & (
    dangjin_fcst["forecast"].dt.date == pd.datetimeb(2021,2,1).date())],
        how = "left").drop(["Forecast time"], axis = 1)
# Out:
# <ipython-input-679-fb973e4be8a4>:6: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dangjin_fcst["forecast"].dt.date == pd.datetime(2021,2,1).date())],

# %% [markdown]
# # 5. 평가

# %% [markdown]
# ## 1) Normalized MAE

# %%
result = DataFrame([

np.hstack(np.squeeze(Models_dangjin(X_test_dangjin_scaled[:,:,0:5],X_test_dangjin_scaled[:,:,5:])))*( 
    train_max_dangjin - train_min_dangjin) + train_min_dangjin,
    
np.hstack(np.squeeze(Models_dangjin_warehouse(X_test_dangjin_scaled[:,:,0:5],X_test_dangjin_scaled[:,:,5:]))) * (
train_max_dangjin - train_min_dangjin) + train_min_dangjin,

np.hstack(np.squeeze(Models_dangjin_floating(X_test_dangjin_scaled[:,:,0:5],X_test_dangjin_scaled[:,:,5:]))) * (
    train_max_dangjin - train_min_dangjin) + train_min_dangjin,

    np.hstack(np.squeeze(Models_ulsan(X_test_ulsan_scaled[:,:,0:5],X_test_ulsan_scaled[:,:,5:]))) * (
    train_max_ulsan - train_min_ulsan) + train_min_ulsan]).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-449-ef6b38cfc42b> in <module>
#       1 result = DataFrame([
#       2
# ----> 3 np.hstack(np.squeeze(Models_dangjin(X_test_dangjin_scaled[:,:,0:5],X_test_dangjin_scaled[:,:,5:])))*(
#       4     train_max_dangjin - train_min_dangjin) + train_min_dangjin,
#       5
#
# NameError: name 'X_test_dangjin_scaled' is not defined

# %%
result = DataFrame([Models_dangjin.predict(X_test_dangjin_lgb),
          Models_dangjin_warehouse.predict(X_test_dangjin_lgb),
          Models_dangjin_floating.predict(X_test_dangjin_lgb),
          Models_ulsan.predict(X_test_ulsan_lgb)]).T

# %%
result = result.dropna()

# %%
def zero_replacer(x):
    x[x < 0] = 0
    
    return x

# %%
result = result.apply(lambda x : zero_replacer(x))

# %%
result = pd.concat([test["time"],result], axis = 1)

# %%
result = result.dropna()

# %%
result.columns = ["time","dangjin","dangjin_warehouse","dangjin_floating","ulsan"]

# %%
def sola_nmae(answer_df, submission_df):
    submission = submission_df[submission_df['time'].isin(answer_df['time'])]
    submission.index = range(submission.shape[0])
    
    # 시간대별 총 발전량
    sum_submission = submission.iloc[:,1:].sum(axis=1)
    sum_answer = answer_df.iloc[:,1:].sum(axis=1)
    
    # 발전소 발전용량
    capacity = {
        'dangjin_floating':1000, # 당진수상태양광 발전용량
        'dangjin_warehouse':700, # 당진자재창고태양광 발전용량
        'dangjin':1000, # 당진태양광 발전용량
        'ulsan':500 # 울산태양광 발전용량
    }
    
    # 총 발전용량
    total_capacity = np.sum(list(capacity.values()))
    
    # 총 발전용량 절대오차
    absolute_error = (sum_answer - sum_submission).abs()
    
    # 발전용량으로 정규화
    absolute_error /= total_capacity
    
    # 총 발전용량의 10% 이상 발전한 데이터 인덱스 추출
    target_idx = sum_answer[sum_answer>=total_capacity*0.1].index
    
    # NMAE(%)
    nmae = 100 * absolute_error[target_idx].mean()
    
    return nmae

# %%
answer_df = test[["time","dangjin_floating","dangjin_warehouse","dangjin","ulsan"]]

# %%
answer_df = answer_df[answer_df["time"] < '2021-01-31']

# %%
sola_nmae(answer_df, result)
# Out:
# 11.459767298740195

# %%
plt.plot(answer_df.loc[:,"dangjin"])
plt.plot(result.loc[:,"dangjin"])

# %%
plt.plot(answer_df[answer_df["time"].dt.date == pd.Timestamp('2021-01-25')]["dangjin_floating"])
plt.plot(result[result["time"].dt.date == pd.Timestamp('2021-01-25')]["dangjin_floating"])

# %%
plt.figure(figsize = (20,10))
plt.plot(answer_df.loc[:,"dangjin_floating"])
plt.plot(result.loc[:,"dangjin_floating"])

# %%
plt.figure(figsize = (20,10))
plt.plot(answer_df.loc[:,"dangjin_floating"])
plt.plot(result.loc[:,"dangjin_floating"])

# %%
plt.figure(figsize = (20,10))
plt.plot(answer_df.loc[:,"dangjin_warehouse"])
plt.plot(result.loc[:,"dangjin_warehouse"])

# %%
plt.figure(figsize = (20,10))
plt.plot(answer_df.loc[:,"ulsan"])
plt.plot(result.loc[:,"ulsan"])

# %% [markdown]
# # 6. Submission

# %%
submission_dangjin = dangjin_fcst[(dangjin_fcst["time"] > '2020-02-01') & (dangjin_fcst["time"] < '2020-03-01')]

# %%
submission_ulsan = ulsan_fcst[(ulsan_fcst["time"] > '2020-02-01') & (ulsan_fcst["time"] < '2020-03-01')]

# %%
result = DataFrame([Models_dangjin.predict(submission_dangjin.iloc[:,1:]),
          Models_dangjin_warehouse.predict(submission_dangjin.iloc[:,1:]),
          Models_dangjin_floating.predict(submission_dangjin.iloc[:,1:]),
          Models_ulsan.predict(submission_ulsan.iloc[:,1:])]).T

# %%
result = pd.concat([pd.DataFrame(submission_dangjin["time"]).reset_index(drop =True), result], axis = 1)

# %%
result.columns = ["time","dangjin","dangjin_warehouse","dangjin_floating","ulsan"]

# %%
result = result[["time","dangjin_floating","dangjin_warehouse","dangjin","ulsan"]]

# %%
submission = pd.read_csv("data/sample_submission.csv")

# %%
submission.iloc[0:695,1] = result.iloc[:,1]
submission.iloc[0:695,2] = result.iloc[:,2]
submission.iloc[0:695,3] = result.iloc[:,3]
submission.iloc[0:695,4] = result.iloc[:,4]

# %%
submission.to_csv("submission.csv", index = False)

# %%
plt.plot(submission.iloc[:,4])
