# %%
import pandas as pd
from pandas import DataFrame, Series
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
    
'''
import keras
from keras import models
from keras.models import Sequential
from keras.models import Model
from keras.models import load_model
from keras import backend as K
from keras import layers
from keras.layers import Layer
from keras.layers import Input,Dense,Flatten,Embedding,Permute,Dot,Reshape
from keras.layers.convolutional import Conv1D,MaxPooling1D,MaxPooling2D
from keras.layers import Dropout
from keras.layers import LSTM,GRU
from keras.callbacks import Callback
from keras.preprocessing import sequence
from keras.utils import np_utils
 '''

from nariflow import Variable
from nariflow import optimizer
from nariflow import GradientTape
#from nariflow import calc_gradient
from nariflow import layer
from nariflow.models import Model
from nariflow import functions as f
from nariflow.core import elementary_function as ef
from nariflow.core import shape_function as sf

import tensorflow as tf
from tensorflow.python.framework import function
import math
 
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score,accuracy_score

#import lightgbm as lgb
 
import scipy

#import statsmodels.api
#import statsmodels as sm
 
import copy
import random
import time
from time import sleep

import re
import os

# %%
os.listdir("data")
# Out:
# ['179502b7cf14f003d.png',
#  'dangjin_fcst_data.csv',
#  'dangjin_obs_data.csv',
#  'energy.csv',
#  'obs',
#  'OBS_ASOS_TIM_20210509142735.csv',
#  'OBS_ASOS_TIM_20210509143013.csv',
#  'OBS_ASOS_TIM_20210509143059.csv',
#  'OBS_ASOS_TIM_20210525163946.csv',
#  'OBS_ASOS_TIM_20210525164100.csv',
#  'OBS_ASOS_TIM_20210525164127.csv',
#  'OBS_ASOS_TIM_20210526161235.csv',
#  'OBS_ASOS_TIM_20210526161318.csv',
#  'OBS_ASOS_TIM_20210526161340.csv',
#  'OBS_ASOS_TIM_20210526161401.csv',
#  'OBS_ASOS_TIM_20210526161419.csv',
#  'OBS_ASOS_TIM_20210526161438.csv',
#  'sample_submission.csv',
#  'site_info.csv',
#  'ulsan_fcst_data.csv',
#  'ulsan_obs_data.csv',
#  'weather',
#  '석문면_강수형태_201801_201812.csv',
#  '석문면_강수형태_201901_201912.csv',
#  '석문면_강수형태_202001_202012.csv',
#  '석문면_강수형태_202101_202102.csv',
#  '석문면_강수확률_201801_201812.csv',
#  '석문면_강수확률_201901_201912.csv',
#  '석문면_강수확률_202001_202012.csv',
#  '석문면_강수확률_202101_202102.csv',
#  '선암동_강수형태_201801_201812.csv',
#  '선암동_강수형태_201901_201912.csv',
#  '선암동_강수형태_202001_202012.csv',
#  '선암동_강수형태_202101_202102.csv',
#  '선암동_강수확률_201801_201812.csv',
#  '선암동_강수확률_201901_201912.csv',
#  '선암동_강수확률_202001_202012.csv',
#  '선암동_강수확률_202101_202102.csv',
#  '한국동서발전 시간대별 태양광 발전량 현황(2015_2017).csv']

# %% [markdown]
# # 1. Data Load

# %%
dangjin_fcst = pd.read_csv("data/dangjin_fcst_data.csv")
dangjin_obs = pd.read_csv("data/dangjin_obs_data.csv")
energy = pd.read_csv("data/energy.csv")
site_info = pd.read_csv("data/site_info.csv")
ulsan_fcst = pd.read_csv("data/ulsan_fcst_data.csv")
ulsan_obs = pd.read_csv("data/ulsan_obs_data.csv")

# %% [markdown]
# ## 1) 데이터 준비

# %% [markdown]
# ### (1) Forecast Time 변환

# %%
dangjin_fcst["forecast"] = pd.to_datetime(dangjin_fcst["Forecast time"]) + dangjin_fcst["forecast"].apply(
    lambda x : pd.Timedelta(x, unit = "H"))

# %%
ulsan_fcst["forecast"] = pd.to_datetime(ulsan_fcst["Forecast time"]) + ulsan_fcst["forecast"].apply(
    lambda x : pd.Timedelta(x, unit = "H"))

# %% [markdown]
# # 2. EDA

# %% [markdown]
# ## 1) 기초 통계 및 결측, 이상치 확인

# %% [markdown]
# ### (1) 결측치

# %%
print(dangjin_fcst.isna().apply(lambda x : x.value_counts()))
print(dangjin_obs.isna().apply(lambda x : x.value_counts()))
print(energy.isna().apply(lambda x : x.value_counts()))
print(site_info.isna().apply(lambda x : x.value_counts()))
print(ulsan_fcst.isna().apply(lambda x : x.value_counts()))
print(ulsan_obs.isna().apply(lambda x : x.value_counts()))
# Out:
#        Forecast time  forecast  Temperature  Humidity  WindSpeed  \
# False         162208    162208       162208    162208     162208
#
#        WindDirection   Cloud
# False         162208  162208
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# False  25626.0  25626.0  25626.0   25589    25590     25590  25591      21656
# True       NaN      NaN      NaN      37       36        36     35       3970
#           time  dangjin_floating  dangjin_warehouse  dangjin    ulsan
# False  25632.0             25608              25584  25632.0  25632.0
# True       NaN                24                 48      NaN      NaN
#        Id  Capacity  Address  InstallationAngle  IncidentAngle  Latitude  \
# False   4         4        4                  4              4         4
#
#        Longitude
# False          4
#        Forecast time  forecast  Temperature  Humidity  WindSpeed  \
# False         162208    162208       162208    162208     162208
#
#        WindDirection   Cloud
# False         162208  162208
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# False  25632.0  25632.0  25632.0   25628    25631     25631  25631      24807
# True       NaN      NaN      NaN       4        1         1      1        825

# %% [markdown]
# Forecast엔 결측치가 없고, obs엔 결측치가 소수 존재한다. Energy 결측치는 이유에 대한 탐색이 필요해보인다.

# %% [markdown]
# #### - Energy 결측 탐색

# %%
energy.loc[energy["dangjin_warehouse"].isna()]
# Out:
#                     time  dangjin_floating  dangjin_warehouse  dangjin  ulsan
# 384   2018-03-17 1:00:00               0.0                NaN        0      0
# 385   2018-03-17 2:00:00               0.0                NaN        0      0
# 386   2018-03-17 3:00:00               0.0                NaN        0      0
# 387   2018-03-17 4:00:00               0.0                NaN        0      0
# 388   2018-03-17 5:00:00               0.0                NaN        0      0
# 389   2018-03-17 6:00:00               0.0                NaN        0      0
# 390   2018-03-17 7:00:00               0.0                NaN        0      0
# 391   2018-03-17 8:00:00              24.0                NaN       16     13
# 392   2018-03-17 9:00:00             162.0                NaN      177     57
# 393  2018-03-17 10:00:00             363.0                NaN      348    206
# 394  2018-03-17 11:00:00             548.0                NaN      532    278
# 395  2018-03-17 12:00:00             689.0                NaN      631    309
# 396  2018-03-17 13:00:00             616.0                NaN      688    366
# 397  2018-03-17 14:00:00             615.0                NaN      706    368
# 398  2018-03-17 15:00:00             689.0                NaN      658    330
# 399  2018-03-17 16:00:00             578.0                NaN      542    272
# 400  2018-03-17 17:00:00             319.0                NaN      272    157
# 20372  2020-06-26 21:00:00               NaN                0.0        0
# 20373  2020-06-26 22:00:00               NaN                0.0        0
# 20374  2020-06-26 23:00:00               NaN                0.0        0
# 20375  2020-06-26 24:00:00               NaN                0.0        0
#
#        ulsan
# 20352      0
# 20353      0
# 20354      0
# 20355      0
# 20356      0
# 20357      0
# 20358      7
# 20359     50
# 20360    161
# 20361    170
# 20362    283
# 20363    318
# 20364    334
# 20365    331
# 20366    303
# 20367    248
# 20368    190
# 20369    101
# 20370     29
# 20371      1
# 20372      0
# 20373      0
# 20374      0
# 20375      0

# %% [markdown]
# Enegry 내부에선 상관성이 있는 변수가 없어보인다.
#
# 정확히 하루 단위로 데이터가 NA이므로, 삭제해도 무방할 것으로 판단됨

# %%
energy = energy.dropna().reset_index(drop = True)

# %% [markdown]
# #### - obs 결측 탐색

# %%
dangjin_obs.isna().apply(lambda x : x.value_counts())
# Out:
#             지점      지점명       일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# False  25626.0  25626.0  25626.0   25589    25590     25590  25591      21656
# True       NaN      NaN      NaN      37       36        36     35       3970

# %%
dangjin_fcst[dangjin_fcst["Forecast time"] == '2019-01-31 11:00:00']
# Out:
#              Forecast time            forecast  Temperature  Humidity  \
# 49728  2019-01-31 11:00:00 2019-01-31 15:00:00         -1.0      40.0
# 49729  2019-01-31 11:00:00 2019-01-31 18:00:00         -3.0      45.0
# 49730  2019-01-31 11:00:00 2019-01-31 21:00:00         -3.0      50.0
# 49731  2019-01-31 11:00:00 2019-02-01 00:00:00         -4.0      50.0
# 49732  2019-01-31 11:00:00 2019-02-01 03:00:00         -2.0      60.0
# 49733  2019-01-31 11:00:00 2019-02-01 06:00:00         -2.0      70.0
# 49734  2019-01-31 11:00:00 2019-02-01 09:00:00         -2.0      70.0
# 49735  2019-01-31 11:00:00 2019-02-01 12:00:00          2.0      45.0
# 49736  2019-01-31 11:00:00 2019-02-01 15:00:00          4.0      45.0
# 49737  2019-01-31 11:00:00 2019-02-01 18:00:00          1.0      65.0
# 49738  2019-01-31 11:00:00 2019-02-01 21:00:00         -2.0      80.0
# 49739  2019-01-31 11:00:00 2019-02-02 00:00:00         -4.0      90.0
# 49740  2019-01-31 11:00:00 2019-02-02 03:00:00          1.0      95.0
# 49741  2019-01-31 11:00:00 2019-02-02 06:00:00          1.0      90.0
# 49742  2019-01-31 11:00:00 2019-02-02 09:00:00          1.0      85.0
# 49743  2019-01-31 11:00:00 2019-02-02 12:00:00          6.0      60.0
# 49744  2019-01-31 11:00:00 2019-02-02 15:00:00          7.0      50.0
# 49745  2019-01-31 11:00:00 2019-02-02 18:00:00          4.0      65.0
# 49746  2019-01-31 11:00:00 2019-02-02 21:00:00          3.0      75.0
# 49747  2019-01-31 11:00:00 2019-02-03 00:00:00          3.0      75.0
#
#        WindSpeed  WindDirection  Cloud
# 49728        9.0          328.0    4.0
# 49729        9.2          323.0    3.0
# 49730       10.9          320.0    3.0
# 49731       10.1          319.0    2.0
# 49732        8.8          320.0    3.0
# 49733        5.9          318.0    3.0
# 49734        2.9          252.0    3.0
# 49735        7.5          284.0    2.0
# 49736        8.1          275.0    2.0
# 49737        7.5          269.0    1.0
# 49738        6.8          262.0    1.0
# 49739        4.4          235.0    1.0
# 49740        3.9          210.0    1.0
# 49741        3.6          214.0    2.0
# 49742        4.4          208.0    2.0
# 49743        5.6          220.0    3.0
# 49744        5.1          208.0    3.0
# 49745        4.8          182.0    3.0
# 49746        4.8          156.0    4.0
# 49747        4.9          127.0    4.0

# %%
dangjin_obs[dangjin_obs["일시"].str.slice(0,10) == '2019-01-31']
# Out:
#        지점 지점명                일시  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  전운량(10분위)
# 8058  129  서산  2019-01-31 00:00     1.4      0.1       0.0   85.0       10.0
# 8059  129  서산  2019-01-31 01:00     1.3      0.4       0.0   87.0       10.0
# 8060  129  서산  2019-01-31 02:00     2.3      1.3      20.0   88.0       10.0
# 8061  129  서산  2019-01-31 03:00     1.8      1.0      20.0   80.0       10.0
# 8062  129  서산  2019-01-31 04:00     1.6      2.5     360.0   56.0       10.0
# 8063  129  서산  2019-01-31 05:00     1.0      1.9     360.0   51.0       10.0
# 8064  129  서산  2019-01-31 06:00     0.6      1.4     360.0   48.0       10.0
# 8065  129  서산  2019-01-31 07:00     0.3      2.9     360.0   48.0       10.0
# 8066  129  서산  2019-01-31 08:00    -0.3      2.4     360.0   45.0       10.0
# 8067  129  서산  2019-01-31 09:00    -0.6      2.7     360.0   44.0       10.0
# 8068  129  서산  2019-01-31 10:00    -0.8      2.4     340.0   42.0       10.0
# 8069  129  서산  2019-01-31 11:00     NaN      NaN       NaN    NaN       10.0
# 8070  129  서산  2019-01-31 12:00     NaN      NaN       NaN    NaN        9.0
# 8071  129  서산  2019-01-31 13:00     NaN      NaN       NaN    NaN       10.0
# 8072  129  서산  2019-01-31 14:00    -0.6      5.3     340.0   42.0       10.0
# 8073  129  서산  2019-01-31 15:00    -0.4      4.7     360.0   40.0        4.0
# 8074  129  서산  2019-01-31 16:00    -1.0      5.1     340.0   39.0        4.0
# 8075  129  서산  2019-01-31 17:00    -1.3      2.6     360.0   42.0        1.0
# 8076  129  서산  2019-01-31 18:00    -2.6      1.5     340.0   43.0        7.0
# 8077  129  서산  2019-01-31 19:00    -3.4      1.5     340.0   46.0        0.0
# 8078  129  서산  2019-01-31 20:00    -3.2      2.2     340.0   49.0        0.0
# 8079  129  서산  2019-01-31 21:00    -3.3      2.5     340.0   49.0        0.0
# 8080  129  서산  2019-01-31 22:00    -3.3      3.8     360.0   45.0        0.0
# 8081  129  서산  2019-01-31 23:00    -3.5      2.3     360.0   45.0        6.0

# %% [markdown]
# 기온, 풍속, 풍향, 습도 결측치는 서로 밀접한 연관이 있는 것으로 보인다.
#
# 활용이 불가능하므로 제외한다.

# %%
dangjin_obs = dangjin_obs.dropna(axis = 0, subset = ["기온(°C)","풍속(m/s)", "풍향(16방위)", "습도(%)"]).reset_index(drop = True)

# %% [markdown]
# ### - 전운량 결측 탐색

# %%
dangjin_obs["전운량(10분위)"].isna().value_counts()
# Out:
# False    21618
# True      3970
# Name: 전운량(10분위), dtype: int64

# %%
dangjin_obs = dangjin_obs.rename(columns = {"일시" : "forecast"})

dangjin_obs["forecast"] = pd.to_datetime(dangjin_obs["forecast"])

# %%
dangjin_obs["date"] = dangjin_obs["forecast"].dt.date
dangjin_obs["hour"] = dangjin_obs["date"].astype("str") + " " + dangjin_obs["forecast"].dt.hour.astype("str")

# %%
# 하루 중 전운량이 NA인 비율

k = dangjin_obs[dangjin_obs["전운량(10분위)"].isna()].groupby("date").apply(lambda x : x["전운량(10분위)"].isna() / len(x))

k.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 최초 예상으로는 전운량이 Na인 경우 하루 전체가 다 그럴것이라는 가설을 세웠지만
#
# 그 가설은 사실이 아닌것으로 판명되었다.

# %%
# 시간 중 전운량이 NA인 비율

k = dangjin_obs[dangjin_obs["전운량(10분위)"].isna()].groupby("hour").apply(lambda x : x["전운량(10분위)"].isna() / len(x))

k.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 2) 파생 변수 생성 전략 탐색

# %% [markdown]
# ### (1) obs의 전운량과 fcst의 cloud간 비교

# %% [markdown]
# #### - 데이터 Merge

# %%
result = pd.merge(dangjin_obs, dangjin_fcst, on = "forecast", how = "left")

# %% [markdown]
# #### - 상관계수

# %%
result[["Cloud","전운량(10분위)"]].corr()
# Out:
#              Cloud  전운량(10분위)
# Cloud      1.00000    0.54449
# 전운량(10분위)  0.54449    1.00000

# %% [markdown]
# 상관도가 생각보다 낮다. 예측과 실제값 사이에 괴리감이 큰 것으로 보인다.

# %% [markdown]
# #### - 오차값(잔차) 확인

# %% [markdown]
# 잔차를 확인하면 이를 이용하여 예측값에서 실제 정답값을 유사하게라도 보정할 수 있지 않을까?
#
# 히스토그램을 그려 잔차가 정규분포를 따르는지 확인하고, 실제 정규성 검정을 수행해본다.

# %%
plt.hist(result["Cloud"] - result["전운량(10분위)"])
# Out:
# (array([ 4267., 10232., 22770., 29142.,  9112.,  7611., 13987., 23917.,
#          5448.,  6340.]),
#  array([-9. , -7.7, -6.4, -5.1, -3.8, -2.5, -1.2,  0.1,  1.4,  2.7,  4. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# 쌍봉 분포를 보인다.
#
# 차이가 전혀 없는 경우(평균이 0인 정규분포)와 차이가 5~6정도 나는 경우(평균이 5인 정규분포)로 나뉘는 것으로 보인다.

# %%
scipy.stats.kstest((result["Cloud"] - result["전운량(10분위)"]).dropna(), "norm")
# Out:
# KstestResult(statistic=0.6031363661771878, pvalue=0.0)

# %% [markdown]
# 아쉽게도, 잔차는 정규분포를 따르지 않는다.

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]
# Out:
#          지점 지점명            forecast  기온(°C)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 25226   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# 25227   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# 25228   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# 25229   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# 25230   129  서산 2018-08-03 15:00:00    34.6      3.6     250.0   54.0
# ...     ...  ..                 ...     ...      ...       ...    ...
# 174529  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174538  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174539  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174540  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
# 174541  129  서산 2021-01-31 18:00:00     7.8      2.0     200.0   70.0
#
#         전운량(10분위)        date           hour        Forecast time  \
# 25226         6.0  2018-08-03  2018-08-03 15  2018-08-01 05:00:00
# 25227         6.0  2018-08-03  2018-08-03 15  2018-08-01 08:00:00
# 25228         6.0  2018-08-03  2018-08-03 15  2018-08-01 11:00:00
# 25229         6.0  2018-08-03  2018-08-03 15  2018-08-01 14:00:00
# 25230         6.0  2018-08-03  2018-08-03 15  2018-08-01 17:00:00
# ...           ...         ...            ...                  ...
# 174529        8.0  2021-01-31  2021-01-31 18  2021-01-30 02:00:00
# 174538        8.0  2021-01-31  2021-01-31 18  2021-01-31 05:00:00
# 174539        8.0  2021-01-31  2021-01-31 18  2021-01-31 08:00:00
# 174540        8.0  2021-01-31  2021-01-31 18  2021-01-31 11:00:00
# 174541        8.0  2021-01-31  2021-01-31 18  2021-01-31 14:00:00
#
#         Temperature  Humidity  WindSpeed  WindDirection  Cloud
# 25226          34.0      55.0        4.1          269.0    1.0
# 25227          34.0      55.0        4.1          269.0    1.0
# 25228          33.0      55.0        4.1          269.0    1.0
# 25229          33.0      55.0        4.1          269.0    1.0
# 25230          33.0      55.0        2.4          294.0    1.0
# ...             ...       ...        ...            ...    ...
# 174529          6.0      75.0        2.9          180.0    3.0
# 174538          6.0      75.0        3.3          168.0    3.0
# 174539          6.0      75.0        3.3          168.0    3.0
# 174540          6.0      75.0        3.3          168.0    3.0
# 174541          6.0      75.0        3.3          168.0    3.0
#
# [16222 rows x 16 columns]

# %%
result["Cloud"].hist()
# Out:
# <AxesSubplot:>

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]["Cloud"].hist()
# Out:
# <AxesSubplot:>

# %%
result[(result["Cloud"] - result["전운량(10분위)"]) == -5]["전운량(10분위)"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 전운량의 예측은 1 ~ 4밖에 없다.
#
# 예측 오차가 크게 나는 경우는 실제 전운량이 6 이상으로 나타나는 경우였다.

# %%
dangjin_fcst.describe()
# Out:
#          Temperature       Humidity      WindSpeed  WindDirection  \
# count  162208.000000  162208.000000  162208.000000  162208.000000
# mean       12.624634      76.996147       3.639262     214.147761
# std         9.816256      17.435418       2.627592     108.020035
# min       -14.000000       5.000000       0.000000       0.000000
# 25%         4.000000      65.000000       1.900000     115.000000
# 50%        13.000000      80.000000       2.800000     237.000000
# 75%        21.000000      90.000000       4.600000     313.000000
# max        36.000000     100.000000      32.299999     360.000000
#
#                Cloud
# count  162208.000000
# mean        2.439411
# std         1.214753
# min         1.000000
# 25%         1.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000

# %% [markdown]
# ## 2) 변수 선별

# %% [markdown]
# ### (1) 변수 선별용 데이터 전처리

# %% [markdown]
# #### - X, y 데이터 생성

# %%
temp = DataFrame(list(DataFrame(list(energy["time"].str.split(" ")))[1].str.split(":")))

# %%
energy["time"] = pd.to_datetime(
    DataFrame(list(energy["time"].str.split(" ")))[0] + 
    " " 
    + (temp[0].astype("int") - 1).astype("str") + ":" + temp[1] + ":" + temp[2])

# %%
energy_obs = pd.merge(energy, dangjin_obs, left_on = "time", right_on = "forecast", how = "left")

# %%
energy_obs = energy_obs.dropna().reset_index(drop = True)

energy_obs = energy_obs.drop(["date","hour", "지점", "지점명", "forecast"], axis = 1)

# %% [markdown]
# #### - 일출 일몰 정보 생성

# %%
def day_night(x):
    if x < 6 or x > 18:
        return 0
    else:
        return 1

# %%
energy_obs["day_night"] = energy_obs["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %% [markdown]
# ### (2) Boruta 알고리즘 활용

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor(n_jobs=-1, max_depth=5, random_state = 42)
forest.fit(energy_obs[["기온(°C)", "풍속(m/s)", "풍향(16방위)", "습도(%)", "전운량(10분위)", "day_night"]], 
           energy_obs["dangjin_warehouse"].to_numpy())
# Out:
# RandomForestRegressor(max_depth=5, n_jobs=-1, random_state=42)

# %%
from boruta import BorutaPy

feat_selector = BorutaPy(forest, 
                         n_estimators='auto',
                         verbose=2, 
                         random_state=42)

# find all relevant features
feat_selector.fit(energy_obs[["기온(°C)", "풍속(m/s)", "풍향(16방위)", "습도(%)", "전운량(10분위)", "day_night"]].to_numpy(), 
                  energy_obs["dangjin_warehouse"].to_numpy())

# check selected features
feat_selector.support_

# check ranking of features
feat_selector.ranking_

# call transform() on X to filter it down to selected features
X_filtered = feat_selector.transform(energy_obs[["기온(°C)", "풍속(m/s)", "풍향(16방위)", "습도(%)", "전운량(10분위)", "day_night"]].to_numpy())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34380/242213129.py in <module>
# ----> 1 from boruta import BorutaPy
#       2
#       3 feat_selector = BorutaPy(forest,
#       4                          n_estimators='auto',
#       5                          verbose=2,
#
# ModuleNotFoundError: No module named 'boruta'

# %% [markdown]
# 선별된 변수는 없다. 모든 변수를 다 활용할 것이다.

# %% [markdown]
# # 3. 데이터 전처리

# %% [markdown]
# ## 1) 결측값 대체

# %% [markdown]
# ### (1) fcst 보간

# %% [markdown]
# #### - spline 보간

# %%
energy['time'] = energy['time'].astype('str')

# %%
temp = DataFrame(list(DataFrame(list(energy["time"].str.split(" ")))[1].str.split(":")))

energy["time"] = pd.to_datetime(
    DataFrame(list(energy["time"].str.split(" ")))[0] + 
    " " 
    + (temp[0].astype("int") - 1).astype("str") + ":" + temp[1] + ":" + temp[2])

energy = energy.dropna().reset_index(drop = True)

# %%
def time_interpolate(x, data):
    
    temp = data[data["time"].dt.date == x].drop_duplicates("time", keep = "last")
    
    min_time = np.min(temp["time"])
    
    max_time = min_time + pd.Timedelta(hours = 23)
    
    time_index = pd.date_range(min_time, max_time, freq = "H")
    
    temp = pd.merge(pd.Series(pd.date_range(min_time, max_time, freq = "H"),name = "time"),
         temp,
         how = "left")
    
    return temp

# %%
dangjin_fcst = dangjin_fcst.dropna(axis = 0, subset = ["Temperature","Humidity", "WindSpeed", "WindDirection"]).reset_index(drop = True)

dangjin_fcst["Forecast time"] = pd.to_datetime(dangjin_fcst["Forecast time"])

dangjin_fcst = dangjin_fcst.rename(columns = {"forecast":"time"})

result = pd.Series(dangjin_fcst["time"].dt.date.unique()).apply(lambda x : time_interpolate(x, dangjin_fcst))

dangjin_fcst = pd.concat(list(result))

del dangjin_fcst["Forecast time"]

dangjin_fcst = dangjin_fcst.drop_duplicates("time").reset_index(drop = True)

# %%
dangjin_fcst.iloc[:,1:] = dangjin_fcst.iloc[:,1:].apply(lambda x : x.interpolate(method = "spline", order = 2))

# %%
ulsan_fcst = ulsan_fcst.dropna(axis = 0, subset = ["Temperature","Humidity", "WindSpeed", "WindDirection"]).reset_index(drop = True)

ulsan_fcst["Forecast time"] = pd.to_datetime(ulsan_fcst["Forecast time"])

ulsan_fcst = ulsan_fcst.rename(columns = {"forecast":"time"})

result = pd.Series(ulsan_fcst["time"].dt.date.unique()).apply(lambda x : time_interpolate(x, ulsan_fcst))

ulsan_fcst = pd.concat(list(result))

del ulsan_fcst["Forecast time"]

ulsan_fcst = ulsan_fcst.drop_duplicates("time").reset_index(drop = True)

# %%
ulsan_fcst.iloc[:,1:] = ulsan_fcst.iloc[:,1:].apply(lambda x : x.interpolate(method = "spline", order = 2))

# %% [markdown]
# ## 2) 파생 변수 생성

# %% [markdown]
# ### (1) day_night 변수 추가

# %%
def day_night(x):
    if x < 5 or x > 19:
        return 0
    else:
        return 1

# %%
dangjin_fcst["day_night"] = dangjin_fcst["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %%
ulsan_fcst["day_night"] = ulsan_fcst["time"].dt.hour.apply(lambda x : day_night(int(x)))

# %% [markdown]
# ### (2) 월 변수 추가

# %% [markdown]
# #### - dangjin

# %%
temp = pd.DataFrame(dangjin_fcst["time"]).copy()

# %%
temp["month"] = dangjin_fcst["time"].dt.month
temp["year"] = dangjin_fcst["time"].dt.year
temp["year"] = temp["year"].apply(lambda x : int(np.where(temp["year"].unique() == x)[0]))
temp["day"] = dangjin_fcst["time"].dt.day

temp["hour"] = dangjin_fcst["time"].dt.hour

# %%
dangjin_fcst = pd.merge(dangjin_fcst, temp, how = "left")

# %%
energy_fcst_dangjin = pd.merge(energy, dangjin_fcst).dropna()

# %% [markdown]
# #### - ulsan

# %%
temp = pd.DataFrame(ulsan_fcst["time"]).copy()

# %%
temp["month"] = ulsan_fcst["time"].dt.month
temp["year"] = ulsan_fcst["time"].dt.year
temp["year"] = temp["year"].apply(lambda x : int(np.where(temp["year"].unique() == x)[0]))
temp["day"] = ulsan_fcst["time"].dt.day

temp["hour"] = ulsan_fcst["time"].dt.hour

# %%
ulsan_fcst = pd.merge(ulsan_fcst, temp)

# %%
energy_fcst_ulsan = pd.merge(energy, ulsan_fcst, how = "left").dropna()

# %% [markdown]
# # 4. 모델링

# %% [markdown]
# ## 1) train_test 분할

# %% [markdown]
# ### (1) 당진 분할

# %%
temp = DataFrame(energy_fcst_dangjin["time"].dt.date)

# %%
def gen():
    n = 0
    while True:
        n += 1
        yield n
        
num = gen()

# %%
temp = temp.groupby("time").apply(lambda x : next(num))

temp = temp.reset_index(name = "num")
temp.columns = ["date","num"]

energy_fcst_dangjin["date"] = energy_fcst_dangjin["time"].dt.date

energy_fcst_dangjin = pd.merge(energy_fcst_dangjin, temp)

k = energy_fcst_dangjin.groupby("num").apply(lambda x : len(x) / 24)

k = k.reset_index(name = "ratio")

k_full = DataFrame(list(set(k["num"]).difference(set(k.loc[k["ratio"] < 1, "num"]))),
         columns = ["num"])

energy_fcst_dangjin = pd.merge(k_full, 
         energy_fcst_dangjin,
         how = "left")

#train_num = np.random.choice(energy_fcst_dangjin["num"].unique(),
#              size = int(len(energy_fcst_dangjin["num"].unique()) * 0.75),
#                replace = False)

train_num = [i for i in range(0, len(energy_fcst_dangjin["num"].unique()) - 30)]

test_num = [i for i in range(len(energy_fcst_dangjin["num"].unique()) - 30, 
                            len(energy_fcst_dangjin["num"].unique()))]

train = pd.merge(DataFrame(train_num, columns = ["num"]), energy_fcst_dangjin)

test = pd.merge(DataFrame(test_num, columns = ["num"]), energy_fcst_dangjin)

X_train_dangjin = train[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "month",
                         "year",
                         "day",
                         "hour",
                         "num"]]

X_train_dangjin = X_train_dangjin.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "month",
                         "year",
                         "day",
                         "hour",]].to_numpy())

X_test_dangjin = test[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "month",
                         "year",
                         "day",
                         "hour",
                       "num"]]

X_test_dangjin = X_test_dangjin.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "month",
                         "year",
                         "day",
                         "hour",]].to_numpy())

X_train_dangjin = np.stack(X_train_dangjin)
X_test_dangjin = np.stack(X_test_dangjin)

# %%
y_train_dangjin = train[["num","dangjin"]]
y_test_dangjin = test[["num","dangjin"]]

y_train_dangjin = np.stack(y_train_dangjin.groupby("num").apply(lambda x : np.array(x["dangjin"])))
y_test_dangjin = np.stack(y_test_dangjin.groupby("num").apply(lambda x : np.array(x["dangjin"])))

# %%
y_train_dangjin_ware = train[["num","dangjin_warehouse"]]
y_test_dangjin_ware = test[["num","dangjin_warehouse"]]

y_train_dangjin_ware = np.stack(y_train_dangjin_ware.groupby("num").apply(lambda x : np.array(x["dangjin_warehouse"])))
y_test_dangjin_ware = np.stack(y_test_dangjin_ware.groupby("num").apply(lambda x : np.array(x["dangjin_warehouse"])))

# %%
y_train_dangjin_float = train[["num","dangjin_floating"]]
y_test_dangjin_float = test[["num","dangjin_floating"]]

y_train_dangjin_float = np.stack(y_train_dangjin_float.groupby("num").apply(lambda x : np.array(x["dangjin_floating"])))
y_test_dangjin_float = np.stack(y_test_dangjin_float.groupby("num").apply(lambda x : np.array(x["dangjin_floating"])))

# %% [markdown]
# ### (2) 울산 분할

# %%
temp = DataFrame(energy_fcst_ulsan["time"].dt.date)

# %%
temp = temp.groupby("time").apply(lambda x : next(num))

temp = temp.reset_index(name = "num")
temp.columns = ["date","num"]

energy_fcst_ulsan["date"] = energy_fcst_ulsan["time"].dt.date

energy_fcst_ulsan = pd.merge(energy_fcst_ulsan, temp)

k = energy_fcst_ulsan.groupby("num").apply(lambda x : len(x) / 24)

# %%
k = k.reset_index(name = "ratio")

k_full = DataFrame(list(set(k["num"]).difference(set(k.loc[k["ratio"] < 1, "num"]))),
         columns = ["num"])

energy_fcst_ulsan = pd.merge(k_full, 
         energy_fcst_ulsan,
         how = "left")

#train_num = np.random.choice(energy_fcst_dangjin["num"].unique(),
#              size = int(len(energy_fcst_dangjin["num"].unique()) * 0.75),
#                replace = False)

train_num = [i for i in range(np.min(energy_fcst_ulsan["num"].unique()), 
                              np.max(energy_fcst_ulsan["num"].unique()) - 30)]

test_num = [i for i in range(np.max(energy_fcst_ulsan["num"].unique()) - 30, 
                            np.max(energy_fcst_ulsan["num"].unique()) + 1)]

train = pd.merge(DataFrame(train_num, columns = ["num"]), energy_fcst_ulsan)

test = pd.merge(DataFrame(test_num, columns = ["num"]), energy_fcst_ulsan)

X_train_ulsan = train[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "year",
                         "month",
                         "day",
                         "hour",
                         "num"]]

X_train_ulsan = X_train_ulsan.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "year",
                         "month",
                         "day",
                         "hour",]].to_numpy())

X_test_ulsan = test[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "year",
                         "month",
                         "day",
                         "hour",
                       "num"]]

X_test_ulsan = X_test_ulsan.groupby('num').apply(lambda x : x[["Temperature", 
                         "Humidity", 
                         "WindSpeed", 
                         "Cloud",
                         "year",
                         "month",
                         "day",
                         "hour",]].to_numpy())

X_train_ulsan = np.stack(X_train_ulsan)
X_test_ulsan = np.stack(X_test_ulsan)

# %%
y_train_ulsan = train[["num","ulsan"]]
y_test_ulsan = test[["num","ulsan"]]

y_train_ulsan = np.stack(y_train_ulsan.groupby("num").apply(lambda x : np.array(x["ulsan"])))
y_test_ulsan = np.stack(y_test_ulsan.groupby("num").apply(lambda x : np.array(x["ulsan"])))

# %% [markdown]
# ## 1) LightGBM

# %% [markdown]
# ### (1) Parameter Tune

# %% [markdown]
# #### - dangjin

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, y_train_dangjin, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin, [-1])

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_valid_dangjin_lgb, y_valid_dangjin_lgb)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
from sklearn.metrics import r2_score, mean_squared_error

def LGB_cv(learning_rate, 
           feature_fraction, 
           bagging_fraction,
           lambda_l2,
           silent=True, 
           nthread=-1):

    params = {"learning_rate": learning_rate,
                "feature_fraction" : feature_fraction,
                "bagging_fraction" : bagging_fraction, 
               "lambda_l2" : lambda_l2,
               "objective" :  "regression",
              "nthread" : nthread
                }
    
    model = lgb.train(params,
                      train_dataset,
                      feval = nmae_10
                     )

    y_pred = model.predict(X_valid_dangjin_lgb)

    mae = np.mean(nmae_10(y_valid_dangjin_lgb, y_pred))

    return 1/mae

# %%
import scipy.optimize as optimize
from bayes_opt import BayesianOptimization

params = {"learning_rate": (0.0001, 0.2),
            "feature_fraction" : (0.0001, 1),
            "bagging_fraction" : (0.0001, 1), 
           "lambda_l2" : (0 , 1),
            }

capacity = 1000
train_max = 1
train_min = 0

bo=BayesianOptimization(f=LGB_cv, 
                        pbounds=params, 
                        verbose=2, 
                        random_state=1 )

bo.maximize(init_points=2, n_iter=100, acq='ei', xi=0.01)

print(bo.max)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l2 | learni... |
# -------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000153 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  1        |  0.09806  |  0.4171   |  0.7204   |  0.000114 |  0.06054  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000062 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  2        |  0.04929  |  0.1468   |  0.09243  |  0.1863   |  0.06918  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  3        |  0.09924  |  0.4182   |  0.7762   |  0.009261 |  0.093    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  4        |  0.03595  |  0.8701   |  0.9523   |  0.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  5        |  0.1001   |  0.1902   |  0.7985   |  0.0      |  0.1085   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000137 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  6        |  0.09984  |  0.0213   |  0.8079   |  0.9649   |  0.1404   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000164 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  7        |  0.1004   |  0.1471   |  0.9069   |  0.5041   |  0.1557   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000162 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  8        |  0.1002   |  0.3552   |  1.0      |  0.8966   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  9        |  0.0359   |  0.4139   |  0.6391   |  1.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000120 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  10       |  0.09953  |  0.3249   |  0.6358   |  0.4005   |  0.1503   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  11       |  0.09973  |  0.02319  |  0.7994   |  0.9642   |  0.1418   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000165 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  12       |  0.09951  |  0.09389  |  1.0      |  0.7747   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  13       |  0.09932  |  0.3002   |  0.8831   |  0.2468   |  0.174    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  14       |  0.09793  |  0.0001   |  0.6693   |  0.5641   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000105 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |  15       |  0.09289  |  0.2341   |  0.4471   |  0.5501   |  0.1898   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# |
acity*0.1)
    
    nmae = 100 * absolute_error[target_idx].mean()
    
    return 'score', nmae, False

# %%
params = {"learning_rate": 0.11703047303328216,
            "feature_fraction" : 0.917548055585948,
            "bagging_fraction" : 0.4542746828242898, 
           "lambda_l2" :  0.2836245541577052,
          "objective" : 'regression'
            }

# %%
capacity = 1000
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000219 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 9187.11	valid_0's score: 11.2619
# [1000]	valid_0's l2: 9545.01	valid_0's score: 11.5843
# Early stopping, best iteration is:
# [29]	valid_0's l2: 8419.05	valid_0's score: 10.4238

# %%
params = {
    'learning_rate': 0.01,
    'objective': 'regression',
    'metric':'mae',
    'seed':42
}

# %%
capacity = 1000
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l1: 44.8488	valid_0's score: 10.5566
# [1000]	valid_0's l1: 46.0278	valid_0's score: 10.5881
# Early stopping, best iteration is:
# [408]	valid_0's l1: 45.9944	valid_0's score: 10.466

# %% [markdown]
# #### - dangjin_ware

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, 
                                                                                                      y_train_dangjin_ware, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin_ware, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
from sklearn.metrics import r2_score, mean_squared_error


# 탐색 대상 함수 (XGBRegressor)
def LGB_cv(learning_rate, 
           feature_fraction, 
           bagging_fraction,
           lambda_l2,
           silent=True, 
           nthread=-1):

    params = {"learning_rate": learning_rate,
                "feature_fraction" : feature_fraction,
                "bagging_fraction" : bagging_fraction, 
               "lambda_l2" : lambda_l2,
               "objective" :  "regression",
              "nthread" : nthread
                }
    
  # 모델 정의
    model = lgb.train(params,
                      train_dataset,
                      feval = nmae_10
                     )

  # 예측값 출력
    y_pred = model.predict(X_valid_dangjin_lgb)

  # 각종 metric 계산
    mae = np.mean(nmae_10(y_valid_dangjin_lgb, y_pred))

  # 오차 최적화로 사용할 metric 반환
    return 1/mae

# %%
import scipy.optimize as optimize
from bayes_opt import BayesianOptimization

params = {"learning_rate": (0.0001, 0.2),
            "feature_fraction" : (0.0001, 1),
            "bagging_fraction" : (0.0001, 1), 
           "lambda_l2" : (0 , 1),
            }

capacity = 700
train_max = 1
train_min = 0

bo=BayesianOptimization(f=LGB_cv, 
                        pbounds=params, 
                        verbose=2, 
                        random_state=42 )

bo.maximize(init_points=2, n_iter=100, acq='ei', xi=0.01)

print(bo.max)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l2 | learni... |
# -------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  1        |  0.1058   |  0.3746   |  0.9507   |  0.732    |  0.1198   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000065 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  2        |  0.05631  |  0.1561   |  0.1561   |  0.05808  |  0.1732   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  3        |  0.1051   |  0.3569   |  0.939    |  0.6836   |  0.13     |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  4        |  0.1045   |  1.0      |  1.0      |  0.728    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000088 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  5        |  0.03753  |  1.0      |  0.3262   |  1.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  6        |  0.1059   |  0.807    |  1.0      |  0.3076   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  7        |  0.1047   |  0.02231  |  0.9827   |  0.9953   |  0.1835   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  8        |  0.03767  |  0.0001   |  1.0      |  0.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000158 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  9        |  0.1038   |  0.6694   |  1.0      |  0.6209   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000396 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  10       |  0.03767  |  1.0      |  1.0      |  0.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000402 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  11       |  0.1046   |  0.1735   |  0.6761   |  0.9404   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  12       |  0.03764  |  0.0001   |  0.7821   |  0.8588   |  0.0001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  13       |  0.1048   |  0.2599   |  0.8964   |  0.9948   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000380 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  14       |  0.07728  |  0.2063   |  0.9699   |  0.01434  |  0.01399  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000056 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  15       |  0.05618  |  0.4484   |  0.088    |  0.05172  |  0.1674   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000099 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  16       |  0.1043   |  0.08316  |  0.7984   |  0.922    |  0.1943   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000098 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  17       |  0.1047   |  0.8038   |  0.9873   |  0.3207   |  0.194    |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  18       |  0.1057   |  0.5379   |  1.0      |  0.3003   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000107 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  19       |  0.1053   |  0.7139   |  0.7476   |  0.04331  |  0.08061  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000355 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  20       |  0.1034   |  0.8454   |  0.7179   |  0.2954   |  0.1082   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000113 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  21       |  0.1042   |  0.6083   |  0.7495   |  0.1901   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000435 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  22       |  0.1038   |  0.5614   |  0.7788   |  0.7081   |  0.1854   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  23       |  0.1044   |  0.5538   |  0.9907   |  0.00868  |  0.1915   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000064 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  24       |  0.05635  |  0.05851  |  0.1289   |  0.5504   |  0.1739   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000138 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  25       |  0.1023   |  0.9474   |  0.6037   |  0.1687   |  0.08809  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000487 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  26       |  0.1043   |  0.7243   |  1.0      |  0.9636   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000081 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  27       |  0.1048   |  0.06151  |  0.516    |  0.4271   |  0.1906   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  28       |  0.1056   |  0.3079   |  0.6207   |  0.4087   |  0.176    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  29       |  0.03759  |  0.6851   |  0.5585   |  0.198    |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  30       |  0.1041   |  0.7663   |  0.8453   |  0.1634   |  0.1923   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000112 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |
seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  75       |  0.1041   |  1.0      |  0.8692   |  0.5717   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000411 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  76       |  0.03762  |  0.5439   |  0.6812   |  1.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  77       |  0.1044   |  0.4706   |  0.6751   |  0.7622   |  0.1188   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  78       |  0.104    |  0.08815  |  0.9392   |  0.4788   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  79       |  0.1039   |  0.6537   |  0.8316   |  0.8563   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  80       |  0.1035   |  0.5388   |  0.6804   |  0.8505   |  0.1905   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  81       |  0.1021   |  1.0      |  0.7913   |  0.9966   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  82       |  0.104    |  0.5999   |  0.8722   |  0.472    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000104 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  83       |  0.1029   |  0.8403   |  0.6401   |  0.3885   |  0.06085  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  84       |  0.08859  |  0.6492   |  0.9227   |  0.4176   |  0.02113  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000504 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  85       |  0.08965  |  0.4647   |  0.6815   |  0.04797  |  0.02603  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000097 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  86       |  0.09273  |  1.0      |  0.5464   |  0.4248   |  0.03433  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  87       |  0.1052   |  0.3806   |  0.5287   |  0.8465   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000103 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  88       |  0.1052   |  0.3052   |  0.6832   |  0.6557   |  0.1931   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000100 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  89       |  0.1037   |  0.445    |  0.5343   |  0.6085   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  90       |  0.105    |  0.8164   |  0.5983   |  0.5459   |  0.1856   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000089 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  91       |  0.09729  |  0.8151   |  0.4371   |  0.7856   |  0.1385   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000106 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  92       |  0.09621  |  0.5968   |  0.4885   |  0.795    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  93       |  0.05234  |  0.5776   |  0.7323   |  0.8554   |  0.005388 |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000122 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  94       |  0.1048   |  0.668    |  0.9898   |  0.615    |  0.1855   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  95       |  0.1048   |  0.3545   |  0.6637   |  0.8519   |  0.1375   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  96       |  0.1058   |  0.3832   |  0.9584   |  0.9609   |  0.1061   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000392 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  97       |  0.1054   |  0.07344  |  0.9753   |  0.6798   |  0.1204   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000125 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  98       |  0.1049   |  0.4706   |  0.8469   |  0.7939   |  0.143    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  99       |  0.1046   |  0.1718   |  1.0      |  0.6296   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000101 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  100      |  0.1054   |  0.4756   |  0.8511   |  0.7944   |  0.1463   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000100 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  101      |  0.1037   |  0.9139   |  0.5939   |  0.7031   |  0.1689   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# |  102      |  0.1018   |  0.3593   |  0.6348   |  0.5941   |  0.06537  |
# =========================================================================
# {'target': 0.10588371500339944, 'params': {'bagging_fraction': 1.0, 'feature_fraction': 1.0, 'lambda_l2': 0.4895603572656096, 'learning_rate': 0.2}}

# %%
params = {"learning_rate": 0.2,
            "feature_fraction" : 1,
            "bagging_fraction" : 1, 
           "lambda_l2" :  0.4895603572656096,
          "objective" : 'regression'
            }

# %%
capacity = 700
dangjin_model = lgb.train(params, train_dataset, 10000, val_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000427 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 5836.37	valid_0's score: 12.9342
# [1000]	valid_0's l2: 5963.06	valid_0's score: 12.898
# Early stopping, best iteration is:
# [11]	valid_0's l2: 3828.07	valid_0's score: 10.5533

# %%
params = {
    'learning_rate': 0.01,
    'objective': 'regression',
    'metric':'mae',
    'seed':42
}

# %%
capacity = 700
dangjin_model = lgb.train(params, train_dataset, 10000, val_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000189 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l1: 30.7167	valid_0's score: 10.3841
# [1000]	valid_0's l1: 36.7864	valid_0's score: 11.367
# Early stopping, best iteration is:
# [391]	valid_0's l1: 31.4522	valid_0's score: 10.3145

# %% [markdown]
# #### - dangjin_float

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, 
                                                                                                      y_train_dangjin_float, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin_float, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
from sklearn.metrics import r2_score, mean_squared_error


# 탐색 대상 함수 (XGBRegressor)
def LGB_cv(learning_rate, 
           feature_fraction, 
           bagging_fraction,
           lambda_l2,
           silent=True, 
           nthread=-1):

    params = {"learning_rate": learning_rate,
                "feature_fraction" : feature_fraction,
                "bagging_fraction" : bagging_fraction, 
               "lambda_l2" : lambda_l2,
               "objective" :  "regression",
              "nthread" : nthread
                }
    
  # 모델 정의
    model = lgb.train(params,
                      train_dataset,
                      feval = nmae_10
                     )

  # 예측값 출력
    y_pred = model.predict(X_valid_dangjin_lgb)

  # 각종 metric 계산
    mae = np.mean(nmae_10(y_valid_dangjin_lgb, y_pred))

  # 오차 최적화로 사용할 metric 반환
    return 1/mae

# %%
import scipy.optimize as optimize
from bayes_opt import BayesianOptimization

params = {"learning_rate": (0.0001, 0.2),
            "feature_fraction" : (0.0001, 1),
            "bagging_fraction" : (0.0001, 1), 
           "lambda_l2" : (0 , 1),
            }

capacity = 1000
train_max = 1
train_min = 0

bo=BayesianOptimization(f=LGB_cv, 
                        pbounds=params, 
                        verbose=2, 
                        random_state=42 )

bo.maximize(init_points=2, n_iter=100, acq='ei', xi=0.01)

print(bo.max)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l2 | learni... |
# -------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  1        |  0.1214   |  0.3746   |  0.9507   |  0.732    |  0.1198   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000065 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |
|
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000361 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  95       |  0.1184   |  0.4357   |  0.8102   |  0.8602   |  0.1592   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  96       |  0.1155   |  0.9411   |  0.7089   |  0.4436   |  0.1955   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000403 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  97       |  0.1186   |  0.07344  |  0.9753   |  0.6798   |  0.1204   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000109 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  98       |  0.119    |  0.1242   |  0.9528   |  0.729    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000119 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  99       |  0.1151   |  0.2749   |  0.8699   |  0.8279   |  0.03692  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000349 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  100      |  0.1165   |  0.1874   |  0.878    |  0.5393   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000365 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  101      |  0.1181   |  0.6907   |  0.7914   |  0.7392   |  0.1103   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000132 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# |  102      |  0.1161   |  0.0001   |  0.8091   |  0.7802   |  0.2      |
# =========================================================================
# {'target': 0.12137219468331263, 'params': {'bagging_fraction': 0.37460266483547777, 'feature_fraction': 0.9507192349792751, 'lambda_l2': 0.7319939418114051, 'learning_rate': 0.11977183099098763}}

# %%
params = {"learning_rate": 0.11977183099098763,
            "feature_fraction" : 0.9507192349792751,
            "bagging_fraction" : 0.37460266483547777, 
           "lambda_l2" :  0.7319939418114051,
          "objective" : 'regression'
            }

# %%
capacity = 1000
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000480 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 6379.21	valid_0's score: 9.28699
# [1000]	valid_0's l2: 6618.53	valid_0's score: 9.45409
# Early stopping, best iteration is:
# [39]	valid_0's l2: 5322.11	valid_0's score: 8.2527

# %%
params = {
    'learning_rate': 0.01,
    'objective': 'regression',
    'metric':'mae',
    'seed':42
}

# %%
capacity = 1000
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000382 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l1: 37.6663	valid_0's score: 8.10502
# [1000]	valid_0's l1: 36.7503	valid_0's score: 8.19653
# Early stopping, best iteration is:
# [340]	valid_0's l1: 40.6576	valid_0's score: 8.04963

# %% [markdown]
# #### -ulsan

# %%
X_train_ulsan_lgb, X_valid_ulsan_lgb, y_train_ulsan_lgb, y_valid_ulsan_lgb = train_test_split(X_train_ulsan, 
                                                                                                      y_train_ulsan, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_ulsan_lgb = np.reshape(X_train_ulsan_lgb, [-1,np.shape(X_train_ulsan_lgb)[-1]])
X_valid_ulsan_lgb = np.reshape(X_valid_ulsan_lgb, [-1,np.shape(X_valid_ulsan_lgb)[-1]])

# %%
y_train_ulsan_lgb = np.reshape(y_train_ulsan_lgb, [-1])
y_valid_ulsan_lgb = np.reshape(y_valid_ulsan_lgb, [-1])

# %%
X_test_ulsan_lgb = np.reshape(X_test_ulsan, [-1,np.shape(X_test_ulsan)[-1]])
y_test_ulsan_lgb = np.reshape(y_test_ulsan, [-1])

# %%
train_dataset = lgb.Dataset(X_train_ulsan_lgb, y_train_ulsan_lgb)
test_dataset = lgb.Dataset(X_test_ulsan_lgb, y_test_ulsan_lgb)
val_dataset = lgb.Dataset(X_valid_ulsan_lgb, y_valid_ulsan_lgb)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
from sklearn.metrics import r2_score, mean_squared_error


# 탐색 대상 함수 (XGBRegressor)
def LGB_cv(learning_rate, 
           feature_fraction, 
           bagging_fraction,
           lambda_l2,
           silent=True, 
           nthread=-1):

    params = {"learning_rate": learning_rate,
                "feature_fraction" : feature_fraction,
                "bagging_fraction" : bagging_fraction, 
               "lambda_l2" : lambda_l2,
               "objective" :  "regression",
              "nthread" : nthread
                }
    
  # 모델 정의
    model = lgb.train(params,
                      train_dataset,
                      feval = nmae_10
                     )

  # 예측값 출력
    y_pred = model.predict(X_valid_ulsan_lgb)

  # 각종 metric 계산
    mae = np.mean(nmae_10(y_valid_ulsan_lgb, y_pred))

  # 오차 최적화로 사용할 metric 반환
    return 1/mae

# %%
import scipy.optimize as optimize
from bayes_opt import BayesianOptimization

params = {"learning_rate": (0.0001, 0.2),
            "feature_fraction" : (0.0001, 1),
            "bagging_fraction" : (0.0001, 1), 
           "lambda_l2" : (0 , 1),
            }

capacity = 500
train_max = 1
train_min = 0

bo=BayesianOptimization(f=LGB_cv, 
                        pbounds=params, 
                        verbose=2, 
                        random_state=1 )

bo.maximize(init_points=2, n_iter=100, acq='ei', xi=0.01)

print(bo.max)
# Out:
# |   iter    |  target   | baggin... | featur... | lambda_l2 | learni... |
# -------------------------------------------------------------------------
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000345 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  1        |  0.12     |  0.4171   |  0.7204   |  0.000114 |  0.06054  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000067 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# |  2        |  0.05311  |  0.1468   |  0.09243  |  0.1863   |  0.06918  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000351 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  3        |  0.123    |  0.4182   |  0.7762   |  0.009261 |  0.093    |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000132 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  4        |  0.04061  |  0.8014   |  1.0      |  0.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000367 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  5        |  0.1236   |  0.2319   |  0.7836   |  0.0      |  0.1622   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  6        |  0.1216   |  0.0213   |  0.8079   |  0.9649   |  0.1404   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000148 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  7        |  0.1248   |  0.2526   |  0.8549   |  0.3223   |  0.1548   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  8        |  0.1246   |  0.0001   |  1.0      |  0.616    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000175 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  9        |  0.1227   |  0.3429   |  1.0      |  0.8149   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000098 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  10       |  0.1223   |  0.3249   |  0.6358   |  0.4005   |  0.1503   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000395 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  11       |  0.1213   |  0.5029   |  0.5716   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000424 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  12       |  0.04056  |  0.243    |  0.7625   |  0.7078   |  0.0001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000095 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  13       |  0.1213   |  0.009563 |  0.5502   |  0.162    |  0.09561  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000108 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  14       |  0.1234   |  0.2557   |  0.8692   |  0.3336   |  0.1494   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000074 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  15       |  0.1154   |  0.2341   |  0.4471   |  0.5501   |  0.1898   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000115 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  16       |  0.1212   |  0.319    |  0.6713   |  0.1853   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000146 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  17       |  0.1248   |  0.0001   |  1.0      |  0.9821   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000121 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  18       |  0.1229   |  0.0001   |  0.8442   |  0.25     |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000144 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  19       |  0.1243   |  0.54     |  1.0      |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000416 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  20       |  0.1222   |  0.8122   |  0.711    |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000078 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |
|
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000523 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  73       |  0.121    |  0.05526  |  0.8842   |  0.8166   |  0.1983   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000131 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  74       |  0.1224   |  0.0001   |  0.5201   |  0.7793   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000100 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  75       |  0.1229   |  0.5273   |  0.8081   |  0.79     |  0.1287   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000168 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  76       |  0.1227   |  0.4181   |  0.8334   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000093 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  77       |  0.117    |  0.9143   |  0.5663   |  1.0      |  0.0542   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000097 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  78       |  0.1213   |  0.1986   |  0.5882   |  1.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000118 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  79       |  0.1225   |  0.0001   |  0.8264   |  0.4562   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000362 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  80       |  0.1211   |  0.6042   |  0.6901   |  0.6522   |  0.08308  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000124 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  81       |  0.1121   |  0.5613   |  0.9634   |  0.4635   |  0.02462  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000074 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  82       |  0.091    |  0.2757   |  0.393    |  0.5682   |  0.02402  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000092 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  83       |  0.1153   |  0.0001   |  0.421    |  0.0      |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000150 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  84       |  0.123    |  0.5017   |  1.0      |  0.8363   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  85       |  0.124    |  0.419    |  0.783    |  0.007542 |  0.1001   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000137 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  86       |  0.1236   |  0.3803   |  1.0      |  0.2949   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000397 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  87       |  0.1224   |  0.3063   |  0.7593   |  0.3632   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000399 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  88       |  0.123    |  0.1314   |  0.8801   |  0.9807   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  89       |  0.1137   |  0.5423   |  0.627    |  0.498    |  0.03662  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000091 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  90       |  0.04048  |  0.0001   |  0.4712   |  1.0      |  0.0001   |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000366 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  91       |  0.122    |  0.08453  |  0.7102   |  0.8912   |  0.1954   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000114 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  92       |  0.1193   |  0.5923   |  0.6222   |  0.845    |  0.0708   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000133 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  93       |  0.1244   |  0.8554   |  0.8524   |  0.8104   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000377 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  94       |  0.123    |  0.5842   |  0.8091   |  0.6512   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  95       |  0.1156   |  0.0001   |  0.4679   |  0.2831   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000439 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  96       |  0.1231   |  0.8025   |  1.0      |  0.6312   |  0.2      |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000389 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  97       |  0.1223   |  0.02707  |  0.807    |  0.9745   |  0.1405   |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000089 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  98       |  0.08258  |  0.2389   |  0.3062   |  0.4796   |  0.02583  |
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000452 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  99       |  0.08909  |  0.1669   |  0.4606   |  0.001345 |  0.02278  |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  100      |  0.1203   |  0.0001   |  0.5566   |  0.5639   |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  101      |  0.1225   |  0.2723   |  0.8507   |  0.176    |  0.2      |
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000126 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# |  102      |  0.125    |  0.3537   |  0.9414   |  0.02487  |  0.1953   |
# =========================================================================
# {'target': 0.125443005960253, 'params': {'bagging_fraction': 0.9307091108023549, 'feature_fraction': 0.9124991619004987, 'lambda_l2': 0.7549427348064354, 'learning_rate': 0.13790082625336098}}

# %%
params = {"learning_rate": 0.13790082625336098,
            "feature_fraction" : 0.9124991619004987,
            "bagging_fraction" : 0.9307091108023549, 
           "lambda_l2" :  0.7549427348064354,
          "objective" : 'regression'
            }

# %%
capacity = 500
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000458 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 808.105	valid_0's score: 6.87715
# [1000]	valid_0's l2: 841.875	valid_0's score: 7.07593
# Early stopping, best iteration is:
# [83]	valid_0's l2: 712.239	valid_0's score: 6.67974

# %%
params = {
    'learning_rate': 0.01,
    'objective': 'regression',
    'metric':'mae',
    'seed':42
}

# %%
capacity = 500
dangjin_model = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000149 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l1: 12.9847	valid_0's score: 6.52038
# [1000]	valid_0's l1: 12.2772	valid_0's score: 6.31288
# [1500]	valid_0's l1: 12.6493	valid_0's score: 6.37416
# Early stopping, best iteration is:
# [943]	valid_0's l1: 12.2219	valid_0's score: 6.33024

# %% [markdown]
# ### (2) 모델 학습

# %%
def nmae_10_lgb(y_pred, dataset):
    y_true = dataset.get_label()
    
    absolute_error = abs(y_true - y_pred)
    absolute_error /= capacity
    
    target_idx = np.where(y_true>=capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx].mean()
    
    return 'score', nmae, False

# %% [markdown]
# #### -dangjin

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, y_train_dangjin, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin, [-1])

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_valid_dangjin_lgb, y_valid_dangjin_lgb)

# %%
params = {"learning_rate": 0.11703047303328216,
            "feature_fraction" : 0.917548055585948,
            "bagging_fraction" : 0.4542746828242898, 
           "lambda_l2" :  0.2836245541577052,
          "objective" : 'regression'
            }

# %%
capacity = 1000
Models_dangjin = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000423 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 139.977576
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 9187.11	valid_0's score: 11.2619
# [1000]	valid_0's l2: 9545.01	valid_0's score: 11.5843
# Early stopping, best iteration is:
# [29]	valid_0's l2: 8419.05	valid_0's score: 10.4238

# %% [markdown]
# #### -dangjin_ware

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, 
                                                                                                      y_train_dangjin_ware, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin_ware, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_valid_dangjin_lgb, y_valid_dangjin_lgb)

# %%
params = {"learning_rate": 0.2,
            "feature_fraction" : 1,
            "bagging_fraction" : 1, 
           "lambda_l2" :  0.4895603572656096,
          "objective" : 'regression'
            }

# %%
capacity = 700
Models_dangjin_warehouse = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000374 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 92.546364
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 5836.37	valid_0's score: 12.9342
# [1000]	valid_0's l2: 5963.06	valid_0's score: 12.898
# Early stopping, best iteration is:
# [11]	valid_0's l2: 3828.07	valid_0's score: 10.5533

# %% [markdown]
# #### - dangjin_float

# %%
X_train_dangjin_lgb, X_valid_dangjin_lgb, y_train_dangjin_lgb, y_valid_dangjin_lgb = train_test_split(X_train_dangjin, 
                                                                                                      y_train_dangjin_float, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_dangjin_lgb = np.reshape(X_train_dangjin_lgb, [-1,np.shape(X_train_dangjin_lgb)[-1]])
X_valid_dangjin_lgb = np.reshape(X_valid_dangjin_lgb, [-1,np.shape(X_valid_dangjin_lgb)[-1]])

# %%
y_train_dangjin_lgb = np.reshape(y_train_dangjin_lgb, [-1])
y_valid_dangjin_lgb = np.reshape(y_valid_dangjin_lgb, [-1])

# %%
X_test_dangjin_lgb = np.reshape(X_test_dangjin, [-1,np.shape(X_test_dangjin)[-1]])
y_test_dangjin_lgb = np.reshape(y_test_dangjin_float, [-1])

# %%
train_dataset = lgb.Dataset(X_train_dangjin_lgb, y_train_dangjin_lgb)
test_dataset = lgb.Dataset(X_test_dangjin_lgb, y_test_dangjin_lgb)
val_dataset = lgb.Dataset(X_valid_dangjin_lgb, y_valid_dangjin_lgb)

# %%
params = {"learning_rate": 0.11977183099098763,
            "feature_fraction" : 0.9507192349792751,
            "bagging_fraction" : 0.37460266483547777, 
           "lambda_l2" :  0.7319939418114051,
          "objective" : 'regression'
            }

# %%
capacity = 1000
Models_dangjin_floating = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000366 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19800, number of used features: 9
# [LightGBM] [Info] Start training from score 122.399495
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 6379.21	valid_0's score: 9.28699
# [1000]	valid_0's l2: 6618.53	valid_0's score: 9.45409
# Early stopping, best iteration is:
# [39]	valid_0's l2: 5322.11	valid_0's score: 8.2527

# %% [markdown]
# #### - ulsan

# %%
X_train_ulsan_lgb, X_valid_ulsan_lgb, y_train_ulsan_lgb, y_valid_ulsan_lgb = train_test_split(X_train_ulsan, 
                                                                                                      y_train_ulsan, 
                                                                                                      test_size = 0.2,
                                                                                                     random_state = 42)

# %%
X_train_ulsan_lgb = np.reshape(X_train_ulsan_lgb, [-1,np.shape(X_train_ulsan_lgb)[-1]])
X_valid_ulsan_lgb = np.reshape(X_valid_ulsan_lgb, [-1,np.shape(X_valid_ulsan_lgb)[-1]])

# %%
y_train_ulsan_lgb = np.reshape(y_train_ulsan_lgb, [-1])
y_valid_ulsan_lgb = np.reshape(y_valid_ulsan_lgb, [-1])

# %%
X_test_ulsan_lgb = np.reshape(X_test_ulsan, [-1,np.shape(X_test_ulsan)[-1]])
y_test_ulsan_lgb = np.reshape(y_test_ulsan, [-1])

# %%
train_dataset = lgb.Dataset(X_train_ulsan_lgb, y_train_ulsan_lgb)
test_dataset = lgb.Dataset(X_test_ulsan_lgb, y_test_ulsan_lgb)
val_dataset = lgb.Dataset(X_valid_ulsan_lgb, y_valid_ulsan_lgb)

# %%
params = {"learning_rate": 0.13790082625336098,
            "feature_fraction" : 0.9124991619004987,
            "bagging_fraction" : 0.9307091108023549, 
           "lambda_l2" :  0.7549427348064354,
          "objective" : 'regression'
            }

# %%
capacity = 500
Models_ulsan = lgb.train(params, train_dataset, 10000, test_dataset, feval=nmae_10_lgb, verbose_eval=500, early_stopping_rounds=1000)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000123 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1094
# [LightGBM] [Info] Number of data points in the train set: 19824, number of used features: 9
# [LightGBM] [Info] Start training from score 64.663186
# Training until validation scores don't improve for 1000 rounds
# [500]	valid_0's l2: 808.105	valid_0's score: 6.87715
# [1000]	valid_0's l2: 841.875	valid_0's score: 7.07593
# Early stopping, best iteration is:
# [83]	valid_0's l2: 712.239	valid_0's score: 6.67974

# %% [markdown]
# ### 2) LSTM_AUTOENCODER

# %% [markdown]
# ### (1) min_max_scale

# %%
train_min_dangjin = np.min(X_train_dangjin)
train_max_dangjin = np.max(X_train_dangjin)

X_train_dangjin_scaled = (X_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

X_test_dangjin_scaled = (X_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

#X_train_dangjin_scaled[:,:,4] = X_train_dangjin[:,:,4]

#X_test_dangjin_scaled[:,:,4] = X_test_dangjin[:,:,4]

# %%
y_train_dangjin_scaled = (y_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_scaled = (y_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_ware_scaled = (y_train_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_ware_scaled = (y_test_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_float_scaled = (y_train_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_float_scaled = (y_test_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %% [markdown]
# #### - 울산

# %%
train_min_ulsan = np.min(X_train_ulsan)
train_max_ulsan = np.max(X_train_ulsan)

X_train_ulsan_scaled = (X_train_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

X_test_ulsan_scaled = (X_test_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

#X_train_ulsan_scaled[:,:,4] = X_train_ulsan[:,:,4]

#X_test_ulsan_scaled[:,:,4] = X_test_ulsan[:,:,4]

# %%
y_train_ulsan_scaled = (y_train_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

y_test_ulsan_scaled = (y_test_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

# %%
class SimpleRNN(Model):
    def __init__(self, hidden_size, out_size):
        super().__init__()
        self.l1 = layer.RNN(hidden_size)
        self.l2 = layer.Linear(out_size, initializer_func='he_uniform')
        
    def forward(self, x):
        y = self.l1(x)
        y = self.l2(y)
        return y

# %%
Models_dangjin = SimpleRNN(200, 24)

optimizers = optimizer.Adam(0.001)

optimizers.setup(Models_dangjin)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
def train_step_dangjin(inp , tar):
    global loss
    with GradientTape() as tape:
        for i in range(inp.shape()[1]):
            output = Models_dangjin(inp[:,i,:])
        loss = f.loss.mean_squared_error(output, tar)
    tape.CalcGradient()
    optimizers.update()
    Models_dangjin.l1.reset_state()

# %%
@tf.function()
def train_step_dangjin_ware(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_dangjin_warehouse(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_dangjin_warehouse.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin_warehouse.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_dangjin_float(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_dangjin_floating(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_dangjin_floating.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin_floating.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_ulsan(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_ulsan(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_ulsan.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_ulsan.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
def val_accuracy(inp, tar, Models):
    output = Models(inp)
    
    test_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
EPOCHS = 200
batch_size = 50

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()
 
for epoch in range(10):
    start = time.time()
    
    i = 1

    while True:

        inp = Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)])
        inp = f.linalg.transpose(inp, [0,2,1])
        
        tar = Variable(y_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)])
        
        i += 1
        
        train_step_dangjin(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {loss.data} Accuracy ')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            break
# Out:
# Epoch 1 Batch 5 Loss 205.84110741533033 Accuracy
# Epoch 1 Batch 10 Loss 1594.8142129724363 Accuracy
# Epoch 1 Batch 15 Loss 3407.0708174078113 Accuracy
# Epoch 1 Batch 20 Loss 3100.6072175412696 Accuracy
# Time taken for 1 epoch: 0.20 secs
#
# Epoch 2 Batch 5 Loss 165.3677688819853 Accuracy
# Epoch 2 Batch 10 Loss 100.99069659847213 Accuracy
# Epoch 2 Batch 15 Loss 42.787594681681895 Accuracy
# Epoch 2 Batch 20 Loss 120.16156157236615 Accuracy
# Time taken for 1 epoch: 0.20 secs
#
# Epoch 3 Batch 5 Loss 155.45801413575032 Accuracy
# Epoch 3 Batch 10 Loss 190.767014200542 Accuracy
# Epoch 3 Batch 15 Loss 92.91888043925901 Accuracy
# Epoch 3 Batch 20 Loss 198.14294872328873 Accuracy
# Time taken for 1 epoch: 0.19 secs
#
# Epoch 4 Batch 5 Loss 221.92792179078148 Accuracy
# Epoch 4 Batch 10 Loss 254.61227086854663 Accuracy
# Epoch 4 Batch 15 Loss 124.01077950163508 Accuracy
# Epoch 4 Batch 20 Loss 252.4432272521898 Accuracy
# Time taken for 1 epoch: 0.19 secs
#
# Epoch 5 Batch 5 Loss 275.83241531852616 Accuracy
# Epoch 5 Batch 10 Loss 317.2566133830821 Accuracy
# Epoch 5 Batch 15 Loss 156.08670136152136 Accuracy
# Epoch 5 Batch 20 Loss 312.8061292806203 Accuracy
# Time taken for 1 epoch: 0.19 secs
#
# Epoch 6 Batch 5 Loss 335.75017316611104 Accuracy
# Epoch 6 Batch 10 Loss 387.3412905575228 Accuracy
# Epoch 6 Batch 15 Loss 192.2416027629357 Accuracy
# Epoch 6 Batch 20 Loss 379.92861091047644 Accuracy
# Time taken for 1 epoch: 0.20 secs
#
# Epoch 7 Batch 5 Loss 401.2631791108288 Accuracy
# Epoch 7 Batch 10 Loss 463.89471804339263 Accuracy
# Epoch 7 Batch 15 Loss 231.60615151895456 Accuracy
# Epoch 7 Batch 20 Loss 452.7616815874983 Accuracy
# Time taken for 1 epoch: 0.20 secs
#
# Epoch 8 Batch 5 Loss 471.49865798736727 Accuracy
# Epoch 8 Batch 10 Loss 546.0736632082593 Accuracy
# Epoch 8 Batch 15 Loss 273.6308722737083 Accuracy
# Epoch 8 Batch 20 Loss 530.6501797305377 Accuracy
# Time taken for 1 epoch: 0.19 secs
#
# Epoch 9 Batch 5 Loss 545.9373329442693 Accuracy
# Epoch 9 Batch 10 Loss 633.3411249293124 Accuracy
# Epoch 9 Batch 15 Loss 317.9874399273337 Accuracy
# Epoch 9 Batch 20 Loss 613.1461612942086 Accuracy
# Time taken for 1 epoch: 0.19 secs
#
# Epoch 10 Batch 5 Loss 624.2157680839737 Accuracy
# Epoch 10 Batch 10 Loss 725.296350579104 Accuracy
# Epoch 10 Batch 15 Loss 364.43464451896864 Accuracy
# Epoch 10 Batch 20 Loss 699.8944415947465 Accuracy
# Time taken for 1 epoch: 0.19 secs

# %%
Models_dangjin.l1.reset_state()

# %%
for i in range(inp.shape()[1]):
    output = Models_dangjin(inp[:, i ,:])

# %%
capacity = 700
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_ware_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin_ware(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_ware_scaled, Models_dangjin_warehouse)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.2723 Accuracy 9.4290
# Epoch 1 Batch 10 Loss 0.2979 Accuracy 10.4948
# Epoch 1 Batch 15 Loss 0.2755 Accuracy 10.8253
# Epoch 1 Batch 20 Loss 0.2739 Accuracy 10.7299
# Time taken for 1 epoch: 5.70 secs
#
# TestLoss 0.0000 TestAccuracy 11.3422
# Epoch 2 Batch 5 Loss 0.2778 Accuracy 10.7166
# Epoch 2 Batch 10 Loss 0.2647 Accuracy 10.3878
# Epoch 2 Batch 15 Loss 0.2534 Accuracy 10.2421
# Epoch 2 Batch 20 Loss 0.2527 Accuracy 10.2024
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 11.3532
# Epoch 3 Batch 5 Loss 0.2556 Accuracy 10.1418
# Epoch 3 Batch 10 Loss 0.2498 Accuracy 10.0402
# Epoch 3 Batch 15 Loss 0.2452 Accuracy 9.9903
# Epoch 3 Batch 20 Loss 0.2427 Accuracy 9.9293
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 11.3021
# Epoch 4 Batch 5 Loss 0.2443 Accuracy 9.8298
# Epoch 4 Batch 10 Loss 0.2399 Accuracy 9.7778
# Epoch 4 Batch 15 Loss 0.2354 Accuracy 9.7146
# Epoch 4 Batch 20 Loss 0.2336 Accuracy 9.6474
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 11.3086
# Epoch 5 Batch 5 Loss 0.2338 Accuracy 9.5742
# Epoch 5 Batch 10 Loss 0.2302 Accuracy 9.4969
# Epoch 5 Batch 15 Loss 0.2272 Accuracy 9.4945
# Epoch 5 Batch 20 Loss 0.2257 Accuracy 9.4474
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 11.2314
# Epoch 6 Batch 5 Loss 0.2257 Accuracy 9.3995
# Epoch 6 Batch 10 Loss 0.2229 Accuracy 9.3387
# Epoch 6 Batch 15 Loss 0.2206 Accuracy 9.3262
# Epoch 6 Batch 20 Loss 0.2194 Accuracy 9.2941
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 11.2614
# Epoch 7 Batch 5 Loss 0.2197 Accuracy 9.2637
# Epoch 7 Batch 10 Loss 0.2173 Accuracy 9.2109
# Epoch 7 Batch 15 Loss 0.2154 Accuracy 9.1929
# Epoch 7 Batch 20 Loss 0.2146 Accuracy 9.1555
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 11.2940
# Epoch 8 Batch 5 Loss 0.2153 Accuracy 9.1553
# Epoch 8 Batch 10 Loss 0.2146 Accuracy 9.1503
# Epoch 8 Batch 15 Loss 0.2140 Accuracy 9.1625
# Epoch 8 Batch 20 Loss 0.2150 Accuracy 9.1807
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 11.3284
# Epoch 9 Batch 5 Loss 0.2171 Accuracy 9.2283
# Epoch 9 Batch 10 Loss 0.2164 Accuracy 9.2111
# Epoch 9 Batch 15 Loss 0.2159 Accuracy 9.2390
# Epoch 9 Batch 20 Loss 0.2162 Accuracy 9.2335
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.3123
# Epoch 10 Batch 5 Loss 0.2179 Accuracy 9.2414
# Epoch 10 Batch 10 Loss 0.2170 Accuracy 9.2411
# Epoch 10 Batch 15 Loss 0.2162 Accuracy 9.2379
# Epoch 10 Batch 20 Loss 0.2170 Accuracy 9.2488
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 11.5741
# Epoch 11 Batch 5 Loss 0.2181 Accuracy 9.2541
# Epoch 11 Batch 10 Loss 0.2174 Accuracy 9.2528
# Epoch 11 Batch 15 Loss 0.2168 Accuracy 9.2741
# Epoch 11 Batch 20 Loss 0.2168 Accuracy 9.2704
# Time taken for 1 epoch: 1.31 secs
#
# TestLoss 0.0000 TestAccuracy 11.7016
# Epoch 12 Batch 5 Loss 0.2174 Accuracy 9.2658
# Epoch 12 Batch 10 Loss 0.2166 Accuracy 9.2529
# Epoch 12 Batch 15 Loss 0.2159 Accuracy 9.2572
# Epoch 12 Batch 20 Loss 0.2161 Accuracy 9.2622
# Time taken for 1 epoch: 1.29 secs
#
# TestLoss 0.0000 TestAccuracy 11.8137
# Epoch 13 Batch 5 Loss 0.2169 Accuracy 9.2663
# Epoch 13 Batch 10 Loss 0.2167 Accuracy 9.2713
# Epoch 13 Batch 15 Loss 0.2168 Accuracy 9.3062
# Epoch 13 Batch 20 Loss 0.2168 Accuracy 9.3104
# Time taken for 1 epoch: 1.31 secs
#
# TestLoss 0.0000 TestAccuracy 11.8984
# Epoch 14 Batch 5 Loss 0.2175 Accuracy 9.3131
# Epoch 14 Batch 10 Loss 0.2170 Accuracy 9.2992
# Epoch 14 Batch 15 Loss 0.2164 Accuracy 9.3044
# Epoch 14 Batch 20 Loss 0.2173 Accuracy 9.3268
# Time taken for 1 epoch: 1.29 secs
#
# TestLoss 0.0000 TestAccuracy 11.8754
# Epoch 15 Batch 5 Loss 0.2180 Accuracy 9.3442
# Epoch 15 Batch 10 Loss 0.2177 Accuracy 9.3348
# Epoch 15 Batch 15 Loss 0.2174 Accuracy 9.3447
# Epoch 15 Batch 20 Loss 0.2171 Accuracy 9.3424
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 11.8991
# Epoch 16 Batch 5 Loss 0.2174 Accuracy 9.3268
# Epoch 16 Batch 10 Loss 0.2170 Accuracy 9.3228
# Epoch 16 Batch 15 Loss 0.2165 Accuracy 9.3237
# Epoch 16 Batch 20 Loss 0.2165 Accuracy 9.3193
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 11.9271
# Epoch 17 Batch 5 Loss 0.2166 Accuracy 9.3053
# Epoch 17 Batch 10 Loss 0.2160 Accuracy 9.2956
# Epoch 17 Batch 15 Loss 0.2154 Accuracy 9.2946
# Epoch 17 Batch 20 Loss 0.2150 Accuracy 9.2827
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 11.9482
# Epoch 18 Batch 5 Loss 0.2153 Accuracy 9.2737
# Epoch 18 Batch 10 Loss 0.2152 Accuracy 9.2685
# Epoch 18 Batch 15 Loss 0.2152 Accuracy 9.2913
# Epoch 18 Batch 20 Loss 0.2154 Accuracy 9.2901
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.9212
# Epoch 19 Batch 5 Loss 0.2164 Accuracy 9.3067
# Epoch 19 Batch 10 Loss 0.2160 Accuracy 9.2934
# Epoch 19 Batch 15 Loss 0.2155 Accuracy 9.2901
# Epoch 19 Batch 20 Loss 0.2158 Accuracy 9.2986
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 11.8923
# Epoch 20 Batch 5 Loss 0.2160 Accuracy 9.2892
# Epoch 20 Batch 10 Loss 0.2158 Accuracy 9.2838
# Epoch 20 Batch 15 Loss 0.2154 Accuracy 9.2836
# Epoch 20 Batch 20 Loss 0.2153 Accuracy 9.2803
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 11.8401
# Epoch 21 Batch 5 Loss 0.2154 Accuracy 9.2695
# Epoch 21 Batch 10 Loss 0.2148 Accuracy 9.2586
# Epoch 21 Batch 15 Loss 0.2142 Accuracy 9.2534
# Epoch 21 Batch 20 Loss 0.2139 Accuracy 9.2429
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 11.8411
# Epoch 22 Batch 5 Loss 0.2138 Accuracy 9.2304
# Epoch 22 Batch 10 Loss 0.2131 Accuracy 9.2126
# Epoch 22 Batch 15 Loss 0.2126 Accuracy 9.2141
# Epoch 22 Batch 20 Loss 0.2122 Accuracy 9.2024
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 11.8149
# Epoch 23 Batch 5 Loss 0.2120 Accuracy 9.1900
# Epoch 23 Batch 10 Loss 0.2114 Accuracy 9.1707
# Epoch 23 Batch 15 Loss 0.2107 Accuracy 9.1665
# Epoch 23 Batch 20 Loss 0.2106 Accuracy 9.1626
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 11.9182
# Epoch 24 Batch 5 Loss 0.2110 Accuracy 9.1501
# Epoch 24 Batch 10 Loss 0.2106 Accuracy 9.1448
# Epoch 24 Batch 15 Loss 0.2104 Accuracy 9.1563
# Epoch 24 Batch 20 Loss 0.2102 Accuracy 9.1483
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 11.8895
# Epoch 25 Batch 5 Loss 0.2105 Accuracy 9.1400
# Epoch 25 Batch 10 Loss 0.2100 Accuracy 9.1294
# Epoch 25 Batch 15 Loss 0.2095 Accuracy 9.1286
# Epoch 25 Batch 20 Loss 0.2092 Accuracy 9.1232
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 11.8706
# Epoch 26 Batch 5 Loss 0.2092 Accuracy 9.1132
# Epoch 26 Batch 10 Loss 0.2086 Accuracy 9.0959
# Epoch 26 Batch 15 Loss 0.2081 Accuracy 9.0945
# Epoch 26 Batch 20 Loss 0.2078 Accuracy 9.0902
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 11.8582
# Epoch 27 Batch 5 Loss 0.2077 Accuracy 9.0824
# Epoch 27 Batch 10 Loss 0.2073 Accuracy 9.0692
# Epoch 27 Batch 15 Loss 0.2069 Accuracy 9.0699
# Epoch 27 Batch 20 Loss 0.2066 Accuracy 9.0662
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 11.8526
# Epoch 28 Batch 5 Loss 0.2065 Accuracy 9.0554
# Epoch 28 Batch 10 Loss 0.2060 Accuracy 9.0436
# Epoch 28 Batch 15 Loss 0.2055 Accuracy 9.0342
# Epoch 28 Batch 20 Loss 0.2053 Accuracy 9.0321
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 11.8416
# Epoch 29 Batch 5 Loss 0.2052 Accuracy 9.0209
# Epoch 29 Batch 10 Loss 0.2052 Accuracy 9.0184
# Epoch 29 Batch 15 Loss 0.2052 Accuracy 9.0304
# Epoch 29 Batch 20 Loss 0.2054 Accuracy 9.0396
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.8375
# Epoch 30 Batch 5 Loss 0.2059 Accuracy 9.0315
# Epoch 30 Batch 10 Loss 0.2056 Accuracy 9.0261
# Epoch 30 Batch 15 Loss 0.2055 Accuracy 9.0301
# Epoch 30 Batch 20 Loss 0.2054 Accuracy 9.0263
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.8387
# Epoch 31 Batch 5 Loss 0.2055 Accuracy 9.0250
# Epoch 31 Batch 10 Loss 0.2054 Accuracy 9.0202
# Epoch 31 Batch 15 Loss 0.2054 Accuracy 9.0293
# Epoch 31 Batch 20 Loss 0.2055 Accuracy 9.0340
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 11.8083
# Epoch 32 Batch 5 Loss 0.2057 Accuracy 9.0376
# Epoch 32 Batch 10 Loss 0.2054 Accuracy 9.0289
# Epoch 32 Batch 15 Loss 0.2050 Accuracy 9.0259
# Epoch 32 Batch 20 Loss 0.2049 Accuracy 9.0246
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 11.7947
# Epoch 33 Batch 5 Loss 0.2049 Accuracy 9.0160
# Epoch 33 Batch 10 Loss 0.2047 Accuracy 9.0119
# Epoch 33 Batch 15 Loss 0.2044 Accuracy 9.0085
# Epoch 33 Batch 20 Loss 0.2044 Accuracy 9.0088
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.8122
# Epoch 34 Batch 5 Loss 0.2046 Accuracy 9.0094
# Epoch 34 Batch 10 Loss 0.2042 Accuracy 9.0003
# Epoch 34 Batch 15 Loss 0.2039 Accuracy 8.9963
# Epoch 34 Batch 20 Loss 0.2038 Accuracy 8.9944
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 11.8020
# Epoch 35 Batch 5 Loss 0.2038 Accuracy 8.9863
# Epoch 35 Batch 10 Loss 0.2035 Accuracy 8.9816
# Epoch 35 Batch 15 Loss 0.2031 Accuracy 8.9754
# Epoch 35 Batch 20 Loss 0.2030 Accuracy 8.9740
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 11.7765
# Epoch 36 Batch 5 Loss 0.2029 Accuracy 8.9651
# Epoch 36 Batch 10 Loss 0.2026 Accuracy 8.9559
# Epoch 36 Batch 15 Loss 0.2022 Accuracy 8.9569
# Epoch 36 Batch 20 Loss 0.2022 Accuracy 8.9565
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.7707
# Epoch 37 Batch 5 Loss 0.2023 Accuracy 8.9550
# Epoch 37 Batch 10 Loss 0.2020 Accuracy 8.9468
# Epoch 37 Batch 15 Loss 0.2018 Accuracy 8.9504
# Epoch 37 Batch 20 Loss 0.2019 Accuracy 8.9494
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 11.7759
# Epoch 38 Batch 5 Loss 0.2020 Accuracy 8.9505
# Epoch 38 Batch 10 Loss 0.2017 Accuracy 8.9451
# Epoch 38 Batch 15 Loss 0.2014 Accuracy 8.9421
# Epoch 38 Batch 20 Loss 0.2014 Accuracy 8.9424
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.8029
# Epoch 39 Batch 5 Loss 0.2014 Accuracy 8.9376
# Epoch 39 Batch 10 Loss 0.2012 Accuracy 8.9318
# Epoch 39 Batch 15 Loss 0.2010 Accuracy 8.9360
# Epoch 39 Batch 20 Loss 0.2009 Accuracy 8.9314
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 11.8122
# Epoch 40 Batch 5 Loss 0.2007 Accuracy 8.9227
# Epoch 40 Batch 10 Loss 0.2005 Accuracy 8.9156
# Epoch 40 Batch 15 Loss 0.2003 Accuracy 8.9203
# Epoch 40 Batch 20 Loss 0.2003 Accuracy 8.9196
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 11.8457
# Epoch 41 Batch 5 Loss 0.2003 Accuracy 8.9202
# Epoch 41 Batch 10 Loss 0.2001 Accuracy 8.9176
# Epoch 41 Batch 15 Loss 0.1999 Accuracy 8.9154
# Epoch 41 Batch 20 Loss 0.2002 Accuracy 8.9255
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.9151
# Epoch 42 Batch 5 Loss 0.2007 Accuracy 8.9275
# Epoch 42 Batch 10 Loss 0.2006 Accuracy 8.9269
# Epoch 42 Batch 15 Loss 0.2006 Accuracy 8.9329
# Epoch 42 Batch 20 Loss 0.2007 Accuracy 8.9346
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 11.9115
# Epoch 43 Batch 5 Loss 0.2008 Accuracy 8.9323
# Epoch 43 Batch 10 Loss 0.2005 Accuracy 8.9285
# Epoch 43 Batch 15 Loss 0.2003 Accuracy 8.9286
# Epoch 43 Batch 20 Loss 0.2001 Accuracy 8.9254
# Time taken for 1 epoch: 1.29 secs
#
# TestLoss 0.0000 TestAccuracy 11.9073
# Epoch 44 Batch 5 Loss 0.2000 Accuracy 8.9211
# Epoch 44 Batch 10 Loss 0.1998 Accuracy 8.9121
# Epoch 44 Batch 15 Loss 0.1996 Accuracy 8.9148
# Epoch 44 Batch 20 Loss 0.1996 Accuracy 8.9143
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 11.9160
# Epoch 45 Batch 5 Loss 0.1995 Accuracy 8.9135
# Epoch 45 Batch 10 Loss 0.1993 Accuracy 8.9065
# Epoch 45 Batch 15 Loss 0.1990 Accuracy 8.9034
# Epoch 45 Batch 20 Loss 0.1989 Accuracy 8.9015
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 11.9436
# Epoch 46 Batch 5 Loss 0.1989 Accuracy 8.8951
# Epoch 46 Batch 10 Loss 0.1986 Accuracy 8.8904
# Epoch 46 Batch 15 Loss 0.1985 Accuracy 8.8930
# Epoch 46 Batch 20 Loss 0.1984 Accuracy 8.8930
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 11.9649
# Epoch 47 Batch 5 Loss 0.1986 Accuracy 8.8882
# Epoch 47 Batch 10 Loss 0.1985 Accuracy 8.8858
# Epoch 47 Batch 15 Loss 0.1985 Accuracy 8.8923
# Epoch 47 Batch 20 Loss 0.1985 Accuracy 8.8907
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 11.9621
# Epoch 48 Batch 5 Loss 0.1986 Accuracy 8.8888
# Epoch 48 Batch 10 Loss 0.1984 Accuracy 8.8828
# Epoch 48 Batch 15 Loss 0.1982 Accuracy 8.8834
# Epoch 48 Batch 20 Loss 0.1982 Accuracy 8.8848
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 11.9719
# Epoch 49 Batch 5 Loss 0.1981 Accuracy 8.8799
# Epoch 49 Batch 10 Loss 0.1979 Accuracy 8.8744
# Epoch 49 Batch 15 Loss 0.1976 Accuracy 8.8713
# Epoch 49 Batch 20 Loss 0.1974 Accuracy 8.8681
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 11.9737
# Epoch 50 Batch 5 Loss 0.1972 Accuracy 8.8609
# Epoch 50 Batch 10 Loss 0.1970 Accuracy 8.8561
# Epoch 50 Batch 15 Loss 0.1967 Accuracy 8.8559
# Epoch 50 Batch 20 Loss 0.1966 Accuracy 8.8523
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 11.9693
# Epoch 51 Batch 5 Loss 0.1964 Accuracy 8.8449
# Epoch 51 Batch 10 Loss 0.1960 Accuracy 8.8373
# Epoch 51 Batch 15 Loss 0.1959 Accuracy 8.8372
# Epoch 51 Batch 20 Loss 0.1957 Accuracy 8.8351
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.9591
# Epoch 52 Batch 5 Loss 0.1957 Accuracy 8.8328
# Epoch 52 Batch 10 Loss 0.1954 Accuracy 8.8251
# Epoch 52 Batch 15 Loss 0.1952 Accuracy 8.8239
# Epoch 52 Batch 20 Loss 0.1951 Accuracy 8.8225
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 11.9755
# Epoch 53 Batch 5 Loss 0.1950 Accuracy 8.8172
# Epoch 53 Batch 10 Loss 0.1949 Accuracy 8.8121
# Epoch 53 Batch 15 Loss 0.1947 Accuracy 8.8124
# Epoch 53 Batch 20 Loss 0.1949 Accuracy 8.8226
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 11.9912
# Epoch 54 Batch 5 Loss 0.1949 Accuracy 8.8183
# Epoch 54 Batch 10 Loss 0.1948 Accuracy 8.8153
# Epoch 54 Batch 15 Loss 0.1947 Accuracy 8.8144
# Epoch 54 Batch 20 Loss 0.1947 Accuracy 8.8186
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 11.9785
# Epoch 55 Batch 5 Loss 0.1947 Accuracy 8.8141
# Epoch 55 Batch 10 Loss 0.1946 Accuracy 8.8116
# Epoch 55 Batch 15 Loss 0.1945 Accuracy 8.8117
# Epoch 55 Batch 20 Loss 0.1944 Accuracy 8.8141
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.9979
# Epoch 56 Batch 5 Loss 0.1943 Accuracy 8.8085
# Epoch 56 Batch 10 Loss 0.1942 Accuracy 8.8027
# Epoch 56 Batch 15 Loss 0.1941 Accuracy 8.8063
# Epoch 56 Batch 20 Loss 0.1943 Accuracy 8.8140
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.0347
# Epoch 57 Batch 5 Loss 0.1944 Accuracy 8.8171
# Epoch 57 Batch 10 Loss 0.1945 Accuracy 8.8172
# Epoch 57 Batch 15 Loss 0.1943 Accuracy 8.8174
# Epoch 57 Batch 20 Loss 0.1945 Accuracy 8.8226
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.0900
# Epoch 58 Batch 5 Loss 0.1946 Accuracy 8.8227
# Epoch 58 Batch 10 Loss 0.1945 Accuracy 8.8203
# Epoch 58 Batch 15 Loss 0.1944 Accuracy 8.8201
# Epoch 58 Batch 20 Loss 0.1943 Accuracy 8.8201
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.0941
# Epoch 59 Batch 5 Loss 0.1942 Accuracy 8.8148
# Epoch 59 Batch 10 Loss 0.1939 Accuracy 8.8100
# Epoch 59 Batch 15 Loss 0.1937 Accuracy 8.8065
# Epoch 59 Batch 20 Loss 0.1936 Accuracy 8.8037
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.0846
# Epoch 60 Batch 5 Loss 0.1934 Accuracy 8.7979
# Epoch 60 Batch 10 Loss 0.1931 Accuracy 8.7900
# Epoch 60 Batch 15 Loss 0.1929 Accuracy 8.7868
# Epoch 60 Batch 20 Loss 0.1928 Accuracy 8.7832
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.0902
# Epoch 61 Batch 5 Loss 0.1926 Accuracy 8.7774
# Epoch 61 Batch 10 Loss 0.1923 Accuracy 8.7715
# Epoch 61 Batch 15 Loss 0.1921 Accuracy 8.7671
# Epoch 61 Batch 20 Loss 0.1920 Accuracy 8.7668
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.0865
# Epoch 62 Batch 5 Loss 0.1919 Accuracy 8.7616
# Epoch 62 Batch 10 Loss 0.1917 Accuracy 8.7590
# Epoch 62 Batch 15 Loss 0.1916 Accuracy 8.7565
# Epoch 62 Batch 20 Loss 0.1915 Accuracy 8.7576
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.0883
# Epoch 63 Batch 5 Loss 0.1914 Accuracy 8.7510
# Epoch 63 Batch 10 Loss 0.1912 Accuracy 8.7454
# Epoch 63 Batch 15 Loss 0.1912 Accuracy 8.7472
# Epoch 63 Batch 20 Loss 0.1913 Accuracy 8.7502
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.1010
# Epoch 64 Batch 5 Loss 0.1913 Accuracy 8.7464
# Epoch 64 Batch 10 Loss 0.1912 Accuracy 8.7446
# Epoch 64 Batch 15 Loss 0.1913 Accuracy 8.7500
# Epoch 64 Batch 20 Loss 0.1913 Accuracy 8.7515
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.0789
# Epoch 65 Batch 5 Loss 0.1916 Accuracy 8.7513
# Epoch 65 Batch 10 Loss 0.1916 Accuracy 8.7525
# Epoch 65 Batch 15 Loss 0.1916 Accuracy 8.7555
# Epoch 65 Batch 20 Loss 0.1918 Accuracy 8.7604
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.0991
# Epoch 66 Batch 5 Loss 0.1923 Accuracy 8.7657
# Epoch 66 Batch 10 Loss 0.1922 Accuracy 8.7648
# Epoch 66 Batch 15 Loss 0.1921 Accuracy 8.7643
# Epoch 66 Batch 20 Loss 0.1920 Accuracy 8.7643
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.0951
# Epoch 67 Batch 5 Loss 0.1920 Accuracy 8.7596
# Epoch 67 Batch 10 Loss 0.1918 Accuracy 8.7557
# Epoch 67 Batch 15 Loss 0.1917 Accuracy 8.7543
# Epoch 67 Batch 20 Loss 0.1916 Accuracy 8.7522
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.0901
# Epoch 68 Batch 5 Loss 0.1915 Accuracy 8.7481
# Epoch 68 Batch 10 Loss 0.1913 Accuracy 8.7416
# Epoch 68 Batch 15 Loss 0.1910 Accuracy 8.7379
# Epoch 68 Batch 20 Loss 0.1909 Accuracy 8.7359
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.0768
# Epoch 69 Batch 5 Loss 0.1907 Accuracy 8.7295
# Epoch 69 Batch 10 Loss 0.1905 Accuracy 8.7229
# Epoch 69 Batch 15 Loss 0.1903 Accuracy 8.7185
# Epoch 69 Batch 20 Loss 0.1901 Accuracy 8.7160
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.0784
# Epoch 70 Batch 5 Loss 0.1900 Accuracy 8.7099
# Epoch 70 Batch 10 Loss 0.1897 Accuracy 8.7038
# Epoch 70 Batch 15 Loss 0.1895 Accuracy 8.6997
# Epoch 70 Batch 20 Loss 0.1895 Accuracy 8.6993
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.0940
# Epoch 71 Batch 5 Loss 0.1893 Accuracy 8.6938
# Epoch 71 Batch 10 Loss 0.1892 Accuracy 8.6883
# Epoch 71 Batch 15 Loss 0.1890 Accuracy 8.6860
# Epoch 71 Batch 20 Loss 0.1889 Accuracy 8.6831
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.1067
# Epoch 72 Batch 5 Loss 0.1887 Accuracy 8.6788
# Epoch 72 Batch 10 Loss 0.1886 Accuracy 8.6759
# Epoch 72 Batch 15 Loss 0.1885 Accuracy 8.6745
# Epoch 72 Batch 20 Loss 0.1886 Accuracy 8.6784
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.1034
# Epoch 73 Batch 5 Loss 0.1885 Accuracy 8.6748
# Epoch 73 Batch 10 Loss 0.1883 Accuracy 8.6723
# Epoch 73 Batch 15 Loss 0.1883 Accuracy 8.6699
# Epoch 73 Batch 20 Loss 0.1883 Accuracy 8.6745
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.1045
# Epoch 74 Batch 5 Loss 0.1882 Accuracy 8.6699
# Epoch 74 Batch 10 Loss 0.1882 Accuracy 8.6665
# Epoch 74 Batch 15 Loss 0.1881 Accuracy 8.6668
# Epoch 74 Batch 20 Loss 0.1880 Accuracy 8.6669
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.1023
# Epoch 75 Batch 5 Loss 0.1879 Accuracy 8.6642
# Epoch 75 Batch 10 Loss 0.1877 Accuracy 8.6584
# Epoch 75 Batch 15 Loss 0.1876 Accuracy 8.6560
# Epoch 75 Batch 20 Loss 0.1874 Accuracy 8.6520
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.0940
# Epoch 76 Batch 5 Loss 0.1874 Accuracy 8.6505
# Epoch 76 Batch 10 Loss 0.1871 Accuracy 8.6446
# Epoch 76 Batch 15 Loss 0.1870 Accuracy 8.6421
# Epoch 76 Batch 20 Loss 0.1869 Accuracy 8.6409
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.1100
# Epoch 77 Batch 5 Loss 0.1868 Accuracy 8.6362
# Epoch 77 Batch 10 Loss 0.1865 Accuracy 8.6307
# Epoch 77 Batch 15 Loss 0.1864 Accuracy 8.6262
# Epoch 77 Batch 20 Loss 0.1862 Accuracy 8.6246
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.1218
# Epoch 78 Batch 5 Loss 0.1861 Accuracy 8.6198
# Epoch 78 Batch 10 Loss 0.1858 Accuracy 8.6141
# Epoch 78 Batch 15 Loss 0.1857 Accuracy 8.6114
# Epoch 78 Batch 20 Loss 0.1856 Accuracy 8.6112
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.1242
# Epoch 79 Batch 5 Loss 0.1855 Accuracy 8.6090
# Epoch 79 Batch 10 Loss 0.1852 Accuracy 8.6023
# Epoch 79 Batch 15 Loss 0.1851 Accuracy 8.5993
# Epoch 79 Batch 20 Loss 0.1850 Accuracy 8.5997
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 12.1352
# Epoch 80 Batch 5 Loss 0.1849 Accuracy 8.5978
# Epoch 80 Batch 10 Loss 0.1847 Accuracy 8.5933
# Epoch 80 Batch 15 Loss 0.1846 Accuracy 8.5911
# Epoch 80 Batch 20 Loss 0.1848 Accuracy 8.5958
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.1423
# Epoch 81 Batch 5 Loss 0.1850 Accuracy 8.5945
# Epoch 81 Batch 10 Loss 0.1851 Accuracy 8.5964
# Epoch 81 Batch 15 Loss 0.1851 Accuracy 8.6012
# Epoch 81 Batch 20 Loss 0.1852 Accuracy 8.6029
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.1259
# Epoch 82 Batch 5 Loss 0.1853 Accuracy 8.6031
# Epoch 82 Batch 10 Loss 0.1852 Accuracy 8.6001
# Epoch 82 Batch 15 Loss 0.1851 Accuracy 8.5981
# Epoch 82 Batch 20 Loss 0.1850 Accuracy 8.5966
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.1441
# Epoch 83 Batch 5 Loss 0.1850 Accuracy 8.5936
# Epoch 83 Batch 10 Loss 0.1848 Accuracy 8.5897
# Epoch 83 Batch 15 Loss 0.1846 Accuracy 8.5863
# Epoch 83 Batch 20 Loss 0.1845 Accuracy 8.5828
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.1456
# Epoch 84 Batch 5 Loss 0.1843 Accuracy 8.5779
# Epoch 84 Batch 10 Loss 0.1841 Accuracy 8.5729
# Epoch 84 Batch 15 Loss 0.1839 Accuracy 8.5697
# Epoch 84 Batch 20 Loss 0.1838 Accuracy 8.5671
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.1451
# Epoch 85 Batch 5 Loss 0.1838 Accuracy 8.5663
# Epoch 85 Batch 10 Loss 0.1837 Accuracy 8.5622
# Epoch 85 Batch 15 Loss 0.1837 Accuracy 8.5644
# Epoch 85 Batch 20 Loss 0.1838 Accuracy 8.5644
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.1495
# Epoch 86 Batch 5 Loss 0.1838 Accuracy 8.5673
# Epoch 86 Batch 10 Loss 0.1838 Accuracy 8.5668
# Epoch 86 Batch 15 Loss 0.1838 Accuracy 8.5654
# Epoch 86 Batch 20 Loss 0.1839 Accuracy 8.5705
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.1559
# Epoch 87 Batch 5 Loss 0.1839 Accuracy 8.5698
# Epoch 87 Batch 10 Loss 0.1839 Accuracy 8.5679
# Epoch 87 Batch 15 Loss 0.1837 Accuracy 8.5669
# Epoch 87 Batch 20 Loss 0.1837 Accuracy 8.5660
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.1474
# Epoch 88 Batch 5 Loss 0.1836 Accuracy 8.5623
# Epoch 88 Batch 10 Loss 0.1834 Accuracy 8.5576
# Epoch 88 Batch 15 Loss 0.1833 Accuracy 8.5554
# Epoch 88 Batch 20 Loss 0.1832 Accuracy 8.5524
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.1421
# Epoch 89 Batch 5 Loss 0.1830 Accuracy 8.5481
# Epoch 89 Batch 10 Loss 0.1828 Accuracy 8.5432
# Epoch 89 Batch 15 Loss 0.1827 Accuracy 8.5401
# Epoch 89 Batch 20 Loss 0.1825 Accuracy 8.5369
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.1445
# Epoch 90 Batch 5 Loss 0.1824 Accuracy 8.5319
# Epoch 90 Batch 10 Loss 0.1821 Accuracy 8.5264
# Epoch 90 Batch 15 Loss 0.1820 Accuracy 8.5228
# Epoch 90 Batch 20 Loss 0.1818 Accuracy 8.5192
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.1460
# Epoch 91 Batch 5 Loss 0.1817 Accuracy 8.5141
# Epoch 91 Batch 10 Loss 0.1815 Accuracy 8.5100
# Epoch 91 Batch 15 Loss 0.1813 Accuracy 8.5063
# Epoch 91 Batch 20 Loss 0.1813 Accuracy 8.5048
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.1500
# Epoch 92 Batch 5 Loss 0.1812 Accuracy 8.5023
# Epoch 92 Batch 10 Loss 0.1810 Accuracy 8.4967
# Epoch 92 Batch 15 Loss 0.1808 Accuracy 8.4945
# Epoch 92 Batch 20 Loss 0.1807 Accuracy 8.4927
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.1505
# Epoch 93 Batch 5 Loss 0.1807 Accuracy 8.4906
# Epoch 93 Batch 10 Loss 0.1805 Accuracy 8.4877
# Epoch 93 Batch 15 Loss 0.1805 Accuracy 8.4874
# Epoch 93 Batch 20 Loss 0.1805 Accuracy 8.4852
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.1588
# Epoch 94 Batch 5 Loss 0.1804 Accuracy 8.4834
# Epoch 94 Batch 10 Loss 0.1803 Accuracy 8.4819
# Epoch 94 Batch 15 Loss 0.1802 Accuracy 8.4821
# Epoch 94 Batch 20 Loss 0.1801 Accuracy 8.4798
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.1525
# Epoch 95 Batch 5 Loss 0.1800 Accuracy 8.4764
# Epoch 95 Batch 10 Loss 0.1799 Accuracy 8.4731
# Epoch 95 Batch 15 Loss 0.1798 Accuracy 8.4717
# Epoch 95 Batch 20 Loss 0.1797 Accuracy 8.4704
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.1497
# Epoch 96 Batch 5 Loss 0.1797 Accuracy 8.4677
# Epoch 96 Batch 10 Loss 0.1797 Accuracy 8.4666
# Epoch 96 Batch 15 Loss 0.1796 Accuracy 8.4670
# Epoch 96 Batch 20 Loss 0.1797 Accuracy 8.4686
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.1443
# Epoch 97 Batch 5 Loss 0.1798 Accuracy 8.4686
# Epoch 97 Batch 10 Loss 0.1796 Accuracy 8.4651
# Epoch 97 Batch 15 Loss 0.1796 Accuracy 8.4641
# Epoch 97 Batch 20 Loss 0.1796 Accuracy 8.4652
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.1599
# Epoch 98 Batch 5 Loss 0.1796 Accuracy 8.4649
# Epoch 98 Batch 10 Loss 0.1795 Accuracy 8.4628
# Epoch 98 Batch 15 Loss 0.1794 Accuracy 8.4611
# Epoch 98 Batch 20 Loss 0.1794 Accuracy 8.4624
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.1764
# Epoch 99 Batch 5 Loss 0.1793 Accuracy 8.4584
# Epoch 99 Batch 10 Loss 0.1792 Accuracy 8.4549
# Epoch 99 Batch 15 Loss 0.1791 Accuracy 8.4536
# Epoch 99 Batch 20 Loss 0.1791 Accuracy 8.4529
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 12.1947
# Epoch 100 Batch 5 Loss 0.1790 Accuracy 8.4520
# Epoch 100 Batch 10 Loss 0.1789 Accuracy 8.4482
# Epoch 100 Batch 15 Loss 0.1788 Accuracy 8.4469
# Epoch 100 Batch 20 Loss 0.1787 Accuracy 8.4442
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.1926
# Epoch 101 Batch 5 Loss 0.1786 Accuracy 8.4405
# Epoch 101 Batch 10 Loss 0.1784 Accuracy 8.4368
# Epoch 101 Batch 15 Loss 0.1783 Accuracy 8.4342
# Epoch 101 Batch 20 Loss 0.1783 Accuracy 8.4337
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.1945
# Epoch 102 Batch 5 Loss 0.1782 Accuracy 8.4308
# Epoch 102 Batch 10 Loss 0.1781 Accuracy 8.4269
# Epoch 102 Batch 15 Loss 0.1780 Accuracy 8.4283
# Epoch 102 Batch 20 Loss 0.1781 Accuracy 8.4294
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.1950
# Epoch 103 Batch 5 Loss 0.1781 Accuracy 8.4303
# Epoch 103 Batch 10 Loss 0.1781 Accuracy 8.4302
# Epoch 103 Batch 15 Loss 0.1781 Accuracy 8.4314
# Epoch 103 Batch 20 Loss 0.1781 Accuracy 8.4314
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.2080
# Epoch 104 Batch 5 Loss 0.1781 Accuracy 8.4299
# Epoch 104 Batch 10 Loss 0.1780 Accuracy 8.4273
# Epoch 104 Batch 15 Loss 0.1779 Accuracy 8.4261
# Epoch 104 Batch 20 Loss 0.1778 Accuracy 8.4250
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 12.1946
# Epoch 105 Batch 5 Loss 0.1777 Accuracy 8.4211
# Epoch 105 Batch 10 Loss 0.1775 Accuracy 8.4161
# Epoch 105 Batch 15 Loss 0.1774 Accuracy 8.4138
# Epoch 105 Batch 20 Loss 0.1773 Accuracy 8.4110
# Time taken for 1 epoch: 1.29 secs
#
# TestLoss 0.0000 TestAccuracy 12.1986
# Epoch 106 Batch 5 Loss 0.1771 Accuracy 8.4060
# Epoch 106 Batch 10 Loss 0.1769 Accuracy 8.4010
# Epoch 106 Batch 15 Loss 0.1767 Accuracy 8.3977
# Epoch 106 Batch 20 Loss 0.1766 Accuracy 8.3943
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.2001
# Epoch 107 Batch 5 Loss 0.1764 Accuracy 8.3894
# Epoch 107 Batch 10 Loss 0.1762 Accuracy 8.3835
# Epoch 107 Batch 15 Loss 0.1761 Accuracy 8.3805
# Epoch 107 Batch 20 Loss 0.1760 Accuracy 8.3768
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.1979
# Epoch 108 Batch 5 Loss 0.1758 Accuracy 8.3724
# Epoch 108 Batch 10 Loss 0.1756 Accuracy 8.3666
# Epoch 108 Batch 15 Loss 0.1754 Accuracy 8.3635
# Epoch 108 Batch 20 Loss 0.1753 Accuracy 8.3592
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.2002
# Epoch 109 Batch 5 Loss 0.1751 Accuracy 8.3542
# Epoch 109 Batch 10 Loss 0.1749 Accuracy 8.3488
# Epoch 109 Batch 15 Loss 0.1747 Accuracy 8.3456
# Epoch 109 Batch 20 Loss 0.1746 Accuracy 8.3412
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.2099
# Epoch 110 Batch 5 Loss 0.1744 Accuracy 8.3359
# Epoch 110 Batch 10 Loss 0.1742 Accuracy 8.3303
# Epoch 110 Batch 15 Loss 0.1741 Accuracy 8.3278
# Epoch 110 Batch 20 Loss 0.1739 Accuracy 8.3236
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.2060
# Epoch 111 Batch 5 Loss 0.1738 Accuracy 8.3196
# Epoch 111 Batch 10 Loss 0.1736 Accuracy 8.3139
# Epoch 111 Batch 15 Loss 0.1734 Accuracy 8.3119
# Epoch 111 Batch 20 Loss 0.1733 Accuracy 8.3081
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.2171
# Epoch 112 Batch 5 Loss 0.1732 Accuracy 8.3026
# Epoch 112 Batch 10 Loss 0.1730 Accuracy 8.2978
# Epoch 112 Batch 15 Loss 0.1729 Accuracy 8.2954
# Epoch 112 Batch 20 Loss 0.1730 Accuracy 8.2987
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 12.2302
# Epoch 113 Batch 5 Loss 0.1731 Accuracy 8.2992
# Epoch 113 Batch 10 Loss 0.1731 Accuracy 8.2986
# Epoch 113 Batch 15 Loss 0.1732 Accuracy 8.3050
# Epoch 113 Batch 20 Loss 0.1734 Accuracy 8.3097
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 12.2490
# Epoch 114 Batch 5 Loss 0.1735 Accuracy 8.3122
# Epoch 114 Batch 10 Loss 0.1736 Accuracy 8.3148
# Epoch 114 Batch 15 Loss 0.1737 Accuracy 8.3191
# Epoch 114 Batch 20 Loss 0.1739 Accuracy 8.3241
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.2645
# Epoch 115 Batch 5 Loss 0.1740 Accuracy 8.3250
# Epoch 115 Batch 10 Loss 0.1740 Accuracy 8.3256
# Epoch 115 Batch 15 Loss 0.1741 Accuracy 8.3281
# Epoch 115 Batch 20 Loss 0.1741 Accuracy 8.3305
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.2770
# Epoch 116 Batch 5 Loss 0.1742 Accuracy 8.3298
# Epoch 116 Batch 10 Loss 0.1741 Accuracy 8.3284
# Epoch 116 Batch 15 Loss 0.1741 Accuracy 8.3308
# Epoch 116 Batch 20 Loss 0.1742 Accuracy 8.3314
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.2843
# Epoch 117 Batch 5 Loss 0.1742 Accuracy 8.3306
# Epoch 117 Batch 10 Loss 0.1741 Accuracy 8.3285
# Epoch 117 Batch 15 Loss 0.1740 Accuracy 8.3281
# Epoch 117 Batch 20 Loss 0.1739 Accuracy 8.3264
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.2807
# Epoch 118 Batch 5 Loss 0.1739 Accuracy 8.3232
# Epoch 118 Batch 10 Loss 0.1738 Accuracy 8.3219
# Epoch 118 Batch 15 Loss 0.1737 Accuracy 8.3206
# Epoch 118 Batch 20 Loss 0.1736 Accuracy 8.3193
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.2972
# Epoch 119 Batch 5 Loss 0.1735 Accuracy 8.3170
# Epoch 119 Batch 10 Loss 0.1735 Accuracy 8.3144
# Epoch 119 Batch 15 Loss 0.1735 Accuracy 8.3168
# Epoch 119 Batch 20 Loss 0.1735 Accuracy 8.3164
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.2985
# Epoch 120 Batch 5 Loss 0.1735 Accuracy 8.3159
# Epoch 120 Batch 10 Loss 0.1734 Accuracy 8.3129
# Epoch 120 Batch 15 Loss 0.1733 Accuracy 8.3109
# Epoch 120 Batch 20 Loss 0.1732 Accuracy 8.3103
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.3042
# Epoch 121 Batch 5 Loss 0.1732 Accuracy 8.3075
# Epoch 121 Batch 10 Loss 0.1731 Accuracy 8.3052
# Epoch 121 Batch 15 Loss 0.1731 Accuracy 8.3069
# Epoch 121 Batch 20 Loss 0.1731 Accuracy 8.3067
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.3021
# Epoch 122 Batch 5 Loss 0.1731 Accuracy 8.3046
# Epoch 122 Batch 10 Loss 0.1730 Accuracy 8.3024
# Epoch 122 Batch 15 Loss 0.1729 Accuracy 8.3025
# Epoch 122 Batch 20 Loss 0.1729 Accuracy 8.3014
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.2960
# Epoch 123 Batch 5 Loss 0.1728 Accuracy 8.2979
# Epoch 123 Batch 10 Loss 0.1727 Accuracy 8.2952
# Epoch 123 Batch 15 Loss 0.1727 Accuracy 8.2954
# Epoch 123 Batch 20 Loss 0.1726 Accuracy 8.2943
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.2907
# Epoch 124 Batch 5 Loss 0.1726 Accuracy 8.2922
# Epoch 124 Batch 10 Loss 0.1725 Accuracy 8.2903
# Epoch 124 Batch 15 Loss 0.1724 Accuracy 8.2886
# Epoch 124 Batch 20 Loss 0.1724 Accuracy 8.2872
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.2888
# Epoch 125 Batch 5 Loss 0.1724 Accuracy 8.2852
# Epoch 125 Batch 10 Loss 0.1722 Accuracy 8.2830
# Epoch 125 Batch 15 Loss 0.1722 Accuracy 8.2825
# Epoch 125 Batch 20 Loss 0.1722 Accuracy 8.2827
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 12.2925
# Epoch 126 Batch 5 Loss 0.1723 Accuracy 8.2809
# Epoch 126 Batch 10 Loss 0.1722 Accuracy 8.2799
# Epoch 126 Batch 15 Loss 0.1722 Accuracy 8.2822
# Epoch 126 Batch 20 Loss 0.1722 Accuracy 8.2830
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.2957
# Epoch 127 Batch 5 Loss 0.1722 Accuracy 8.2839
# Epoch 127 Batch 10 Loss 0.1721 Accuracy 8.2808
# Epoch 127 Batch 15 Loss 0.1720 Accuracy 8.2811
# Epoch 127 Batch 20 Loss 0.1720 Accuracy 8.2815
# Time taken for 1 epoch: 1.28 secs
#
# TestLoss 0.0000 TestAccuracy 12.3148
# Epoch 128 Batch 5 Loss 0.1720 Accuracy 8.2792
# Epoch 128 Batch 10 Loss 0.1718 Accuracy 8.2764
# Epoch 128 Batch 15 Loss 0.1717 Accuracy 8.2743
# Epoch 128 Batch 20 Loss 0.1717 Accuracy 8.2737
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.3159
# Epoch 129 Batch 5 Loss 0.1716 Accuracy 8.2697
# Epoch 129 Batch 10 Loss 0.1714 Accuracy 8.2657
# Epoch 129 Batch 15 Loss 0.1713 Accuracy 8.2649
# Epoch 129 Batch 20 Loss 0.1713 Accuracy 8.2632
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.3126
# Epoch 130 Batch 5 Loss 0.1712 Accuracy 8.2598
# Epoch 130 Batch 10 Loss 0.1710 Accuracy 8.2563
# Epoch 130 Batch 15 Loss 0.1709 Accuracy 8.2542
# Epoch 130 Batch 20 Loss 0.1708 Accuracy 8.2526
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.3121
# Epoch 131 Batch 5 Loss 0.1707 Accuracy 8.2495
# Epoch 131 Batch 10 Loss 0.1706 Accuracy 8.2452
# Epoch 131 Batch 15 Loss 0.1705 Accuracy 8.2444
# Epoch 131 Batch 20 Loss 0.1704 Accuracy 8.2421
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.3085
# Epoch 132 Batch 5 Loss 0.1703 Accuracy 8.2384
# Epoch 132 Batch 10 Loss 0.1702 Accuracy 8.2357
# Epoch 132 Batch 15 Loss 0.1701 Accuracy 8.2346
# Epoch 132 Batch 20 Loss 0.1701 Accuracy 8.2334
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.3130
# Epoch 133 Batch 5 Loss 0.1700 Accuracy 8.2305
# Epoch 133 Batch 10 Loss 0.1698 Accuracy 8.2276
# Epoch 133 Batch 15 Loss 0.1698 Accuracy 8.2282
# Epoch 133 Batch 20 Loss 0.1697 Accuracy 8.2260
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.3126
# Epoch 134 Batch 5 Loss 0.1696 Accuracy 8.2229
# Epoch 134 Batch 10 Loss 0.1694 Accuracy 8.2184
# Epoch 134 Batch 15 Loss 0.1693 Accuracy 8.2177
# Epoch 134 Batch 20 Loss 0.1693 Accuracy 8.2155
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.3156
# Epoch 135 Batch 5 Loss 0.1691 Accuracy 8.2111
# Epoch 135 Batch 10 Loss 0.1690 Accuracy 8.2075
# Epoch 135 Batch 15 Loss 0.1689 Accuracy 8.2051
# Epoch 135 Batch 20 Loss 0.1688 Accuracy 8.2032
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.3101
# Epoch 136 Batch 5 Loss 0.1687 Accuracy 8.1994
# Epoch 136 Batch 10 Loss 0.1685 Accuracy 8.1956
# Epoch 136 Batch 15 Loss 0.1684 Accuracy 8.1944
# Epoch 136 Batch 20 Loss 0.1684 Accuracy 8.1931
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.3132
# Epoch 137 Batch 5 Loss 0.1682 Accuracy 8.1893
# Epoch 137 Batch 10 Loss 0.1681 Accuracy 8.1858
# Epoch 137 Batch 15 Loss 0.1680 Accuracy 8.1852
# Epoch 137 Batch 20 Loss 0.1680 Accuracy 8.1836
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.3127
# Epoch 138 Batch 5 Loss 0.1678 Accuracy 8.1796
# Epoch 138 Batch 10 Loss 0.1677 Accuracy 8.1758
# Epoch 138 Batch 15 Loss 0.1676 Accuracy 8.1734
# Epoch 138 Batch 20 Loss 0.1676 Accuracy 8.1729
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.3084
# Epoch 139 Batch 5 Loss 0.1674 Accuracy 8.1692
# Epoch 139 Batch 10 Loss 0.1673 Accuracy 8.1653
# Epoch 139 Batch 15 Loss 0.1672 Accuracy 8.1645
# Epoch 139 Batch 20 Loss 0.1672 Accuracy 8.1649
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.3107
# Epoch 140 Batch 5 Loss 0.1671 Accuracy 8.1619
# Epoch 140 Batch 10 Loss 0.1670 Accuracy 8.1599
# Epoch 140 Batch 15 Loss 0.1670 Accuracy 8.1597
# Epoch 140 Batch 20 Loss 0.1670 Accuracy 8.1611
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.3244
# Epoch 141 Batch 5 Loss 0.1669 Accuracy 8.1576
# Epoch 141 Batch 10 Loss 0.1667 Accuracy 8.1536
# Epoch 141 Batch 15 Loss 0.1666 Accuracy 8.1511
# Epoch 141 Batch 20 Loss 0.1665 Accuracy 8.1494
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.3315
# Epoch 142 Batch 5 Loss 0.1664 Accuracy 8.1450
# Epoch 142 Batch 10 Loss 0.1662 Accuracy 8.1407
# Epoch 142 Batch 15 Loss 0.1661 Accuracy 8.1375
# Epoch 142 Batch 20 Loss 0.1660 Accuracy 8.1354
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.3383
# Epoch 143 Batch 5 Loss 0.1659 Accuracy 8.1307
# Epoch 143 Batch 10 Loss 0.1657 Accuracy 8.1257
# Epoch 143 Batch 15 Loss 0.1656 Accuracy 8.1227
# Epoch 143 Batch 20 Loss 0.1655 Accuracy 8.1194
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.3491
# Epoch 144 Batch 5 Loss 0.1653 Accuracy 8.1147
# Epoch 144 Batch 10 Loss 0.1651 Accuracy 8.1100
# Epoch 144 Batch 15 Loss 0.1650 Accuracy 8.1069
# Epoch 144 Batch 20 Loss 0.1649 Accuracy 8.1036
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 12.3550
# Epoch 145 Batch 5 Loss 0.1647 Accuracy 8.0986
# Epoch 145 Batch 10 Loss 0.1645 Accuracy 8.0935
# Epoch 145 Batch 15 Loss 0.1644 Accuracy 8.0900
# Epoch 145 Batch 20 Loss 0.1643 Accuracy 8.0860
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.3567
# Epoch 146 Batch 5 Loss 0.1641 Accuracy 8.0812
# Epoch 146 Batch 10 Loss 0.1639 Accuracy 8.0764
# Epoch 146 Batch 15 Loss 0.1638 Accuracy 8.0731
# Epoch 146 Batch 20 Loss 0.1637 Accuracy 8.0705
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.3638
# Epoch 147 Batch 5 Loss 0.1635 Accuracy 8.0656
# Epoch 147 Batch 10 Loss 0.1634 Accuracy 8.0605
# Epoch 147 Batch 15 Loss 0.1633 Accuracy 8.0577
# Epoch 147 Batch 20 Loss 0.1632 Accuracy 8.0550
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.3692
# Epoch 148 Batch 5 Loss 0.1631 Accuracy 8.0523
# Epoch 148 Batch 10 Loss 0.1629 Accuracy 8.0482
# Epoch 148 Batch 15 Loss 0.1628 Accuracy 8.0452
# Epoch 148 Batch 20 Loss 0.1627 Accuracy 8.0427
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.3808
# Epoch 149 Batch 5 Loss 0.1626 Accuracy 8.0390
# Epoch 149 Batch 10 Loss 0.1624 Accuracy 8.0347
# Epoch 149 Batch 15 Loss 0.1623 Accuracy 8.0318
# Epoch 149 Batch 20 Loss 0.1622 Accuracy 8.0292
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 12.3846
# Epoch 150 Batch 5 Loss 0.1621 Accuracy 8.0254
# Epoch 150 Batch 10 Loss 0.1619 Accuracy 8.0212
# Epoch 150 Batch 15 Loss 0.1618 Accuracy 8.0184
# Epoch 150 Batch 20 Loss 0.1617 Accuracy 8.0156
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.3863
# Epoch 151 Batch 5 Loss 0.1615 Accuracy 8.0114
# Epoch 151 Batch 10 Loss 0.1614 Accuracy 8.0073
# Epoch 151 Batch 15 Loss 0.1613 Accuracy 8.0051
# Epoch 151 Batch 20 Loss 0.1612 Accuracy 8.0029
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.3883
# Epoch 152 Batch 5 Loss 0.1611 Accuracy 8.0005
# Epoch 152 Batch 10 Loss 0.1609 Accuracy 7.9967
# Epoch 152 Batch 15 Loss 0.1608 Accuracy 7.9939
# Epoch 152 Batch 20 Loss 0.1607 Accuracy 7.9905
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.3916
# Epoch 153 Batch 5 Loss 0.1606 Accuracy 7.9863
# Epoch 153 Batch 10 Loss 0.1604 Accuracy 7.9820
# Epoch 153 Batch 15 Loss 0.1603 Accuracy 7.9801
# Epoch 153 Batch 20 Loss 0.1602 Accuracy 7.9772
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.3867
# Epoch 154 Batch 5 Loss 0.1601 Accuracy 7.9741
# Epoch 154 Batch 10 Loss 0.1600 Accuracy 7.9699
# Epoch 154 Batch 15 Loss 0.1599 Accuracy 7.9686
# Epoch 154 Batch 20 Loss 0.1598 Accuracy 7.9661
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 12.3844
# Epoch 155 Batch 5 Loss 0.1597 Accuracy 7.9620
# Epoch 155 Batch 10 Loss 0.1596 Accuracy 7.9582
# Epoch 155 Batch 15 Loss 0.1595 Accuracy 7.9563
# Epoch 155 Batch 20 Loss 0.1594 Accuracy 7.9538
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.3912
# Epoch 156 Batch 5 Loss 0.1593 Accuracy 7.9507
# Epoch 156 Batch 10 Loss 0.1591 Accuracy 7.9468
# Epoch 156 Batch 15 Loss 0.1591 Accuracy 7.9441
# Epoch 156 Batch 20 Loss 0.1590 Accuracy 7.9416
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.3973
# Epoch 157 Batch 5 Loss 0.1588 Accuracy 7.9372
# Epoch 157 Batch 10 Loss 0.1587 Accuracy 7.9326
# Epoch 157 Batch 15 Loss 0.1585 Accuracy 7.9303
# Epoch 157 Batch 20 Loss 0.1584 Accuracy 7.9270
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.3984
# Epoch 158 Batch 5 Loss 0.1583 Accuracy 7.9234
# Epoch 158 Batch 10 Loss 0.1582 Accuracy 7.9190
# Epoch 158 Batch 15 Loss 0.1580 Accuracy 7.9162
# Epoch 158 Batch 20 Loss 0.1579 Accuracy 7.9124
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.4114
# Epoch 159 Batch 5 Loss 0.1578 Accuracy 7.9088
# Epoch 159 Batch 10 Loss 0.1577 Accuracy 7.9054
# Epoch 159 Batch 15 Loss 0.1576 Accuracy 7.9027
# Epoch 159 Batch 20 Loss 0.1575 Accuracy 7.8998
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.4172
# Epoch 160 Batch 5 Loss 0.1573 Accuracy 7.8956
# Epoch 160 Batch 10 Loss 0.1572 Accuracy 7.8920
# Epoch 160 Batch 15 Loss 0.1571 Accuracy 7.8897
# Epoch 160 Batch 20 Loss 0.1570 Accuracy 7.8872
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.4204
# Epoch 161 Batch 5 Loss 0.1569 Accuracy 7.8831
# Epoch 161 Batch 10 Loss 0.1568 Accuracy 7.8801
# Epoch 161 Batch 15 Loss 0.1567 Accuracy 7.8792
# Epoch 161 Batch 20 Loss 0.1566 Accuracy 7.8759
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.4243
# Epoch 162 Batch 5 Loss 0.1565 Accuracy 7.8719
# Epoch 162 Batch 10 Loss 0.1564 Accuracy 7.8692
# Epoch 162 Batch 15 Loss 0.1563 Accuracy 7.8682
# Epoch 162 Batch 20 Loss 0.1563 Accuracy 7.8672
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 12.4172
# Epoch 163 Batch 5 Loss 0.1563 Accuracy 7.8662
# Epoch 163 Batch 10 Loss 0.1562 Accuracy 7.8658
# Epoch 163 Batch 15 Loss 0.1562 Accuracy 7.8663
# Epoch 163 Batch 20 Loss 0.1562 Accuracy 7.8662
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.4217
# Epoch 164 Batch 5 Loss 0.1561 Accuracy 7.8649
# Epoch 164 Batch 10 Loss 0.1561 Accuracy 7.8635
# Epoch 164 Batch 15 Loss 0.1560 Accuracy 7.8635
# Epoch 164 Batch 20 Loss 0.1560 Accuracy 7.8627
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 12.4194
# Epoch 165 Batch 5 Loss 0.1559 Accuracy 7.8604
# Epoch 165 Batch 10 Loss 0.1558 Accuracy 7.8576
# Epoch 165 Batch 15 Loss 0.1558 Accuracy 7.8576
# Epoch 165 Batch 20 Loss 0.1557 Accuracy 7.8557
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.4151
# Epoch 166 Batch 5 Loss 0.1557 Accuracy 7.8531
# Epoch 166 Batch 10 Loss 0.1558 Accuracy 7.8546
# Epoch 166 Batch 15 Loss 0.1558 Accuracy 7.8578
# Epoch 166 Batch 20 Loss 0.1559 Accuracy 7.8594
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.4245
# Epoch 167 Batch 5 Loss 0.1560 Accuracy 7.8597
# Epoch 167 Batch 10 Loss 0.1560 Accuracy 7.8601
# Epoch 167 Batch 15 Loss 0.1561 Accuracy 7.8627
# Epoch 167 Batch 20 Loss 0.1562 Accuracy 7.8647
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.4292
# Epoch 168 Batch 5 Loss 0.1563 Accuracy 7.8654
# Epoch 168 Batch 10 Loss 0.1562 Accuracy 7.8645
# Epoch 168 Batch 15 Loss 0.1562 Accuracy 7.8649
# Epoch 168 Batch 20 Loss 0.1562 Accuracy 7.8657
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.4256
# Epoch 169 Batch 5 Loss 0.1562 Accuracy 7.8646
# Epoch 169 Batch 10 Loss 0.1561 Accuracy 7.8627
# Epoch 169 Batch 15 Loss 0.1561 Accuracy 7.8632
# Epoch 169 Batch 20 Loss 0.1561 Accuracy 7.8630
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.4202
# Epoch 170 Batch 5 Loss 0.1560 Accuracy 7.8611
# Epoch 170 Batch 10 Loss 0.1560 Accuracy 7.8590
# Epoch 170 Batch 15 Loss 0.1559 Accuracy 7.8589
# Epoch 170 Batch 20 Loss 0.1559 Accuracy 7.8593
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.4318
# Epoch 171 Batch 5 Loss 0.1559 Accuracy 7.8566
# Epoch 171 Batch 10 Loss 0.1558 Accuracy 7.8548
# Epoch 171 Batch 15 Loss 0.1557 Accuracy 7.8536
# Epoch 171 Batch 20 Loss 0.1557 Accuracy 7.8529
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.4386
# Epoch 172 Batch 5 Loss 0.1556 Accuracy 7.8507
# Epoch 172 Batch 10 Loss 0.1555 Accuracy 7.8479
# Epoch 172 Batch 15 Loss 0.1554 Accuracy 7.8459
# Epoch 172 Batch 20 Loss 0.1554 Accuracy 7.8444
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.4362
# Epoch 173 Batch 5 Loss 0.1553 Accuracy 7.8411
# Epoch 173 Batch 10 Loss 0.1551 Accuracy 7.8376
# Epoch 173 Batch 15 Loss 0.1550 Accuracy 7.8354
# Epoch 173 Batch 20 Loss 0.1550 Accuracy 7.8329
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.4346
# Epoch 174 Batch 5 Loss 0.1548 Accuracy 7.8288
# Epoch 174 Batch 10 Loss 0.1547 Accuracy 7.8247
# Epoch 174 Batch 15 Loss 0.1546 Accuracy 7.8219
# Epoch 174 Batch 20 Loss 0.1545 Accuracy 7.8188
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.4356
# Epoch 175 Batch 5 Loss 0.1544 Accuracy 7.8152
# Epoch 175 Batch 10 Loss 0.1542 Accuracy 7.8112
# Epoch 175 Batch 15 Loss 0.1541 Accuracy 7.8080
# Epoch 175 Batch 20 Loss 0.1540 Accuracy 7.8044
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 12.4390
# Epoch 176 Batch 5 Loss 0.1538 Accuracy 7.8000
# Epoch 176 Batch 10 Loss 0.1537 Accuracy 7.7960
# Epoch 176 Batch 15 Loss 0.1536 Accuracy 7.7929
# Epoch 176 Batch 20 Loss 0.1535 Accuracy 7.7894
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.4394
# Epoch 177 Batch 5 Loss 0.1533 Accuracy 7.7850
# Epoch 177 Batch 10 Loss 0.1532 Accuracy 7.7806
# Epoch 177 Batch 15 Loss 0.1531 Accuracy 7.7775
# Epoch 177 Batch 20 Loss 0.1529 Accuracy 7.7743
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.4428
# Epoch 178 Batch 5 Loss 0.1528 Accuracy 7.7700
# Epoch 178 Batch 10 Loss 0.1527 Accuracy 7.7656
# Epoch 178 Batch 15 Loss 0.1526 Accuracy 7.7630
# Epoch 178 Batch 20 Loss 0.1525 Accuracy 7.7600
# Time taken for 1 epoch: 1.29 secs
#
# TestLoss 0.0000 TestAccuracy 12.4476
# Epoch 179 Batch 5 Loss 0.1524 Accuracy 7.7568
# Epoch 179 Batch 10 Loss 0.1522 Accuracy 7.7531
# Epoch 179 Batch 15 Loss 0.1521 Accuracy 7.7502
# Epoch 179 Batch 20 Loss 0.1520 Accuracy 7.7472
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 12.4549
# Epoch 180 Batch 5 Loss 0.1519 Accuracy 7.7435
# Epoch 180 Batch 10 Loss 0.1518 Accuracy 7.7407
# Epoch 180 Batch 15 Loss 0.1517 Accuracy 7.7384
# Epoch 180 Batch 20 Loss 0.1516 Accuracy 7.7363
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.4619
# Epoch 181 Batch 5 Loss 0.1515 Accuracy 7.7329
# Epoch 181 Batch 10 Loss 0.1514 Accuracy 7.7300
# Epoch 181 Batch 15 Loss 0.1514 Accuracy 7.7299
# Epoch 181 Batch 20 Loss 0.1513 Accuracy 7.7288
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 12.4619
# Epoch 182 Batch 5 Loss 0.1512 Accuracy 7.7273
# Epoch 182 Batch 10 Loss 0.1511 Accuracy 7.7240
# Epoch 182 Batch 15 Loss 0.1511 Accuracy 7.7230
# Epoch 182 Batch 20 Loss 0.1510 Accuracy 7.7213
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.4644
# Epoch 183 Batch 5 Loss 0.1509 Accuracy 7.7188
# Epoch 183 Batch 10 Loss 0.1508 Accuracy 7.7159
# Epoch 183 Batch 15 Loss 0.1507 Accuracy 7.7145
# Epoch 183 Batch 20 Loss 0.1506 Accuracy 7.7117
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.4601
# Epoch 184 Batch 5 Loss 0.1505 Accuracy 7.7080
# Epoch 184 Batch 10 Loss 0.1504 Accuracy 7.7037
# Epoch 184 Batch 15 Loss 0.1503 Accuracy 7.7010
# Epoch 184 Batch 20 Loss 0.1502 Accuracy 7.6985
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.4668
# Epoch 185 Batch 5 Loss 0.1501 Accuracy 7.6941
# Epoch 185 Batch 10 Loss 0.1499 Accuracy 7.6897
# Epoch 185 Batch 15 Loss 0.1498 Accuracy 7.6860
# Epoch 185 Batch 20 Loss 0.1497 Accuracy 7.6827
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.4723
# Epoch 186 Batch 5 Loss 0.1495 Accuracy 7.6784
# Epoch 186 Batch 10 Loss 0.1494 Accuracy 7.6740
# Epoch 186 Batch 15 Loss 0.1493 Accuracy 7.6705
# Epoch 186 Batch 20 Loss 0.1492 Accuracy 7.6684
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 12.4778
# Epoch 187 Batch 5 Loss 0.1491 Accuracy 7.6640
# Epoch 187 Batch 10 Loss 0.1489 Accuracy 7.6595
# Epoch 187 Batch 15 Loss 0.1488 Accuracy 7.6567
# Epoch 187 Batch 20 Loss 0.1487 Accuracy 7.6539
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.4813
# Epoch 188 Batch 5 Loss 0.1486 Accuracy 7.6503
# Epoch 188 Batch 10 Loss 0.1485 Accuracy 7.6461
# Epoch 188 Batch 15 Loss 0.1484 Accuracy 7.6431
# Epoch 188 Batch 20 Loss 0.1483 Accuracy 7.6405
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.4866
# Epoch 189 Batch 5 Loss 0.1482 Accuracy 7.6361
# Epoch 189 Batch 10 Loss 0.1480 Accuracy 7.6323
# Epoch 189 Batch 15 Loss 0.1479 Accuracy 7.6294
# Epoch 189 Batch 20 Loss 0.1478 Accuracy 7.6265
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.4886
# Epoch 190 Batch 5 Loss 0.1477 Accuracy 7.6226
# Epoch 190 Batch 10 Loss 0.1476 Accuracy 7.6187
# Epoch 190 Batch 15 Loss 0.1475 Accuracy 7.6157
# Epoch 190 Batch 20 Loss 0.1474 Accuracy 7.6126
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.4922
# Epoch 191 Batch 5 Loss 0.1473 Accuracy 7.6091
# Epoch 191 Batch 10 Loss 0.1471 Accuracy 7.6060
# Epoch 191 Batch 15 Loss 0.1470 Accuracy 7.6028
# Epoch 191 Batch 20 Loss 0.1469 Accuracy 7.5998
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.4974
# Epoch 192 Batch 5 Loss 0.1468 Accuracy 7.5961
# Epoch 192 Batch 10 Loss 0.1467 Accuracy 7.5931
# Epoch 192 Batch 15 Loss 0.1466 Accuracy 7.5916
# Epoch 192 Batch 20 Loss 0.1466 Accuracy 7.5897
# Time taken for 1 epoch: 1.31 secs
#
# TestLoss 0.0000 TestAccuracy 12.4986
# Epoch 193 Batch 5 Loss 0.1465 Accuracy 7.5871
# Epoch 193 Batch 10 Loss 0.1464 Accuracy 7.5838
# Epoch 193 Batch 15 Loss 0.1463 Accuracy 7.5819
# Epoch 193 Batch 20 Loss 0.1462 Accuracy 7.5790
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 12.5023
# Epoch 194 Batch 5 Loss 0.1461 Accuracy 7.5757
# Epoch 194 Batch 10 Loss 0.1460 Accuracy 7.5725
# Epoch 194 Batch 15 Loss 0.1459 Accuracy 7.5699
# Epoch 194 Batch 20 Loss 0.1458 Accuracy 7.5675
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 12.5147
# Epoch 195 Batch 5 Loss 0.1457 Accuracy 7.5645
# Epoch 195 Batch 10 Loss 0.1456 Accuracy 7.5610
# Epoch 195 Batch 15 Loss 0.1455 Accuracy 7.5583
# Epoch 195 Batch 20 Loss 0.1454 Accuracy 7.5552
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 12.5192
# Epoch 196 Batch 5 Loss 0.1452 Accuracy 7.5512
# Epoch 196 Batch 10 Loss 0.1451 Accuracy 7.5477
# Epoch 196 Batch 15 Loss 0.1450 Accuracy 7.5451
# Epoch 196 Batch 20 Loss 0.1449 Accuracy 7.5423
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.5203
# Epoch 197 Batch 5 Loss 0.1448 Accuracy 7.5384
# Epoch 197 Batch 10 Loss 0.1447 Accuracy 7.5348
# Epoch 197 Batch 15 Loss 0.1446 Accuracy 7.5320
# Epoch 197 Batch 20 Loss 0.1445 Accuracy 7.5291
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.5201
# Epoch 198 Batch 5 Loss 0.1444 Accuracy 7.5249
# Epoch 198 Batch 10 Loss 0.1442 Accuracy 7.5212
# Epoch 198 Batch 15 Loss 0.1441 Accuracy 7.5181
# Epoch 198 Batch 20 Loss 0.1440 Accuracy 7.5146
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 12.5238
# Epoch 199 Batch 5 Loss 0.1439 Accuracy 7.5103
# Epoch 199 Batch 10 Loss 0.1437 Accuracy 7.5062
# Epoch 199 Batch 15 Loss 0.1436 Accuracy 7.5029
# Epoch 199 Batch 20 Loss 0.1435 Accuracy 7.4999
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 12.5260
# Epoch 200 Batch 5 Loss 0.1434 Accuracy 7.4972
# Epoch 200 Batch 10 Loss 0.1433 Accuracy 7.4939
# Epoch 200 Batch 15 Loss 0.1432 Accuracy 7.4916
# Epoch 200 Batch 20 Loss 0.1432 Accuracy 7.4893
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 12.5345

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_float_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin_float(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_float_scaled, Models_dangjin_floating)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 4.3241 Accuracy 33.1366
# Epoch 1 Batch 10 Loss 3.4052 Accuracy 30.5749
# Epoch 1 Batch 15 Loss 2.8855 Accuracy 26.7058
# Epoch 1 Batch 20 Loss 2.7327 Accuracy 26.0660
# Time taken for 1 epoch: 5.57 secs
#
# WARNING:tensorflow:Layer train_model_3 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 17.8200
# Epoch 2 Batch 5 Loss 2.6561 Accuracy 25.1141
# Epoch 2 Batch 10 Loss 2.5432 Accuracy 24.1625
# Epoch 2 Batch 15 Loss 2.3699 Accuracy 22.6359
# Epoch 2 Batch 20 Loss 2.3125 Accuracy 22.7770
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 14.5090
# Epoch 3 Batch 5 Loss 2.2098 Accuracy 21.8170
# Epoch 3 Batch 10 Loss 2.1218 Accuracy 21.3256
# Epoch 3 Batch 15 Loss 2.0259 Accuracy 20.7584
# Epoch 3 Batch 20 Loss 1.9421 Accuracy 20.3013
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 12.8312
# Epoch 4 Batch 5 Loss 1.8615 Accuracy 19.6938
# Epoch 4 Batch 10 Loss 1.8170 Accuracy 19.3979
# Epoch 4 Batch 15 Loss 1.7498 Accuracy 19.0318
# Epoch 4 Batch 20 Loss 1.7025 Accuracy 18.8076
# Time taken for 1 epoch: 1.13 secs
#
# TestLoss 0.0000 TestAccuracy 12.0478
# Epoch 5 Batch 5 Loss 1.6555 Accuracy 18.4348
# Epoch 5 Batch 10 Loss 1.6234 Accuracy 18.1333
# Epoch 5 Batch 15 Loss 1.5716 Accuracy 17.7930
# Epoch 5 Batch 20 Loss 1.5417 Accuracy 17.7145
# Time taken for 1 epoch: 1.11 secs
#
# TestLoss 0.0000 TestAccuracy 11.5192
# Epoch 6 Batch 5 Loss 1.5125 Accuracy 17.5587
# Epoch 6 Batch 10 Loss 1.4880 Accuracy 17.3159
# Epoch 6 Batch 15 Loss 1.4547 Accuracy 17.0300
# Epoch 6 Batch 20 Loss 1.4338 Accuracy 16.9866
# Time taken for 1 epoch: 1.12 secs
#
# TestLoss 0.0000 TestAccuracy 11.2816
# Epoch 7 Batch 5 Loss 1.4205 Accuracy 16.9930
# Epoch 7 Batch 10 Loss 1.3973 Accuracy 16.7801
# Epoch 7 Batch 15 Loss 1.3789 Accuracy 16.5674
# Epoch 7 Batch 20 Loss 1.3603 Accuracy 16.4859
# Time taken for 1 epoch: 1.15 secs
#
# TestLoss 0.0000 TestAccuracy 11.1256
# Epoch 8 Batch 5 Loss 1.3532 Accuracy 16.5369
# Epoch 8 Batch 10 Loss 1.3326 Accuracy 16.3941
# Epoch 8 Batch 15 Loss 1.3201 Accuracy 16.2355
# Epoch 8 Batch 20 Loss 1.3046 Accuracy 16.1333
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 10.9373
# Epoch 9 Batch 5 Loss 1.2967 Accuracy 16.1472
# Epoch 9 Batch 10 Loss 1.2811 Accuracy 16.0432
# Epoch 9 Batch 15 Loss 1.2695 Accuracy 15.9068
# Epoch 9 Batch 20 Loss 1.2570 Accuracy 15.8224
# Time taken for 1 epoch: 1.13 secs
#
# TestLoss 0.0000 TestAccuracy 10.7616
# Epoch 10 Batch 5 Loss 1.2499 Accuracy 15.8254
# Epoch 10 Batch 10 Loss 1.2374 Accuracy 15.7351
# Epoch 10 Batch 15 Loss 1.2276 Accuracy 15.6182
# Epoch 10 Batch 20 Loss 1.2174 Accuracy 15.5542
# Time taken for 1 epoch: 1.13 secs
#
# TestLoss 0.0000 TestAccuracy 10.6247
# Epoch 11 Batch 5 Loss 1.2122 Accuracy 15.5677
# Epoch 11 Batch 10 Loss 1.2016 Accuracy 15.4863
# Epoch 11 Batch 15 Loss 1.1937 Accuracy 15.3842
# Epoch 11 Batch 20 Loss 1.1852 Accuracy 15.3317
# Time taken for 1 epoch: 1.12 secs
#
# TestLoss 0.0000 TestAccuracy 10.5132
# Epoch 12 Batch 5 Loss 1.1814 Accuracy 15.3531
# Epoch 12 Batch 10 Loss 1.1722 Accuracy 15.2885
# Epoch 12 Batch 15 Loss 1.1657 Accuracy 15.2012
# Epoch 12 Batch 20 Loss 1.1583 Accuracy 15.1540
# Time taken for 1 epoch: 1.09 secs
#
# TestLoss 0.0000 TestAccuracy 10.4185
# Epoch 13 Batch 5 Loss 1.1551 Accuracy 15.1738
# Epoch 13 Batch 10 Loss 1.1471 Accuracy 15.1113
# Epoch 13 Batch 15 Loss 1.1415 Accuracy 15.0324
# Epoch 13 Batch 20 Loss 1.1353 Accuracy 14.9939
# Time taken for 1 epoch: 1.10 secs
#
# TestLoss 0.0000 TestAccuracy 10.3385
# Epoch 14 Batch 5 Loss 1.1328 Accuracy 15.0161
# Epoch 14 Batch 10 Loss 1.1259 Accuracy 14.9677
# Epoch 14 Batch 15 Loss 1.1211 Accuracy 14.8973
# Epoch 14 Batch 20 Loss 1.1156 Accuracy 14.8614
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.2654
# Epoch 15 Batch 5 Loss 1.1135 Accuracy 14.8842
# Epoch 15 Batch 10 Loss 1.1070 Accuracy 14.8325
# Epoch 15 Batch 15 Loss 1.1029 Accuracy 14.7681
# Epoch 15 Batch 20 Loss 1.0982 Accuracy 14.7411
# Time taken for 1 epoch: 1.11 secs
#
# TestLoss 0.0000 TestAccuracy 10.2148
# Epoch 16 Batch 5 Loss 1.0967 Accuracy 14.7676
# Epoch 16 Batch 10 Loss 1.0911 Accuracy 14.7290
# Epoch 16 Batch 15 Loss 1.0875 Accuracy 14.6719
# Epoch 16 Batch 20 Loss 1.0830 Accuracy 14.6404
# Time taken for 1 epoch: 1.12 secs
#
# TestLoss 0.0000 TestAccuracy 10.1616
# Epoch 17 Batch 5 Loss 1.0817 Accuracy 14.6606
# Epoch 17 Batch 10 Loss 1.0764 Accuracy 14.6125
# Epoch 17 Batch 15 Loss 1.0720 Accuracy 14.5541
# Epoch 17 Batch 20 Loss 1.0687 Accuracy 14.5403
# Time taken for 1 epoch: 1.13 secs
#
# TestLoss 0.0000 TestAccuracy 10.1095
# Epoch 18 Batch 5 Loss 1.0676 Accuracy 14.5557
# Epoch 18 Batch 10 Loss 1.0637 Accuracy 14.5223
# Epoch 18 Batch 15 Loss 1.0588 Accuracy 14.4750
# Epoch 18 Batch 20 Loss 1.0554 Accuracy 14.4595
# Time taken for 1 epoch: 1.16 secs
#
# TestLoss 0.0000 TestAccuracy 10.2891
# Epoch 19 Batch 5 Loss 1.0549 Accuracy 14.4671
# Epoch 19 Batch 10 Loss 1.0523 Accuracy 14.4344
# Epoch 19 Batch 15 Loss 1.0491 Accuracy 14.3897
# Epoch 19 Batch 20 Loss 1.0468 Accuracy 14.3878
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.2418
# Epoch 20 Batch 5 Loss 1.0463 Accuracy 14.4117
# Epoch 20 Batch 10 Loss 1.0431 Accuracy 14.3862
# Epoch 20 Batch 15 Loss 1.0406 Accuracy 14.3444
# Epoch 20 Batch 20 Loss 1.0377 Accuracy 14.3235
# Time taken for 1 epoch: 1.11 secs
#
# TestLoss 0.0000 TestAccuracy 10.1929
# Epoch 21 Batch 5 Loss 1.0371 Accuracy 14.3438
# Epoch 21 Batch 10 Loss 1.0336 Accuracy 14.3185
# Epoch 21 Batch 15 Loss 1.0310 Accuracy 14.2798
# Epoch 21 Batch 20 Loss 1.0284 Accuracy 14.2614
# Time taken for 1 epoch: 1.13 secs
#
# TestLoss 0.0000 TestAccuracy 10.1495
# Epoch 22 Batch 5 Loss 1.0275 Accuracy 14.2752
# Epoch 22 Batch 10 Loss 1.0245 Accuracy 14.2511
# Epoch 22 Batch 15 Loss 1.0221 Accuracy 14.2135
# Epoch 22 Batch 20 Loss 1.0197 Accuracy 14.1978
# Time taken for 1 epoch: 1.13 secs
#
# TestLoss 0.0000 TestAccuracy 10.1080
# Epoch 23 Batch 5 Loss 1.0191 Accuracy 14.2149
# Epoch 23 Batch 10 Loss 1.0161 Accuracy 14.1922
# Epoch 23 Batch 15 Loss 1.0140 Accuracy 14.1570
# Epoch 23 Batch 20 Loss 1.0117 Accuracy 14.1415
# Time taken for 1 epoch: 1.13 secs
#
# TestLoss 0.0000 TestAccuracy 10.0694
# Epoch 24 Batch 5 Loss 1.0112 Accuracy 14.1585
# Epoch 24 Batch 10 Loss 1.0083 Accuracy 14.1357
# Epoch 24 Batch 15 Loss 1.0064 Accuracy 14.1020
# Epoch 24 Batch 20 Loss 1.0043 Accuracy 14.0883
# Time taken for 1 epoch: 1.16 secs
#
# TestLoss 0.0000 TestAccuracy 10.0358
# Epoch 25 Batch 5 Loss 1.0041 Accuracy 14.1080
# Epoch 25 Batch 10 Loss 1.0012 Accuracy 14.0835
# Epoch 25 Batch 15 Loss 0.9995 Accuracy 14.0515
# Epoch 25 Batch 20 Loss 0.9975 Accuracy 14.0389
# Time taken for 1 epoch: 1.13 secs
#
# TestLoss 0.0000 TestAccuracy 10.0081
# Epoch 26 Batch 5 Loss 0.9976 Accuracy 14.0603
# Epoch 26 Batch 10 Loss 0.9947 Accuracy 14.0377
# Epoch 26 Batch 15 Loss 0.9930 Accuracy 14.0068
# Epoch 26 Batch 20 Loss 0.9910 Accuracy 13.9947
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 9.9749
# Epoch 27 Batch 5 Loss 0.9907 Accuracy 14.0065
# Epoch 27 Batch 10 Loss 0.9885 Accuracy 13.9815
# Epoch 27 Batch 15 Loss 0.9854 Accuracy 13.9449
# Epoch 27 Batch 20 Loss 0.9835 Accuracy 13.9423
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 9.9524
# Epoch 28 Batch 5 Loss 0.9810 Accuracy 13.9166
# Epoch 28 Batch 10 Loss 0.9795 Accuracy 13.9126
# Epoch 28 Batch 15 Loss 0.9778 Accuracy 13.8970
# Epoch 28 Batch 20 Loss 0.9774 Accuracy 13.9117
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.9376
# Epoch 29 Batch 5 Loss 0.9769 Accuracy 13.9182
# Epoch 29 Batch 10 Loss 0.9761 Accuracy 13.8953
# Epoch 29 Batch 15 Loss 0.9739 Accuracy 13.8643
# Epoch 29 Batch 20 Loss 0.9731 Accuracy 13.8711
# Time taken for 1 epoch: 1.29 secs
#
# TestLoss 0.0000 TestAccuracy 9.9152
# Epoch 30 Batch 5 Loss 0.9727 Accuracy 13.8851
# Epoch 30 Batch 10 Loss 0.9706 Accuracy 13.8632
# Epoch 30 Batch 15 Loss 0.9685 Accuracy 13.8341
# Epoch 30 Batch 20 Loss 0.9670 Accuracy 13.8300
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy
# Epoch 40 Batch 15 Loss 0.8902 Accuracy 13.2582
# Epoch 40 Batch 20 Loss 0.8886 Accuracy 13.2524
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 9.6532
# Epoch 41 Batch 5 Loss 0.8883 Accuracy 13.2650
# Epoch 41 Batch 10 Loss 0.8863 Accuracy 13.2439
# Epoch 41 Batch 15 Loss 0.8842 Accuracy 13.2206
# Epoch 41 Batch 20 Loss 0.8824 Accuracy 13.2088
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 9.6647
# Epoch 42 Batch 5 Loss 0.8818 Accuracy 13.2129
# Epoch 42 Batch 10 Loss 0.8803 Accuracy 13.1916
# Epoch 42 Batch 15 Loss 0.8782 Accuracy 13.1677
# Epoch 42 Batch 20 Loss 0.8771 Accuracy 13.1670
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 9.6814
# Epoch 43 Batch 5 Loss 0.8766 Accuracy 13.1726
# Epoch 43 Batch 10 Loss 0.8752 Accuracy 13.1527
# Epoch 43 Batch 15 Loss 0.8727 Accuracy 13.1303
# Epoch 43 Batch 20 Loss 0.8716 Accuracy 13.1320
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 9.6500
# Epoch 44 Batch 5 Loss 0.8707 Accuracy 13.1344
# Epoch 44 Batch 10 Loss 0.8693 Accuracy 13.1154
# Epoch 44 Batch 15 Loss 0.8671 Accuracy 13.0925
# Epoch 44 Batch 20 Loss 0.8655 Accuracy 13.0848
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.6330
# Epoch 45 Batch 5 Loss 0.8642 Accuracy 13.0775
# Epoch 45 Batch 10 Loss 0.8630 Accuracy 13.0634
# Epoch 45 Batch 15 Loss 0.8611 Accuracy 13.0429
# Epoch 45 Batch 20 Loss 0.8600 Accuracy 13.0414
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 9.6562
# Epoch 46 Batch 5 Loss 0.8595 Accuracy 13.0476
# Epoch 46 Batch 10 Loss 0.8582 Accuracy 13.0305
# Epoch 46 Batch 15 Loss 0.8565 Accuracy 13.0108
# Epoch 46 Batch 20 Loss 0.8550 Accuracy 13.0015
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.6575
# Epoch 47 Batch 5 Loss 0.8549 Accuracy 13.0134
# Epoch 47 Batch 10 Loss 0.8531 Accuracy 12.9962
# Epoch 47 Batch 15 Loss 0.8514 Accuracy 12.9786
# Epoch 47 Batch 20 Loss 0.8498 Accuracy 12.9632
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 9.6822
# Epoch 48 Batch 5 Loss 0.8498 Accuracy 12.9739
# Epoch 48 Batch 10 Loss 0.8480 Accuracy 12.9537
# Epoch 48 Batch 15 Loss 0.8461 Accuracy 12.9323
# Epoch 48 Batch 20 Loss 0.8449 Accuracy 12.9235
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.6987
# Epoch 49 Batch 5 Loss 0.8448 Accuracy 12.9334
# Epoch 49 Batch 10 Loss 0.8430 Accuracy 12.9141
# Epoch 49 Batch 15 Loss 0.8412 Accuracy 12.8934
# Epoch 49 Batch 20 Loss 0.8397 Accuracy 12.8822
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.7194
# Epoch 50 Batch 5 Loss 0.8395 Accuracy 12.8898
# Epoch 50 Batch 10 Loss 0.8377 Accuracy 12.8713
# Epoch 50 Batch 15 Loss 0.8361 Accuracy 12.8519
# Epoch 50 Batch 20 Loss 0.8346 Accuracy 12.8391
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.0049
# Epoch 72 Batch 5 Loss 0.7500 Accuracy 12.1111
# Epoch 72 Batch 10 Loss 0.7490 Accuracy 12.0997
# Epoch 72 Batch 15 Loss 0.7479 Accuracy 12.0870
# Epoch 72 Batch 20 Loss 0.7470 Accuracy 12.0793
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.0074
# Epoch 73 Batch 5 Loss 0.7470 Accuracy 12.0845
# Epoch 73 Batch 10 Loss 0.7459 Accuracy 12.0730
# Epoch 73 Batch 15 Loss 0.7448 Accuracy 12.0601
# Epoch 73 Batch 20 Loss 0.7440 Accuracy 12.0508
# Time taken for 1 epoch: 1.28 secs
#
# TestLoss 0.0000 TestAccuracy 10.0303
# Epoch 74 Batch 5 Loss 0.7438 Accuracy 12.0552
# Epoch 74 Batch 10 Loss 0.7428 Accuracy 12.0454
# Epoch 74 Batch 15 Loss 0.7419 Accuracy 12.0343
# Epoch 74 Batch 20 Loss 0.7412 Accuracy 12.0262
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.0268
# Epoch 75 Batch 5 Loss 0.7411 Accuracy 12.0312
# Epoch 75 Batch 10 Loss 0.7400 Accuracy 12.0212
# Epoch 75 Batch 15 Loss 0.7389 Accuracy 12.0081
# Epoch 75 Batch 20 Loss 0.7380 Accuracy 11.9983
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.0416
# Epoch 76 Batch 5 Loss 0.7378 Accuracy 12.0009
# Epoch 76 Batch 10 Loss 0.7368 Accuracy 11.9905
# Epoch 76 Batch 15 Loss 0.7358 Accuracy 11.9790
# Epoch 76 Batch 20 Loss 0.7351 Accuracy 11.9710
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.0491
# Epoch 77 Batch 5 Loss 0.7349 Accuracy 11.9751
# Epoch 77 Batch 10 Loss 0.7339 Accuracy 11.9659
# Epoch 77 Batch 15 Loss 0.7329 Accuracy 11.9541
# Epoch 77 Batch 20 Loss 0.7321 Accuracy 11.9433
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.0544
# Epoch 78 Batch 5 Loss 0.7318 Accuracy 11.9460
# Epoch 78 Batch 10 Loss 0.7308 Accuracy 11.9363
# Epoch 78 Batch 15 Loss 0.7298 Accuracy 11.9249
# Epoch 78 Batch 20 Loss 0.7291 Accuracy 11.9150
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 10.0647
# Epoch 79 Batch 5 Loss 0.7289 Accuracy 11.9184
# Epoch 79 Batch 10 Loss 0.7279 Accuracy 11.9092
# Epoch 79 Batch 15 Loss 0.7269 Accuracy 11.8975
# Epoch 79 Batch 20 Loss 0.7262 Accuracy 11.8888
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.0657
# Epoch 80 Batch 5 Loss 0.7260 Accuracy 11.8924
# Epoch 80 Batch 10 Loss 0.7251 Accuracy 11.8836
# Epoch 80 Batch 15 Loss 0.7240 Accuracy 11.8721
# Epoch 80 Batch 20 Loss 0.7233 Accuracy 11.8622
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.0776
# Epoch 81 Batch 5 Loss 0.7231 Accuracy 11.8650
# Epoch 81 Batch 10 Loss 0.7221 Accuracy 11.8565
# Epoch 81 Batch 15 Loss 0.7212 Accuracy 11.8458
# Epoch 81 Batch 20 Loss 0.7205 Accuracy 11.8363
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.0858
# Epoch 82 Batch 5 Loss 0.7203 Accuracy 11.8396
# Epoch 82 Batch 10 Loss 0.7194 Accuracy 11.8316
# Epoch 82 Batch 15 Loss 0.7186 Accuracy 11.8200
# Epoch 82 Batch 20 Loss 0.7179 Accuracy 11.8116
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 10.0830
# Epoch 83 Batch 5 Loss 0.7176 Accuracy 11.8142
# Epoch 83 Batch 10 Loss 0.7168 Accuracy 11.8055
# Epoch 83 Batch 15 Loss 0.7158 Accuracy 11.7950
# Epoch 83 Batch 20 Loss 0.7151 Accuracy 11.7860
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 10.1012
# Epoch 84 Batch 5 Loss 0.7149 Accuracy 11.7894
# Epoch 84 Batch 10 Loss 0.7140 Accuracy 11.7806
# Epoch 84 Batch 15 Loss 0.7132 Accuracy 11.7707
# Epoch 84 Batch 20 Loss 0.7125 Accuracy 11.7622
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 10.0934
# Epoch 85 Batch 5 Loss 0.7123 Accuracy 11.7645
# Epoch 85 Batch 10 Loss 0.7116 Accuracy 11.7589
# Epoch 85 Batch 15 Loss 0.7108 Accuracy 11.7499
# Epoch 85 Batch 20 Loss 0.7102 Accuracy 11.7409
# Time taken for 1 epoch: 1.28 secs
#
# TestLoss 0.0000 TestAccuracy 10.1041
# Epoch 86 Batch 5 Loss 0.7103 Accuracy 11.7465
# Epoch 86 Batch 10 Loss 0.7096 Accuracy 11.7398
# Epoch 86 Batch 15 Loss 0.7089 Accuracy 11.7314
# Epoch 86 Batch 20 Loss 0.7085 Accuracy 11.7278
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.1143
# Epoch 87 Batch 5 Loss 0.7084 Accuracy 11.7316
# Epoch 87 Batch 10 Loss 0.7077 Accuracy 11.7249
# Epoch 87 Batch 15 Loss 0.7071 Accuracy 11.7162
# Epoch 87 Batch 20 Loss 0.7065 Accuracy 11.7105
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.1395
# Epoch 88 Batch 5 Loss 0.7065 Accuracy 11.7155
# Epoch 88 Batch 10 Loss 0.7059 Accuracy 11.7077
# Epoch 88 Batch 15 Loss 0.7051 Accuracy 11.6987
# Epoch 88 Batch 20 Loss 0.7046 Accuracy 11.6932
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.1421
# Epoch 89 Batch 5 Loss 0.7046 Accuracy 11.6983
# Epoch 89 Batch 10 Loss 0.7037 Accuracy 11.6910
# Epoch 89 Batch 15 Loss 0.7031 Accuracy 11.6814
# Epoch 89 Batch 20 Loss 0.7025 Accuracy 11.6748
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.1482
# Epoch 90 Batch 5 Loss 0.7024 Accuracy 11.6783
# Epoch 90 Batch 10 Loss 0.7016 Accuracy 11.6708
# Epoch 90 Batch 15 Loss 0.7007 Accuracy 11.6609
# Epoch 90 Batch 20 Loss 0.7001 Accuracy 11.6528
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.1588
# Epoch 91 Batch 5 Loss 0.6999 Accuracy 11.6554
# Epoch 91 Batch 10 Loss 0.6991 Accuracy 11.6482
# Epoch 91 Batch 15 Loss 0.6984 Accuracy 11.6382
# Epoch 91 Batch 20 Loss 0.6978 Accuracy 11.6309
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 10.1557
# Epoch 92 Batch 5 Loss 0.6977 Accuracy 11.6338
# Epoch 92 Batch 10 Loss 0.6968 Accuracy 11.6267
# Epoch 92 Batch 15 Loss 0.6960 Accuracy 11.6162
# Epoch 92 Batch 20 Loss 0.6954 Accuracy 11.6085
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.1739
# Epoch 93 Batch 5 Loss 0.6952 Accuracy 11.6101
# Epoch 93 Batch 10 Loss 0.6944 Accuracy 11.6030
# Epoch 93 Batch 15 Loss 0.6937 Accuracy 11.5938
# Epoch 93 Batch 20 Loss 0.6930 Accuracy 11.5857
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.1704
# Epoch 94 Batch 5 Loss 0.6930 Accuracy 11.5890
# Epoch 94 Batch 10 Loss 0.6923 Accuracy 11.5825
# Epoch 94 Batch 15 Loss 0.6915 Accuracy 11.5722
# Epoch 94 Batch 20 Loss 0.6911 Accuracy 11.5670
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.1886
# Epoch 95 Batch 5 Loss 0.6908 Accuracy 11.5682
# Epoch 95 Batch 10 Loss 0.6901 Accuracy 11.5616
# Epoch 95 Batch 15 Loss 0.6894 Accuracy 11.5531
# Epoch 95 Batch 20 Loss 0.6889 Accuracy 11.5470
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.1897
# Epoch 96 Batch 5 Loss 0.6887 Accuracy 11.5489
# Epoch 96 Batch 10 Loss 0.6880 Accuracy 11.5420
# Epoch 96 Batch 15 Loss 0.6873 Accuracy 11.5327
# Epoch 96 Batch 20 Loss 0.6868 Accuracy 11.5257
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.1985
# Epoch 97 Batch 5 Loss 0.6866 Accuracy 11.5281
# Epoch 97 Batch 10 Loss 0.6859 Accuracy 11.5211
# Epoch 97 Batch 15 Loss 0.6852 Accuracy 11.5128
# Epoch 97 Batch 20 Loss 0.6848 Accuracy 11.5088
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.2063
# Epoch 98 Batch 5 Loss 0.6847 Accuracy 11.5116
# Epoch 98 Batch 10 Loss 0.6841 Accuracy 11.5051
# Epoch 98 Batch 15 Loss 0.6834 Accuracy 11.4967
# Epoch 98 Batch 20 Loss 0.6829 Accuracy 11.4908
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 10.1994
# Epoch 99 Batch 5 Loss 0.6827 Accuracy 11.4916
# Epoch 99 Batch 10 Loss 0.6820 Accuracy 11.4844
# Epoch 99 Batch 15 Loss 0.6813 Accuracy 11.4756
# Epoch 99 Batch 20 Loss 0.6809 Accuracy 11.4708
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.2163
# Epoch 100 Batch 5 Loss 0.6808 Accuracy 11.4743
# Epoch 100 Batch 10 Loss 0.6802 Accuracy 11.4675
# Epoch 100 Batch 15 Loss 0.6796 Accuracy 11.4590
# Epoch 100 Batch 20 Loss 0.6791 Accuracy 11.4525
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.2185
# Epoch 101 Batch 5 Loss 0.6790 Accuracy 11.4560
# Epoch 101 Batch 10 Loss 0.6784 Accuracy 11.4499
# Epoch 101 Batch 15 Loss 0.6777 Accuracy 11.4419
# Epoch 101 Batch 20 Loss 0.6773 Accuracy 11.4362
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.2290
# Epoch 102 Batch 5 Loss 0.6772 Accuracy 11.4394
# Epoch 102 Batch 10 Loss 0.6766 Accuracy 11.4341
# Epoch 102 Batch 15 Loss 0.6759 Accuracy 11.4262
# Epoch 102 Batch 20 Loss 0.6755 Accuracy 11.4205
# Time taken for 1 epoch: 1.29 secs
#
# TestLoss 0.0000 TestAccuracy 10.2249
# Epoch 103 Batch 5 Loss 0.6755 Accuracy 11.4242
# Epoch 103 Batch 10 Loss 0.6748 Accuracy 11.4182
# Epoch 103 Batch 15 Loss 0.6741 Accuracy 11.4095
# Epoch 103 Batch 20 Loss 0.6736 Accuracy 11.4031
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.2497
# Epoch 104 Batch 5 Loss 0.6735 Accuracy 11.4057
# Epoch 104 Batch 10 Loss 0.6729 Accuracy 11.3989
# Epoch 104 Batch 15 Loss 0.6722 Accuracy 11.3909
# Epoch 104 Batch 20 Loss 0.6717 Accuracy 11.3840
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 10.2490
# Epoch 105 Batch 5 Loss 0.6716 Accuracy 11.3868
# Epoch 105 Batch 10 Loss 0.6710 Accuracy 11.3807
# Epoch 105 Batch 15 Loss 0.6703 Accuracy 11.3729
# Epoch 105 Batch 20 Loss 0.6699 Accuracy 11.3672
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.2602
# Epoch 106 Batch 5 Loss 0.6699 Accuracy 11.3710
# Epoch 106 Batch 10 Loss 0.6692 Accuracy 11.3659
# Epoch 106 Batch 15 Loss 0.6685 Accuracy 11.3578
# Epoch 106 Batch 20 Loss 0.6681 Accuracy 11.3515
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.2596
# Epoch 107 Batch 5 Loss 0.6679 Accuracy 11.3533
# Epoch 107 Batch 10 Loss 0.6673 Accuracy 11.3477
# Epoch 107 Batch 15 Loss 0.6666 Accuracy 11.3398
# Epoch 107 Batch 20 Loss 0.6661 Accuracy 11.3325
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 10.2686
# Epoch 108 Batch 5 Loss 0.6660 Accuracy 11.3345
# Epoch 108 Batch 10 Loss 0.6654 Accuracy 11.3297
# Epoch 108 Batch 15 Loss 0.6648 Accuracy 11.3230
# Epoch 108 Batch 20 Loss 0.6645 Accuracy 11.3163
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.2611
# Epoch 109 Batch 5 Loss 0.6644 Accuracy 11.3194
# Epoch 109 Batch 10 Loss 0.6638 Accuracy 11.3145
# Epoch 109 Batch 15 Loss 0.6632 Accuracy 11.3067
# Epoch 109 Batch 20 Loss 0.6629 Accuracy 11.3028
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 10.2627
# Epoch 110 Batch 5 Loss 0.6627 Accuracy 11.3046
# Epoch 110 Batch 10 Loss 0.6621 Accuracy 11.2997
# Epoch 110 Batch 15 Loss 0.6615 Accuracy 11.2919
# Epoch 110 Batch 20 Loss 0.6611 Accuracy 11.2851
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 10.2614
# Epoch 111 Batch 5 Loss 0.6609 Accuracy 11.2868
# Epoch 111 Batch 10 Loss 0.6603 Accuracy 11.2809
# Epoch 111 Batch 15 Loss 0.6596 Accuracy 11.2734
# Epoch 111 Batch 20 Loss 0.6592 Accuracy 11.2690
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 10.2652
# Epoch 112 Batch 5 Loss 0.6592 Accuracy 11.2721
# Epoch 112 Batch 10 Loss 0.6587 Accuracy 11.2659
# Epoch 112 Batch 15 Loss 0.6581 Accuracy 11.2580
# Epoch 112 Batch 20 Loss 0.6578 Accuracy 11.2543
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.2977
# Epoch 124 Batch 5 Loss 0.6410 Accuracy 11.0994
# Epoch 124 Batch 10 Loss 0.6405 Accuracy 11.0949
# Epoch 124 Batch 15 Loss 0.6400 Accuracy 11.0888
# Epoch 124 Batch 20 Loss 0.6397 Accuracy 11.0838
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.2910
# Epoch 125 Batch 5 Loss 0.6395 Accuracy 11.0856
# Epoch 125 Batch 10 Loss 0.6390 Accuracy 11.0809
# Epoch 125 Batch 15 Loss 0.6385 Accuracy 11.0743
# Epoch 125 Batch 20 Loss 0.6381 Accuracy 11.0680
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.2901
# Epoch 126 Batch 5 Loss 0.6379 Accuracy 11.0689
# Epoch 126 Batch 10 Loss 0.6374 Accuracy 11.0645
# Epoch 126 Batch 15 Loss 0.6368 Accuracy 11.0578
# Epoch 126 Batch 20 Loss 0.6366 Accuracy 11.0525
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.3007
# Epoch 127 Batch 5 Loss 0.6363 Accuracy 11.0533
# Epoch 127 Batch 10 Loss 0.6359 Accuracy 11.0490
# Epoch 127 Batch 15 Loss 0.6353 Accuracy 11.0433
# Epoch 127 Batch 20 Loss 0.6350 Accuracy 11.0382
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.2969
# Epoch 128 Batch 5 Loss 0.6349 Accuracy 11.0402
# Epoch 128 Batch 10 Loss 0.6344 Accuracy 11.0357
# Epoch 128 Batch 15 Loss 0.6339 Accuracy 11.0296
# Epoch 128 Batch 20 Loss 0.6335 Accuracy 11.0238
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.2924
# Epoch 129 Batch 5 Loss 0.6334 Accuracy 11.0247
# Epoch 129 Batch 10 Loss 0.6329 Accuracy 11.0203
# Epoch 129 Batch 15 Loss 0.6324 Accuracy 11.0138
# Epoch 129 Batch 20 Loss 0.6321 Accuracy 11.0088
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.2965
# Epoch 130 Batch 5 Loss 0.6319 Accuracy 11.0099
# Epoch 130 Batch 10 Loss 0.6314 Accuracy 11.0057
# Epoch 130 Batch 15 Loss 0.6309 Accuracy 10.9998
# Epoch 130 Batch 20 Loss 0.6306 Accuracy 10.9944
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 10.3148
# Epoch 131 Batch 5 Loss 0.6304 Accuracy 10.9951
# Epoch 131 Batch 10 Loss 0.6299 Accuracy 10.9912
# Epoch 131 Batch 15 Loss 0.6295 Accuracy 10.9863
# Epoch 131 Batch 20 Loss 0.6292 Accuracy 10.9815
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 10.3129
# Epoch 132 Batch 5 Loss 0.6292 Accuracy 10.9847
# Epoch 132 Batch 10 Loss 0.6288 Accuracy 10.9807
# Epoch 132 Batch 15 Loss 0.6283 Accuracy 10.9752
# Epoch 132 Batch 20 Loss 0.6281 Accuracy 10.9728
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.3394
# Epoch 133 Batch 5 Loss 0.6280 Accuracy 10.9731
# Epoch 133 Batch 10 Loss 0.6276 Accuracy 10.9691
# Epoch 133 Batch 15 Loss 0.6271 Accuracy 10.9641
# Epoch 133 Batch 20 Loss 0.6268 Accuracy 10.9600
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.3367
# Epoch 134 Batch 5 Loss 0.6268 Accuracy 10.9627
# Epoch 134 Batch 10 Loss 0.6265 Accuracy 10.9586
# Epoch 134 Batch 15 Loss 0.6260 Accuracy 10.9533
# Epoch 134 Batch 20 Loss 0.6258 Accuracy 10.9497
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.3431
# Epoch 135 Batch 5 Loss 0.6256 Accuracy 10.9510
# Epoch 135 Batch 10 Loss 0.6252 Accuracy 10.9470
# Epoch 135 Batch 15 Loss 0.6248 Accuracy 10.9417
# Epoch 135 Batch 20 Loss 0.6247 Accuracy 10.9397
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.3534
# Epoch 136 Batch 5 Loss 0.6246 Accuracy 10.9422
# Epoch 136 Batch 10 Loss 0.6242 Accuracy 10.9392
# Epoch 136 Batch 15 Loss 0.6237 Accuracy 10.9336
# Epoch 136 Batch 20 Loss 0.6235 Accuracy 10.9305
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.3593
# Epoch 137 Batch 5 Loss 0.6232 Accuracy 10.9286
# Epoch 137 Batch 10 Loss 0.6229 Accuracy 10.9252
# Epoch 137 Batch 15 Loss 0.6225 Accuracy 10.9207
# Epoch 137 Batch 20 Loss 0.6222 Accuracy 10.9177
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.3710
# Epoch 138 Batch 5 Loss 0.6223 Accuracy 10.9211
# Epoch 138 Batch 10 Loss 0.6220 Accuracy 10.9172
# Epoch 138 Batch 15 Loss 0.6216 Accuracy 10.9122
# Epoch 138 Batch 20 Loss 0.6216 Accuracy 10.9111
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.3856
# Epoch 139 Batch 5 Loss 0.6216 Accuracy 10.9146
# Epoch 139 Batch 10 Loss 0.6212 Accuracy 10.9117
# Epoch 139 Batch 15 Loss 0.6209 Accuracy 10.9069
# Epoch 139 Batch 20 Loss 0.6206 Accuracy 10.9020
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.3819
# Epoch 140 Batch 5 Loss 0.6206 Accuracy 10.9050
# Epoch 140 Batch 10 Loss 0.6202 Accuracy 10.9017
# Epoch 140 Batch 15 Loss 0.6198 Accuracy 10.8967
# Epoch 140 Batch 20 Loss 0.6197 Accuracy 10.8947
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.3988
# Epoch 141 Batch 5 Loss 0.6196 Accuracy 10.8963
# Epoch 141 Batch 10 Loss 0.6192 Accuracy 10.8945
# Epoch 141 Batch 15 Loss 0.6189 Accuracy 10.8900
# Epoch 141 Batch 20 Loss 0.6186 Accuracy 10.8846
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.3975
# Epoch 142 Batch 5 Loss 0.6186 Accuracy 10.8871
# Epoch 142 Batch 10 Loss 0.6182 Accuracy 10.8843
# Epoch 142 Batch 15 Loss 0.6178 Accuracy 10.8796
# Epoch 142 Batch 20 Loss 0.6177 Accuracy 10.8784
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.4045
# Epoch 143 Batch 5 Loss 0.6176 Accuracy 10.8795
# Epoch 143 Batch 10 Loss 0.6172 Accuracy 10.8768
# Epoch 143 Batch 15 Loss 0.6169 Accuracy 10.8723
# Epoch 143 Batch 20 Loss 0.6166 Accuracy 10.8675
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 10.4039
# Epoch 144 Batch 5 Loss 0.6166 Accuracy 10.8707
# Epoch 144 Batch 10 Loss 0.6162 Accuracy 10.8677
# Epoch 144 Batch 15 Loss 0.6158 Accuracy 10.8626
# Epoch 144 Batch 20 Loss 0.6158 Accuracy 10.8615
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 10.4265
# Epoch 145 Batch 5 Loss 0.6156 Accuracy 10.8621
# Epoch 145 Batch 10 Loss 0.6153 Accuracy 10.8601
# Epoch 145 Batch 15 Loss 0.6149 Accuracy 10.8556
# Epoch 145 Batch 20 Loss 0.6147 Accuracy 10.8510
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 10.4323
# Epoch 146 Batch 5 Loss 0.6147 Accuracy 10.8546
# Epoch 146 Batch 10 Loss 0.6144 Accuracy 10.8515
# Epoch 146 Batch 15 Loss 0.6140 Accuracy 10.8464
# Epoch 146 Batch 20 Loss 0.6139 Accuracy 10.8439
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.4368
# Epoch 147 Batch 5 Loss 0.6138 Accuracy 10.8451
# Epoch 147 Batch 10 Loss 0.6134 Accuracy 10.8421
# Epoch 147 Batch 15 Loss 0.6130 Accuracy 10.8369
# Epoch 147 Batch 20 Loss 0.6127 Accuracy 10.8322
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 10.4345
# Epoch 148 Batch 5 Loss 0.6126 Accuracy 10.8336
# Epoch 148 Batch 10 Loss 0.6122 Accuracy 10.8298
# Epoch 148 Batch 15 Loss 0.6118 Accuracy 10.8243
# Epoch 148 Batch 20 Loss 0.6115 Accuracy 10.8206
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 10.4326
# Epoch 149 Batch 5 Loss 0.6114 Accuracy 10.8221
# Epoch 149 Batch 10 Loss 0.6110 Accuracy 10.8185
# Epoch 149 Batch 15 Loss 0.6106 Accuracy 10.8133
# Epoch 149 Batch 20 Loss 0.6104 Accuracy 10.8094
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 10.4352
# Epoch 150 Batch 5 Loss 0.6102 Accuracy 10.8099
# Epoch 150 Batch 10 Loss 0.6098 Accuracy 10.8061
# Epoch 150 Batch 15 Loss 0.6094 Accuracy 10.8012
# Epoch 150 Batch 20 Loss 0.6091 Accuracy 10.7968
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.4289
# Epoch 151 Batch 5 Loss 0.6090 Accuracy 10.7982
# Epoch 151 Batch 10 Loss 0.6086 Accuracy 10.7942
# Epoch 151 Batch 15 Loss 0.6082 Accuracy 10.7898
# Epoch 151 Batch 20 Loss 0.6079 Accuracy 10.7853
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 10.4243
# Epoch 152 Batch 5 Loss 0.6078 Accuracy 10.7857
# Epoch 152 Batch 10 Loss 0.6074 Accuracy 10.7821
# Epoch 152 Batch 15 Loss 0.6069 Accuracy 10.7769
# Epoch 152 Batch 20 Loss 0.6067 Accuracy 10.7723
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.4199
# Epoch 153 Batch 5 Loss 0.6066 Accuracy 10.7732
# Epoch 153 Batch 10 Loss 0.6061 Accuracy 10.7696
# Epoch 153 Batch 15 Loss 0.6057 Accuracy 10.7643
# Epoch 153 Batch 20 Loss 0.6055 Accuracy 10.7605
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.4271
# Epoch 154 Batch 5 Loss 0.6052 Accuracy 10.7598
# Epoch 154 Batch 10 Loss 0.6049 Accuracy 10.7562
# Epoch 154 Batch 15 Loss 0.6044 Accuracy 10.7514
# Epoch 154 Batch 20 Loss 0.6042 Accuracy 10.7474
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.4168
# Epoch 155 Batch 5 Loss 0.6040 Accuracy 10.7481
# Epoch 155 Batch 10 Loss 0.6036 Accuracy 10.7438
# Epoch 155 Batch 15 Loss 0.6033 Accuracy 10.7393
# Epoch 155 Batch 20 Loss 0.6031 Accuracy 10.7366
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 10.4276
# Epoch 156 Batch 5 Loss 0.6030 Accuracy 10.7377
# Epoch 156 Batch 10 Loss 0.6026 Accuracy 10.7350
# Epoch 156 Batch 15 Loss 0.6023 Accuracy 10.7312
# Epoch 156 Batch 20 Loss 0.6021 Accuracy 10.7271
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 10.4280
# Epoch 157 Batch 5 Loss 0.6020 Accuracy 10.7295
# Epoch 157 Batch 10 Loss 0.6017 Accuracy 10.7270
# Epoch 157 Batch 15 Loss 0.6013 Accuracy 10.7224
# Epoch 157 Batch 20 Loss 0.6012 Accuracy 10.7196
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.4282
# Epoch 158 Batch 5 Loss 0.6009 Accuracy 10.7181
# Epoch 158 Batch 10 Loss 0.6006 Accuracy 10.7145
# Epoch 158 Batch 15 Loss 0.6002 Accuracy 10.7101
# Epoch 158 Batch 20 Loss 0.5999 Accuracy 10.7064
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 10.4237
# Epoch 159 Batch 5 Loss 0.5999 Accuracy 10.7084
# Epoch 159 Batch 10 Loss 0.5995 Accuracy 10.7050
# Epoch 159 Batch 15 Loss 0.5992 Accuracy 10.7004
# Epoch 159 Batch 20 Loss 0.5990 Accuracy 10.6984
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.4302
# Epoch 160 Batch 5 Loss 0.5989 Accuracy 10.6987
# Epoch 160 Batch 10 Loss 0.5985 Accuracy 10.6957
# Epoch 160 Batch 15 Loss 0.5982 Accuracy 10.6916
# Epoch 160 Batch 20 Loss 0.5980 Accuracy 10.6873
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 10.4289
# Epoch 161 Batch 5 Loss 0.5979 Accuracy 10.6887
# Epoch 161 Batch 10 Loss 0.5975 Accuracy 10.6864
# Epoch 161 Batch 15 Loss 0.5972 Accuracy 10.6821
# Epoch 161 Batch 20 Loss 0.5970 Accuracy 10.6799
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.4364
# Epoch 162 Batch 5 Loss 0.5968 Accuracy 10.6791
# Epoch 162 Batch 10 Loss 0.5964 Accuracy 10.6761
# Epoch 162 Batch 15 Loss 0.5961 Accuracy 10.6719
# Epoch 162 Batch 20 Loss 0.5958 Accuracy 10.6674
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.4241
# Epoch 163 Batch 5 Loss 0.5958 Accuracy 10.6691
# Epoch 163 Batch 10 Loss 0.5954 Accuracy 10.6657
# Epoch 163 Batch 15 Loss 0.5951 Accuracy 10.6620
# Epoch 163 Batch 20 Loss 0.5950 Accuracy 10.6601
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.4302
# Epoch 164 Batch 5 Loss 0.5948 Accuracy 10.6602
# Epoch 164 Batch 10 Loss 0.5945 Accuracy 10.6576
# Epoch 164 Batch 15 Loss 0.5942 Accuracy 10.6537
# Epoch 164 Batch 20 Loss 0.5939 Accuracy 10.6507
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.4304
# Epoch 165 Batch 5 Loss 0.5938 Accuracy 10.6511
# Epoch 165 Batch 10 Loss 0.5935 Accuracy 10.6483
# Epoch 165 Batch 15 Loss 0.5931 Accuracy 10.6437
# Epoch 165 Batch 20 Loss 0.5929 Accuracy 10.6408
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 10.4336
# Epoch 166 Batch 5 Loss 0.5927 Accuracy 10.6390
# Epoch 166 Batch 10 Loss 0.5923 Accuracy 10.6359
# Epoch 166 Batch 15 Loss 0.5919 Accuracy 10.6316
# Epoch 166 Batch 20 Loss 0.5917 Accuracy 10.6287
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.4279
# Epoch 167 Batch 5 Loss 0.5916 Accuracy 10.6296
# Epoch 167 Batch 10 Loss 0.5913 Accuracy 10.6265
# Epoch 167 Batch 15 Loss 0.5910 Accuracy 10.6225
# Epoch 167 Batch 20 Loss 0.5909 Accuracy 10.6213
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.4366
# Epoch 168 Batch 5 Loss 0.5907 Accuracy 10.6212
# Epoch 168 Batch 10 Loss 0.5904 Accuracy 10.6182
# Epoch 168 Batch 15 Loss 0.5900 Accuracy 10.6144
# Epoch 168 Batch 20 Loss 0.5898 Accuracy 10.6102
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.4343
# Epoch 169 Batch 5 Loss 0.5897 Accuracy 10.6119
# Epoch 169 Batch 10 Loss 0.5894 Accuracy 10.6087
# Epoch 169 Batch 15 Loss 0.5891 Accuracy 10.6049
# Epoch 169 Batch 20 Loss 0.5890 Accuracy 10.6027
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 10.4401
# Epoch 170 Batch 5 Loss 0.5888 Accuracy 10.6028
# Epoch 170 Batch 10 Loss 0.5884 Accuracy 10.5995
# Epoch 170 Batch 15 Loss 0.5881 Accuracy 10.5954
# Epoch 170 Batch 20 Loss 0.5878 Accuracy 10.5915
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.4409
# Epoch 171 Batch 5 Loss 0.5877 Accuracy 10.5926
# Epoch 171 Batch 10 Loss 0.5874 Accuracy 10.5894
# Epoch 171 Batch 15 Loss 0.5871 Accuracy 10.5856
# Epoch 171 Batch 20 Loss 0.5869 Accuracy 10.5829
# Time taken for 1 epoch: 1.29 secs
#
# TestLoss 0.0000 TestAccuracy 10.4400
# Epoch 172 Batch 5 Loss 0.5867 Accuracy 10.5831
# Epoch 172 Batch 10 Loss 0.5864 Accuracy 10.5794
# Epoch 172 Batch 15 Loss 0.5860 Accuracy 10.5753
# Epoch 172 Batch 20 Loss 0.5858 Accuracy 10.5715
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 10.4351
# Epoch 173 Batch 5 Loss 0.5857 Accuracy 10.5722
# Epoch 173 Batch 10 Loss 0.5854 Accuracy 10.5695
# Epoch 173 Batch 15 Loss 0.5851 Accuracy 10.5658
# Epoch 173 Batch 20 Loss 0.5850 Accuracy 10.5644
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 10.4429
# Epoch 174 Batch 5 Loss 0.5849 Accuracy 10.5648
# Epoch 174 Batch 10 Loss 0.5846 Accuracy 10.5626
# Epoch 174 Batch 15 Loss 0.5843 Accuracy 10.5593
# Epoch 174 Batch 20 Loss 0.5841 Accuracy 10.5560
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.4592
# Epoch 175 Batch 5 Loss 0.5841 Accuracy 10.5585
# Epoch 175 Batch 10 Loss 0.5838 Accuracy 10.5556
# Epoch 175 Batch 15 Loss 0.5835 Accuracy 10.5512
# Epoch 175 Batch 20 Loss 0.5834 Accuracy 10.5493
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 10.4614
# Epoch 176 Batch 5 Loss 0.5831 Accuracy 10.5473
# Epoch 176 Batch 10 Loss 0.5829 Accuracy 10.5453
# Epoch 176 Batch 15 Loss 0.5825 Accuracy 10.5417
# Epoch 176 Batch 20 Loss 0.5823 Accuracy 10.5388
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.4551
# Epoch 177 Batch 5 Loss 0.5822 Accuracy 10.5396
# Epoch 177 Batch 10 Loss 0.5820 Accuracy 10.5363
# Epoch 177 Batch 15 Loss 0.5816 Accuracy 10.5323
# Epoch 177 Batch 20 Loss 0.5815 Accuracy 10.5310
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 10.4582
# Epoch 178 Batch 5 Loss 0.5814 Accuracy 10.5318
# Epoch 178 Batch 10 Loss 0.5811 Accuracy 10.5290
# Epoch 178 Batch 15 Loss 0.5808 Accuracy 10.5252
# Epoch 178 Batch 20 Loss 0.5806 Accuracy 10.5213
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.4497
# Epoch 179 Batch 5 Loss 0.5805 Accuracy 10.5222
# Epoch 179 Batch 10 Loss 0.5802 Accuracy 10.5189
# Epoch 179 Batch 15 Loss 0.5799 Accuracy 10.5152
# Epoch 179 Batch 20 Loss 0.5797 Accuracy 10.5117
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 10.4543
# Epoch 180 Batch 5 Loss 0.5796 Accuracy 10.5129
# Epoch 180 Batch 10 Loss 0.5792 Accuracy 10.5105
# Epoch 180 Batch 15 Loss 0.5789 Accuracy 10.5069
# Epoch 180 Batch 20 Loss 0.5788 Accuracy 10.5041
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.4547
# Epoch 181 Batch 5 Loss 0.5786 Accuracy 10.5039
# Epoch 181 Batch 10 Loss 0.5783 Accuracy 10.5009
# Epoch 181 Batch 15 Loss 0.5779 Accuracy 10.4968
# Epoch 181 Batch 20 Loss 0.5777 Accuracy 10.4927
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 10.4530
# Epoch 182 Batch 5 Loss 0.5776 Accuracy 10.4927
# Epoch 182 Batch 10 Loss 0.5772 Accuracy 10.4894
# Epoch 182 Batch 15 Loss 0.5769 Accuracy 10.4856
# Epoch 182 Batch 20 Loss 0.5767 Accuracy 10.4824
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.4514
# Epoch 183 Batch 5 Loss 0.5765 Accuracy 10.4818
# Epoch 183 Batch 10 Loss 0.5762 Accuracy 10.4784
# Epoch 183 Batch 15 Loss 0.5758 Accuracy 10.4747
# Epoch 183 Batch 20 Loss 0.5757 Accuracy 10.4723
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.4502
# Epoch 184 Batch 5 Loss 0.5755 Accuracy 10.4717
# Epoch 184 Batch 10 Loss 0.5752 Accuracy 10.4688
# Epoch 184 Batch 15 Loss 0.5749 Accuracy 10.4650
# Epoch 184 Batch 20 Loss 0.5747 Accuracy 10.4617
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.4555
# Epoch 185 Batch 5 Loss 0.5745 Accuracy 10.4623
# Epoch 185 Batch 10 Loss 0.5742 Accuracy 10.4597
# Epoch 185 Batch 15 Loss 0.5739 Accuracy 10.4558
# Epoch 185 Batch 20 Loss 0.5738 Accuracy 10.4536
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 10.4588
# Epoch 186 Batch 5 Loss 0.5736 Accuracy 10.4527
# Epoch 186 Batch 10 Loss 0.5733 Accuracy 10.4500
# Epoch 186 Batch 15 Loss 0.5731 Accuracy 10.4473
# Epoch 186 Batch 20 Loss 0.5729 Accuracy 10.4442
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.4630
# Epoch 187 Batch 5 Loss 0.5729 Accuracy 10.4466
# Epoch 187 Batch 10 Loss 0.5727 Accuracy 10.4448
# Epoch 187 Batch 15 Loss 0.5725 Accuracy 10.4416
# Epoch 187 Batch 20 Loss 0.5725 Accuracy 10.4410
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 10.4683
# Epoch 188 Batch 5 Loss 0.5724 Accuracy 10.4411
# Epoch 188 Batch 10 Loss 0.5721 Accuracy 10.4393
# Epoch 188 Batch 15 Loss 0.5718 Accuracy 10.4359
# Epoch 188 Batch 20 Loss 0.5717 Accuracy 10.4331
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.4727
# Epoch 189 Batch 5 Loss 0.5716 Accuracy 10.4342
# Epoch 189 Batch 10 Loss 0.5713 Accuracy 10.4317
# Epoch 189 Batch 15 Loss 0.5711 Accuracy 10.4283
# Epoch 189 Batch 20 Loss 0.5710 Accuracy 10.4275
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.4697
# Epoch 190 Batch 5 Loss 0.5709 Accuracy 10.4282
# Epoch 190 Batch 10 Loss 0.5707 Accuracy 10.4257
# Epoch 190 Batch 15 Loss 0.5704 Accuracy 10.4217
# Epoch 190 Batch 20 Loss 0.5702 Accuracy 10.4190
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 10.4662
# Epoch 191 Batch 5 Loss 0.5701 Accuracy 10.4194
# Epoch 191 Batch 10 Loss 0.5698 Accuracy 10.4165
# Epoch 191 Batch 15 Loss 0.5695 Accuracy 10.4129
# Epoch 191 Batch 20 Loss 0.5694 Accuracy 10.4103
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.4669
# Epoch 192 Batch 5 Loss 0.5692 Accuracy 10.4111
# Epoch 192 Batch 10 Loss 0.5690 Accuracy 10.4086
# Epoch 192 Batch 15 Loss 0.5687 Accuracy 10.4050
# Epoch 192 Batch 20 Loss 0.5686 Accuracy 10.4032
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.4716
# Epoch 193 Batch 5 Loss 0.5684 Accuracy 10.4036
# Epoch 193 Batch 10 Loss 0.5682 Accuracy 10.4011
# Epoch 193 Batch 15 Loss 0.5679 Accuracy 10.3979
# Epoch 193 Batch 20 Loss 0.5677 Accuracy 10.3942
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 10.4658
# Epoch 194 Batch 5 Loss 0.5676 Accuracy 10.3948
# Epoch 194 Batch 10 Loss 0.5673 Accuracy 10.3922
# Epoch 194 Batch 15 Loss 0.5670 Accuracy 10.3892
# Epoch 194 Batch 20 Loss 0.5669 Accuracy 10.3864
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.4623
# Epoch 195 Batch 5 Loss 0.5668 Accuracy 10.3877
# Epoch 195 Batch 10 Loss 0.5665 Accuracy 10.3845
# Epoch 195 Batch 15 Loss 0.5662 Accuracy 10.3810
# Epoch 195 Batch 20 Loss 0.5661 Accuracy 10.3785
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.4628
# Epoch 196 Batch 5 Loss 0.5660 Accuracy 10.3796
# Epoch 196 Batch 10 Loss 0.5658 Accuracy 10.3768
# Epoch 196 Batch 15 Loss 0.5655 Accuracy 10.3732
# Epoch 196 Batch 20 Loss 0.5654 Accuracy 10.3718
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.4638
# Epoch 197 Batch 5 Loss 0.5653 Accuracy 10.3720
# Epoch 197 Batch 10 Loss 0.5651 Accuracy 10.3696
# Epoch 197 Batch 15 Loss 0.5648 Accuracy 10.3663
# Epoch 197 Batch 20 Loss 0.5646 Accuracy 10.3633
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.4549
# Epoch 198 Batch 5 Loss 0.5645 Accuracy 10.3642
# Epoch 198 Batch 10 Loss 0.5642 Accuracy 10.3614
# Epoch 198 Batch 15 Loss 0.5640 Accuracy 10.3588
# Epoch 198 Batch 20 Loss 0.5639 Accuracy 10.3568
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 10.4552
# Epoch 199 Batch 5 Loss 0.5638 Accuracy 10.3573
# Epoch 199 Batch 10 Loss 0.5634 Accuracy 10.3545
# Epoch 199 Batch 15 Loss 0.5632 Accuracy 10.3512
# Epoch 199 Batch 20 Loss 0.5630 Accuracy 10.3480
# Time taken for 1 epoch: 1.31 secs
#
# TestLoss 0.0000 TestAccuracy 10.4573
# Epoch 200 Batch 5 Loss 0.5629 Accuracy 10.3486
# Epoch 200 Batch 10 Loss 0.5626 Accuracy 10.3471
# Epoch 200 Batch 15 Loss 0.5624 Accuracy 10.3442
# Epoch 200 Batch 20 Loss 0.5623 Accuracy 10.3418
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 10.4612

# %%
capacity = 500
train_max = train_max_ulsan.copy()
train_min = train_min_ulsan.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_ulsan_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_ulsan_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_ulsan(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_ulsan_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_ulsan_scaled, y_test_ulsan_scaled, Models_ulsan)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 1.3024 Accuracy 31.0924
# Epoch 1 Batch 10 Loss 1.1129 Accuracy 32.4122
# Epoch 1 Batch 15 Loss 0.9977 Accuracy 32.2828
# Epoch 1 Batch 20 Loss 0.9806 Accuracy 30.0477
# Time taken for 1 epoch: 5.61 secs
#
# WARNING:tensorflow:Layer train_model_1 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 28.0032
# Epoch 2 Batch 5 Loss 0.9371 Accuracy 29.2473
# Epoch 2 Batch 10 Loss 0.9041 Accuracy 29.0418
# Epoch 2 Batch 15 Loss 0.8653 Accuracy 27.7879
# Epoch 2 Batch 20 Loss 0.8488 Accuracy 27.0748
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 26.4041
# Epoch 3 Batch 5 Loss 0.8262 Accuracy 26.5451
# Epoch 3 Batch 10 Loss 0.7925 Accuracy 25.8233
# Epoch 3 Batch 15 Loss 0.7606 Accuracy 24.8772
# Epoch 3 Batch 20 Loss 0.7514 Accuracy 24.6539
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 23.9669
# Epoch 4 Batch 5 Loss 0.7274 Accuracy 24.1724
# Epoch 4 Batch 10 Loss 0.6962 Accuracy 23.4435
# Epoch 4 Batch 15 Loss 0.6722 Accuracy 22.7215
# Epoch 4 Batch 20 Loss 0.6635 Accuracy 22.7420
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 21.4665
# Epoch 5 Batch 5 Loss 0.6427 Accuracy 22.2171
# Epoch 5 Batch 10 Loss 0.6271 Accuracy 21.8685
# Epoch 5 Batch 15 Loss 0.6091 Accuracy 21.5268
# Epoch 5 Batch 20 Loss 0.5952 Accuracy 21.2618
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 19.1576
# Epoch 6 Batch 5 Loss 0.5790 Accuracy 20.8216
# Epoch 6 Batch 10 Loss 0.5653 Accuracy 20.5023
# Epoch 6 Batch 15 Loss 0.5514 Accuracy 20.1917
# Epoch 6 Batch 20 Loss 0.5406 Accuracy 19.9706
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 17.5320
# Epoch 7 Batch 5 Loss 0.5286 Accuracy 19.6773
# Epoch 7 Batch 10 Loss 0.5176 Accuracy 19.4419
# Epoch 7 Batch 15 Loss 0.5086 Accuracy 19.2085
# Epoch 7 Batch 20 Loss 0.4996 Accuracy 19.0249
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 16.4960
# Epoch 8 Batch 5 Loss 0.4904 Accuracy 18.8271
# Epoch 8 Batch 10 Loss 0.4827 Accuracy 18.6310
# Epoch 8 Batch 15 Loss 0.4748 Accuracy 18.4576
# Epoch 8 Batch 20 Loss 0.4683 Accuracy 18.3575
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 15.4615
# Epoch 9 Batch 5 Loss 0.4601 Accuracy 18.1346
# Epoch 9 Batch 10 Loss 0.4589 Accuracy 18.1502
# Epoch 9 Batch 15 Loss 0.4541 Accuracy 17.9996
# Epoch 9 Batch 20 Loss 0.4491 Accuracy 17.9051
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 15.1032
# Epoch 10 Batch 5 Loss 0.4442 Accuracy 17.8323
# Epoch 10 Batch 10 Loss 0.4384 Accuracy 17.7075
# Epoch 10 Batch 15 Loss 0.4343 Accuracy 17.5689
# Epoch 10 Batch 20 Loss 0.4305 Accuracy 17.4958
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 14.6838
# Epoch 11 Batch 5 Loss 0.4261 Accuracy 17.4121
# Epoch 11 Batch 10 Loss 0.4215 Accuracy 17.3116
# Epoch 11 Batch 15 Loss 0.4178 Accuracy 17.2004
# Epoch 11 Batch 20 Loss 0.4145 Accuracy 17.1402
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 14.3064
# Epoch 12 Batch 5 Loss 0.4105 Accuracy 17.0627
# Epoch 12 Batch 10 Loss 0.4066 Accuracy 16.9731
# Epoch 12 Batch 15 Loss 0.4042 Accuracy 16.8717
# Epoch 12 Batch 20 Loss 0.4010 Accuracy 16.8232
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 14.0720
# Epoch 13 Batch 5 Loss 0.3978 Accuracy 16.7811
# Epoch 13 Batch 10 Loss 0.3936 Accuracy 16.6755
# Epoch 13 Batch 15 Loss 0.3900 Accuracy 16.5865
# Epoch 13 Batch 20 Loss 0.3886 Accuracy 16.5373
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 13.5767
# Epoch 14 Batch 5 Loss 0.3854 Accuracy 16.4535
# Epoch 14 Batch 10 Loss 0.3823 Accuracy 16.4089
# Epoch 14 Batch 15 Loss 0.3800 Accuracy 16.3476
# Epoch 14 Batch 20 Loss 0.3771 Accuracy 16.2732
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 13.1132
# Epoch 15 Batch 5 Loss 0.3738 Accuracy 16.1984
# Epoch 15 Batch 10 Loss 0.3711 Accuracy 16.1317
# Epoch 15 Batch 15 Loss 0.3686 Accuracy 16.0765
# Epoch 15 Batch 20 Loss 0.3657 Accuracy 16.0091
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 12.7468
# Epoch 16 Batch 5 Loss 0.3624 Accuracy 15.9213
# Epoch 16 Batch 10 Loss 0.3600 Accuracy 15.8684
# Epoch 16 Batch 15 Loss 0.3579 Accuracy 15.8144
# Epoch 16 Batch 20 Loss 0.3554 Accuracy 15.7485
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 12.4908
# Epoch 17 Batch 5 Loss 0.3524 Accuracy 15.6849
# Epoch 17 Batch 10 Loss 0.3493 Accuracy 15.6001
# Epoch 17 Batch 15 Loss 0.3466 Accuracy 15.5282
# Epoch 17 Batch 20 Loss 0.3442 Accuracy 15.4697
# Time taken for 1 epoch: 1.16 secs
#
# TestLoss 0.0000 TestAccuracy 12.2536
# Epoch 18 Batch 5 Loss 0.3411 Accuracy 15.3679
# Epoch 18 Batch 10 Loss 0.3386 Accuracy 15.3127
# Epoch 18 Batch 15 Loss 0.3368 Accuracy 15.2611
# Epoch 18 Batch 20 Loss 0.3346 Accuracy 15.2070
# Time taken for 1 epoch: 1.16 secs
#
# TestLoss 0.0000 TestAccuracy 11.9993
# Epoch 19 Batch 5 Loss 0.3319 Accuracy 15.1261
# Epoch 19 Batch 10 Loss 0.3295 Accuracy 15.0668
# Epoch 19 Batch 15 Loss 0.3274 Accuracy 15.0173
# Epoch 19 Batch 20 Loss 0.3254 Accuracy 14.9547
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 11.8458
# Epoch 20 Batch 5 Loss 0.3230 Accuracy 14.8825
# Epoch 20 Batch 10 Loss 0.3209 Accuracy 14.8269
# Epoch 20 Batch 15 Loss 0.3187 Accuracy 14.7731
# Epoch 20 Batch 20 Loss 0.3169 Accuracy 14.7143
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 11.6743
# Epoch 21 Batch 5 Loss 0.3145 Accuracy 14.6426
# Epoch 21 Batch 10 Loss 0.3125 Accuracy 14.5906
# Epoch 21 Batch 15 Loss 0.3106 Accuracy 14.5440
# Epoch 21 Batch 20 Loss 0.3089 Accuracy 14.4892
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 11.5035
# Epoch 22 Batch 5 Loss 0.3067 Accuracy 14.4208
# Epoch 22 Batch 10 Loss 0.3048 Accuracy 14.3736
# Epoch 22 Batch 15 Loss 0.3031 Accuracy 14.3321
# Epoch 22 Batch 20 Loss 0.3016 Accuracy 14.2834
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 11.3564
# Epoch 23 Batch 5 Loss 0.2996 Accuracy 14.2191
# Epoch 23 Batch 10 Loss 0.2979 Accuracy 14.1771
# Epoch 23 Batch 15 Loss 0.2963 Accuracy 14.1395
# Epoch 23 Batch 20 Loss 0.2949 Accuracy 14.0927
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 11.2146
# Epoch 24 Batch 5 Loss 0.2931 Accuracy 14.0358
# Epoch 24 Batch 10 Loss 0.2915 Accuracy 13.9941
# Epoch 24 Batch 15 Loss 0.2899 Accuracy 13.9581
# Epoch 24 Batch 20 Loss 0.2887 Accuracy 13.9156
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 11.0927
# Epoch 25 Batch 5 Loss 0.2870 Accuracy 13.8619
# Epoch 25 Batch 10 Loss 0.2855 Accuracy 13.8238
# Epoch 25 Batch 15 Loss 0.2841 Accuracy 13.7907
# Epoch 25 Batch 20 Loss 0.2829 Accuracy 13.7508
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 10.9726
# Epoch 26 Batch 5 Loss 0.2814 Accuracy 13.7015
# Epoch 26 Batch 10 Loss 0.2799 Accuracy 13.6651
# Epoch 26 Batch 15 Loss 0.2786 Accuracy 13.6342
# Epoch 26 Batch 20 Loss 0.2776 Accuracy 13.5976
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.8648
# Epoch 27 Batch 5 Loss 0.2761 Accuracy 13.5506
# Epoch 27 Batch 10 Loss 0.2747 Accuracy 13.5173
# Epoch 27 Batch 15 Loss 0.2736 Accuracy 13.4888
# Epoch 27 Batch 20 Loss 0.2726 Accuracy 13.4546
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.7612
# Epoch 28 Batch 5 Loss 0.2712 Accuracy 13.4112
# Epoch 28 Batch 10 Loss 0.2699 Accuracy 13.3795
# Epoch 28 Batch 15 Loss 0.2688 Accuracy 13.3526
# Epoch 28 Batch 20 Loss 0.2679 Accuracy 13.3208
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 10.6640
# Epoch 29 Batch 5 Loss 0.2666 Accuracy 13.2795
# Epoch 29 Batch 10 Loss 0.2654 Accuracy 13.2499
# Epoch 29 Batch 15 Loss 0.2644 Accuracy 13.2251
# Epoch 29 Batch 20 Loss 0.2635 Accuracy 13.1953
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10.5687
# Epoch 30 Batch 5 Loss 0.2623 Accuracy 13.1564
# Epoch 30 Batch 10 Loss 0.2612 Accuracy 13.1284
# Epoch 30 Batch 15 Loss 0.2602 Accuracy 13.1055
# Epoch 30 Batch 20 Loss 0.2594 Accuracy 13.0780
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 10.4764
# Epoch 31 Batch 5 Loss 0.2583 Accuracy 13.0413
# Epoch 31 Batch 10 Loss 0.2572 Accuracy 13.0155
# Epoch 31 Batch 15 Loss 0.2564 Accuracy 12.9963
# Epoch 31 Batch 20 Loss 0.2557 Accuracy 12.9712
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.3957
# Epoch 32 Batch 5 Loss 0.2546 Accuracy 12.9354
# Epoch 32 Batch 10 Loss 0.2535 Accuracy 12.9113
# Epoch 32 Batch 15 Loss 0.2527 Accuracy 12.8918
# Epoch 32 Batch 20 Loss 0.2521 Accuracy 12.8712
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 10.3360
# Epoch 33 Batch 5 Loss 0.2510 Accuracy 12.8317
# Epoch 33 Batch 10 Loss 0.2500 Accuracy 12.8093
# Epoch 33 Batch 15 Loss 0.2493 Accuracy 12.7923
# Epoch 33 Batch 20 Loss 0.2486 Accuracy 12.7697
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 10
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.7401
# Epoch 45 Batch 5 Loss 0.2191 Accuracy 11.9048
# Epoch 45 Batch 10 Loss 0.2185 Accuracy 11.8893
# Epoch 45 Batch 15 Loss 0.2180 Accuracy 11.8779
# Epoch 45 Batch 20 Loss 0.2177 Accuracy 11.8652
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 9.6961
# Epoch 46 Batch 5 Loss 0.2171 Accuracy 11.8463
# Epoch 46 Batch 10 Loss 0.2165 Accuracy 11.8312
# Epoch 46 Batch 15 Loss 0.2160 Accuracy 11.8202
# Epoch 46 Batch 20 Loss 0.2157 Accuracy 11.8077
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 9.6565
# Epoch 47 Batch 5 Loss 0.2152 Accuracy 11.7907
# Epoch 47 Batch 10 Loss 0.2146 Accuracy 11.7750
# Epoch 47 Batch 15 Loss 0.2141 Accuracy 11.7636
# Epoch 47 Batch 20 Loss 0.2138 Accuracy 11.7514
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 9.6296
# Epoch 48 Batch 5 Loss 0.2133 Accuracy 11.7352
# Epoch 48 Batch 10 Loss 0.2127 Accuracy 11.7198
# Epoch 48 Batch 15 Loss 0.2122 Accuracy 11.7088
# Epoch 48 Batch 20 Loss 0.2120 Accuracy 11.6960
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 9.5940
# Epoch 49 Batch 5 Loss 0.2115 Accuracy 11.6811
# Epoch 49 Batch 10 Loss 0.2109 Accuracy 11.6656
# Epoch 49 Batch 15 Loss 0.2104 Accuracy 11.6546
# Epoch 49 Batch 20 Loss 0.2102 Accuracy 11.6420
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.5612
# Epoch 50 Batch 5 Loss 0.2098 Accuracy 11.6309
# Epoch 50 Batch 10 Loss 0.2093 Accuracy 11.6164
# Epoch 50 Batch 15 Loss 0.2088 Accuracy 11.6051
# Epoch 50 Batch 20 Loss 0.2086 Accuracy 11.5934
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.5278
# Epoch 51 Batch 5 Loss 0.2081 Accuracy 11.5789
# Epoch 51 Batch 10 Loss 0.2076 Accuracy 11.5656
# Epoch 51 Batch 15 Loss 0.2071 Accuracy 11.5551
# Epoch 51 Batch 20 Loss 0.2069 Accuracy 11.5459
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.5111
# Epoch 52 Batch 5 Loss 0.2064 Accuracy 11.5281
# Epoch 52 Batch 10 Loss 0.2059 Accuracy 11.5165
# Epoch 52 Batch 15 Loss 0.2055 Accuracy 11.5071
# Epoch 52 Batch 20 Loss 0.2053 Accuracy 11.4991
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 9.4854
# Epoch 53 Batch 5 Loss 0.2048 Accuracy 11.4822
# Epoch 53 Batch 10 Loss 0.2043 Accuracy 11.4698
# Epoch 53 Batch 15 Loss 0.2039 Accuracy 11.4620
# Epoch 53 Batch 20 Loss 0.2038 Accuracy 11.4547
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.4781
# Epoch 54 Batch 5 Loss 0.2034 Accuracy 11.4438
# Epoch 54 Batch 10 Loss 0.2030 Accuracy 11.4335
# Epoch 54 Batch 15 Loss 0.2027 Accuracy 11.4282
# Epoch 54 Batch 20 Loss 0.2026 Accuracy 11.4217
# Time taken for 1 epoch: 1.16 secs
#
# TestLoss 0.0000 TestAccuracy 9.4613
# Epoch 55 Batch 5 Loss 0.2022 Accuracy 11.4111
# Epoch 55 Batch 10 Loss 0.2018 Accuracy 11.4000
# Epoch 55 Batch 15 Loss 0.2014 Accuracy 11.3916
# Epoch 55 Batch 20 Loss 0.2013 Accuracy 11.3842
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.4415
# Epoch 56 Batch 5 Loss 0.2009 Accuracy 11.3722
# Epoch 56 Batch 10 Loss 0.2005 Accuracy 11.3608
# Epoch 56 Batch 15 Loss 0.2001 Accuracy 11.3547
# Epoch 56 Batch 20 Loss 0.2000 Accuracy 11.3455
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.4220
# Epoch 57 Batch 5 Loss 0.1999 Accuracy 11.3482
# Epoch 57 Batch 10 Loss 0.1996 Accuracy 11.3403
# Epoch 57 Batch 15 Loss 0.1993 Accuracy 11.3327
# Epoch 57 Batch 20 Loss 0.1991 Accuracy 11.3258
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.4098
# Epoch 58 Batch 5 Loss 0.1987 Accuracy 11.3119
# Epoch 58 Batch 10 Loss 0.1984 Accuracy 11.3036
# Epoch 58 Batch 15 Loss 0.1981 Accuracy 11.2971
# Epoch 58 Batch 20 Loss 0.1980 Accuracy 11.2930
# Time taken for 1 epoch: 1.16 secs
#
# TestLoss 0.0000 TestAccuracy 9.3892
# Epoch 59 Batch 5 Loss 0.1976 Accuracy 11.2771
# Epoch 59 Batch 10 Loss 0.1972 Accuracy 11.2699
# Epoch 59 Batch 15 Loss 0.1970 Accuracy 11.2656
# Epoch 59 Batch 20 Loss 0.1969 Accuracy 11.2592
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.3704
# Epoch 60 Batch 5 Loss 0.1965 Accuracy 11.2485
# Epoch 60 Batch 10 Loss 0.1962 Accuracy 11.2402
# Epoch 60 Batch 15 Loss 0.1959 Accuracy 11.2362
# Epoch 60 Batch 20 Loss 0.1958 Accuracy 11.2299
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.3775
# Epoch 61 Batch 5 Loss 0.1955 Accuracy 11.2220
# Epoch 61 Batch 10 Loss 0.1952 Accuracy 11.2140
# Epoch 61 Batch 15 Loss 0.1949 Accuracy 11.2055
# Epoch 61 Batch 20 Loss 0.1947 Accuracy 11.2004
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.3719
# Epoch 62 Batch 5 Loss 0.1944 Accuracy 11.1857
# Epoch 62 Batch 10 Loss 0.1940 Accuracy 11.1767
# Epoch 62 Batch 15 Loss 0.1937 Accuracy 11.1705
# Epoch 62 Batch 20 Loss 0.1936 Accuracy 11.1631
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 9.3454
# Epoch 63 Batch 5 Loss 0.1933 Accuracy 11.1553
# Epoch 63 Batch 10 Loss 0.1930 Accuracy 11.1466
# Epoch 63 Batch 15 Loss 0.1927 Accuracy 11.1409
# Epoch 63 Batch 20 Loss 0.1926 Accuracy 11.1363
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 9.3382
# Epoch 64 Batch 5 Loss 0.1923 Accuracy 11.1250
# Epoch 64 Batch 10 Loss 0.1919 Accuracy 11.1147
# Epoch 64 Batch 15 Loss 0.1916 Accuracy 11.1063
# Epoch 64 Batch 20 Loss 0.1915 Accuracy 11.0994
# Time taken for 1 epoch: 1.32 secs
#
# TestLoss 0.0000 TestAccuracy 9.3210
# Epoch 65 Batch 5 Loss 0.1911 Accuracy 11.0881
# Epoch 65 Batch 10 Loss 0.1908 Accuracy 11.0784
# Epoch 65 Batch 15 Loss 0.1905 Accuracy 11.0720
# Epoch 65 Batch 20 Loss 0.1904 Accuracy 11.0666
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.3156
# Epoch 66 Batch 5 Loss 0.1901 Accuracy 11.0566
# Epoch 66 Batch 10 Loss 0.1897 Accuracy 11.0474
# Epoch 66 Batch 15 Loss 0.1894 Accuracy 11.0409
# Epoch 66 Batch 20 Loss 0.1893 Accuracy 11.0351
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 9.2956
# Epoch 67 Batch 5 Loss 0.1890 Accuracy 11.0254
# Epoch 67 Batch 10 Loss 0.1887 Accuracy 11.0159
# Epoch 67 Batch 15 Loss 0.1884 Accuracy 11.0092
# Epoch 67 Batch 20 Loss 0.1883 Accuracy 11.0042
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 9.2919
# Epoch 68 Batch 5 Loss 0.1880 Accuracy 10.9939
# Epoch 68 Batch 10 Loss 0.1877 Accuracy 10.9851
# Epoch 68 Batch 15 Loss 0.1874 Accuracy 10.9790
# Epoch 68 Batch 20 Loss 0.1873 Accuracy 10.9739
# Time taken for 1 epoch: 1.28 secs
#
# TestLoss 0.0000 TestAccuracy 9.2793
# Epoch 69 Batch 5 Loss 0.1870 Accuracy 10.9634
# Epoch 69 Batch 10 Loss 0.1867 Accuracy 10.9550
# Epoch 69 Batch 15 Loss 0.1864 Accuracy 10.9492
# Epoch 69 Batch 20 Loss 0.1863 Accuracy 10.9448
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 9.2797
# Epoch 70 Batch 5 Loss 0.1861 Accuracy 10.9355
# Epoch 70 Batch 10 Loss 0.1858 Accuracy 10.9281
# Epoch 70 Batch 15 Loss 0.1855 Accuracy 10.9231
# Epoch 70 Batch 20 Loss 0.1855 Accuracy 10.9192
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.2655
# Epoch 71 Batch 5 Loss 0.1852 Accuracy 10.9100
# Epoch 71 Batch 10 Loss 0.1849 Accuracy 10.9025
# Epoch 71 Batch 15 Loss 0.1847 Accuracy 10.8967
# Epoch 71 Batch 20 Loss 0.1846 Accuracy 10.8921
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 9.2463
# Epoch 72 Batch 5 Loss 0.1843 Accuracy 10.8830
# Epoch 72 Batch 10 Loss 0.1840 Accuracy 10.8754
# Epoch 72 Batch 15 Loss 0.1838 Accuracy 10.8705
# Epoch 72 Batch 20 Loss 0.1837 Accuracy 10.8661
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.2217
# Epoch 73 Batch 5 Loss 0.1835 Accuracy 10.8587
# Epoch 73 Batch 10 Loss 0.1832 Accuracy 10.8509
# Epoch 73 Batch 15 Loss 0.1830 Accuracy 10.8457
# Epoch 73 Batch 20 Loss 0.1829 Accuracy 10.8399
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 9.2234
# Epoch 74 Batch 5 Loss 0.1827 Accuracy 10.8352
# Epoch 74 Batch 10 Loss 0.1824 Accuracy 10.8276
# Epoch 74 Batch 15 Loss 0.1822 Accuracy 10.8214
# Epoch 74 Batch 20 Loss 0.1821 Accuracy 10.8185
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.2252
# Epoch 75 Batch 5 Loss 0.1818 Accuracy 10.8061
# Epoch 75 Batch 10 Loss 0.1816 Accuracy 10.8013
# Epoch 75 Batch 15 Loss 0.1814 Accuracy 10.7986
# Epoch 75 Batch 20 Loss 0.1813 Accuracy 10.7933
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 9.1986
# Epoch 76 Batch 5 Loss 0.1811 Accuracy 10.7867
# Epoch 76 Batch 10 Loss 0.1808 Accuracy 10.7800
# Epoch 76 Batch 15 Loss 0.1806 Accuracy 10.7750
# Epoch 76 Batch 20 Loss 0.1805 Accuracy 10.7725
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.2090
# Epoch 77 Batch 5 Loss 0.1803 Accuracy 10.7626
# Epoch 77 Batch 10 Loss 0.1800 Accuracy 10.7565
# Epoch 77 Batch 15 Loss 0.1798 Accuracy 10.7526
# Epoch 77 Batch 20 Loss 0.1798 Accuracy 10.7469
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 9.1890
# Epoch 78 Batch 5 Loss 0.1795 Accuracy 10.7408
# Epoch 78 Batch 10 Loss 0.1793 Accuracy 10.7340
# Epoch 78 Batch 15 Loss 0.1790 Accuracy 10.7279
# Epoch 78 Batch 20 Loss 0.1790 Accuracy 10.7254
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 9.2053
# Epoch 79 Batch 5 Loss 0.1787 Accuracy 10.7153
# Epoch 79 Batch 10 Loss 0.1785 Accuracy 10.7091
# Epoch 79 Batch 15 Loss 0.1783 Accuracy 10.7055
# Epoch 79 Batch 20 Loss 0.1782 Accuracy 10.7014
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.1816
# Epoch 80 Batch 5 Loss 0.1781 Accuracy 10.6959
# Epoch 80 Batch 10 Loss 0.1778 Accuracy 10.6896
# Epoch 80 Batch 15 Loss 0.1776 Accuracy 10.6865
# Epoch 80 Batch 20 Loss 0.1776 Accuracy 10.6832
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 9.1711
# Epoch 81 Batch 5 Loss 0.1774 Accuracy 10.6792
# Epoch 81 Batch 10 Loss 0.1772 Accuracy 10.6722
# Epoch 81 Batch 15 Loss 0.1770 Accuracy 10.6667
# Epoch 81 Batch 20 Loss 0.1769 Accuracy 10.6609
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.1550
# Epoch 82 Batch 5 Loss 0.1767 Accuracy 10.6542
# Epoch 82 Batch 10 Loss 0.1764 Accuracy 10.6476
# Epoch 82 Batch 15 Loss 0.1762 Accuracy 10.6421
# Epoch 82 Batch 20 Loss 0.1762 Accuracy 10.6394
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 9.1654
# Epoch 83 Batch 5 Loss 0.1759 Accuracy 10.6290
# Epoch 83 Batch 10 Loss 0.1757 Accuracy 10.6243
# Epoch 83 Batch 15 Loss 0.1755 Accuracy 10.6228
# Epoch 83 Batch 20 Loss 0.1756 Accuracy 10.6199
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 9.1524
# Epoch 84 Batch 5 Loss 0.1754 Accuracy 10.6162
# Epoch 84 Batch 10 Loss 0.1752 Accuracy 10.6099
# Epoch 84 Batch 15 Loss 0.1750 Accuracy 10.6053
# Epoch 84 Batch 20 Loss 0.1749 Accuracy 10.6009
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 9.1393
# Epoch 85 Batch 5 Loss 0.1747 Accuracy 10.5940
# Epoch 85 Batch 10 Loss 0.1745 Accuracy 10.5877
# Epoch 85 Batch 15 Loss 0.1742 Accuracy 10.5828
# Epoch 85 Batch 20 Loss 0.1742 Accuracy 10.5788
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 9.1292
# Epoch 86 Batch 5 Loss 0.1739 Accuracy 10.5706
# Epoch 86 Batch 10 Loss 0.1737 Accuracy 10.5644
# Epoch 86 Batch 15 Loss 0.1735 Accuracy 10.5604
# Epoch 86 Batch 20 Loss 0.1735 Accuracy 10.5563
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 9.1221
# Epoch 87 Batch 5 Loss 0.1733 Accuracy 10.5509
# Epoch 87 Batch 10 Loss 0.1731 Accuracy 10.5444
# Epoch 87 Batch 15 Loss 0.1729 Accuracy 10.5398
# Epoch 87 Batch 20 Loss 0.1728 Accuracy 10.5359
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 9.1150
# Epoch 88 Batch 5 Loss 0.1727 Accuracy 10.5308
# Epoch 88 Batch 10 Loss 0.1724 Accuracy 10.5245
# Epoch 88 Batch 15 Loss 0.1723 Accuracy 10.5209
# Epoch 88 Batch 20 Loss 0.1722 Accuracy 10.5164
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 9.1109
# Epoch 89 Batch 5 Loss 0.1721 Accuracy 10.5140
# Epoch 89 Batch 10 Loss 0.1719 Accuracy 10.5085
# Epoch 89 Batch 15 Loss 0.1718 Accuracy 10.5059
# Epoch 89 Batch 20 Loss 0.1717 Accuracy 10.5045
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 9.0995
# Epoch 90 Batch 5 Loss 0.1716 Accuracy 10.4969
# Epoch 90 Batch 10 Loss 0.1715 Accuracy 10.4967
# Epoch 90 Batch 15 Loss 0.1714 Accuracy 10.4973
# Epoch 90 Batch 20 Loss 0.1714 Accuracy 10.4958
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 9.0871
# Epoch 91 Batch 5 Loss 0.1712 Accuracy 10.4895
# Epoch 91 Batch 10 Loss 0.1710 Accuracy 10.4846
# Epoch 91 Batch 15 Loss 0.1708 Accuracy 10.4807
# Epoch 91 Batch 20 Loss 0.1708 Accuracy 10.4776
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 9.0770
# Epoch 92 Batch 5 Loss 0.1706 Accuracy 10.4720
# Epoch 92 Batch 10 Loss 0.1704 Accuracy 10.4662
# Epoch 92 Batch 15 Loss 0.1702 Accuracy 10.4616
# Epoch 92 Batch 20 Loss 0.1702 Accuracy 10.4575
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.0627
# Epoch 93 Batch 5 Loss 0.1700 Accuracy 10.4513
# Epoch 93 Batch 10 Loss 0.1698 Accuracy 10.4453
# Epoch 93 Batch 15 Loss 0.1696 Accuracy 10.4416
# Epoch 93 Batch 20 Loss 0.1696 Accuracy 10.4384
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 9.0559
# Epoch 94 Batch 5 Loss 0.1694 Accuracy 10.4317
# Epoch 94 Batch 10 Loss 0.1692 Accuracy 10.4260
# Epoch 94 Batch 15 Loss 0.1690 Accuracy 10.4229
# Epoch 94 Batch 20 Loss 0.1690 Accuracy 10.4200
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 9.0439
# Epoch 95 Batch 5 Loss 0.1688 Accuracy 10.4143
# Epoch 95 Batch 10 Loss 0.1686 Accuracy 10.4087
# Epoch 95 Batch 15 Loss 0.1685 Accuracy 10.4048
# Epoch 95 Batch 20 Loss 0.1684 Accuracy 10.4012
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.0268
# Epoch 96 Batch 5 Loss 0.1682 Accuracy 10.3953
# Epoch 96 Batch 10 Loss 0.1680 Accuracy 10.3896
# Epoch 96 Batch 15 Loss 0.1679 Accuracy 10.3855
# Epoch 96 Batch 20 Loss 0.1678 Accuracy 10.3825
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.0189
# Epoch 97 Batch 5 Loss 0.1676 Accuracy 10.3756
# Epoch 97 Batch 10 Loss 0.1674 Accuracy 10.3703
# Epoch 97 Batch 15 Loss 0.1673 Accuracy 10.3672
# Epoch 97 Batch 20 Loss 0.1672 Accuracy 10.3643
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 9.0077
# Epoch 98 Batch 5 Loss 0.1671 Accuracy 10.3584
# Epoch 98 Batch 10 Loss 0.1669 Accuracy 10.3533
# Epoch 98 Batch 15 Loss 0.1667 Accuracy 10.3507
# Epoch 98 Batch 20 Loss 0.1667 Accuracy 10.3481
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 9.0059
# Epoch 99 Batch 5 Loss 0.1666 Accuracy 10.3439
# Epoch 99 Batch 10 Loss 0.1664 Accuracy 10.3386
# Epoch 99 Batch 15 Loss 0.1662 Accuracy 10.3350
# Epoch 99 Batch 20 Loss 0.1662 Accuracy 10.3311
# Time taken for 1 epoch: 1.18 secs
#
# TestLoss 0.0000 TestAccuracy 8.9895
# Epoch 100 Batch 5 Loss 0.1660 Accuracy 10.3263
# Epoch 100 Batch 10 Loss 0.1659 Accuracy 10.3210
# Epoch 100 Batch 15 Loss 0.1657 Accuracy 10.3172
# Epoch 100 Batch 20 Loss 0.1656 Accuracy 10.3142
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.9757
# Epoch 101 Batch 5 Loss 0.1655 Accuracy 10.3075
# Epoch 101 Batch 10 Loss 0.1653 Accuracy 10.3024
# Epoch 101 Batch 15 Loss 0.1651 Accuracy 10.2990
# Epoch 101 Batch 20 Loss 0.1651 Accuracy 10.2961
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.9596
# Epoch 102 Batch 5 Loss 0.1649 Accuracy 10.2896
# Epoch 102 Batch 10 Loss 0.1647 Accuracy 10.2850
# Epoch 102 Batch 15 Loss 0.1646 Accuracy 10.2834
# Epoch 102 Batch 20 Loss 0.1646 Accuracy 10.2815
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 8.9641
# Epoch 103 Batch 5 Loss 0.1644 Accuracy 10.2772
# Epoch 103 Batch 10 Loss 0.1643 Accuracy 10.2735
# Epoch 103 Batch 15 Loss 0.1641 Accuracy 10.2710
# Epoch 103 Batch 20 Loss 0.1641 Accuracy 10.2677
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.9583
# Epoch 104 Batch 5 Loss 0.1639 Accuracy 10.2617
# Epoch 104 Batch 10 Loss 0.1638 Accuracy 10.2580
# Epoch 104 Batch 15 Loss 0.1636 Accuracy 10.2553
# Epoch 104 Batch 20 Loss 0.1636 Accuracy 10.2525
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 8.9538
# Epoch 105 Batch 5 Loss 0.1635 Accuracy 10.2471
# Epoch 105 Batch 10 Loss 0.1633 Accuracy 10.2433
# Epoch 105 Batch 15 Loss 0.1632 Accuracy 10.2410
# Epoch 105 Batch 20 Loss 0.1631 Accuracy 10.2373
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 8.9408
# Epoch 106 Batch 5 Loss 0.1630 Accuracy 10.2343
# Epoch 106 Batch 10 Loss 0.1629 Accuracy 10.2297
# Epoch 106 Batch 15 Loss 0.1627 Accuracy 10.2269
# Epoch 106 Batch 20 Loss 0.1627 Accuracy 10.2232
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 8.9316
# Epoch 107 Batch 5 Loss 0.1626 Accuracy 10.2204
# Epoch 107 Batch 10 Loss 0.1624 Accuracy 10.2161
# Epoch 107 Batch 15 Loss 0.1623 Accuracy 10.2144
# Epoch 107 Batch 20 Loss 0.1623 Accuracy 10.2117
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 8.9106
# Epoch 108 Batch 5 Loss 0.1622 Accuracy 10.2092
# Epoch 108 Batch 10 Loss 0.1621 Accuracy 10.2061
# Epoch 108 Batch 15 Loss 0.1620 Accuracy 10.2043
# Epoch 108 Batch 20 Loss 0.1620 Accuracy 10.2029
# Time taken for 1 epoch: 1.27 secs
#
# TestLoss 0.0000 TestAccuracy 8.9216
# Epoch 109 Batch 5 Loss 0.1619 Accuracy 10.1999
# Epoch 109 Batch 10 Loss 0.1617 Accuracy 10.1968
# Epoch 109 Batch 15 Loss 0.1616 Accuracy 10.1959
# Epoch 109 Batch 20 Loss 0.1616 Accuracy 10.1926
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 8.9066
# Epoch 110 Batch 5 Loss 0.1616 Accuracy 10.1934
# Epoch 110 Batch 10 Loss 0.1614 Accuracy 10.1894
# Epoch 110 Batch 15 Loss 0.1613 Accuracy 10.1879
# Epoch 110 Batch 20 Loss 0.1613 Accuracy 10.1847
# Time taken for 1 epoch: 1.26 secs
#
# TestLoss 0.0000 TestAccuracy 8.8916
# Epoch 111 Batch 5 Loss 0.1612 Accuracy 10.1815
# Epoch 111 Batch 10 Loss 0.1610 Accuracy 10.1768
# Epoch 111 Batch 15 Loss 0.1609 Accuracy 10.1733
# Epoch 111 Batch 20 Loss 0.1609 Accuracy 10.1706
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.8790
# Epoch 112 Batch 5 Loss 0.1607 Accuracy 10.1649
# Epoch 112 Batch 10 Loss 0.1606 Accuracy 10.1608
# Epoch 112 Batch 15 Loss 0.1604 Accuracy 10.1581
# Epoch 112 Batch 20 Loss 0.1604 Accuracy 10.1553
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.8666
# Epoch 113 Batch 5 Loss 0.1603 Accuracy 10.1496
# Epoch 113 Batch 10 Loss 0.1601 Accuracy 10.1458
# Epoch 113 Batch 15 Loss 0.1600 Accuracy 10.1441
# Epoch 113 Batch 20 Loss 0.1600 Accuracy 10.1423
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.8615
# Epoch 114 Batch 5 Loss 0.1598 Accuracy 10.1368
# Epoch 114 Batch 10 Loss 0.1597 Accuracy 10.1332
# Epoch 114 Batch 15 Loss 0.1596 Accuracy 10.1312
# Epoch 114 Batch 20 Loss 0.1595 Accuracy 10.1279
# Time taken for 1 epoch: 1.17 secs
#
# TestLoss 0.0000 TestAccuracy 8.8471
# Epoch 115 Batch 5 Loss 0.1594 Accuracy 10.1243
# Epoch 115 Batch 10 Loss 0.1593 Accuracy 10.1195
# Epoch 115 Batch 15 Loss 0.1591 Accuracy 10.1160
# Epoch 115 Batch 20 Loss 0.1591 Accuracy 10.1133
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 8.8460
# Epoch 116 Batch 5 Loss 0.1590 Accuracy 10.1093
# Epoch 116 Batch 10 Loss 0.1588 Accuracy 10.1049
# Epoch 116 Batch 15 Loss 0.1587 Accuracy 10.1042
# Epoch 116 Batch 20 Loss 0.1587 Accuracy 10.1025
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.8384
# Epoch 117 Batch 5 Loss 0.1586 Accuracy 10.0990
# Epoch 117 Batch 10 Loss 0.1585 Accuracy 10.0945
# Epoch 117 Batch 15 Loss 0.1583 Accuracy 10.0919
# Epoch 117 Batch 20 Loss 0.1583 Accuracy 10.0886
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 8.8291
# Epoch 118 Batch 5 Loss 0.1582 Accuracy 10.0863
# Epoch 118 Batch 10 Loss 0.1581 Accuracy 10.0832
# Epoch 118 Batch 15 Loss 0.1579 Accuracy 10.0797
# Epoch 118 Batch 20 Loss 0.1579 Accuracy 10.0787
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.8459
# Epoch 119 Batch 5 Loss 0.1578 Accuracy 10.0722
# Epoch 119 Batch 10 Loss 0.1577 Accuracy 10.0698
# Epoch 119 Batch 15 Loss 0.1576 Accuracy 10.0703
# Epoch 119 Batch 20 Loss 0.1576 Accuracy 10.0697
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 8.8290
# Epoch 120 Batch 5 Loss 0.1575 Accuracy 10.0659
# Epoch 120 Batch 10 Loss 0.1574 Accuracy 10.0632
# Epoch 120 Batch 15 Loss 0.1573 Accuracy 10.0624
# Epoch 120 Batch 20 Loss 0.1573 Accuracy 10.0607
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.8334
# Epoch 121 Batch 5 Loss 0.1573 Accuracy 10.0595
# Epoch 121 Batch 10 Loss 0.1571 Accuracy 10.0565
# Epoch 121 Batch 15 Loss 0.1570 Accuracy 10.0528
# Epoch 121 Batch 20 Loss 0.1570 Accuracy 10.0510
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.8183
# Epoch 122 Batch 5 Loss 0.1569 Accuracy 10.0458
# Epoch 122 Batch 10 Loss 0.1568 Accuracy 10.0428
# Epoch 122 Batch 15 Loss 0.1567 Accuracy 10.0424
# Epoch 122 Batch 20 Loss 0.1567 Accuracy 10.0411
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.8140
# Epoch 123 Batch 5 Loss 0.1565 Accuracy 10.0370
# Epoch 123 Batch 10 Loss 0.1564 Accuracy 10.0334
# Epoch 123 Batch 15 Loss 0.1563 Accuracy 10.0310
# Epoch 123 Batch 20 Loss 0.1563 Accuracy 10.0275
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.8005
# Epoch 124 Batch 5 Loss 0.1562 Accuracy 10.0259
# Epoch 124 Batch 10 Loss 0.1560 Accuracy 10.0216
# Epoch 124 Batch 15 Loss 0.1559 Accuracy 10.0181
# Epoch 124 Batch 20 Loss 0.1559 Accuracy 10.0165
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.8079
# Epoch 125 Batch 5 Loss 0.1558 Accuracy 10.0111
# Epoch 125 Batch 10 Loss 0.1556 Accuracy 10.0076
# Epoch 125 Batch 15 Loss 0.1555 Accuracy 10.0073
# Epoch 125 Batch 20 Loss 0.1556 Accuracy 10.0062
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 8.8049
# Epoch 126 Batch 5 Loss 0.1555 Accuracy 10.0038
# Epoch 126 Batch 10 Loss 0.1553 Accuracy 10.0001
# Epoch 126 Batch 15 Loss 0.1552 Accuracy 9.9977
# Epoch 126 Batch 20 Loss 0.1552 Accuracy 9.9947
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.7892
# Epoch 127 Batch 5 Loss 0.1551 Accuracy 9.9923
# Epoch 127 Batch 10 Loss 0.1550 Accuracy 9.9891
# Epoch 127 Batch 15 Loss 0.1549 Accuracy 9.9862
# Epoch 127 Batch 20 Loss 0.1549 Accuracy 9.9852
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 8.5103
# Epoch 170 Batch 5 Loss 0.1437 Accuracy 9.6299
# Epoch 170 Batch 10 Loss 0.1437 Accuracy 9.6275
# Epoch 170 Batch 15 Loss 0.1436 Accuracy 9.6258
# Epoch 170 Batch 20 Loss 0.1436 Accuracy 9.6240
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 8.5006
# Epoch 171 Batch 5 Loss 0.1435 Accuracy 9.6210
# Epoch 171 Batch 10 Loss 0.1434 Accuracy 9.6193
# Epoch 171 Batch 15 Loss 0.1434 Accuracy 9.6183
# Epoch 171 Batch 20 Loss 0.1434 Accuracy 9.6173
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 8.4940
# Epoch 172 Batch 5 Loss 0.1433 Accuracy 9.6149
# Epoch 172 Batch 10 Loss 0.1432 Accuracy 9.6131
# Epoch 172 Batch 15 Loss 0.1432 Accuracy 9.6138
# Epoch 172 Batch 20 Loss 0.1432 Accuracy 9.6136
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 8.5133
# Epoch 173 Batch 5 Loss 0.1432 Accuracy 9.6141
# Epoch 173 Batch 10 Loss 0.1431 Accuracy 9.6136
# Epoch 173 Batch 15 Loss 0.1431 Accuracy 9.6129
# Epoch 173 Batch 20 Loss 0.1431 Accuracy 9.6133
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 8.5195
# Epoch 174 Batch 5 Loss 0.1430 Accuracy 9.6101
# Epoch 174 Batch 10 Loss 0.1430 Accuracy 9.6089
# Epoch 174 Batch 15 Loss 0.1430 Accuracy 9.6097
# Epoch 174 Batch 20 Loss 0.1430 Accuracy 9.6099
# Time taken for 1 epoch: 1.31 secs
#
# TestLoss 0.0000 TestAccuracy 8.5254
# Epoch 175 Batch 5 Loss 0.1429 Accuracy 9.6083
# Epoch 175 Batch 10 Loss 0.1429 Accuracy 9.6072
# Epoch 175 Batch 15 Loss 0.1428 Accuracy 9.6066
# Epoch 175 Batch 20 Loss 0.1428 Accuracy 9.6053
# Time taken for 1 epoch: 1.31 secs
#
# TestLoss 0.0000 TestAccuracy 8.5186
# Epoch 176 Batch 5 Loss 0.1428 Accuracy 9.6046
# Epoch 176 Batch 10 Loss 0.1427 Accuracy 9.6025
# Epoch 176 Batch 15 Loss 0.1427 Accuracy 9.6008
# Epoch 176 Batch 20 Loss 0.1427 Accuracy 9.6022
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.5132
# Epoch 177 Batch 5 Loss 0.1426 Accuracy 9.6002
# Epoch 177 Batch 10 Loss 0.1426 Accuracy 9.5982
# Epoch 177 Batch 15 Loss 0.1425 Accuracy 9.5981
# Epoch 177 Batch 20 Loss 0.1425 Accuracy 9.5973
# Time taken for 1 epoch: 1.25 secs
#
# TestLoss 0.0000 TestAccuracy 8.5085
# Epoch 178 Batch 5 Loss 0.1425 Accuracy 9.5954
# Epoch 178 Batch 10 Loss 0.1424 Accuracy 9.5933
# Epoch 178 Batch 15 Loss 0.1423 Accuracy 9.5921
# Epoch 178 Batch 20 Loss 0.1423 Accuracy 9.5903
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 8.4987
# Epoch 179 Batch 5 Loss 0.1423 Accuracy 9.5889
# Epoch 179 Batch 10 Loss 0.1422 Accuracy 9.5874
# Epoch 179 Batch 15 Loss 0.1421 Accuracy 9.5863
# Time taken for 1 epoch: 1.19 secs
#
# TestLoss 0.0000 TestAccuracy 8.4843
# Epoch 189 Batch 5 Loss 0.1405 Accuracy 9.5353
# Epoch 189 Batch 10 Loss 0.1404 Accuracy 9.5336
# Epoch 189 Batch 15 Loss 0.1404 Accuracy 9.5321
# Epoch 189 Batch 20 Loss 0.1404 Accuracy 9.5315
# Time taken for 1 epoch: 1.28 secs
#
# TestLoss 0.0000 TestAccuracy 8.4799
# Epoch 190 Batch 5 Loss 0.1403 Accuracy 9.5283
# Epoch 190 Batch 10 Loss 0.1402 Accuracy 9.5267
# Epoch 190 Batch 15 Loss 0.1402 Accuracy 9.5264
# Epoch 190 Batch 20 Loss 0.1402 Accuracy 9.5257
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 8.4754
# Epoch 191 Batch 5 Loss 0.1401 Accuracy 9.5233
# Epoch 191 Batch 10 Loss 0.1401 Accuracy 9.5217
# Epoch 191 Batch 15 Loss 0.1400 Accuracy 9.5220
# Epoch 191 Batch 20 Loss 0.1401 Accuracy 9.5202
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 8.4697
# Epoch 192 Batch 5 Loss 0.1400 Accuracy 9.5198
# Epoch 192 Batch 10 Loss 0.1400 Accuracy 9.5195
# Epoch 192 Batch 15 Loss 0.1399 Accuracy 9.5187
# Epoch 192 Batch 20 Loss 0.1399 Accuracy 9.5184
# Time taken for 1 epoch: 1.23 secs
#
# TestLoss 0.0000 TestAccuracy 8.4642
# Epoch 193 Batch 5 Loss 0.1399 Accuracy 9.5155
# Epoch 193 Batch 10 Loss 0.1398 Accuracy 9.5140
# Epoch 193 Batch 15 Loss 0.1398 Accuracy 9.5138
# Epoch 193 Batch 20 Loss 0.1398 Accuracy 9.5127
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.4614
# Epoch 194 Batch 5 Loss 0.1397 Accuracy 9.5115
# Epoch 194 Batch 10 Loss 0.1397 Accuracy 9.5093
# Epoch 194 Batch 15 Loss 0.1396 Accuracy 9.5085
# Epoch 194 Batch 20 Loss 0.1396 Accuracy 9.5067
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.4516
# Epoch 195 Batch 5 Loss 0.1395 Accuracy 9.5057
# Epoch 195 Batch 10 Loss 0.1395 Accuracy 9.5041
# Epoch 195 Batch 15 Loss 0.1394 Accuracy 9.5026
# Epoch 195 Batch 20 Loss 0.1394 Accuracy 9.5014
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.4457
# Epoch 196 Batch 5 Loss 0.1393 Accuracy 9.4988
# Epoch 196 Batch 10 Loss 0.1393 Accuracy 9.4970
# Epoch 196 Batch 15 Loss 0.1392 Accuracy 9.4969
# Epoch 196 Batch 20 Loss 0.1392 Accuracy 9.4963
# Time taken for 1 epoch: 1.22 secs
#
# TestLoss 0.0000 TestAccuracy 8.4486
# Epoch 197 Batch 5 Loss 0.1392 Accuracy 9.4942
# Epoch 197 Batch 10 Loss 0.1391 Accuracy 9.4921
# Epoch 197 Batch 15 Loss 0.1391 Accuracy 9.4907
# Epoch 197 Batch 20 Loss 0.1390 Accuracy 9.4892
# Time taken for 1 epoch: 1.21 secs
#
# TestLoss 0.0000 TestAccuracy 8.4428
# Epoch 198 Batch 5 Loss 0.1390 Accuracy 9.4879
# Epoch 198 Batch 10 Loss 0.1389 Accuracy 9.4864
# Epoch 198 Batch 15 Loss 0.1389 Accuracy 9.4852
# Epoch 198 Batch 20 Loss 0.1389 Accuracy 9.4850
# Time taken for 1 epoch: 1.24 secs
#
# TestLoss 0.0000 TestAccuracy 8.4455
# Epoch 199 Batch 5 Loss 0.1388 Accuracy 9.4822
# Epoch 199 Batch 10 Loss 0.1388 Accuracy 9.4810
# Epoch 199 Batch 15 Loss 0.1387 Accuracy 9.4817
# Epoch 199 Batch 20 Loss 0.1388 Accuracy 9.4812
# Time taken for 1 epoch: 1.30 secs
#
# TestLoss 0.0000 TestAccuracy 8.4413
# Epoch 200 Batch 5 Loss 0.1388 Accuracy 9.4812
# Epoch 200 Batch 10 Loss 0.1387 Accuracy 9.4797
# Epoch 200 Batch 15 Loss 0.1387 Accuracy 9.4791
# Epoch 200 Batch 20 Loss 0.1387 Accuracy 9.4779
# Time taken for 1 epoch: 1.20 secs
#
# TestLoss 0.0000 TestAccuracy 8.4380

# %% [markdown]
# ## 3) CNN-LSTM

# %% [markdown]
# ### (1) min_max scale

# %% [markdown]
# #### - 당진

# %%
train_min_dangjin = np.min(X_train_dangjin)
train_max_dangjin = np.max(X_train_dangjin)

X_train_dangjin_scaled = (X_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

X_test_dangjin_scaled = (X_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

X_train_dangjin_scaled[:,:,5] = X_train_dangjin[:,:,5]

X_test_dangjin_scaled[:,:,5] = X_test_dangjin[:,:,5]

# %%
y_train_dangjin_scaled = (y_train_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_scaled = (y_test_dangjin - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_ware_scaled = (y_train_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_ware_scaled = (y_test_dangjin_ware - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %%
y_train_dangjin_float_scaled = (y_train_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

y_test_dangjin_float_scaled = (y_test_dangjin_float - train_min_dangjin) / (train_max_dangjin - train_min_dangjin)

# %% [markdown]
# #### - 울산

# %%
train_min_ulsan = np.min(X_train_ulsan)
train_max_ulsan = np.max(X_train_ulsan)

X_train_ulsan_scaled = (X_train_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

X_test_ulsan_scaled = (X_test_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

X_train_ulsan_scaled[:,:,5] = X_train_ulsan[:,:,5]

X_test_ulsan_scaled[:,:,5] = X_test_ulsan[:,:,5]

# %%
y_train_ulsan_scaled = (y_train_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

y_test_ulsan_scaled = (y_test_ulsan - train_min_ulsan) / (train_max_ulsan - train_min_ulsan)

# %% [markdown]
# ### (2) 모델 구성

# %%
class TrainModel(tf.keras.Model):
    def __init__(self, 
                 kernel_size, 
                 lstm_dim):
        
        super(TrainModel, self).__init__()

        self.kernel_size = kernel_size
        self.lstm_dim = lstm_dim
     
    def build(self, input_shape):
    
        self.conv = tf.keras.layers.Dense(self.kernel_size, 
                                      activation = "relu")
        
        self.conv_2 = tf.keras.layers.Dense(self.kernel_size, 
                                      activation = "relu")
        
        self.lstm = tf.keras.layers.LSTM(self.lstm_dim,
                                        return_sequences = True)
        
        self.concat = tf.keras.layers.Add()
        
        self.dropout = tf.keras.layers.Dropout(0.2)
        
        output_layer = tf.keras.layers.Dense(1, activation = "relu")
        
        self.outputs = tf.keras.layers.TimeDistributed(output_layer)
    
    def call(self, input_tensor):
        
        
        conv_output = self.conv(input_tensor)
        conv_output = self.dropout(conv_output)
        conv_output = self.conv_2(conv_output)
        conv_output = self.dropout(conv_output)
        
        lstm_output_1 = self.lstm(conv_output)
        
        output = self.outputs(lstm_output_1)
        
        return output

# %% [markdown]
# ### (3) 모델 컴파일

# %% [markdown]
# #### - 학습 스케쥴러 정의

# %%
Models_dangjin = TrainModel(
                     kernel_size = 200, 
                      lstm_dim = 256)

Models_dangjin_warehouse = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

Models_ulsan = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

Models_dangjin_floating = TrainModel(
                      kernel_size = 200, 
                      lstm_dim = 256)

# %%
def nmae_10(y_true, y_pred):
    
    y_true = y_true * (train_max - train_min) + train_min
    y_pred = y_pred * (train_max - train_min) + train_min
    
    absolute_error = abs(y_true - y_pred)
    absolute_error = absolute_error / capacity
    
    target_idx = np.where(y_true >= capacity*0.1)
    
    nmae = 100 * absolute_error[target_idx]
    
    return nmae

# %%
@tf.function()
def train_step_dangjin(inp , tar):
    with tf.GradientTape() as tape:
        
        output = Models_dangjin(inp)

        loss =  loss_function(tar, output)
    
    gradients = tape.gradient(loss, Models_dangjin.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_dangjin_floating(inp , tar):
    with tf.GradientTape() as tape:
        output = Models_dangjin_floating(inp)

        loss =  loss_function(tar, output)
 
    gradients = tape.gradient(loss, Models_dangjin_floating.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin_floating.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_dangjin_warehouse(inp , tar):
    with tf.GradientTape() as tape:
        output = Models_dangjin_warehouse(inp)

        loss =  loss_function(tar, output)
 
    gradients = tape.gradient(loss, Models_dangjin_warehouse.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_dangjin_warehouse.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
@tf.function()
def train_step_ulsan(inp , tar):
    with tf.GradientTape() as tape:
        output = Models_ulsan(inp)

        loss =  loss_function(tar, output)
 
    gradients = tape.gradient(loss, Models_ulsan.trainable_variables)
    optimizer.apply_gradients(zip(gradients, Models_ulsan.trainable_variables))
  
    train_loss(loss)
    train_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
def val_accuracy(inp, tar, Models):
    output = Models(inp)
    
    test_accuracy(tf.numpy_function(nmae_10, 
                                     [tar, tf.squeeze(output, -1)], 
                                     tf.float32))

# %%
EPOCHS = 300
batch_size = 50

# %% [markdown]
# #### - dangjin

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_scaled, Models_dangjin)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.0225 Accuracy 29.1710
# Epoch 1 Batch 10 Loss 0.0175 Accuracy 32.9480
# Epoch 1 Batch 15 Loss 0.0145 Accuracy 27.1681
# Epoch 1 Batch 20 Loss 0.0127 Accuracy 25.8063
# Time taken for 1 epoch: 1.69 secs
#
# WARNING:tensorflow:Layer train_model is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 21.1337
# Epoch 2 Batch 5 Loss 0.0116 Accuracy 24.9597
# Epoch 2 Batch 10 Loss 0.0109 Accuracy 23.9365
# Epoch 2 Batch 15 Loss 0.0100 Accuracy 22.5892
# Epoch 2 Batch 20 Loss 0.0096 Accuracy 22.5278
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 18.3319
# Epoch 3 Batch 5 Loss 0.0091 Accuracy 21.6150
# Epoch 3 Batch 10 Loss 0.0086 Accuracy 21.1613
# Epoch 3 Batch 15 Loss 0.0082 Accuracy 20.3750
# Epoch 3 Batch 20 Loss 0.0082 Accuracy 20.7229
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 17.4027
# Epoch 4 Batch 5 Loss 0.0078 Accuracy 19.9771
# Epoch 4 Batch 10 Loss 0.0076 Accuracy 19.6993
# Epoch 4 Batch 15 Loss 0.0074 Accuracy 19.3139
# Epoch 4 Batch 20 Loss 0.0072 Accuracy 19.0959
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 16.3373
# Epoch 5 Batch 5 Loss 0.0069 Accuracy 18.7567
# Epoch 5 Batch 10 Loss 0.0068 Accuracy 18.5004
# Epoch 5 Batch 15 Loss 0.0066 Accuracy 18.1700
# Epoch 5 Batch 20 Loss 0.0065 Accuracy 18.2169
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 15.6800
# Epoch 6 Batch 5 Loss 0.0064 Accuracy 17.9611
# Epoch 6 Batch 10 Loss 0.0063 Accuracy 17.7812
# Epoch 6 Batch 15 Loss 0.0062 Accuracy 17.5601
# Epoch 6 Batch 20 Loss 0.0061 Accuracy 17.5609
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 15.2467
# Epoch 7 Batch 5 Loss 0.0060 Accuracy 17.3674
# Epoch 7 Batch 10 Loss 0.0059 Accuracy 17.2366
# Epoch 7 Batch 15 Loss 0.0058 Accuracy 17.0583
# Epoch 7 Batch 20 Loss 0.0058 Accuracy 17.0897
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 14.9204
# Epoch 8 Batch 5 Loss 0.0057 Accuracy 16.9476
# Epoch 8 Batch 10 Loss 0.0056 Accuracy 16.8493
# Epoch 8 Batch 15 Loss 0.0056 Accuracy 16.7100
# Epoch 8 Batch 20 Loss 0.0055 Accuracy 16.7448
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 14.6827
# Epoch 9 Batch 5 Loss 0.0055 Accuracy 16.6266
# Epoch 9 Batch 10 Loss 0.0054 Accuracy 16.5441
# Epoch 9 Batch 15 Loss 0.0054 Accuracy 16.4269
# Epoch 9 Batch 20 Loss 0.0053 Accuracy 16.4655
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 14.4848
# Epoch 10 Batch 5 Loss 0.0053 Accuracy 16.3740
# Epoch 10 Batch 10 Loss 0.0053 Accuracy 16.3032
# Epoch 10 Batch 15 Loss 0.0052 Accuracy 16.2023
# Epoch 10 Batch 20 Loss 0.0052 Accuracy 16.2421
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 14.3261
# Epoch 11 Batch 5 Loss 0.0051 Accuracy 16.1672
# Epoch 11 Batch 10 Loss 0.0051 Accuracy 16.1056
# Epoch 11 Batch 15 Loss 0.0051 Accuracy 16.0170
# Epoch 11 Batch 20 Loss 0.0051 Accuracy 16.0616
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 14.1957
# Epoch 12 Batch 5 Loss 0.0050 Accuracy 15.9993
# Epoch 12 Batch 10 Loss 0.0050 Accuracy 15.9451
# Epoch 12 Batch 15 Loss 0.0050 Accuracy 15.8666
# Epoch 12 Batch 20 Loss 0.0050 Accuracy 15.9090
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 14.0843
# Epoch 13 Batch 5 Loss 0.0049 Accuracy 15.8572
# Epoch 13 Batch 10 Loss 0.0049 Accuracy 15.8085
# Epoch 13 Batch 15 Loss 0.0049 Accuracy 15.7373
# Epoch 13 Batch 20 Loss 0.0049 Accuracy 15.7795
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.9896
# Epoch 14 Batch 5 Loss 0.0048 Accuracy 15.7367
# Epoch 14 Batch 10 Loss 0.0048 Accuracy 15.6925
# Epoch 14 Batch 15 Loss 0.0048 Accuracy 15.6274
# Epoch 14 Batch 20 Loss 0.0048 Accuracy 15.6692
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.9077
# Epoch 15 Batch 5 Loss 0.0048 Accuracy 15.6340
# Epoch 15 Batch 10 Loss 0.0047 Accuracy 15.5936
# Epoch 15 Batch 15 Loss 0.0047 Accuracy 15.5333
# Epoch 15 Batch 20 Loss 0.0047 Accuracy 15.5740
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 13.8376
# Epoch 16 Batch 5 Loss 0.0047 Accuracy 15.5452
# Epoch 16 Batch 10 Loss 0.0047 Accuracy 15.5075
# Epoch 16 Batch 15 Loss 0.0047 Accuracy 15.4512
# Epoch 16 Batch 20 Loss 0.0047 Accuracy 15.4901
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 13.7745
# Epoch 17 Batch 5 Loss 0.0046 Accuracy 15.4669
# Epoch 17 Batch 10 Loss 0.0046 Accuracy 15.4322
# Epoch 17 Batch 15 Loss 0.0046 Accuracy 15.3792
# Epoch 17 Batch 20 Loss 0.0046 Accuracy 15.4166
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 13.7213
# Epoch 18 Batch 5 Loss 0.0046 Accuracy 15.3985
# Epoch 18 Batch 10 Loss 0.0046 Accuracy 15.3659
# Epoch 18 Batch 15 Loss 0.0046 Accuracy 15.3158
# Epoch 18 Batch 20 Loss 0.0046 Accuracy 15.3516
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.6737
# Epoch 19 Batch 5 Loss 0.0045 Accuracy 15.3377
# Epoch 19 Batch 10 Loss 0.0045 Accuracy 15.3073
# Epoch 19 Batch 15 Loss 0.0045 Accuracy 15.2598
# Epoch 19 Batch 20 Loss 0.0045 Accuracy 15.2934
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 13.6323
# Epoch 20 Batch 5 Loss 0.0045 Accuracy 15.2833
# Epoch 20 Batch 10 Loss 0.0045 Accuracy 15.2546
# Epoch 20 Batch 15 Loss 0.0045 Accuracy 15.2098
# Epoch 20 Batch 20 Loss 0.0045 Accuracy 15.2417
# Time taken for 1 epoch: 0.60 secs
#
# TestLoss 0.0000 TestAccuracy 13.5977
# Epoch 21 Batch 5 Loss 0.0045 Accuracy 15.2341
# Epoch 21 Batch 10 Loss 0.0045 Accuracy 15.2072
# Epoch 21 Batch 15 Loss 0.0044 Accuracy 15.1647
# Epoch 21 Batch 20 Loss 0.0044 Accuracy 15.1949
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 13.5688
# Epoch 22 Batch 5 Loss 0.0044 Accuracy 15.1895
# Epoch 22 Batch 10 Loss 0.0044 Accuracy 15.1638
# Epoch 22 Batch 15 Loss 0.0044 Accuracy 15.1232
# Epoch 22 Batch 20 Loss 0.0044 Accuracy 15.1522
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5449
# Epoch 23 Batch 5 Loss 0.0044 Accuracy 15.1489
# Epoch 23 Batch 10 Loss 0.0044 Accuracy 15.1244
# Epoch 23 Batch 15 Loss 0.0044 Accuracy 15.0857
# Epoch 23 Batch 20 Loss 0.0044 Accuracy 15.1133
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5261
# Epoch 24 Batch 5 Loss 0.0044 Accuracy 15.1117
# Epoch 24 Batch 10 Loss 0.0044 Accuracy 15.0884
# Epoch 24 Batch 15 Loss 0.0044 Accuracy 15.0514
# Epoch 24 Batch 20 Loss 0.0044 Accuracy 15.0778
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5127
# Epoch 25 Batch 5 Loss 0.0044 Accuracy 15.0783
# Epoch 25 Batch 10 Loss 0.0043 Accuracy 15.0558
# Epoch 25 Batch 15 Loss 0.0043 Accuracy 15.0202
# Epoch 25 Batch 20 Loss 0.0043 Accuracy 15.0456
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5034
# Epoch 26 Batch 5 Loss 0.0043 Accuracy 15.0477
# Epoch 26 Batch 10 Loss 0.0043 Accuracy 15.0261
# Epoch 26 Batch 15 Loss 0.0043 Accuracy 14.9919
# Epoch 26 Batch 20 Loss 0.0043 Accuracy 15.0159
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.4978
# Epoch 27 Batch 5 Loss 0.0043 Accuracy 15.0198
# Epoch 27 Batch 10 Loss 0.0043 Accuracy 14.9993
# Epoch 27 Batch 15 Loss 0.0043 Accuracy 14.9666
# Epoch 27 Batch 20 Loss 0.0043 Accuracy 14.9890
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.4975
# Epoch 28 Batch 5 Loss 0.0043 Accuracy 14.9946
# Epoch 28 Batch 10 Loss 0.0043 Accuracy 14.9753
# Epoch 28 Batch 15 Loss 0.0043 Accuracy 14.9441
# Epoch 28 Batch 20 Loss 0.0043 Accuracy 14.9651
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5007
# Epoch 29 Batch 5 Loss 0.0043 Accuracy 14.9721
# Epoch 29 Batch 10 Loss 0.0043 Accuracy 14.9534
# Epoch 29 Batch 15 Loss 0.0043 Accuracy 14.9238
# Epoch 29 Batch 20 Loss 0.0043 Accuracy 14.9435
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5087
# Epoch 30 Batch 5 Loss 0.0043 Accuracy 14.9517
# Epoch 30 Batch 10 Loss 0.0043 Accuracy 14.9345
# Epoch 30 Batch 15 Loss 0.0043 Accuracy 14.9067
# Epoch 30 Batch 20 Loss 0.0043 Accuracy 14.9247
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5189
# Epoch 31 Batch 5 Loss 0.0042 Accuracy 14.9344
# Epoch 31 Batch 10 Loss 0.0042 Accuracy 14.9184
# Epoch 31 Batch 15 Loss 0.0042 Accuracy 14.8925
# Epoch 31 Batch 20 Loss 0.0042 Accuracy 14.9085
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5325
# Epoch 32 Batch 5 Loss 0.0042 Accuracy 14.9189
# Epoch 32 Batch 10 Loss 0.0042 Accuracy 14.9048
# Epoch 32 Batch 15 Loss 0.0042 Accuracy 14.8811
# Epoch 32 Batch 20 Loss 0.0042 Accuracy 14.8952
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5461
# Epoch 33 Batch 5 Loss 0.0042 Accuracy 14.9062
# Epoch 33 Batch 10 Loss 0.0042 Accuracy 14.8935
# Epoch 33 Batch 15 Loss 0.0042 Accuracy 14.8720
# Epoch 33 Batch 20 Loss 0.0042 Accuracy 14.8826
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5566
# Epoch 34 Batch 5 Loss 0.0042 Accuracy 14.8939
# Epoch 34 Batch 10 Loss 0.0042 Accuracy 14.8830
# Epoch 34 Batch 15 Loss 0.0042 Accuracy 14.8635
# Epoch 34 Batch 20 Loss 0.0042 Accuracy 14.8716
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5659
# Epoch 35 Batch 5 Loss 0.0042 Accuracy 14.8824
# Epoch 35 Batch 10 Loss 0.0042 Accuracy 14.8728
# Epoch 35 Batch 15 Loss 0.0042 Accuracy 14.8547
# Epoch 35 Batch 20 Loss 0.0042 Accuracy 14.8609
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5739
# Epoch 36 Batch 5 Loss 0.0042 Accuracy 14.8703
# Epoch 36 Batch 10 Loss 0.0042 Accuracy 14.8620
# Epoch 36 Batch 15 Loss 0.0042 Accuracy 14.8449
# Epoch 36 Batch 20 Loss 0.0042 Accuracy 14.8503
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5796
# Epoch 37 Batch 5 Loss 0.0042 Accuracy 14.8585
# Epoch 37 Batch 10 Loss 0.0042 Accuracy 14.8501
# Epoch 37 Batch 15 Loss 0.0042 Accuracy 14.8332
# Epoch 37 Batch 20 Loss 0.0042 Accuracy 14.8382
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5859
# Epoch 38 Batch 5 Loss 0.0042 Accuracy 14.8450
# Epoch 38 Batch 10 Loss 0.0042 Accuracy 14.8375
# Epoch 38 Batch 15 Loss 0.0042 Accuracy 14.8208
# Epoch 38 Batch 20 Loss 0.0042 Accuracy 14.8263
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5920
# Epoch 39 Batch 5 Loss 0.0042 Accuracy 14.8327
# Epoch 39 Batch 10 Loss 0.0042 Accuracy 14.8252
# Epoch 39 Batch 15 Loss 0.0041 Accuracy 14.8090
# Epoch 39 Batch 20 Loss 0.0041 Accuracy 14.8130
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5950
# Epoch 40 Batch 5 Loss 0.0041 Accuracy 14.8183
# Epoch 40 Batch 10 Loss 0.0041 Accuracy 14.8117
# Epoch 40 Batch 15 Loss 0.0041 Accuracy 14.7961
# Epoch 40 Batch 20 Loss 0.0041 Accuracy 14.8000
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.5956
# Epoch 41 Batch 5 Loss 0.0041 Accuracy 14.8048
# Epoch 41 Batch 10 Loss 0.0041 Accuracy 14.7979
# Epoch 41 Batch 15 Loss 0.0041 Accuracy 14.7824
# Epoch 41 Batch 20 Loss 0.0041 Accuracy 14.7858
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5958
# Epoch 42 Batch 5 Loss 0.0041 Accuracy 14.7894
# Epoch 42 Batch 10 Loss 0.0041 Accuracy 14.7825
# Epoch 42 Batch 15 Loss 0.0041 Accuracy 14.7672
# Epoch 42 Batch 20 Loss 0.0041 Accuracy 14.7713
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5978
# Epoch 43 Batch 5 Loss 0.0041 Accuracy 14.7747
# Epoch 43 Batch 10 Loss 0.0041 Accuracy 14.7676
# Epoch 43 Batch 15 Loss 0.0041 Accuracy 14.7524
# Epoch 43 Batch 20 Loss 0.0041 Accuracy 14.7567
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.6013
# Epoch 44 Batch 5 Loss 0.0041 Accuracy 14.7594
# Epoch 44 Batch 10 Loss 0.0041 Accuracy 14.7524
# Epoch 44 Batch 15 Loss 0.0041 Accuracy 14.7375
# Epoch 44 Batch 20 Loss 0.0041 Accuracy 14.7423
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.6064
# Epoch 45 Batch 5 Loss 0.0041 Accuracy 14.7447
# Epoch 45 Batch 10 Loss 0.0041 Accuracy 14.7375
# Epoch 45 Batch 15 Loss 0.0041 Accuracy 14.7228
# Epoch 45 Batch 20 Loss 0.0041 Accuracy 14.7285
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.6126
# Epoch 46 Batch 5 Loss 0.0041 Accuracy 14.7302
# Epoch 46 Batch 10 Loss 0.0041 Accuracy 14.7232
# Epoch 46 Batch 15 Loss 0.0041 Accuracy 14.7090
# Epoch 46 Batch 20 Loss 0.0041 Accuracy 14.7150
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.6166
# Epoch 47 Batch 5 Loss 0.0041 Accuracy 14.7158
# Epoch 47 Batch 10 Loss 0.0041 Accuracy 14.7090
# Epoch 47 Batch 15 Loss 0.0041 Accuracy 14.6952
# Epoch 47 Batch 20 Loss 0.0040 Accuracy 14.7011
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.6157
# Epoch 48 Batch 5 Loss 0.0040 Accuracy 14.7016
# Epoch 48 Batch 10 Loss 0.0040 Accuracy 14.6960
# Epoch 48 Batch 15 Loss 0.0040 Accuracy 14.6829
# Epoch 48 Batch 20 Loss 0.0040 Accuracy 14.6909
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 13.6060
# Epoch 49 Batch 5 Loss 0.0040 Accuracy 14.6899
# Epoch 49 Batch 10 Loss 0.0040 Accuracy 14.6828
# Epoch 49 Batch 15 Loss 0.0040 Accuracy 14.6704
# Epoch 49 Batch 20 Loss 0.0040 Accuracy 14.6781
# Time taken for 1 epoch: 0.58 secs
#
# TestLoss 0.0000 TestAccuracy 13.5944
# Epoch 50 Batch 5 Loss 0.0040 Accuracy 14.6780
# Epoch 50 Batch 10 Loss 0.0040 Accuracy 14.6699
# Epoch 50 Batch 15 Loss 0.0040 Accuracy 14.6567
# Epoch 50 Batch 20 Loss 0.0040 Accuracy 14.6644
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5862
# Epoch 51 Batch 5 Loss 0.0040 Accuracy 14.6643
# Epoch 51 Batch 10 Loss 0.0040 Accuracy 14.6567
# Epoch 51 Batch 15 Loss 0.0040 Accuracy 14.6438
# Epoch 51 Batch 20 Loss 0.0040 Accuracy 14.6515
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5806
# Epoch 52 Batch 5 Loss 0.0040 Accuracy 14.6502
# Epoch 52 Batch 10 Loss 0.0040 Accuracy 14.6433
# Epoch 52 Batch 15 Loss 0.0040 Accuracy 14.6312
# Epoch 52 Batch 20 Loss 0.0040 Accuracy 14.6377
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5712
# Epoch 53 Batch 5 Loss 0.0040 Accuracy 14.6356
# Epoch 53 Batch 10 Loss 0.0040 Accuracy 14.6275
# Epoch 53 Batch 15 Loss 0.0040 Accuracy 14.6152
# Epoch 53 Batch 20 Loss 0.0040 Accuracy 14.6223
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5648
# Epoch 54 Batch 5 Loss 0.0040 Accuracy 14.6197
# Epoch 54 Batch 10 Loss 0.0040 Accuracy 14.6119
# Epoch 54 Batch 15 Loss 0.0040 Accuracy 14.6000
# Epoch 54 Batch 20 Loss 0.0040 Accuracy 14.6072
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5589
# Epoch 55 Batch 5 Loss 0.0040 Accuracy 14.6043
# Epoch 55 Batch 10 Loss 0.0039 Accuracy 14.5966
# Epoch 55 Batch 15 Loss 0.0039 Accuracy 14.5854
# Epoch 55 Batch 20 Loss 0.0039 Accuracy 14.5916
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5487
# Epoch 56 Batch 5 Loss 0.0039 Accuracy 14.5885
# Epoch 56 Batch 10 Loss 0.0039 Accuracy 14.5805
# Epoch 56 Batch 15 Loss 0.0039 Accuracy 14.5699
# Epoch 56 Batch 20 Loss 0.0039 Accuracy 14.5752
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5387
# Epoch 57 Batch 5 Loss 0.0039 Accuracy 14.5719
# Epoch 57 Batch 10 Loss 0.0039 Accuracy 14.5639
# Epoch 57 Batch 15 Loss 0.0039 Accuracy 14.5536
# Epoch 57 Batch 20 Loss 0.0039 Accuracy 14.5586
# Time taken for 1 epoch: 0.56 secs
#
# TestLoss 0.0000 TestAccuracy 13.5301
# Epoch 58 Batch 5 Loss 0.0039 Accuracy 14.5549
# Epoch 58 Batch 10 Loss 0.0039 Accuracy 14.5471
# Epoch 58 Batch 15 Loss 0.0039 Accuracy 14.5371
# Epoch 58 Batch 20 Loss 0.0039 Accuracy 14.5422
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5223
# Epoch 59 Batch 5 Loss 0.0039 Accuracy 14.5378
# Epoch 59 Batch 10 Loss 0.0039 Accuracy 14.5302
# Epoch 59 Batch 15 Loss 0.0039 Accuracy 14.5204
# Epoch 59 Batch 20 Loss 0.0039 Accuracy 14.5255
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.5135
# Epoch 60 Batch 5 Loss 0.0039 Accuracy 14.5205
# Epoch 60 Batch 10 Loss 0.0039 Accuracy 14.5130
# Epoch 60 Batch 15 Loss 0.0039 Accuracy 14.5035
# Epoch 60 Batch 20 Loss 0.0039 Accuracy 14.5081
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.5039
# Epoch 61 Batch 5 Loss 0.0039 Accuracy 14.5029
# Epoch 61 Batch 10 Loss 0.0039 Accuracy 14.4955
# Epoch 61 Batch 15 Loss 0.0039 Accuracy 14.4863
# Epoch 61 Batch 20 Loss 0.0039 Accuracy 14.4906
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.4945
# Epoch 62 Batch 5 Loss 0.0039 Accuracy 14.4850
# Epoch 62 Batch 10 Loss 0.0039 Accuracy 14.4777
# Epoch 62 Batch 15 Loss 0.0039 Accuracy 14.4688
# Epoch 62 Batch 20 Loss 0.0039 Accuracy 14.4729
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.4847
# Epoch 63 Batch 5 Loss 0.0038 Accuracy 14.4668
# Epoch 63 Batch 10 Loss 0.0038 Accuracy 14.4596
# Epoch 63 Batch 15 Loss 0.0038 Accuracy 14.4509
# Epoch 63 Batch 20 Loss 0.0038 Accuracy 14.4548
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.4748
# Epoch 64 Batch 5 Loss 0.0038 Accuracy 14.4483
# Epoch 64 Batch 10 Loss 0.0038 Accuracy 14.4412
# Epoch 64 Batch 15 Loss 0.0038 Accuracy 14.4327
# Epoch 64 Batch 20 Loss 0.0038 Accuracy 14.4362
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.4643
# Epoch 65 Batch 5 Loss 0.0038 Accuracy 14.4295
# Epoch 65 Batch 10 Loss 0.0038 Accuracy 14.4225
# Epoch 65 Batch 15 Loss 0.0038 Accuracy 14.4142
# Epoch 65 Batch 20 Loss 0.0038 Accuracy 14.4167
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.4525
# Epoch 66 Batch 5 Loss 0.0038 Accuracy 14.4096
# Epoch 66 Batch 10 Loss 0.0038 Accuracy 14.4030
# Epoch 66 Batch 15 Loss 0.0038 Accuracy 14.3942
# Epoch 66 Batch 20 Loss 0.0038 Accuracy 14.3970
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.4361
# Epoch 67 Batch 5 Loss 0.0038 Accuracy 14.3895
# Epoch 67 Batch 10 Loss 0.0038 Accuracy 14.3825
# Epoch 67 Batch 15 Loss 0.0038 Accuracy 14.3738
# Epoch 67 Batch 20 Loss 0.0038 Accuracy 14.3771
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.4258
# Epoch 68 Batch 5 Loss 0.0038 Accuracy 14.3696
# Epoch 68 Batch 10 Loss 0.0038 Accuracy 14.3629
# Epoch 68 Batch 15 Loss 0.0038 Accuracy 14.3538
# Epoch 68 Batch 20 Loss 0.0038 Accuracy 14.3576
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.4155
# Epoch 69 Batch 5 Loss 0.0038 Accuracy 14.3502
# Epoch 69 Batch 10 Loss 0.0038 Accuracy 14.3436
# Epoch 69 Batch 15 Loss 0.0038 Accuracy 14.3352
# Epoch 69 Batch 20 Loss 0.0038 Accuracy 14.3384
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.4023
# Epoch 70 Batch 5 Loss 0.0038 Accuracy 14.3311
# Epoch 70 Batch 10 Loss 0.0038 Accuracy 14.3244
# Epoch 70 Batch 15 Loss 0.0038 Accuracy 14.3167
# Epoch 70 Batch 20 Loss 0.0038 Accuracy 14.3189
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.3892
# Epoch 71 Batch 5 Loss 0.0037 Accuracy 14.3116
# Epoch 71 Batch 10 Loss 0.0037 Accuracy 14.3049
# Epoch 71 Batch 15 Loss 0.0037 Accuracy 14.2974
# Epoch 71 Batch 20 Loss 0.0037 Accuracy 14.2991
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.3774
# Epoch 72 Batch 5 Loss 0.0037 Accuracy 14.2919
# Epoch 72 Batch 10 Loss 0.0037 Accuracy 14.2853
# Epoch 72 Batch 15 Loss 0.0037 Accuracy 14.2779
# Epoch 72 Batch 20 Loss 0.0037 Accuracy 14.2797
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.3663
# Epoch 73 Batch 5 Loss 0.0037 Accuracy 14.2723
# Epoch 73 Batch 10 Loss 0.0037 Accuracy 14.2659
# Epoch 73 Batch 15 Loss 0.0037 Accuracy 14.2586
# Epoch 73 Batch 20 Loss 0.0037 Accuracy 14.2601
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.3545
# Epoch 74 Batch 5 Loss 0.0037 Accuracy 14.2527
# Epoch 74 Batch 10 Loss 0.0037 Accuracy 14.2465
# Epoch 74 Batch 15 Loss 0.0037 Accuracy 14.2395
# Epoch 74 Batch 20 Loss 0.0037 Accuracy 14.2408
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.3425
# Epoch 75 Batch 5 Loss 0.0037 Accuracy 14.2332
# Epoch 75 Batch 10 Loss 0.0037 Accuracy 14.2270
# Epoch 75 Batch 15 Loss 0.0037 Accuracy 14.2202
# Epoch 75 Batch 20 Loss 0.0037 Accuracy 14.2212
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 13.3299
# Epoch 76 Batch 5 Loss 0.0037 Accuracy 14.2136
# Epoch 76 Batch 10 Loss 0.0037 Accuracy 14.2074
# Epoch 76 Batch 15 Loss 0.0037 Accuracy 14.2009
# Epoch 76 Batch 20 Loss 0.0037 Accuracy 14.2015
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.3175
# Epoch 77 Batch 5 Loss 0.0037 Accuracy 14.1938
# Epoch 77 Batch 10 Loss 0.0037 Accuracy 14.1878
# Epoch 77 Batch 15 Loss 0.0037 Accuracy 14.1814
# Epoch 77 Batch 20 Loss 0.0037 Accuracy 14.1819
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.3045
# Epoch 78 Batch 5 Loss 0.0037 Accuracy 14.1740
# Epoch 78 Batch 10 Loss 0.0037 Accuracy 14.1681
# Epoch 78 Batch 15 Loss 0.0037 Accuracy 14.1620
# Epoch 78 Batch 20 Loss 0.0037 Accuracy 14.1621
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.2914
# Epoch 79 Batch 5 Loss 0.0037 Accuracy 14.1543
# Epoch 79 Batch 10 Loss 0.0036 Accuracy 14.1484
# Epoch 79 Batch 15 Loss 0.0036 Accuracy 14.1423
# Epoch 79 Batch 20 Loss 0.0036 Accuracy 14.1423
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2775
# Epoch 80 Batch 5 Loss 0.0036 Accuracy 14.1344
# Epoch 80 Batch 10 Loss 0.0036 Accuracy 14.1287
# Epoch 80 Batch 15 Loss 0.0036 Accuracy 14.1228
# Epoch 80 Batch 20 Loss 0.0036 Accuracy 14.1225
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2637
# Epoch 81 Batch 5 Loss 0.0036 Accuracy 14.1146
# Epoch 81 Batch 10 Loss 0.0036 Accuracy 14.1089
# Epoch 81 Batch 15 Loss 0.0036 Accuracy 14.1032
# Epoch 81 Batch 20 Loss 0.0036 Accuracy 14.1028
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2490
# Epoch 82 Batch 5 Loss 0.0036 Accuracy 14.0949
# Epoch 82 Batch 10 Loss 0.0036 Accuracy 14.0893
# Epoch 82 Batch 15 Loss 0.0036 Accuracy 14.0836
# Epoch 82 Batch 20 Loss 0.0036 Accuracy 14.0830
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 13.2348
# Epoch 83 Batch 5 Loss 0.0036 Accuracy 14.0750
# Epoch 83 Batch 10 Loss 0.0036 Accuracy 14.0695
# Epoch 83 Batch 15 Loss 0.0036 Accuracy 14.0640
# Epoch 83 Batch 20 Loss 0.0036 Accuracy 14.0633
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2198
# Epoch 84 Batch 5 Loss 0.0036 Accuracy 14.0554
# Epoch 84 Batch 10 Loss 0.0036 Accuracy 14.0499
# Epoch 84 Batch 15 Loss 0.0036 Accuracy 14.0445
# Epoch 84 Batch 20 Loss 0.0036 Accuracy 14.0435
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.2046
# Epoch 85 Batch 5 Loss 0.0036 Accuracy 14.0357
# Epoch 85 Batch 10 Loss 0.0036 Accuracy 14.0303
# Epoch 85 Batch 15 Loss 0.0036 Accuracy 14.0251
# Epoch 85 Batch 20 Loss 0.0036 Accuracy 14.0240
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13.1884
# Epoch 86 Batch 5 Loss 0.0036 Accuracy 14.0161
# Epoch 86 Batch 10 Loss 0.0036 Accuracy 14.0108
# Epoch 86 Batch 15 Loss 0.0036 Accuracy 14.0055
# Epoch 86 Batch 20 Loss 0.0036 Accuracy 14.0041
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 13
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.5282
# Epoch 120 Batch 5 Loss 0.0032 Accuracy 13.4109
# Epoch 120 Batch 10 Loss 0.0032 Accuracy 13.4063
# Epoch 120 Batch 15 Loss 0.0032 Accuracy 13.4023
# Epoch 120 Batch 20 Loss 0.0032 Accuracy 13.3992
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.5112
# Epoch 121 Batch 5 Loss 0.0032 Accuracy 13.3946
# Epoch 121 Batch 10 Loss 0.0032 Accuracy 13.3900
# Epoch 121 Batch 15 Loss 0.0032 Accuracy 13.3858
# Epoch 121 Batch 20 Loss 0.0032 Accuracy 13.3826
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.4947
# Epoch 122 Batch 5 Loss 0.0032 Accuracy 13.3780
# Epoch 122 Batch 10 Loss 0.0032 Accuracy 13.3735
# Epoch 122 Batch 15 Loss 0.0032 Accuracy 13.3692
# Epoch 122 Batch 20 Loss 0.0032 Accuracy 13.3661
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.4785
# Epoch 123 Batch 5 Loss 0.0032 Accuracy 13.3615
# Epoch 123 Batch 10 Loss 0.0032 Accuracy 13.3571
# Epoch 123 Batch 15 Loss 0.0032 Accuracy 13.3528
# Epoch 123 Batch 20 Loss 0.0032 Accuracy 13.3496
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 12.4627
# Epoch 124 Batch 5 Loss 0.0032 Accuracy 13.3451
# Epoch 124 Batch 10 Loss 0.0032 Accuracy 13.3407
# Epoch 124 Batch 15 Loss 0.0032 Accuracy 13.3364
# Epoch 124 Batch 20 Loss 0.0032 Accuracy 13.3332
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.4475
# Epoch 125 Batch 5 Loss 0.0032 Accuracy 13.3288
# Epoch 125 Batch 10 Loss 0.0032 Accuracy 13.3244
# Epoch 125 Batch 15 Loss 0.0032 Accuracy 13.3199
# Epoch 125 Batch 20 Loss 0.0032 Accuracy 13.3168
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.4327
# Epoch 126 Batch 5 Loss 0.0032 Accuracy 13.3123
# Epoch 126 Batch 10 Loss 0.0032 Accuracy 13.3081
# Epoch 126 Batch 15 Loss 0.0032 Accuracy 13.3036
# Epoch 126 Batch 20 Loss 0.0032 Accuracy 13.3005
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.4181
# Epoch 127 Batch 5 Loss 0.0032 Accuracy 13.2961
# Epoch 127 Batch 10 Loss 0.0032 Accuracy 13.2919
# Epoch 127 Batch 15 Loss 0.0032 Accuracy 13.2874
# Epoch 127 Batch 20 Loss 0.0032 Accuracy 13.2842
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.4037
# Epoch 128 Batch 5 Loss 0.0032 Accuracy 13.2799
# Epoch 128 Batch 10 Loss 0.0032 Accuracy 13.2758
# Epoch 128 Batch 15 Loss 0.0032 Accuracy 13.2713
# Epoch 128 Batch 20 Loss 0.0032 Accuracy 13.2681
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.3895
# Epoch 129 Batch 5 Loss 0.0032 Accuracy 13.2639
# Epoch 129 Batch 10 Loss 0.0032 Accuracy 13.2598
# Epoch 129 Batch 15 Loss 0.0032 Accuracy 13.2552
# Epoch 129 Batch 20 Loss 0.0032 Accuracy 13.2521
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 12.3756
# Epoch 130 Batch 5 Loss 0.0032 Accuracy 13.2479
# Epoch 130 Batch 10 Loss 0.0032 Accuracy 13.2438
# Epoch 130 Batch 15 Loss 0.0032 Accuracy 13.2393
# Epoch 130 Batch 20 Loss 0.0032 Accuracy 13.2362
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.0105
# Epoch 163 Batch 5 Loss 0.0029 Accuracy 12.7932
# Epoch 163 Batch 10 Loss 0.0029 Accuracy 12.7906
# Epoch 163 Batch 15 Loss 0.0029 Accuracy 12.7868
# Epoch 163 Batch 20 Loss 0.0029 Accuracy 12.7845
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 12.0028
# Epoch 164 Batch 5 Loss 0.0029 Accuracy 12.7816
# Epoch 164 Batch 10 Loss 0.0029 Accuracy 12.7790
# Epoch 164 Batch 15 Loss 0.0029 Accuracy 12.7752
# Epoch 164 Batch 20 Loss 0.0029 Accuracy 12.7729
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.9950
# Epoch 165 Batch 5 Loss 0.0029 Accuracy 12.7701
# Epoch 165 Batch 10 Loss 0.0029 Accuracy 12.7674
# Epoch 165 Batch 15 Loss 0.0029 Accuracy 12.7637
# Epoch 165 Batch 20 Loss 0.0029 Accuracy 12.7614
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.9871
# Epoch 166 Batch 5 Loss 0.0029 Accuracy 12.7585
# Epoch 166 Batch 10 Loss 0.0029 Accuracy 12.7559
# Epoch 166 Batch 15 Loss 0.0029 Accuracy 12.7522
# Epoch 166 Batch 20 Loss 0.0029 Accuracy 12.7499
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.9789
# Epoch 167 Batch 5 Loss 0.0029 Accuracy 12.7471
# Epoch 167 Batch 10 Loss 0.0029 Accuracy 12.7444
# Epoch 167 Batch 15 Loss 0.0029 Accuracy 12.7408
# Epoch 167 Batch 20 Loss 0.0029 Accuracy 12.7384
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.9707
# Epoch 168 Batch 5 Loss 0.0029 Accuracy 12.7357
# Epoch 168 Batch 10 Loss 0.0029 Accuracy 12.7330
# Epoch 168 Batch 15 Loss 0.0029 Accuracy 12.7294
# Epoch 168 Batch 20 Loss 0.0029 Accuracy 12.7271
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9625
# Epoch 169 Batch 5 Loss 0.0029 Accuracy 12.7244
# Epoch 169 Batch 10 Loss 0.0029 Accuracy 12.7217
# Epoch 169 Batch 15 Loss 0.0029 Accuracy 12.7181
# Epoch 169 Batch 20 Loss 0.0029 Accuracy 12.7159
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9544
# Epoch 170 Batch 5 Loss 0.0029 Accuracy 12.7132
# Epoch 170 Batch 10 Loss 0.0029 Accuracy 12.7106
# Epoch 170 Batch 15 Loss 0.0029 Accuracy 12.7070
# Epoch 170 Batch 20 Loss 0.0029 Accuracy 12.7048
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.9463
# Epoch 171 Batch 5 Loss 0.0029 Accuracy 12.7021
# Epoch 171 Batch 10 Loss 0.0029 Accuracy 12.6995
# Epoch 171 Batch 15 Loss 0.0029 Accuracy 12.6960
# Epoch 171 Batch 20 Loss 0.0029 Accuracy 12.6938
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.9384
# Epoch 172 Batch 5 Loss 0.0029 Accuracy 12.6912
# Epoch 172 Batch 10 Loss 0.0029 Accuracy 12.6885
# Epoch 172 Batch 15 Loss 0.0029 Accuracy 12.6850
# Epoch 172 Batch 20 Loss 0.0029 Accuracy 12.6828
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9304
# Epoch 173 Batch 5 Loss 0.0029 Accuracy 12.6803
# Epoch 173 Batch 10 Loss 0.0029 Accuracy 12.6776
# Epoch 173 Batch 15 Loss 0.0029 Accuracy 12.6741
# Epoch 173 Batch 20 Loss 0.0029 Accuracy 12.6720
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9224
# Epoch 174 Batch 5 Loss 0.0029 Accuracy 12.6695
# Epoch 174 Batch 10 Loss 0.0029 Accuracy 12.6669
# Epoch 174 Batch 15 Loss 0.0029 Accuracy 12.6634
# Epoch 174 Batch 20 Loss 0.0029 Accuracy 12.6613
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9144
# Epoch 175 Batch 5 Loss 0.0029 Accuracy 12.6588
# Epoch 175 Batch 10 Loss 0.0029 Accuracy 12.6562
# Epoch 175 Batch 15 Loss 0.0029 Accuracy 12.6528
# Epoch 175 Batch 20 Loss 0.0029 Accuracy 12.6507
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.9064
# Epoch 176 Batch 5 Loss 0.0029 Accuracy 12.6483
# Epoch 176 Batch 10 Loss 0.0029 Accuracy 12.6457
# Epoch 176 Batch 15 Loss 0.0029 Accuracy 12.6422
# Epoch 176 Batch 20 Loss 0.0029 Accuracy 12.6403
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8985
# Epoch 177 Batch 5 Loss 0.0029 Accuracy 12.6378
# Epoch 177 Batch 10 Loss 0.0029 Accuracy 12.6353
# Epoch 177 Batch 15 Loss 0.0029 Accuracy 12.6318
# Epoch 177 Batch 20 Loss 0.0029 Accuracy 12.6298
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.8906
# Epoch 178 Batch 5 Loss 0.0029 Accuracy 12.6274
# Epoch 178 Batch 10 Loss 0.0029 Accuracy 12.6249
# Epoch 178 Batch 15 Loss 0.0029 Accuracy 12.6215
# Epoch 178 Batch 20 Loss 0.0029 Accuracy 12.6194
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8825
# Epoch 179 Batch 5 Loss 0.0029 Accuracy 12.6174
# Epoch 179 Batch 10 Loss 0.0029 Accuracy 12.6151
# Epoch 179 Batch 15 Loss 0.0028 Accuracy 12.6115
# Epoch 179 Batch 20 Loss 0.0028 Accuracy 12.6099
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8760
# Epoch 180 Batch 5 Loss 0.0028 Accuracy 12.6077
# Epoch 180 Batch 10 Loss 0.0028 Accuracy 12.6055
# Epoch 180 Batch 15 Loss 0.0028 Accuracy 12.6021
# Epoch 180 Batch 20 Loss 0.0028 Accuracy 12.6005
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8695
# Epoch 181 Batch 5 Loss 0.0028 Accuracy 12.5980
# Epoch 181 Batch 10 Loss 0.0028 Accuracy 12.5957
# Epoch 181 Batch 15 Loss 0.0028 Accuracy 12.5924
# Epoch 181 Batch 20 Loss 0.0028 Accuracy 12.5907
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.8628
# Epoch 182 Batch 5 Loss 0.0028 Accuracy 12.5882
# Epoch 182 Batch 10 Loss 0.0028 Accuracy 12.5859
# ...
# Epoch 240 Batch 10 Loss 0.0026 Accuracy 12.1416
# Epoch 240 Batch 15 Loss 0.0026 Accuracy 12.1397
# Epoch 240 Batch 20 Loss 0.0026 Accuracy 12.1389
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5346
# Epoch 241 Batch 5 Loss 0.0026 Accuracy 12.1384
# Epoch 241 Batch 10 Loss 0.0026 Accuracy 12.1373
# Epoch 241 Batch 15 Loss 0.0026 Accuracy 12.1355
# Epoch 241 Batch 20 Loss 0.0026 Accuracy 12.1342
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4976
# Epoch 253 Batch 5 Loss 0.0026 Accuracy 12.0684
# Epoch 253 Batch 10 Loss 0.0026 Accuracy 12.0669
# Epoch 253 Batch 15 Loss 0.0026 Accuracy 12.0645
# Epoch 253 Batch 20 Loss 0.0026 Accuracy 12.0640
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4937
# Epoch 254 Batch 5 Loss 0.0026 Accuracy 12.0624
# Epoch 254 Batch 10 Loss 0.0026 Accuracy 12.0608
# Epoch 254 Batch 15 Loss 0.0026 Accuracy 12.0585
# Epoch 254 Batch 20 Loss 0.0026 Accuracy 12.0575
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4907
# Epoch 255 Batch 5 Loss 0.0026 Accuracy 12.0561
# Epoch 255 Batch 10 Loss 0.0026 Accuracy 12.0546
# Epoch 255 Batch 15 Loss 0.0026 Accuracy 12.0522
# Epoch 255 Batch 20 Loss 0.0026 Accuracy 12.0517
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4877
# Epoch 256 Batch 5 Loss 0.0026 Accuracy 12.0502
# Epoch 256 Batch 10 Loss 0.0026 Accuracy 12.0487
# Epoch 256 Batch 15 Loss 0.0026 Accuracy 12.0464
# Epoch 256 Batch 20 Loss 0.0026 Accuracy 12.0460
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4843
# Epoch 257 Batch 5 Loss 0.0026 Accuracy 12.0444
# Epoch 257 Batch 10 Loss 0.0026 Accuracy 12.0429
# Epoch 257 Batch 15 Loss 0.0026 Accuracy 12.0406
# Epoch 257 Batch 20 Loss 0.0026 Accuracy 12.0398
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4810
# Epoch 258 Batch 5 Loss 0.0026 Accuracy 12.0383
# Epoch 258 Batch 10 Loss 0.0026 Accuracy 12.0368
# Epoch 258 Batch 15 Loss 0.0026 Accuracy 12.0344
# Epoch 258 Batch 20 Loss 0.0026 Accuracy 12.0337
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4781
# Epoch 259 Batch 5 Loss 0.0026 Accuracy 12.0322
# Epoch 259 Batch 10 Loss 0.0026 Accuracy 12.0307
# Epoch 259 Batch 15 Loss 0.0026 Accuracy 12.0284
# Epoch 259 Batch 20 Loss 0.0026 Accuracy 12.0277
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4753
# Epoch 260 Batch 5 Loss 0.0026 Accuracy 12.0263
# Epoch 260 Batch 10 Loss 0.0026 Accuracy 12.0248
# Epoch 260 Batch 15 Loss 0.0026 Accuracy 12.0226
# Epoch 260 Batch 20 Loss 0.0026 Accuracy 12.0221
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4724
# Epoch 261 Batch 5 Loss 0.0026 Accuracy 12.0206
# Epoch 261 Batch 10 Loss 0.0026 Accuracy 12.0192
# Epoch 261 Batch 15 Loss 0.0026 Accuracy 12.0168
# Epoch 261 Batch 20 Loss 0.0026 Accuracy 12.0164
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4696
# Epoch 262 Batch 5 Loss 0.0026 Accuracy 12.0150
# Epoch 262 Batch 10 Loss 0.0026 Accuracy 12.0136
# Epoch 262 Batch 15 Loss 0.0026 Accuracy 12.0114
# Epoch 262 Batch 20 Loss 0.0026 Accuracy 12.0108
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4666
# Epoch 263 Batch 5 Loss 0.0026 Accuracy 12.0095
# Epoch 263 Batch 10 Loss 0.0026 Accuracy 12.0082
# Epoch 263 Batch 15 Loss 0.0026 Accuracy 12.0059
# Epoch 263 Batch 20 Loss 0.0026 Accuracy 12.0055
# Time taken for 1 epoch: 0.56 secs
#
# TestLoss 0.0000 TestAccuracy 11.4633
# Epoch 264 Batch 5 Loss 0.0026 Accuracy 12.0044
# Epoch 264 Batch 10 Loss 0.0026 Accuracy 12.0031
# Epoch 264 Batch 15 Loss 0.0025 Accuracy 12.0009
# Epoch 264 Batch 20 Loss 0.0025 Accuracy 12.0009
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4607
# Epoch 265 Batch 5 Loss 0.0025 Accuracy 11.9994
# Epoch 265 Batch 10 Loss 0.0025 Accuracy 11.9983
# Epoch 265 Batch 15 Loss 0.0025 Accuracy 11.9961
# Epoch 265 Batch 20 Loss 0.0025 Accuracy 11.9959
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4569
# Epoch 266 Batch 5 Loss 0.0025 Accuracy 11.9952
# Epoch 266 Batch 10 Loss 0.0025 Accuracy 11.9939
# Epoch 266 Batch 15 Loss 0.0025 Accuracy 11.9917
# Epoch 266 Batch 20 Loss 0.0025 Accuracy 11.9924
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4567
# Epoch 267 Batch 5 Loss 0.0025 Accuracy 11.9910
# Epoch 267 Batch 10 Loss 0.0025 Accuracy 11.9900
# Epoch 267 Batch 15 Loss 0.0025 Accuracy 11.9880
# Epoch 267 Batch 20 Loss 0.0025 Accuracy 11.9883
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4527
# Epoch 268 Batch 5 Loss 0.0025 Accuracy 11.9872
# Epoch 268 Batch 10 Loss 0.0025 Accuracy 11.9857
# Epoch 268 Batch 15 Loss 0.0025 Accuracy 11.9835
# Epoch 268 Batch 20 Loss 0.0025 Accuracy 11.9836
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4517
# Epoch 269 Batch 5 Loss 0.0025 Accuracy 11.9827
# Epoch 269 Batch 10 Loss 0.0025 Accuracy 11.9815
# Epoch 269 Batch 15 Loss 0.0025 Accuracy 11.9792
# Epoch 269 Batch 20 Loss 0.0025 Accuracy 11.9803
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4523
# Epoch 270 Batch 5 Loss 0.0025 Accuracy 11.9791
# Epoch 270 Batch 10 Loss 0.0025 Accuracy 11.9782
# Epoch 270 Batch 15 Loss 0.0025 Accuracy 11.9759
# Epoch 270 Batch 20 Loss 0.0025 Accuracy 11.9774
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4535
# Epoch 271 Batch 5 Loss 0.0025 Accuracy 11.9765
# Epoch 271 Batch 10 Loss 0.0025 Accuracy 11.9754
# Epoch 271 Batch 15 Loss 0.0025 Accuracy 11.9732
# Epoch 271 Batch 20 Loss 0.0025 Accuracy 11.9739
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4501
# Epoch 272 Batch 5 Loss 0.0025 Accuracy 11.9730
# Epoch 272 Batch 10 Loss 0.0025 Accuracy 11.9718
# Epoch 272 Batch 15 Loss 0.0025 Accuracy 11.9697
# Epoch 272 Batch 20 Loss 0.0025 Accuracy 11.9701
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4479
# Epoch 273 Batch 5 Loss 0.0025 Accuracy 11.9686
# Epoch 273 Batch 10 Loss 0.0025 Accuracy 11.9675
# Epoch 273 Batch 15 Loss 0.0025 Accuracy 11.9653
# Epoch 273 Batch 20 Loss 0.0025 Accuracy 11.9666
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4494
# Epoch 274 Batch 5 Loss 0.0025 Accuracy 11.9655
# Epoch 274 Batch 10 Loss 0.0025 Accuracy 11.9645
# Epoch 274 Batch 15 Loss 0.0025 Accuracy 11.9623
# Epoch 274 Batch 20 Loss 0.0025 Accuracy 11.9633
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4517
# Epoch 275 Batch 5 Loss 0.0025 Accuracy 11.9625
# Epoch 275 Batch 10 Loss 0.0025 Accuracy 11.9617
# Epoch 275 Batch 15 Loss 0.0025 Accuracy 11.9594
# Epoch 275 Batch 20 Loss 0.0025 Accuracy 11.9609
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4607
# Epoch 276 Batch 5 Loss 0.0025 Accuracy 11.9606
# Epoch 276 Batch 10 Loss 0.0025 Accuracy 11.9598
# Epoch 276 Batch 15 Loss 0.0025 Accuracy 11.9579
# Epoch 276 Batch 20 Loss 0.0025 Accuracy 11.9608
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4704
# Epoch 277 Batch 5 Loss 0.0025 Accuracy 11.9610
# Epoch 277 Batch 10 Loss 0.0025 Accuracy 11.9602
# Epoch 277 Batch 15 Loss 0.0025 Accuracy 11.9582
# Epoch 277 Batch 20 Loss 0.0025 Accuracy 11.9587
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4691
# Epoch 278 Batch 5 Loss 0.0025 Accuracy 11.9594
# Epoch 278 Batch 10 Loss 0.0025 Accuracy 11.9587
# Epoch 278 Batch 15 Loss 0.0025 Accuracy 11.9572
# Epoch 278 Batch 20 Loss 0.0025 Accuracy 11.9566
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4659
# Epoch 279 Batch 5 Loss 0.0025 Accuracy 11.9559
# Epoch 279 Batch 10 Loss 0.0025 Accuracy 11.9546
# Epoch 279 Batch 15 Loss 0.0025 Accuracy 11.9526
# Epoch 279 Batch 20 Loss 0.0025 Accuracy 11.9525
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4635
# Epoch 280 Batch 5 Loss 0.0025 Accuracy 11.9514
# Epoch 280 Batch 10 Loss 0.0025 Accuracy 11.9502
# Epoch 280 Batch 15 Loss 0.0025 Accuracy 11.9482
# Epoch 280 Batch 20 Loss 0.0025 Accuracy 11.9478
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4615
# Epoch 281 Batch 5 Loss 0.0025 Accuracy 11.9469
# Epoch 281 Batch 10 Loss 0.0025 Accuracy 11.9457
# Epoch 281 Batch 15 Loss 0.0025 Accuracy 11.9435
# Epoch 281 Batch 20 Loss 0.0025 Accuracy 11.9436
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 11.4619
# Epoch 282 Batch 5 Loss 0.0025 Accuracy 11.9427
# Epoch 282 Batch 10 Loss 0.0025 Accuracy 11.9418
# Epoch 282 Batch 15 Loss 0.0025 Accuracy 11.9395
# Epoch 282 Batch 20 Loss 0.0025 Accuracy 11.9406
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 11.4701
# Epoch 283 Batch 5 Loss 0.0025 Accuracy 11.9405
# Epoch 283 Batch 10 Loss 0.0025 Accuracy 11.9397
# Epoch 283 Batch 15 Loss 0.0025 Accuracy 11.9378
# Epoch 283 Batch 20 Loss 0.0025 Accuracy 11.9411
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 11.4811
# Epoch 284 Batch 5 Loss 0.0025 Accuracy 11.9422
# Epoch 284 Batch 10 Loss 0.0025 Accuracy 11.9422
# Epoch 284 Batch 15 Loss 0.0025 Accuracy 11.9410
# Epoch 284 Batch 20 Loss 0.0025 Accuracy 11.9401
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4846
# Epoch 285 Batch 5 Loss 0.0025 Accuracy 11.9411
# Epoch 285 Batch 10 Loss 0.0025 Accuracy 11.9406
# Epoch 285 Batch 15 Loss 0.0025 Accuracy 11.9401
# Epoch 285 Batch 20 Loss 0.0025 Accuracy 11.9393
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4847
# Epoch 286 Batch 5 Loss 0.0025 Accuracy 11.9394
# Epoch 286 Batch 10 Loss 0.0025 Accuracy 11.9382
# Epoch 286 Batch 15 Loss 0.0025 Accuracy 11.9365
# Epoch 286 Batch 20 Loss 0.0025 Accuracy 11.9362
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.4813
# Epoch 287 Batch 5 Loss 0.0025 Accuracy 11.9354
# Epoch 287 Batch 10 Loss 0.0025 Accuracy 11.9341
# Epoch 287 Batch 15 Loss 0.0025 Accuracy 11.9320
# Epoch 287 Batch 20 Loss 0.0025 Accuracy 11.9320
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4797
# Epoch 288 Batch 5 Loss 0.0025 Accuracy 11.9308
# Epoch 288 Batch 10 Loss 0.0025 Accuracy 11.9298
# Epoch 288 Batch 15 Loss 0.0025 Accuracy 11.9276
# Epoch 288 Batch 20 Loss 0.0025 Accuracy 11.9280
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4803
# Epoch 289 Batch 5 Loss 0.0025 Accuracy 11.9270
# Epoch 289 Batch 10 Loss 0.0025 Accuracy 11.9261
# Epoch 289 Batch 15 Loss 0.0025 Accuracy 11.9239
# Epoch 289 Batch 20 Loss 0.0025 Accuracy 11.9247
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4869
# Epoch 290 Batch 5 Loss 0.0025 Accuracy 11.9244
# Epoch 290 Batch 10 Loss 0.0025 Accuracy 11.9236
# Epoch 290 Batch 15 Loss 0.0025 Accuracy 11.9216
# Epoch 290 Batch 20 Loss 0.0025 Accuracy 11.9229
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.4995
# Epoch 291 Batch 5 Loss 0.0025 Accuracy 11.9240
# Epoch 291 Batch 10 Loss 0.0025 Accuracy 11.9232
# Epoch 291 Batch 15 Loss 0.0025 Accuracy 11.9219
# Epoch 291 Batch 20 Loss 0.0025 Accuracy 11.9229
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5122
# Epoch 292 Batch 5 Loss 0.0025 Accuracy 11.9245
# Epoch 292 Batch 10 Loss 0.0025 Accuracy 11.9245
# Epoch 292 Batch 15 Loss 0.0025 Accuracy 11.9226
# Epoch 292 Batch 20 Loss 0.0025 Accuracy 11.9226
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5090
# Epoch 293 Batch 5 Loss 0.0025 Accuracy 11.9219
# Epoch 293 Batch 10 Loss 0.0025 Accuracy 11.9208
# Epoch 293 Batch 15 Loss 0.0025 Accuracy 11.9191
# Epoch 293 Batch 20 Loss 0.0025 Accuracy 11.9188
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5056
# Epoch 294 Batch 5 Loss 0.0025 Accuracy 11.9179
# Epoch 294 Batch 10 Loss 0.0025 Accuracy 11.9167
# Epoch 294 Batch 15 Loss 0.0025 Accuracy 11.9146
# Epoch 294 Batch 20 Loss 0.0025 Accuracy 11.9146
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5038
# Epoch 295 Batch 5 Loss 0.0025 Accuracy 11.9135
# Epoch 295 Batch 10 Loss 0.0025 Accuracy 11.9125
# Epoch 295 Batch 15 Loss 0.0025 Accuracy 11.9106
# Epoch 295 Batch 20 Loss 0.0025 Accuracy 11.9105
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5044
# Epoch 296 Batch 5 Loss 0.0025 Accuracy 11.9096
# Epoch 296 Batch 10 Loss 0.0025 Accuracy 11.9087
# Epoch 296 Batch 15 Loss 0.0025 Accuracy 11.9066
# Epoch 296 Batch 20 Loss 0.0025 Accuracy 11.9071
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5139
# Epoch 297 Batch 5 Loss 0.0025 Accuracy 11.9075
# Epoch 297 Batch 10 Loss 0.0025 Accuracy 11.9067
# Epoch 297 Batch 15 Loss 0.0025 Accuracy 11.9053
# Epoch 297 Batch 20 Loss 0.0025 Accuracy 11.9067
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5235
# Epoch 298 Batch 5 Loss 0.0025 Accuracy 11.9077
# Epoch 298 Batch 10 Loss 0.0025 Accuracy 11.9075
# Epoch 298 Batch 15 Loss 0.0025 Accuracy 11.9054
# Epoch 298 Batch 20 Loss 0.0025 Accuracy 11.9057
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5204
# Epoch 299 Batch 5 Loss 0.0025 Accuracy 11.9049
# Epoch 299 Batch 10 Loss 0.0025 Accuracy 11.9042
# Epoch 299 Batch 15 Loss 0.0025 Accuracy 11.9026
# Epoch 299 Batch 20 Loss 0.0025 Accuracy 11.9023
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 11.5175
# Epoch 300 Batch 5 Loss 0.0025 Accuracy 11.9013
# Epoch 300 Batch 10 Loss 0.0025 Accuracy 11.9002
# Epoch 300 Batch 15 Loss 0.0025 Accuracy 11.8983
# Epoch 300 Batch 20 Loss 0.0025 Accuracy 11.8979
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 11.5156

# %% [markdown]
# #### - dangjin_ware

# %%
capacity = 700
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
optimizer = tf.keras.optimizers.Adam()

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_ware_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin_warehouse(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_ware_scaled, Models_dangjin_warehouse)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.0177 Accuracy 44.3165
# Epoch 1 Batch 10 Loss 0.0129 Accuracy 44.9041
# Epoch 1 Batch 15 Loss 0.0116 Accuracy 44.9911
# Epoch 1 Batch 20 Loss 0.0115 Accuracy 45.8457
# Time taken for 1 epoch: 1.67 secs
#
# WARNING:tensorflow:Layer train_model_13 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 41.5551
# Epoch 2 Batch 5 Loss 0.0111 Accuracy 45.8923
# Epoch 2 Batch 10 Loss 0.0108 Accuracy 45.8131
# Epoch 2 Batch 15 Loss 0.0106 Accuracy 45.7180
# Epoch 2 Batch 20 Loss 0.0106 Accuracy 46.0371
# Time taken for 1 epoch: 0.57 secs
#
# TestLoss 0.0000 TestAccuracy 41.5551
# Epoch 3 Batch 5 Loss 0.0106 Accuracy 46.0406
# Epoch 3 Batch 10 Loss 0.0104 Accuracy 45.9792
# Epoch 3 Batch 15 Loss 0.0103 Accuracy 45.9045
# Epoch 3 Batch 20 Loss 0.0104 Accuracy 46.0989
# Time taken for 1 epoch: 0.55 secs
#
# TestLoss 0.0000 TestAccuracy 41.5551
# Epoch
secs
#
# TestLoss 0.0000 TestAccuracy 41.5551
# Epoch 15 Batch 5 Loss 0.0099 Accuracy 46.1918
# Epoch 15 Batch 10 Loss 0.0099 Accuracy 46.1789
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-6e058a70f208> in <module>
#      25         i += 1
#      26
# ---> 27         train_step_dangjin_warehouse(inp, tar)
#      28
#      29         if i % 5 == 0:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### - dangjin_float

# %%
capacity = 1000
train_max = train_max_dangjin.copy()
train_min = train_min_dangjin.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 
for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_dangjin_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_dangjin_float_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_dangjin_floating(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_dangjin_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_dangjin_scaled, y_test_dangjin_float_scaled, Models_dangjin_floating)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.3223 Accuracy 84.6864
# Epoch 1 Batch 10 Loss 0.1519 Accuracy 63.0835
# Epoch 1 Batch 15 Loss 0.1020 Accuracy 54.7482
# Epoch 1 Batch 20 Loss 0.0794 Accuracy 51.4029
# Time taken for 1 epoch: 1.65 secs
#
# WARNING:tensorflow:Layer train_model_17 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 2 Batch 5 Loss 0.0669 Accuracy 49.7515
# Epoch 2 Batch 10 Loss 0.0581 Accuracy 48.5406
# Epoch 2 Batch 15 Loss 0.0513 Accuracy 47.0836
# Epoch 2 Batch 20 Loss 0.0468 Accuracy 46.4378
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 3 Batch 5 Loss 0.0437 Accuracy 46.1400
# Epoch 3 Batch 10 Loss 0.0408 Accuracy 45.7701
# Epoch 3 Batch 15 Loss 0.0382 Accuracy 45.0903
# Epoch 3 Batch 20 Loss 0.0363 Accuracy 44.8331
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 4 Batch 5 Loss 0.0350 Accuracy 44.7644
# Epoch 4 Batch 10 Loss 0.0336 Accuracy 44.5962
# Epoch 4 Batch 15 Loss 0.0321 Accuracy 44.1736
# Epoch 4 Batch 20 Loss 0.0311 Accuracy 44.0399
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 5 Batch 5 Loss 0.0304 Accuracy 44.0390
# Epoch 5 Batch 10 Loss 0.0296 Accuracy 43.9475
# Epoch 5 Batch 15 Loss 0.0287 Accuracy 43.6467
# Epoch 5 Batch 20 Loss 0.0280 Accuracy 43.5668
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 6 Batch 5 Loss 0.0276 Accuracy 43.5911
# Epoch 6 Batch 10 Loss 0.0271 Accuracy 43.5359
# Epoch 6 Batch 15 Loss 0.0264 Accuracy 43.3046
# Epoch 6 Batch 20 Loss 0.0260 Accuracy 43.2527
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 7 Batch 5 Loss 0.0257 Accuracy 43.2869
# Epoch 7 Batch 10 Loss 0.0253 Accuracy 43.2515
# Epoch 7 Batch 15 Loss 0.0248 Accuracy 43.0646
# Epoch 7 Batch 20 Loss 0.0245 Accuracy 43.0288
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 8 Batch 5 Loss 0.0243 Accuracy 43.0668
# Epoch 8 Batch 10 Loss 0.0240 Accuracy 43.0433
# Epoch 8 Batch 15 Loss 0.0237 Accuracy 42.8869
# Epoch 8 Batch 20 Loss 0.0234 Accuracy 42.8613
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 9 Batch 5 Loss 0.0233 Accuracy 42.9003
# Epoch 9 Batch 10 Loss 0.0231 Accuracy 42.8842
# Epoch 9 Batch 15 Loss 0.0228 Accuracy 42.7501
# Epoch 9 Batch 20 Loss 0.0226 Accuracy 42.7311
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 10 Batch 5 Loss 0.0225 Accuracy 42.7698
# Epoch 10 Batch 10 Loss 0.0223 Accuracy 42.7587
# Epoch 10 Batch 15 Loss 0.0220 Accuracy 42.6414
# Epoch 10 Batch 20 Loss 0.0219 Accuracy 42.6271
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 11 Batch 5 Loss 0.0218 Accuracy 42.6648
# Epoch 11 Batch 10 Loss 0.0217 Accuracy 42.6572
# Epoch 11 Batch 15 Loss 0.0215 Accuracy 42.5531
# Epoch 11 Batch 20 Loss 0.0213 Accuracy 42.5421
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 12 Batch 5 Loss 0.0213 Accuracy 42.5785
# Epoch 12 Batch 10 Loss 0.0212 Accuracy 42.5734
# Epoch 12 Batch 15 Loss 0.0210 Accuracy 42.4798
# Epoch 12 Batch 20 Loss 0.0209 Accuracy 42.4713
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 13 Batch 5 Loss 0.0208 Accuracy 42.5063
# Epoch 13 Batch 10 Loss 0.0207 Accuracy 42.5030
# Epoch 13 Batch 15 Loss 0.0206 Accuracy 42.4181
# Epoch 13 Batch 20 Loss 0.0205 Accuracy 42.4114
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 14 Batch 5 Loss 0.0205 Accuracy 42.4451
# Epoch 14 Batch 10 Loss 0.0204 Accuracy 42.4431
# Epoch 14 Batch 15 Loss 0.0202 Accuracy 42.3654
# Epoch 14 Batch 20 Loss 0.0202 Accuracy 42.3602
# Time taken for 1 epoch: 0.56 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 15 Batch 5 Loss 0.0201 Accuracy 42.3924
# Epoch 15 Batch 10 Loss 0.0201 Accuracy 42.3914
# Epoch 15 Batch 15 Loss 0.0199 Accuracy 42.3198
# Epoch 15 Batch 20 Loss 0.0199 Accuracy 42.3157
# Time taken for 1 epoch: 0.53 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 16 Batch 5 Loss 0.0199 Accuracy 42.3467
# Epoch 16 Batch 10 Loss 0.0198 Accuracy 42.3465
# Epoch 16 Batch 15 Loss 0.0197 Accuracy 42.2801
# Epoch 16 Batch 20 Loss 0.0196 Accuracy 42.2769
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 37.2523
# Epoch 17 Batch 5 Loss 0.0196 Accuracy 42.3066
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-105-7464026fc746> in <module>
#      23         i += 1
#      24
# ---> 25         train_step_dangjin_floating(inp, tar)
#      26
#      27         if i % 5 == 0:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1659       `args` and `kwargs`.
#    1660     """
# -> 1661     return self._call_flat(
#    1662         (t for t in nest.flatten((args, kwargs), expand_composites=True)
#    1663          if isinstance(t, (ops.Tensor,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1743         and executing_eagerly):
#    1744       # No tape is watching; skip to running the function.
# -> 1745       return self._build_call_outputs(self._inference_function.call(
#    1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     591       with _InterpolateFunctionError(self):
#     592         if cancellation_manager is None:
# --> 593           outputs = execute.execute(
#     594               str(self.signature.name),
#     595               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %% [markdown]
# #### - ulsan

# %%
capacity = 500
train_max = train_max_ulsan.copy()
train_min = train_min_ulsan.copy()

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.Mean(name='train_accuracy')

test_loss = tf.keras.metrics.Mean(name = "test_loss")
test_accuracy = tf.keras.metrics.Mean(name = "test_accuracy")
 
loss_function = tf.keras.losses.MeanSquaredError(reduction = tf.keras.losses.Reduction.NONE)
 

for epoch in range(EPOCHS):
    start = time.time()
    
    i = 1

    while True:

        inp = tf.Variable(X_train_ulsan_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)
        tar = tf.Variable(y_train_ulsan_scaled[(i - 1) * batch_size : (i * batch_size)], dtype = tf.float32)

        i += 1

        train_step_ulsan(inp, tar)

        if i % 5 == 0:
            print(f'Epoch {epoch + 1} Batch {i} Loss {train_loss.result():.4f} Accuracy {train_accuracy.result():.4f}')

        if i > int(len(X_train_ulsan_scaled) / batch_size) :
            print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
            val_accuracy(X_test_ulsan_scaled, y_test_ulsan_scaled, Models_ulsan)
            print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
            break
# Out:
# Epoch 1 Batch 5 Loss 0.0059 Accuracy 48.1035
# Epoch 1 Batch 10 Loss 0.0056 Accuracy 48.4553
# Epoch 1 Batch 15 Loss 0.0053 Accuracy 47.6245
# Epoch 1 Batch 20 Loss 0.0055 Accuracy 47.9485
# Time taken for 1 epoch: 1.01 secs
#
# WARNING:tensorflow:Layer train_model_16 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 2 Batch 5 Loss 0.0055 Accuracy 47.9824
# Epoch 2 Batch 10 Loss 0.0055 Accuracy 48.1132
# Epoch 2 Batch 15 Loss 0.0054 Accuracy 47.8201
# Epoch 2 Batch 20 Loss 0.0055 Accuracy 47.9524
# Time taken for 1 epoch: 0.50 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 3 Batch 5 Loss 0.0055 Accuracy 47.9706
# Epoch 3 Batch 10 Loss 0.0055 Accuracy 48.0493
# Epoch 3 Batch 15 Loss 0.0054 Accuracy 47.8706
# Epoch 3 Batch 20 Loss 0.0055 Accuracy 47.9537
# Time taken for 1 epoch: 0.49 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 4 Batch 5 Loss 0.0055 Accuracy 47.9661
# Epoch 4 Batch 10 Loss 0.0055 Accuracy 48.0224
# Epoch 4 Batch 15 Loss 0.0054 Accuracy 47.8937
# Epoch 4 Batch 20 Loss 0.0054 Accuracy 47.9543
# Time taken for 1 epoch: 0.49 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 5 Batch 5 Loss 0.0055 Accuracy 47.9637
# Epoch 5 Batch 10 Loss 0.0055 Accuracy 48.0075
# Epoch 5 Batch 15 Loss 0.0054 Accuracy 47.9070
# Epoch 5 Batch 20 Loss 0.0054 Accuracy 47.9547
# Time taken for 1 epoch: 0.48 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 6 Batch 5 Loss 0.0055 Accuracy 47.9623
# Epoch 6 Batch 10 Loss 0.0055 Accuracy 47.9981
# Epoch 6 Batch 15 Loss 0.0054 Accuracy 47.9156
# Epoch 6 Batch 20 Loss 0.0054 Accuracy 47.9549
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 7 Batch 5 Loss 0.0055 Accuracy 47.9613
# Epoch 7 Batch 10 Loss 0.0055 Accuracy 47.9916
# Epoch 7 Batch 15 Loss 0.0054 Accuracy 47.9217
# Epoch 7 Batch 20 Loss 0.0054 Accuracy 47.9551
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 8 Batch 5 Loss 0.0055 Accuracy 47.9606
# Epoch 8 Batch 10 Loss 0.0055 Accuracy 47.9869
# Epoch 8 Batch 15 Loss 0.0054 Accuracy 47.9262
# Epoch 8 Batch 20 Loss 0.0054 Accuracy 47.9552
# Time taken for 1 epoch: 0.47 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch
Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 193 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 193 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 193 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 193 Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 194 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 194 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 194 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 194 Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 195 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 195 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 195 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 195 Batch 20 Loss 0.0054 Accuracy 47.9563
# Time taken for 1 epoch: 0.54 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 196 Batch 5 Loss 0.0054 Accuracy 47.9565
# Epoch 196 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 196 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 196 Batch 20 Loss 0.0054 Accuracy 47.9562
# Time taken for 1 epoch: 0.52 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 197 Batch 5 Loss 0.0054 Accuracy 47.9564
# Epoch 197 Batch 10 Loss 0.0054 Accuracy 47.9575
# Epoch 197 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 197 Batch 20 Loss 0.0054 Accuracy 47.9562
# Time taken for 1 epoch: 0.50 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 198 Batch 5 Loss 0.0054 Accuracy 47.9564
# Epoch 198 Batch 10 Loss 0.0054 Accuracy 47.9574
# Epoch 198 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 198 Batch 20 Loss 0.0054 Accuracy 47.9562
# Time taken for 1 epoch: 0.51 secs
#
# TestLoss 0.0000 TestAccuracy 49.6618
# Epoch 199 Batch 5 Loss 0.0054 Accuracy 47.9564
# Epoch 199 Batch 10 Loss 0.0054 Accuracy 47.9574
# Epoch 199 Batch 15 Loss 0.0054 Accuracy 47.9551
# Epoch 199 Batch 20 Loss 0.0054 Accuracy 47.9562
# Time taken for 1 epoch: 0.51 secs
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-112-92bca7e2782d> in <module>
#      31         if i > int(len(X_train_ulsan_scaled) / batch_size) :
#      32             print(f'Time taken for 1 epoch: {time.time() - start:.2f} secs\n')
# ---> 33             val_accuracy(X_test_ulsan_scaled, y_test_ulsan_scaled, Models_ulsan)
#      34             print(f'TestLoss {test_loss.result():.4f} TestAccuracy {test_accuracy.result():.4f}')
#      35             break
#
# <ipython-input-111-5fa1a869a583> in val_accuracy(inp, tar, Models)
#       1 def val_accuracy(inp, tar, Models):
# ----> 2     output = Models(inp)
#       3
#       4     test_accuracy(tf.numpy_function(nmae_10,
#       5                                      [tar, tf.squeeze(output, -1)],
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# <ipython-input-74-d29ceb546d0b> in call(self, input_tensor)
#      42         conv_output = self.dropout(conv_output)
#      43
# ---> 44         lstm_output_1 = self.lstm(conv_output)
#      45
#      46         output = self.outputs(lstm_output_1)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent.py in __call__(self, inputs, initial_state, constants, **kwargs)
#     652
#     653     if initial_state is None and constants is None:
# --> 654       return super(RNN, self).__call__(inputs, **kwargs)
#     655
#     656     # If any of `initial_state` or `constants` are specified and are Keras
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     966           with base_layer_utils.autocast_context_manager(
#     967               self._compute_dtype):
# --> 968             outputs = self.call(cast_inputs, *args, **kwargs)
#     969           self._handle_activity_regularization(inputs, outputs)
#     970           self._set_mask_metadata(inputs, outputs, input_masks)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py in call(self, inputs, mask, training, initial_state)
#    1181               **gpu_lstm_kwargs)
#    1182         else:
# -> 1183           last_output, outputs, new_h, new_c, runtime = standard_lstm(
#    1184               **normal_lstm_kwargs)
#    1185       else:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py in standard_lstm(inputs, init_h, init_c, kernel, recurrent_kernel, bias, activation, recurrent_activation, mask, time_major, go_backwards, sequence_lengths, zero_output_for_mask)
#    1308     return h, [h, c]
#    1309
# -> 1310   last_output, outputs, new_states = K.rnn(
#    1311       step,
#    1312       inputs, [init_h, init_c],
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in rnn(step_function, inputs, initial_states, go_backwards, mask, constants, unroll, input_length, time_major, zero_output_for_mask)
#    4234         return (time + 1, output_ta_t) + tuple(new_states)
#    4235
# -> 4236       final_outputs = control_flow_ops.while_loop(
#    4237           body=_step,
#    4238           loop_vars=(time, output_ta) + states,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\control_flow_ops.py in while_loop(cond, body, loop_vars, shape_invariants, parallel_iterations, back_prop, swap_memory, name, maximum_iterations, return_same_structure)
#    2725                                               list(loop_vars))
#    2726       while cond(*loop_vars):
# -> 2727         loop_vars = body(*loop_vars)
#    2728         if try_to_pack and not isinstance(loop_vars, (list, _basetuple)):
#    2729           packed = True
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\backend.py in _step(time, output_ta_t, *states)
#    4220         current_input = tuple(ta.read(time) for ta in input_ta)
#    4221         current_input = nest.pack_sequence_as(inputs, current_input)
# -> 4222         output, new_states = step_function(current_input,
#    4223                                            tuple(states) + tuple(constants))
#    4224         flat_state = nest.flatten(states)
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\layers\recurrent_v2.py in step(cell_inputs, cell_states)
#    1302     i = recurrent_activation(z0)
#    1303     f = recurrent_activation(z1)
# -> 1304     c = f * c_tm1 + i * activation(z2)
#    1305     o = recurrent_activation(z3)
#    1306
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py in binary_op_wrapper(x, y)
#     982     with ops.name_scope(None, op_name, [x, y]) as name:
#     983       if isinstance(x, ops.Tensor) and isinstance(y, ops.Tensor):
# --> 984         return func(x, y, name=name)
#     985       elif not isinstance(y, sparse_tensor.SparseTensor):
#     986         try:
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py in _mul_dispatch(x, y, name)
#    1281   is_tensor_y = isinstance(y, ops.Tensor)
#    1282   if is_tensor_y:
# -> 1283     return gen_math_ops.mul(x, y, name=name)
#    1284   else:
#    1285     assert isinstance(y, sparse_tensor.SparseTensor)  # Case: Dense * Sparse.
#
# ~\anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py in mul(x, y, name)
#    6076   if tld.is_eager:
#    6077     try:
# -> 6078       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6079         _ctx._context_handle, tld.device_name, "Mul", name, tld.op_callbacks,
#    6080         x, y)
#
# KeyboardInterrupt:

# %%
dangjin_fcst["Forecast time"] = pd.to_datetime(dangjin_fcst["Forecast time"])

# %%
dangjin_fcst[(dangjin_fcst["Forecast time"] == pd.Timestamp(2021,1,31,23,0,0)) & (
    dangjin_fcst["forecast"].dt.date == pd.datetime(2021,2,1).date())]
# Out:
# <ipython-input-430-d9d50c632d67>:2: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dangjin_fcst["forecast"].dt.date == pd.datetime(2021,2,1).date())]
#              Forecast time            forecast  Temperature  Humidity  \
# 157990 2021-01-31 23:00:00 2021-02-01 03:00:00          7.0      90.0
# 157991 2021-01-31 23:00:00 2021-02-01 06:00:00          6.0      90.0
# 157992 2021-01-31 23:00:00 2021-02-01 09:00:00          6.0      95.0
# 157993 2021-01-31 23:00:00 2021-02-01 12:00:00          9.0      75.0
# 157994 2021-01-31 23:00:00 2021-02-01 15:00:00          8.0      70.0
# 157995 2021-01-31 23:00:00 2021-02-01 18:00:00          4.0      75.0
# 157996 2021-01-31 23:00:00 2021-02-01 21:00:00          1.0      65.0
#
#         WindSpeed  WindDirection  Cloud
# 157990        3.4          207.0    4.0
# 157991        2.5          222.0    4.0
# 157992        3.3          232.0    4.0
# 157993        2.9          262.0    4.0
# 157994        5.2          312.0    3.0
# 157995        3.6          309.0    3.0
# 157996        6.6          325.0    3.0

# %%
dangjin_fcst_fore = pd.merge(pd.DataFrame(pd.date_range(start = pd.Timestamp(2021,2,1,0,0,0), 
              end = pd.Timestamp(2021,2,1,23,0,0),
             freq = "H"),
            columns = ["forecast"]),
         dangjin_fcst[(dangjin_fcst["Forecast time"] == pd.Timestamp(2021,1,31,23,0,0)) & (
    dangjin_fcst["forecast"].dt.date == pd.datetimeb(2021,2,1).date())],
        how = "left").drop(["Forecast time"], axis = 1)
# Out:
# <ipython-input-679-fb973e4be8a4>:6: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   dangjin_fcst["forecast"].dt.date == pd.datetime(2021,2,1).date())],

# %% [markdown]
# # 5. 평가

# %% [markdown]
# ## 1) Normalized MAE

# %%
result = DataFrame([

np.hstack(np.squeeze(Models_dangjin(X_test_dangjin_scaled)))*( 
    train_max_dangjin - train_min_dangjin) + train_min_dangjin,
    
np.hstack(np.squeeze(Models_dangjin_warehouse(X_test_dangjin_scaled))) * (
train_max_dangjin - train_min_dangjin) + train_min_dangjin,

np.hstack(np.squeeze(Models_dangjin_floating(X_test_dangjin_scaled))) * (
    train_max_dangjin - train_min_dangjin) + train_min_dangjin,

    np.hstack(np.squeeze(Models_ulsan(X_test_ulsan_scaled))) * (
    train_max_ulsan - train_min_ulsan) + train_min_ulsan]).T

# %%
result = DataFrame([Models_dangjin.predict(X_test_dangjin_lgb),
          Models_dangjin_warehouse.predict(X_test_dangjin_lgb),
          Models_dangjin_floating.predict(X_test_dangjin_lgb),
          Models_ulsan.predict(X_test_ulsan_lgb)]).T

# %%
result = result.dropna()

# %%
def zero_replacer(x):
    x[x < 0] = 0
    
    return x

# %%
result = result.apply(lambda x : zero_replacer(x))

# %%
result = pd.concat([test["time"],result], axis = 1)

# %%
result = result.dropna()

# %%
result.columns = ["time","dangjin","dangjin_warehouse","dangjin_floating","ulsan"]

# %%
def sola_nmae(answer_df, submission_df):
    submission = submission_df[submission_df['time'].isin(answer_df['time'])]
    submission.index = range(submission.shape[0])
    
    # 시간대별 총 발전량
    sum_submission = submission.iloc[:,1:].sum(axis=1)
    sum_answer = answer_df.iloc[:,1:].sum(axis=1)
    
    # 발전소 발전용량
    capacity = {
        'dangjin_floating':1000, # 당진수상태양광 발전용량
        'dangjin_warehouse':700, # 당진자재창고태양광 발전용량
        'dangjin':1000, # 당진태양광 발전용량
        'ulsan':500 # 울산태양광 발전용량
    }
    
    # 총 발전용량
    total_capacity = np.sum(list(capacity.values()))
    
    # 총 발전용량 절대오차
    absolute_error = (sum_answer - sum_submission).abs()
    
    # 발전용량으로 정규화
    absolute_error /= total_capacity
    
    # 총 발전용량의 10% 이상 발전한 데이터 인덱스 추출
    target_idx = sum_answer[sum_answer>=total_capacity*0.1].index
    
    # NMAE(%)
    nmae = 100 * absolute_error[target_idx].mean()
    
    return nmae

# %%
answer_df = test[["time","dangjin_floating","dangjin_warehouse","dangjin","ulsan"]]

# %%
answer_df = answer_df[answer_df["time"] < '2021-01-31']

# %%
sola_nmae(answer_df, result)
# Out:
# 11.928700907569265

# %%
sola_nmae(answer_df, result)
# Out:
# 13.50601553065436

# %%
plt.plot(answer_df.loc[:,"dangjin"])
plt.plot(result.loc[:,"dangjin"])

# %%
plt.plot(answer_df[answer_df["time"].dt.date == pd.Timestamp('2021-01-02')]["dangjin_floating"])
plt.plot(result[result["time"].dt.date == pd.Timestamp('2021-01-02')]["dangjin_floating"])

# %%
plt.figure(figsize = (20,10))
plt.plot(answer_df.loc[:,"dangjin_floating"])
plt.plot(result.loc[:,"dangjin_floating"])

# %%
plt.figure(figsize = (20,10))
plt.plot(answer_df.loc[:,"dangjin"])
plt.plot(result.loc[:,"dangjin"])

# %%
plt.figure(figsize = (20,10))
plt.plot(answer_df.loc[:,"dangjin_warehouse"])
plt.plot(result.loc[:,"dangjin_warehouse"])

# %%
plt.figure(figsize = (20,10))
plt.plot(answer_df.loc[:,"ulsan"])
plt.plot(result.loc[:,"ulsan"])

# %% [markdown]
# # 6. Submission

# %%
def zero_replacer(x):
    x[x < 0] = 0
    
    return x

# %%
#LightGBM

submission_dangjin = dangjin_fcst[(dangjin_fcst["time"] > '2020-02-01') & (dangjin_fcst["time"] < '2020-03-01')]

submission_dangjin = submission_dangjin.drop(["WindDirection"], axis = 1)

submission_ulsan = ulsan_fcst[(ulsan_fcst["time"] > '2020-02-01') & (ulsan_fcst["time"] < '2020-03-01')]

submission_ulsan = submission_ulsan.drop(["WindDirection"], axis = 1)

result = DataFrame([Models_dangjin.predict(submission_dangjin.iloc[:,1:]),
          Models_dangjin_warehouse.predict(submission_dangjin.iloc[:,1:]),
          Models_dangjin_floating.predict(submission_dangjin.iloc[:,1:]),
          Models_ulsan.predict(submission_ulsan.iloc[:,1:])]).T

result.columns = ["dangjin","dangjin_warehouse","dangjin_floating","ulsan"]

result = result[["dangjin_floating","dangjin_warehouse","dangjin","ulsan"]]

submission = pd.read_csv("data/sample_submission.csv")

result = result.apply(lambda x : zero_replacer(x))

submission.iloc[0:695,1] = result.iloc[:,0]
submission.iloc[0:695,2] = result.iloc[:,1]
submission.iloc[0:695,3] = result.iloc[:,2]
submission.iloc[0:695,4] = result.iloc[:,3]

submission.to_csv("submission.csv", index = False)

# %%
energy_fcst_ulsan
# Out:
#         num                time  dangjin_floating  dangjin_warehouse  dangjin  \
# 0      1067 2018-03-02 00:00:00               0.0                0.0        0
# 1      1067 2018-03-02 01:00:00               0.0                0.0        0
# 2      1067 2018-03-02 02:00:00               0.0                0.0        0
# 3      1067 2018-03-02 03:00:00               0.0                0.0        0
# 4      1067 2018-03-02 04:00:00               0.0                0.0        0
# ...     ...                 ...               ...                ...      ...
# 25531  2130 2021-01-31 19:00:00               0.0                0.0        0
# 25532  2130 2021-01-31 20:00:00               0.0                0.0        0
# 25533  2130 2021-01-31 21:00:00               0.0                0.0        0
# 25534  2130 2021-01-31 22:00:00               0.0                0.0        0
# 25535  2130 2021-01-31 23:00:00               0.0                0.0        0
#
#        ulsan  Temperature   Humidity  WindSpeed  WindDirection     Cloud  \
# 0          0     2.758622  28.868616  -1.754513     296.178762  1.582083
# 1          0     2.624791  28.680616  -2.616446     281.857569  1.612726
# 2          0     2.557080  28.578482  -3.332783     263.167052  1.643103
# 3          0     2.555487  28.562213  -3.903523     240.107211  1.673213
# 4          0     2.620012  28.631809  -4.328667     212.678046  1.703056
# ...      ...          ...        ...        ...            ...       ...
# 25531      0    10.049707  54.215463   3.288448     196.369194  2.280903
# 25532      0    10.084327  57.238509   3.379024     201.536737  2.279816
# 25533      0     9.000000  60.000000   3.500000     204.000000  4.000000
# 25534      0    10.224648  60.729591   3.582716     202.931130  2.277357
# 25535      0    10.330348  62.775607   3.695832     199.115552  2.275985
#
#        day_night  month  year   day  hour        date
# 0            0.0    3.0   0.0   2.0   0.0  2018-03-02
# 1            0.0    3.0   0.0   2.0   1.0  2018-03-02
# 2            0.0    3.0   0.0   2.0   2.0  2018-03-02
# 3            0.0    3.0   0.0   2.0   3.0  2018-03-02
# 4            0.0    3.0   0.0   2.0   4.0  2018-03-02
# ...          ...    ...   ...   ...   ...         ...
# 25531        1.0    1.0   3.0  31.0  19.0  2021-01-31
# 25532        0.0    1.0   3.0  31.0  20.0  2021-01-31
# 25533        0.0    1.0   3.0  31.0  21.0  2021-01-31
# 25534        0.0    1.0   3.0  31.0  22.0  2021-01-31
# 25535        0.0    1.0   3.0  31.0  23.0  2021-01-31
#
# [25536 rows x 17 columns]

# %%
#LSTM

submission_dangjin = energy_fcst_dangjin[(energy_fcst_dangjin["time"] > '2020-01-31 23:00:00') & (energy_fcst_dangjin["time"] < '2020-03-01')]
submission_ulsan =  energy_fcst_ulsan[(energy_fcst_ulsan["time"] > '2020-01-31 23:00:00') & (energy_fcst_ulsan["time"] < '2020-03-01')]

submission_dangjin = np.stack(submission_dangjin.loc[:,["num","Temperature","Humidity","WindSpeed","Cloud","month","year","day","hour"]].groupby("num").apply(lambda x : np.array(x)))
submission_ulsan = np.stack(submission_ulsan.loc[:,["num","Temperature","Humidity","WindSpeed","Cloud","month","year","day","hour"]].groupby("num").apply(lambda x : np.array(x)))

result = DataFrame([

np.hstack(np.squeeze(Models_dangjin(submission_dangjin[:,:,1:]))) * ( 
    train_max_dangjin - train_min_dangjin) + train_min_dangjin,
    
np.hstack(np.squeeze(Models_dangjin_warehouse(submission_dangjin[:,:,1:]))) * (
    train_max_dangjin - train_min_dangjin) + train_min_dangjin,

np.hstack(np.squeeze(Models_dangjin_floating(submission_dangjin[:,:,1:]))) * (
    train_max_dangjin - train_min_dangjin) + train_min_dangjin,

    np.hstack(np.squeeze(Models_ulsan(submission_ulsan[:,:,1:]))) * (
    train_max_ulsan - train_min_ulsan) + train_min_ulsan]).T

result.columns = ["dangjin","dangjin_warehouse","dangjin_floating","ulsan"]

result = result[["dangjin_floating","dangjin_warehouse","dangjin","ulsan"]]

submission = pd.read_csv("data/sample_submission.csv")

result = result.apply(lambda x : zero_replacer(x))

submission.iloc[0:695,1] = result.iloc[:,0]
submission.iloc[0:695,2] = result.iloc[:,1]
submission.iloc[0:695,3] = result.iloc[:,2]
submission.iloc[0:695,4] = result.iloc[:,3]

submission.to_csv("submission.csv", index = False)

# %%
plt.plot(submission.iloc[:,2])
